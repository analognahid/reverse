# %%
#-------------------------------------------------------------------------------
# elftools example: dwarf_lineprogram_filenames.py
#
# In the .debug_line section, the Dwarf line program generates a matrix
# of address-source references. This example demonstrates accessing the state
# of each line program entry to retrieve the underlying filenames.
#
# William Woodruff (william@yossarian.net)
# This code is in the public domain
#-------------------------------------------------------------------------------
from __future__ import print_function
from collections import defaultdict
import os
import sys
import posixpath

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.
# sys.path[0:0] = ['.', '..']

from elftools.elf.elffile import ELFFile



def attribute_has_range_list(attr):
    """ Only some attributes can have range list values, if they have the
        required DW_FORM (rangelistptr "class" in DWARF spec v3)
    """
    if attr.name == 'DW_AT_ranges':
        if attr.form in ('DW_FORM_data4', 'DW_FORM_data8'):
            return True
    return False


def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        dwarfinfo = elffile.get_dwarf_info()
        aranges = dwarfinfo.get_aranges()
        
        #         aranges_entries = aranges.entries
        print(len(aranges.entries))
        print(aranges.entries,'__\n\n')
        
        range_lists = dwarfinfo.range_lists()
        if range_lists is None:
            print('  file has no .debug_ranges section')
            return
        
#       print(dir(aranges))


        ranges_count = 0
        for CU in dwarfinfo.iter_CUs():
        # A CU provides a simple API to iterate over all the DIEs in it.
            for DIE in CU.iter_DIEs():
                # Go over all attributes of the DIE. Each attribute is an
                # AttributeValue object (from elftools.dwarf.die), which we
                # can examine.
                if DIE.tag=='DW_TAG_inlined_subroutine' or DIE.tag == 'DW_TAG_compile_unit':
                    for attr in DIE.attributes.values():
                        if attr.name == 'DW_AT_ranges':



    #                         # This is a range list. Its value is an offset into
    #                         # the .debug_ranges section, so we can use the range
    #                         # lists object to decode it.
                            rangelist = range_lists.get_range_list_at_offset(
                                attr.value)
                            ranges_count+=len(rangelist)
                            print('   DIE %s. attr %s.\n%s' % (
                                DIE.tag,
                                attr.name,
                                rangelist))
                            print("\n"*3)

        print('\n\n\n',ranges_count)
            

        

filePath = '/home/nahid/reverse/binaries/gnuit/src/gitfm' #25 CU
process_file(filePath)
# Out:
# Processing file: /home/nahid/reverse/binaries/gnuit/src/gitfm
# 341
# [ARangeEntry(begin_addr=20192, length=5, info_offset=76698, unit_length=60, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=20441, length=72, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=20513, length=25, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=20538, length=813, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=21351, length=315, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=21666, length=298, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=21964, length=147, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=22111, length=94, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=22205, length=729, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=22934, length=339, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=23273, length=288, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=23561, length=754, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=24315, length=876, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=25191, length=690, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=25881, length=127, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=26008, length=130, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=26138, length=121, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=26259, length=112, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=26371, length=41, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=26412, length=89, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=26501, length=2663, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=29164, length=114, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=29278, length=1039, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=30317, length=46, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=30363, length=145, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=30508, length=91, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=30599, length=131, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=30730, length=13707, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=44437, length=23, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=44460, length=439, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=44899, length=16, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=44915, length=111, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=45026, length=106, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0), ARangeEntry(begin_addr=45132, length=77, info_offset=10414, unit_length=956, version=2, a ...
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=64, entry_length=10, begin_offset=20441, end_offset=20513, is_absolute=True), RangeEntry(entry_offset=74, entry_length=10, begin_offset=20513, end_offset=20538, is_absolute=True), RangeEntry(entry_offset=84, entry_length=11, begin_offset=20538, end_offset=21351, is_absolute=True), RangeEntry(entry_offset=95, entry_length=11, begin_offset=21351, end_offset=21666, is_absolute=True), RangeEntry(entry_offset=106, entry_length=11, begin_offset=21666, end_offset=21964, is_absolute=True), RangeEntry(entry_offset=117, entry_length=11, begin_offset=21964, end_offset=22111, is_absolute=True), RangeEntry(entry_offset=128, entry_length=10, begin_offset=22111, end_offset=22205, is_absolute=True), RangeEntry(entry_offset=138, entry_length=11, begin_offset=22205, end_offset=22934, is_absolute=True), RangeEntry(entry_offset=149, entry_length=11, begin_offset=22934, end_offset=23273, is_absolute=True), RangeEntry(entry_offset=160, entry_length=11, begin_offset=23273, end_offset=23561, is_absolute=True), RangeEntry(entry_offset=171, entry_length=11, begin_offset=23561, end_offset=24315, is_absolute=True), RangeEntry(entry_offset=182, entry_length=11, begin_offset=24315, end_offset=25191, is_absolute=True), RangeEntry(entry_offset=193, entry_length=11, begin_offset=25191, end_offset=25881, is_absolute=True), RangeEntry(entry_offset=204, entry_length=10, begin_offset=25881, end_offset=26008, is_absolute=True), RangeEntry(entry_offset=214, entry_length=11, begin_offset=26008, end_offset=26138, is_absolute=True), RangeEntry(entry_offset=225, entry_length=10, begin_offset=26138, end_offset=26259, is_absolute=True), RangeEntry(entry_offset=235, entry_length=10, begin_offset=26259, end_offset=26371, is_absolute=True), RangeEntry(entry_offset=245, entry_length=10, begin_offset=26371, end_offset=26412, is_absolute=True), RangeEntry(entry_offset=255, entry_length=10, begin_offset=26412, end_offset=26501, is_absolute=True), RangeEntry(entry_offset=265, entry_length=11, begin_offset=26501, end_offset=29164, is_absolute=True), RangeEntry(entry_offset=276, entry_length=10, begin_offset=29164, end_offset=29278, is_absolute=True), RangeEntry(entry_offset=286, entry_length=11, begin_offset=29278, end_offset=30317, is_absolute=True), RangeEntry(entry_offset=297, entry_length=10, begin_offset=30317, end_offset=30363, is_absolute=True), RangeEntry(entry_offset=307, entry_length=11, begin_offset=30363, end_offset=30508, is_absolute=True), RangeEntry(entry_offset=318, entry_length=10, begin_offset=30508, end_offset=30599, is_absolute=True), RangeEntry(entry_offset=328, entry_length=11, begin_offset=30599, end_offset=30730, is_absolute=True), RangeEntry(entry_offset=339, entry_length=11, begin_offset=30730, end_offset=44437, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=379, entry_length=10, begin_offset=44437, end_offset=44460, is_absolute=True), RangeEntry(entry_offset=389, entry_length=11, begin_offset=44460, end_offset=44899, is_absolute=True), RangeEntry(entry_offset=400, entry_length=10, begin_offset=44899, end_offset=44915, is_absolute=True), RangeEntry(entry_offset=410, entry_length=10, begin_offset=44915, end_offset=45026, is_absolute=True), RangeEntry(entry_offset=420, entry_length=10, begin_offset=45026, end_offset=45132, is_absolute=True), RangeEntry(entry_offset=430, entry_length=10, begin_offset=45132, end_offset=45209, is_absolute=True), RangeEntry(entry_offset=440, entry_length=10, begin_offset=45209, end_offset=45260, is_absolute=True), RangeEntry(entry_offset=450, entry_length=10, begin_offset=45260, end_offset=45314, is_absolute=True), RangeEntry(entry_offset=460, entry_length=10, begin_offset=45314, end_offset=45368, is_absolute=True), RangeEntry(entry_offset=470, entry_length=10, begin_offset=45368, end_offset=45495, is_absolute=True), RangeEntry(entry_offset=480, entry_length=11, begin_offset=45495, end_offset=45766, is_absolute=True), RangeEntry(entry_offset=491, entry_length=11, begin_offset=45766, end_offset=46263, is_absolute=True), RangeEntry(entry_offset=502, entry_length=11, begin_offset=46263, end_offset=46746, is_absolute=True), RangeEntry(entry_offset=513, entry_length=10, begin_offset=46746, end_offset=46854, is_absolute=True), RangeEntry(entry_offset=523, entry_length=11, begin_offset=46854, end_offset=47082, is_absolute=True), RangeEntry(entry_offset=534, entry_length=10, begin_offset=47082, end_offset=47157, is_absolute=True), RangeEntry(entry_offset=544, entry_length=10, begin_offset=47157, end_offset=47269, is_absolute=True), RangeEntry(entry_offset=554, entry_length=11, begin_offset=47269, end_offset=47462, is_absolute=True), RangeEntry(entry_offset=565, entry_length=10, begin_offset=47462, end_offset=47566, is_absolute=True), RangeEntry(entry_offset=575, entry_length=10, begin_offset=47566, end_offset=47615, is_absolute=True), RangeEntry(entry_offset=585, entry_length=11, begin_offset=47615, end_offset=47803, is_absolute=True), RangeEntry(entry_offset=596, entry_length=11, begin_offset=47803, end_offset=48008, is_absolute=True), RangeEntry(entry_offset=607, entry_length=11, begin_offset=48008, end_offset=48219, is_absolute=True), RangeEntry(entry_offset=618, entry_length=11, begin_offset=48219, end_offset=48474, is_absolute=True), RangeEntry(entry_offset=629, entry_length=11, begin_offset=48474, end_offset=48726, is_absolute=True), RangeEntry(entry_offset=640, entry_length=10, begin_offset=48726, end_offset=48789, is_absolute=True), RangeEntry(entry_offset=650, entry_length=10, begin_offset=48789, end_offset=48824, is_absolute=True), RangeEntry(entry_offset=660, entry_length=10, begin_offset=48824, end_offset=48867, is_absolute=True), RangeEntry(entry_offset=670, entry_length=10, begin_offset=48867, end_offset=48907, is_absolute=True), RangeEntry(entry_offset=680, entry_length=10, begin_offset=48907, end_offset=48950, is_absolute=True), RangeEntry(entry_offset=690, entry_length=10, begin_offset=48950, end_offset=48993, is_absolute=True), RangeEntry(entry_offset=700, entry_length=10, begin_offset=48993, end_offset=49033, is_absolute=True), RangeEntry(entry_offset=710, entry_length=10, begin_offset=49033, end_offset=49087, is_absolute=True), RangeEntry(entry_offset=720, entry_length=10, begin_offset=49087, end_offset=49123, is_absolute=True), RangeEntry(entry_offset=730, entry_length=10, begin_offset=49123, end_offset=49227, is_absolute=True), RangeEntry(entry_offset=740, entry_length=10, begin_offset=49227, end_offset=49255, is_absolute=True), RangeEntry(entry_offset=750, entry_length=10, begin_offset=49255, end_offset=49283, is_absolute=True), RangeEntry(entry_offset=760, entry_length=10, begin_offset=49283, end_offset=49409, is_absolute=True), RangeEntry(entry_offset=770, entry_length=11, begin_offset=49409, end_offset=49538, i ...
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=996, entry_length=10, begin_offset=55920, end_offset=55985, is_absolute=True), RangeEntry(entry_offset=1006, entry_length=10, begin_offset=55985, end_offset=56023, is_absolute=True), RangeEntry(entry_offset=1016, entry_length=10, begin_offset=56023, end_offset=56090, is_absolute=True), RangeEntry(entry_offset=1026, entry_length=11, begin_offset=56090, end_offset=56252, is_absolute=True), RangeEntry(entry_offset=1037, entry_length=10, begin_offset=56252, end_offset=56350, is_absolute=True), RangeEntry(entry_offset=1047, entry_length=10, begin_offset=56350, end_offset=56427, is_absolute=True), RangeEntry(entry_offset=1057, entry_length=10, begin_offset=56427, end_offset=56447, is_absolute=True), RangeEntry(entry_offset=1067, entry_length=10, begin_offset=56447, end_offset=56468, is_absolute=True), RangeEntry(entry_offset=1077, entry_length=10, begin_offset=56468, end_offset=56489, is_absolute=True), RangeEntry(entry_offset=1087, entry_length=10, begin_offset=56489, end_offset=56510, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=1110, entry_length=10, begin_offset=56510, end_offset=56585, is_absolute=True), RangeEntry(entry_offset=1120, entry_length=11, begin_offset=56585, end_offset=57097, is_absolute=True), RangeEntry(entry_offset=1131, entry_length=10, begin_offset=57097, end_offset=57195, is_absolute=True), RangeEntry(entry_offset=1141, entry_length=10, begin_offset=57195, end_offset=57278, is_absolute=True), RangeEntry(entry_offset=1151, entry_length=11, begin_offset=57278, end_offset=57690, is_absolute=True), RangeEntry(entry_offset=1162, entry_length=10, begin_offset=57690, end_offset=57769, is_absolute=True), RangeEntry(entry_offset=1172, entry_length=10, begin_offset=57769, end_offset=57861, is_absolute=True), RangeEntry(entry_offset=1182, entry_length=11, begin_offset=57861, end_offset=58137, is_absolute=True), RangeEntry(entry_offset=1193, entry_length=10, begin_offset=58137, end_offset=58240, is_absolute=True), RangeEntry(entry_offset=1203, entry_length=10, begin_offset=58240, end_offset=58278, is_absolute=True), RangeEntry(entry_offset=1213, entry_length=10, begin_offset=58278, end_offset=58320, is_absolute=True), RangeEntry(entry_offset=1223, entry_length=10, begin_offset=58320, end_offset=58350, is_absolute=True), RangeEntry(entry_offset=1233, entry_length=10, begin_offset=58350, end_offset=58383, is_absolute=True), RangeEntry(entry_offset=1243, entry_length=10, begin_offset=58383, end_offset=58423, is_absolute=True), RangeEntry(entry_offset=1253, entry_length=10, begin_offset=58423, end_offset=58463, is_absolute=True), RangeEntry(entry_offset=1263, entry_length=10, begin_offset=58463, end_offset=58523, is_absolute=True), RangeEntry(entry_offset=1273, entry_length=10, begin_offset=58523, end_offset=58587, is_absolute=True), RangeEntry(entry_offset=1283, entry_length=10, begin_offset=58587, end_offset=58658, is_absolute=True), RangeEntry(entry_offset=1293, entry_length=10, begin_offset=58658, end_offset=58729, is_absolute=True), RangeEntry(entry_offset=1303, entry_length=11, begin_offset=58729, end_offset=58965, is_absolute=True), RangeEntry(entry_offset=1314, entry_length=11, begin_offset=58965, end_offset=59193, is_absolute=True), RangeEntry(entry_offset=1325, entry_length=10, begin_offset=59193, end_offset=59240, is_absolute=True), RangeEntry(entry_offset=1335, entry_length=10, begin_offset=59240, end_offset=59287, is_absolute=True), RangeEntry(entry_offset=1345, entry_length=11, begin_offset=59287, end_offset=59649, is_absolute=True), RangeEntry(entry_offset=1356, entry_length=11, begin_offset=59649, end_offset=59938, is_absolute=True), RangeEntry(entry_offset=1367, entry_length=11, begin_offset=59938, end_offset=60246, is_absolute=True), RangeEntry(entry_offset=1378, entry_length=11, begin_offset=60246, end_offset=60444, is_absolute=True), RangeEntry(entry_offset=1389, entry_length=11, begin_offset=60444, end_offset=60642, is_absolute=True), RangeEntry(entry_offset=1400, entry_length=11, begin_offset=60642, end_offset=60824, is_absolute=True), RangeEntry(entry_offset=1411, entry_length=10, begin_offset=60824, end_offset=60926, is_absolute=True), RangeEntry(entry_offset=1421, entry_length=11, begin_offset=60926, end_offset=61095, is_absolute=True), RangeEntry(entry_offset=1432, entry_length=10, begin_offset=61095, end_offset=61207, is_absolute=True), RangeEntry(entry_offset=1442, entry_length=10, begin_offset=61207, end_offset=61284, is_absolute=True), RangeEntry(entry_offset=1452, entry_length=11, begin_offset=61284, end_offset=61449, is_absolute=True), RangeEntry(entry_offset=1463, entry_length=11, begin_offset=61449, end_offset=61615, is_absolute=True), RangeEntry(entry_offset=1474, entry_length=11, begin_offset=61615, end_offset=61781, is_absolute=True), RangeEntry(entry_offset=1485, entry_length=11, begin_offset=61781, end_offset=62085, is_absolute=True), RangeEntry(entry_offset=1496, entry_length=11, begin_offset=62085, end_offset=62515, is_absolute=True), RangeEntry(entry_offset=1507, entry_length=11,  ...
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=1616, entry_length=11, begin_offset=65699, end_offset=65869, is_absolute=True), RangeEntry(entry_offset=1627, entry_length=10, begin_offset=65869, end_offset=65895, is_absolute=True), RangeEntry(entry_offset=1637, entry_length=10, begin_offset=65895, end_offset=66004, is_absolute=True), RangeEntry(entry_offset=1647, entry_length=11, begin_offset=66004, end_offset=67284, is_absolute=True), RangeEntry(entry_offset=1658, entry_length=11, begin_offset=67284, end_offset=67536, is_absolute=True), RangeEntry(entry_offset=1669, entry_length=11, begin_offset=67536, end_offset=67671, is_absolute=True), RangeEntry(entry_offset=1680, entry_length=10, begin_offset=67671, end_offset=67715, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=1859, entry_length=10, begin_offset=67715, end_offset=67764, is_absolute=True), RangeEntry(entry_offset=1869, entry_length=11, begin_offset=67764, end_offset=68591, is_absolute=True), RangeEntry(entry_offset=1880, entry_length=11, begin_offset=68591, end_offset=68845, is_absolute=True), RangeEntry(entry_offset=1891, entry_length=10, begin_offset=68845, end_offset=68867, is_absolute=True), RangeEntry(entry_offset=1901, entry_length=11, begin_offset=68867, end_offset=69086, is_absolute=True), RangeEntry(entry_offset=1912, entry_length=11, begin_offset=69086, end_offset=69808, is_absolute=True), RangeEntry(entry_offset=1923, entry_length=10, begin_offset=69808, end_offset=69834, is_absolute=True), RangeEntry(entry_offset=1933, entry_length=10, begin_offset=69834, end_offset=69886, is_absolute=True), RangeEntry(entry_offset=1943, entry_length=10, begin_offset=69886, end_offset=69938, is_absolute=True), RangeEntry(entry_offset=1953, entry_length=10, begin_offset=69938, end_offset=69990, is_absolute=True), RangeEntry(entry_offset=1963, entry_length=10, begin_offset=69990, end_offset=70042, is_absolute=True), RangeEntry(entry_offset=1973, entry_length=10, begin_offset=70042, end_offset=70098, is_absolute=True), RangeEntry(entry_offset=1983, entry_length=10, begin_offset=70098, end_offset=70205, is_absolute=True), RangeEntry(entry_offset=1993, entry_length=10, begin_offset=70205, end_offset=70327, is_absolute=True), RangeEntry(entry_offset=2003, entry_length=10, begin_offset=70327, end_offset=70383, is_absolute=True), RangeEntry(entry_offset=2013, entry_length=10, begin_offset=70383, end_offset=70426, is_absolute=True), RangeEntry(entry_offset=2023, entry_length=10, begin_offset=70426, end_offset=70449, is_absolute=True), RangeEntry(entry_offset=2033, entry_length=10, begin_offset=70449, end_offset=70472, is_absolute=True), RangeEntry(entry_offset=2043, entry_length=11, begin_offset=70472, end_offset=70752, is_absolute=True), RangeEntry(entry_offset=2054, entry_length=10, begin_offset=70752, end_offset=70782, is_absolute=True), RangeEntry(entry_offset=2064, entry_length=10, begin_offset=70782, end_offset=70896, is_absolute=True), RangeEntry(entry_offset=2074, entry_length=10, begin_offset=70896, end_offset=71016, is_absolute=True), RangeEntry(entry_offset=2084, entry_length=11, begin_offset=71016, end_offset=71165, is_absolute=True), RangeEntry(entry_offset=2095, entry_length=11, begin_offset=71165, end_offset=71335, is_absolute=True), RangeEntry(entry_offset=2106, entry_length=11, begin_offset=71335, end_offset=71536, is_absolute=True), RangeEntry(entry_offset=2117, entry_length=11, begin_offset=71536, end_offset=71995, is_absolute=True), RangeEntry(entry_offset=2128, entry_length=11, begin_offset=71995, end_offset=74296, is_absolute=True), RangeEntry(entry_offset=2139, entry_length=11, begin_offset=74296, end_offset=78113, is_absolute=True), RangeEntry(entry_offset=2150, entry_length=10, begin_offset=78113, end_offset=78153, is_absolute=True), RangeEntry(entry_offset=2160, entry_length=11, begin_offset=78153, end_offset=78371, is_absolute=True), RangeEntry(entry_offset=2171, entry_length=11, begin_offset=78371, end_offset=78722, is_absolute=True), RangeEntry(entry_offset=2182, entry_length=11, begin_offset=78722, end_offset=79029, is_absolute=True), RangeEntry(entry_offset=2193, entry_length=10, begin_offset=79029, end_offset=79110, is_absolute=True), RangeEntry(entry_offset=2203, entry_length=11, begin_offset=79110, end_offset=79718, is_absolute=True), RangeEntry(entry_offset=2214, entry_length=11, begin_offset=79718, end_offset=80218, is_absolute=True), RangeEntry(entry_offset=2225, entry_length=11, begin_offset=80218, end_offset=82089, is_absolute=True), RangeEntry(entry_offset=2236, entry_length=11, begin_offset=82089, end_offset=82923, is_absolute=True), RangeEntry(entry_offset=2247, entry_length=10, begin_offset=82923, end_offset=83013, is_absolute=True), RangeEntry(entry_offset=2257, entry_length=11,  ...
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=2635, entry_length=10, begin_offset=115555, end_offset=115613, is_absolute=True), RangeEntry(entry_offset=2645, entry_length=11, begin_offset=115613, end_offset=115919, is_absolute=True), RangeEntry(entry_offset=2656, entry_length=10, begin_offset=115919, end_offset=115945, is_absolute=True), RangeEntry(entry_offset=2666, entry_length=10, begin_offset=115945, end_offset=116008, is_absolute=True), RangeEntry(entry_offset=2676, entry_length=11, begin_offset=116008, end_offset=116467, is_absolute=True), RangeEntry(entry_offset=2687, entry_length=11, begin_offset=116467, end_offset=117236, is_absolute=True), RangeEntry(entry_offset=2698, entry_length=11, begin_offset=117236, end_offset=118060, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=2722, entry_length=10, begin_offset=118060, end_offset=118155, is_absolute=True), RangeEntry(entry_offset=2732, entry_length=10, begin_offset=118155, end_offset=118193, is_absolute=True), RangeEntry(entry_offset=2742, entry_length=11, begin_offset=118193, end_offset=118437, is_absolute=True), RangeEntry(entry_offset=2753, entry_length=11, begin_offset=118437, end_offset=118567, is_absolute=True), RangeEntry(entry_offset=2764, entry_length=11, begin_offset=118567, end_offset=119724, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=2788, entry_length=11, begin_offset=119724, end_offset=119905, is_absolute=True), RangeEntry(entry_offset=2799, entry_length=11, begin_offset=119905, end_offset=120096, is_absolute=True), RangeEntry(entry_offset=2810, entry_length=11, begin_offset=120096, end_offset=120241, is_absolute=True), RangeEntry(entry_offset=2821, entry_length=11, begin_offset=120241, end_offset=120451, is_absolute=True), RangeEntry(entry_offset=2832, entry_length=10, begin_offset=120451, end_offset=120545, is_absolute=True), RangeEntry(entry_offset=2842, entry_length=11, begin_offset=120545, end_offset=120861, is_absolute=True), RangeEntry(entry_offset=2853, entry_length=11, begin_offset=120861, end_offset=121058, is_absolute=True), RangeEntry(entry_offset=2864, entry_length=11, begin_offset=121058, end_offset=121796, is_absolute=True), RangeEntry(entry_offset=2875, entry_length=11, begin_offset=121796, end_offset=122109, is_absolute=True), RangeEntry(entry_offset=2886, entry_length=10, begin_offset=122109, end_offset=122217, is_absolute=True), RangeEntry(entry_offset=2896, entry_length=11, begin_offset=122217, end_offset=122444, is_absolute=True), RangeEntry(entry_offset=2907, entry_length=11, begin_offset=122444, end_offset=122654, is_absolute=True), RangeEntry(entry_offset=2918, entry_length=10, begin_offset=122654, end_offset=122764, is_absolute=True), RangeEntry(entry_offset=2928, entry_length=11, begin_offset=122764, end_offset=123019, is_absolute=True), RangeEntry(entry_offset=2939, entry_length=11, begin_offset=123019, end_offset=123417, is_absolute=True), RangeEntry(entry_offset=2950, entry_length=11, begin_offset=123417, end_offset=123608, is_absolute=True), RangeEntry(entry_offset=2961, entry_length=11, begin_offset=123608, end_offset=123889, is_absolute=True), RangeEntry(entry_offset=2972, entry_length=10, begin_offset=123889, end_offset=124004, is_absolute=True), RangeEntry(entry_offset=2982, entry_length=10, begin_offset=124004, end_offset=124095, is_absolute=True), RangeEntry(entry_offset=2992, entry_length=10, begin_offset=124095, end_offset=124170, is_absolute=True), RangeEntry(entry_offset=3002, entry_length=11, begin_offset=124170, end_offset=124337, is_absolute=True), RangeEntry(entry_offset=3013, entry_length=10, begin_offset=124337, end_offset=124447, is_absolute=True), RangeEntry(entry_offset=3023, entry_length=11, begin_offset=124447, end_offset=124842, is_absolute=True), RangeEntry(entry_offset=3034, entry_length=10, begin_offset=124842, end_offset=124969, is_absolute=True), RangeEntry(entry_offset=3044, entry_length=10, begin_offset=124969, end_offset=125035, is_absolute=True), RangeEntry(entry_offset=3054, entry_length=11, begin_offset=125035, end_offset=125515, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=3078, entry_length=11, begin_offset=125515, end_offset=125677, is_absolute=True), RangeEntry(entry_offset=3089, entry_length=10, begin_offset=125677, end_offset=125724, is_absolute=True), RangeEntry(entry_offset=3099, entry_length=10, begin_offset=125724, end_offset=125836, is_absolute=True), RangeEntry(entry_offset=3109, entry_length=10, begin_offset=125836, end_offset=125926, is_absolute=True), RangeEntry(entry_offset=3119, entry_length=10, begin_offset=125926, end_offset=125984, is_absolute=True), RangeEntry(entry_offset=3129, entry_length=10, begin_offset=125984, end_offset=126106, is_absolute=True), RangeEntry(entry_offset=3139, entry_length=10, begin_offset=126106, end_offset=126154, is_absolute=True), RangeEntry(entry_offset=3149, entry_length=11, begin_offset=126154, end_offset=126297, is_absolute=True), RangeEntry(entry_offset=3160, entry_length=11, begin_offset=126297, end_offset=126443, is_absolute=True), RangeEntry(entry_offset=3171, entry_length=11, begin_offset=126443, end_offset=126610, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=3195, entry_length=10, begin_offset=126610, end_offset=126638, is_absolute=True), RangeEntry(entry_offset=3205, entry_length=10, begin_offset=126638, end_offset=126693, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=3228, entry_length=10, begin_offset=126693, end_offset=126796, is_absolute=True), RangeEntry(entry_offset=3238, entry_length=10, begin_offset=126796, end_offset=126899, is_absolute=True), RangeEntry(entry_offset=3248, entry_length=10, begin_offset=126899, end_offset=127005, is_absolute=True), RangeEntry(entry_offset=3258, entry_length=10, begin_offset=127005, end_offset=127122, is_absolute=True), RangeEntry(entry_offset=3268, entry_length=10, begin_offset=127122, end_offset=127204, is_absolute=True), RangeEntry(entry_offset=3278, entry_length=10, begin_offset=127204, end_offset=127289, is_absolute=True), RangeEntry(entry_offset=3288, entry_length=10, begin_offset=127289, end_offset=127374, is_absolute=True), RangeEntry(entry_offset=3298, entry_length=11, begin_offset=127374, end_offset=127536, is_absolute=True), RangeEntry(entry_offset=3309, entry_length=10, begin_offset=127536, end_offset=127640, is_absolute=True), RangeEntry(entry_offset=3319, entry_length=10, begin_offset=127640, end_offset=127756, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=3342, entry_length=10, begin_offset=127756, end_offset=127806, is_absolute=True), RangeEntry(entry_offset=3352, entry_length=10, begin_offset=127806, end_offset=127873, is_absolute=True), RangeEntry(entry_offset=3362, entry_length=11, begin_offset=127873, end_offset=128016, is_absolute=True), RangeEntry(entry_offset=3373, entry_length=11, begin_offset=128016, end_offset=128177, is_absolute=True), RangeEntry(entry_offset=3384, entry_length=10, begin_offset=128177, end_offset=128296, is_absolute=True), RangeEntry(entry_offset=3394, entry_length=10, begin_offset=128296, end_offset=128373, is_absolute=True), RangeEntry(entry_offset=3404, entry_length=10, begin_offset=128373, end_offset=128394, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=3443, entry_length=11, begin_offset=128394, end_offset=128752, is_absolute=True), RangeEntry(entry_offset=3454, entry_length=11, begin_offset=128752, end_offset=128967, is_absolute=True), RangeEntry(entry_offset=3465, entry_length=10, begin_offset=128967, end_offset=129032, is_absolute=True), RangeEntry(entry_offset=3475, entry_length=11, begin_offset=129032, end_offset=129379, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=3518, entry_length=11, begin_offset=129379, end_offset=129652, is_absolute=True), RangeEntry(entry_offset=3529, entry_length=11, begin_offset=129652, end_offset=129873, is_absolute=True), RangeEntry(entry_offset=3540, entry_length=11, begin_offset=129873, end_offset=130336, is_absolute=True), RangeEntry(entry_offset=3551, entry_length=11, begin_offset=130336, end_offset=131220, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=3632, entry_length=10, begin_offset=131220, end_offset=131305, is_absolute=True), RangeEntry(entry_offset=3642, entry_length=10, begin_offset=131305, end_offset=131373, is_absolute=True), RangeEntry(entry_offset=3652, entry_length=10, begin_offset=131373, end_offset=131396, is_absolute=True), RangeEntry(entry_offset=3662, entry_length=10, begin_offset=131396, end_offset=131509, is_absolute=True), RangeEntry(entry_offset=3672, entry_length=11, begin_offset=131509, end_offset=132007, is_absolute=True), RangeEntry(entry_offset=3683, entry_length=11, begin_offset=132007, end_offset=132181, is_absolute=True), RangeEntry(entry_offset=3694, entry_length=10, begin_offset=132181, end_offset=132197, is_absolute=True), RangeEntry(entry_offset=3704, entry_length=11, begin_offset=132197, end_offset=132701, is_absolute=True), RangeEntry(entry_offset=3715, entry_length=10, begin_offset=132701, end_offset=132749, is_absolute=True), RangeEntry(entry_offset=3725, entry_length=10, begin_offset=132749, end_offset=132797, is_absolute=True), RangeEntry(entry_offset=3735, entry_length=11, begin_offset=132797, end_offset=132953, is_absolute=True), RangeEntry(entry_offset=3746, entry_length=11, begin_offset=132953, end_offset=133219, is_absolute=True), RangeEntry(entry_offset=3757, entry_length=10, begin_offset=133219, end_offset=133264, is_absolute=True), RangeEntry(entry_offset=3767, entry_length=11, begin_offset=133264, end_offset=133497, is_absolute=True), RangeEntry(entry_offset=3778, entry_length=10, begin_offset=133497, end_offset=133542, is_absolute=True), RangeEntry(entry_offset=3788, entry_length=11, begin_offset=133542, end_offset=134218, is_absolute=True), RangeEntry(entry_offset=3799, entry_length=11, begin_offset=134218, end_offset=134737, is_absolute=True), RangeEntry(entry_offset=3810, entry_length=11, begin_offset=134737, end_offset=135200, is_absolute=True), RangeEntry(entry_offset=3821, entry_length=10, begin_offset=135200, end_offset=135248, is_absolute=True), RangeEntry(entry_offset=3831, entry_length=10, begin_offset=135248, end_offset=135296, is_absolute=True), RangeEntry(entry_offset=3841, entry_length=10, begin_offset=135296, end_offset=135366, is_absolute=True), RangeEntry(entry_offset=3851, entry_length=10, begin_offset=135366, end_offset=135433, is_absolute=True), RangeEntry(entry_offset=3861, entry_length=10, begin_offset=135433, end_offset=135506, is_absolute=True), RangeEntry(entry_offset=3871, entry_length=10, begin_offset=135506, end_offset=135523, is_absolute=True), RangeEntry(entry_offset=3881, entry_length=10, begin_offset=135523, end_offset=135608, is_absolute=True), RangeEntry(entry_offset=3891, entry_length=11, begin_offset=135608, end_offset=135740, is_absolute=True), RangeEntry(entry_offset=3902, entry_length=10, begin_offset=135740, end_offset=135803, is_absolute=True), RangeEntry(entry_offset=3912, entry_length=11, begin_offset=135803, end_offset=136718, is_absolute=True), RangeEntry(entry_offset=3923, entry_length=11, begin_offset=136718, end_offset=137020, is_absolute=True), RangeEntry(entry_offset=3934, entry_length=11, begin_offset=137020, end_offset=137363, is_absolute=True), RangeEntry(entry_offset=3945, entry_length=11, begin_offset=137363, end_offset=137753, is_absolute=True), RangeEntry(entry_offset=3956, entry_length=11, begin_offset=137753, end_offset=140535, is_absolute=True), RangeEntry(entry_offset=3967, entry_length=11, begin_offset=140535, end_offset=141875, is_absolute=True), RangeEntry(entry_offset=3978, entry_length=11, begin_offset=141875, end_offset=142786, is_absolute=True), RangeEntry(entry_offset=3989, entry_length=11, begin_offset=142786, end_offset=143315, is_absolute=True), RangeEntry(entry_offset=4000, entry_length=11, begin_offset=143315, end_offset=144490, is_absolute=True)]
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4463, entry_length=5, begin_offset=3113, end_offset=3194, is_absolute=False), RangeEntry(entry_offset=4468, entry_length=5, begin_offset=3232, end_offset=3319, is_absolute=False), RangeEntry(entry_offset=4473, entry_length=5, begin_offset=3323, end_offset=3344, is_absolute=False), RangeEntry(entry_offset=4478, entry_length=5, begin_offset=3408, end_offset=3491, is_absolute=False), RangeEntry(entry_offset=4483, entry_length=5, begin_offset=3504, end_offset=3544, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4122, entry_length=5, begin_offset=362, end_offset=362, is_absolute=False), RangeEntry(entry_offset=4127, entry_length=5, begin_offset=371, end_offset=544, is_absolute=False), RangeEntry(entry_offset=4132, entry_length=5, begin_offset=1520, end_offset=1540, is_absolute=False), RangeEntry(entry_offset=4137, entry_length=5, begin_offset=1872, end_offset=1872, is_absolute=False), RangeEntry(entry_offset=4142, entry_length=5, begin_offset=2272, end_offset=2320, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4148, entry_length=5, begin_offset=396, end_offset=544, is_absolute=False), RangeEntry(entry_offset=4153, entry_length=5, begin_offset=1528, end_offset=1540, is_absolute=False), RangeEntry(entry_offset=4158, entry_length=5, begin_offset=2272, end_offset=2320, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4180, entry_length=5, begin_offset=1540, end_offset=1581, is_absolute=False), RangeEntry(entry_offset=4185, entry_length=5, begin_offset=1872, end_offset=1919, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4191, entry_length=5, begin_offset=1953, end_offset=1953, is_absolute=False), RangeEntry(entry_offset=4196, entry_length=5, begin_offset=2056, end_offset=2208, is_absolute=False), RangeEntry(entry_offset=4201, entry_length=5, begin_offset=2342, end_offset=2347, is_absolute=False), RangeEntry(entry_offset=4206, entry_length=5, begin_offset=2349, end_offset=2368, is_absolute=False), RangeEntry(entry_offset=4211, entry_length=5, begin_offset=2416, end_offset=2466, is_absolute=False), RangeEntry(entry_offset=4216, entry_length=5, begin_offset=2514, end_offset=2528, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4222, entry_length=5, begin_offset=2066, end_offset=2208, is_absolute=False), RangeEntry(entry_offset=4227, entry_length=5, begin_offset=2416, end_offset=2466, is_absolute=False), RangeEntry(entry_offset=4232, entry_length=5, begin_offset=2514, end_offset=2528, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4254, entry_length=5, begin_offset=1953, end_offset=1953, is_absolute=False), RangeEntry(entry_offset=4259, entry_length=5, begin_offset=1955, end_offset=1996, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4265, entry_length=5, begin_offset=1048, end_offset=1194, is_absolute=False), RangeEntry(entry_offset=4270, entry_length=5, begin_offset=2368, end_offset=2416, is_absolute=False), RangeEntry(entry_offset=4275, entry_length=5, begin_offset=2503, end_offset=2514, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4281, entry_length=5, begin_offset=1069, end_offset=1194, is_absolute=False), RangeEntry(entry_offset=4286, entry_length=5, begin_offset=2368, end_offset=2416, is_absolute=False), RangeEntry(entry_offset=4291, entry_length=5, begin_offset=2503, end_offset=2514, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4313, entry_length=5, begin_offset=1261, end_offset=1265, is_absolute=False), RangeEntry(entry_offset=4318, entry_length=5, begin_offset=1268, end_offset=1276, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4351, entry_length=5, begin_offset=784, end_offset=787, is_absolute=False), RangeEntry(entry_offset=4356, entry_length=5, begin_offset=795, end_offset=807, is_absolute=False), RangeEntry(entry_offset=4361, entry_length=5, begin_offset=810, end_offset=976, is_absolute=False), RangeEntry(entry_offset=4366, entry_length=5, begin_offset=1384, end_offset=1424, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4372, entry_length=5, begin_offset=810, end_offset=818, is_absolute=False), RangeEntry(entry_offset=4377, entry_length=5, begin_offset=821, end_offset=842, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4426, entry_length=5, begin_offset=2615, end_offset=2617, is_absolute=False), RangeEntry(entry_offset=4431, entry_length=5, begin_offset=2620, end_offset=2650, is_absolute=False), RangeEntry(entry_offset=4436, entry_length=5, begin_offset=2670, end_offset=2688, is_absolute=False), RangeEntry(entry_offset=4441, entry_length=5, begin_offset=2737, end_offset=2820, is_absolute=False), RangeEntry(entry_offset=4446, entry_length=5, begin_offset=2998, end_offset=3019, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4452, entry_length=5, begin_offset=2855, end_offset=2988, is_absolute=False), RangeEntry(entry_offset=4457, entry_length=5, begin_offset=3024, end_offset=3045, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4554, entry_length=5, begin_offset=772, end_offset=779, is_absolute=False), RangeEntry(entry_offset=4559, entry_length=5, begin_offset=782, end_offset=787, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4538, entry_length=5, begin_offset=540, end_offset=543, is_absolute=False), RangeEntry(entry_offset=4543, entry_length=5, begin_offset=545, end_offset=549, is_absolute=False), RangeEntry(entry_offset=4548, entry_length=5, begin_offset=552, end_offset=557, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4527, entry_length=5, begin_offset=340, end_offset=347, is_absolute=False), RangeEntry(entry_offset=4532, entry_length=5, begin_offset=350, end_offset=355, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4517, entry_length=3, begin_offset=108, end_offset=111, is_absolute=False), RangeEntry(entry_offset=4520, entry_length=3, begin_offset=113, end_offset=117, is_absolute=False), RangeEntry(entry_offset=4523, entry_length=3, begin_offset=120, end_offset=125, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4649, entry_length=5, begin_offset=327, end_offset=340, is_absolute=False), RangeEntry(entry_offset=4654, entry_length=5, begin_offset=344, end_offset=353, is_absolute=False), RangeEntry(entry_offset=4659, entry_length=5, begin_offset=356, end_offset=366, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4665, entry_length=5, begin_offset=327, end_offset=340, is_absolute=False), RangeEntry(entry_offset=4670, entry_length=5, begin_offset=353, end_offset=353, is_absolute=False), RangeEntry(entry_offset=4675, entry_length=5, begin_offset=361, end_offset=366, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4681, entry_length=5, begin_offset=344, end_offset=353, is_absolute=False), RangeEntry(entry_offset=4686, entry_length=5, begin_offset=353, end_offset=353, is_absolute=False), RangeEntry(entry_offset=4691, entry_length=5, begin_offset=356, end_offset=361, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4596, entry_length=5, begin_offset=165, end_offset=170, is_absolute=False), RangeEntry(entry_offset=4601, entry_length=5, begin_offset=173, end_offset=188, is_absolute=False), RangeEntry(entry_offset=4606, entry_length=5, begin_offset=190, end_offset=195, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4577, entry_length=3, begin_offset=68, end_offset=68, is_absolute=False), RangeEntry(entry_offset=4580, entry_length=3, begin_offset=72, end_offset=125, is_absolute=False), RangeEntry(entry_offset=4583, entry_length=5, begin_offset=128, end_offset=150, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4589, entry_length=3, begin_offset=102, end_offset=108, is_absolute=False), RangeEntry(entry_offset=4592, entry_length=3, begin_offset=111, end_offset=125, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4612, entry_length=5, begin_offset=244, end_offset=244, is_absolute=False), RangeEntry(entry_offset=4617, entry_length=5, begin_offset=253, end_offset=256, is_absolute=False), RangeEntry(entry_offset=4622, entry_length=5, begin_offset=260, end_offset=278, is_absolute=False), RangeEntry(entry_offset=4627, entry_length=5, begin_offset=296, end_offset=301, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4633, entry_length=5, begin_offset=278, end_offset=278, is_absolute=False), RangeEntry(entry_offset=4638, entry_length=5, begin_offset=282, end_offset=288, is_absolute=False), RangeEntry(entry_offset=4643, entry_length=5, begin_offset=291, end_offset=296, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4732, entry_length=5, begin_offset=465, end_offset=465, is_absolute=False), RangeEntry(entry_offset=4737, entry_length=5, begin_offset=470, end_offset=500, is_absolute=False), RangeEntry(entry_offset=4742, entry_length=5, begin_offset=1070, end_offset=1085, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4748, entry_length=5, begin_offset=480, end_offset=495, is_absolute=False), RangeEntry(entry_offset=4753, entry_length=5, begin_offset=1070, end_offset=1085, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4759, entry_length=5, begin_offset=465, end_offset=470, is_absolute=False), RangeEntry(entry_offset=4764, entry_length=5, begin_offset=621, end_offset=621, is_absolute=False), RangeEntry(entry_offset=4769, entry_length=5, begin_offset=626, end_offset=657, is_absolute=False), RangeEntry(entry_offset=4774, entry_length=5, begin_offset=1085, end_offset=1100, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4780, entry_length=5, begin_offset=465, end_offset=470, is_absolute=False), RangeEntry(entry_offset=4785, entry_length=5, begin_offset=632, end_offset=647, is_absolute=False), RangeEntry(entry_offset=4790, entry_length=5, begin_offset=1085, end_offset=1100, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4796, entry_length=5, begin_offset=528, end_offset=536, is_absolute=False), RangeEntry(entry_offset=4801, entry_length=5, begin_offset=536, end_offset=546, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4807, entry_length=5, begin_offset=546, end_offset=549, is_absolute=False), RangeEntry(entry_offset=4812, entry_length=5, begin_offset=552, end_offset=563, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4807, entry_length=5, begin_offset=546, end_offset=549, is_absolute=False), RangeEntry(entry_offset=4812, entry_length=5, begin_offset=552, end_offset=563, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4818, entry_length=5, begin_offset=563, end_offset=576, is_absolute=False), RangeEntry(entry_offset=4823, entry_length=5, begin_offset=764, end_offset=781, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4829, entry_length=5, begin_offset=579, end_offset=614, is_absolute=False), RangeEntry(entry_offset=4834, entry_length=5, begin_offset=1054, end_offset=1063, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4840, entry_length=5, begin_offset=579, end_offset=591, is_absolute=False), RangeEntry(entry_offset=4845, entry_length=5, begin_offset=591, end_offset=600, is_absolute=False), RangeEntry(entry_offset=4850, entry_length=5, begin_offset=600, end_offset=612, is_absolute=False), RangeEntry(entry_offset=4855, entry_length=5, begin_offset=1059, end_offset=1063, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4861, entry_length=5, begin_offset=660, end_offset=660, is_absolute=False), RangeEntry(entry_offset=4866, entry_length=5, begin_offset=665, end_offset=697, is_absolute=False), RangeEntry(entry_offset=4871, entry_length=5, begin_offset=1100, end_offset=1115, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4877, entry_length=5, begin_offset=672, end_offset=687, is_absolute=False), RangeEntry(entry_offset=4882, entry_length=5, begin_offset=1100, end_offset=1115, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4888, entry_length=5, begin_offset=725, end_offset=725, is_absolute=False), RangeEntry(entry_offset=4893, entry_length=5, begin_offset=730, end_offset=761, is_absolute=False), RangeEntry(entry_offset=4898, entry_length=5, begin_offset=809, end_offset=814, is_absolute=False), RangeEntry(entry_offset=4903, entry_length=5, begin_offset=1115, end_offset=1130, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4909, entry_length=5, begin_offset=736, end_offset=751, is_absolute=False), RangeEntry(entry_offset=4914, entry_length=5, begin_offset=809, end_offset=814, is_absolute=False), RangeEntry(entry_offset=4919, entry_length=5, begin_offset=1115, end_offset=1130, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4925, entry_length=5, begin_offset=809, end_offset=809, is_absolute=False), RangeEntry(entry_offset=4930, entry_length=5, begin_offset=814, end_offset=849, is_absolute=False), RangeEntry(entry_offset=4935, entry_length=5, begin_offset=1130, end_offset=1145, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4941, entry_length=5, begin_offset=824, end_offset=839, is_absolute=False), RangeEntry(entry_offset=4946, entry_length=5, begin_offset=1130, end_offset=1145, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4964, entry_length=5, begin_offset=425, end_offset=430, is_absolute=False), RangeEntry(entry_offset=4969, entry_length=5, begin_offset=434, end_offset=439, is_absolute=False), RangeEntry(entry_offset=4974, entry_length=5, begin_offset=447, end_offset=454, is_absolute=False), RangeEntry(entry_offset=4979, entry_length=5, begin_offset=459, end_offset=471, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [RangeEntry(entry_offset=4985, entry_length=5, begin_offset=488, end_offset=504, is_absolute=False), RangeEntry(entry_offset=4990, entry_length=5, begin_offset=507, end_offset=512, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_compile_unit. attr DW_AT_ranges.
# [RangeEntry(entry_offset=5622, entry_length=11, begin_offset=151584, end_offset=155678, is_absolute=True), RangeEntry(entry_offset=5633, entry_length=10, begin_offset=20192, end_offset=20197, is_absolute=True)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5597, base_address=155568), RangeEntry(entry_offset=5606, entry_length=3, begin_offset=0, end_offset=6, is_absolute=False), RangeEntry(entry_offset=5609, entry_length=3, begin_offset=14, end_offset=19, is_absolute=False), RangeEntry(entry_offset=5612, entry_length=3, begin_offset=24, end_offset=45, is_absolute=False), RangeEntry(entry_offset=5615, entry_length=3, begin_offset=48, end_offset=50, is_absolute=False), RangeEntry(entry_offset=5618, entry_length=3, begin_offset=55, end_offset=57, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5537, base_address=155400), RangeEntry(entry_offset=5546, entry_length=3, begin_offset=0, end_offset=11, is_absolute=False), RangeEntry(entry_offset=5549, entry_length=3, begin_offset=27, end_offset=80, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5553, base_address=155400), RangeEntry(entry_offset=5562, entry_length=3, begin_offset=0, end_offset=4, is_absolute=False), RangeEntry(entry_offset=5565, entry_length=3, begin_offset=27, end_offset=31, is_absolute=False), RangeEntry(entry_offset=5568, entry_length=3, begin_offset=36, end_offset=70, is_absolute=False), RangeEntry(entry_offset=5571, entry_length=3, begin_offset=70, end_offset=75, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5575, base_address=155400), RangeEntry(entry_offset=5584, entry_length=3, begin_offset=0, end_offset=4, is_absolute=False), RangeEntry(entry_offset=5587, entry_length=3, begin_offset=31, end_offset=31, is_absolute=False), RangeEntry(entry_offset=5590, entry_length=3, begin_offset=36, end_offset=41, is_absolute=False), RangeEntry(entry_offset=5593, entry_length=3, begin_offset=47, end_offset=52, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5493, base_address=155275), RangeEntry(entry_offset=5502, entry_length=3, begin_offset=0, end_offset=4, is_absolute=False), RangeEntry(entry_offset=5505, entry_length=3, begin_offset=23, end_offset=28, is_absolute=False), RangeEntry(entry_offset=5508, entry_length=3, begin_offset=34, end_offset=64, is_absolute=False), RangeEntry(entry_offset=5511, entry_length=3, begin_offset=64, end_offset=73, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5515, base_address=155275), RangeEntry(entry_offset=5524, entry_length=3, begin_offset=0, end_offset=4, is_absolute=False), RangeEntry(entry_offset=5527, entry_length=3, begin_offset=23, end_offset=28, is_absolute=False), RangeEntry(entry_offset=5530, entry_length=3, begin_offset=34, end_offset=39, is_absolute=False), RangeEntry(entry_offset=5533, entry_length=3, begin_offset=54, end_offset=54, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5299, base_address=154183), RangeEntry(entry_offset=5308, entry_length=3, begin_offset=0, end_offset=2, is_absolute=False), RangeEntry(entry_offset=5311, entry_length=3, begin_offset=16, end_offset=21, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5332, base_address=154208), RangeEntry(entry_offset=5341, entry_length=3, begin_offset=0, end_offset=3, is_absolute=False), RangeEntry(entry_offset=5344, entry_length=3, begin_offset=12, end_offset=21, is_absolute=False), RangeEntry(entry_offset=5347, entry_length=3, begin_offset=34, end_offset=38, is_absolute=False), RangeEntry(entry_offset=5350, entry_length=3, begin_offset=45, end_offset=63, is_absolute=False), RangeEntry(entry_offset=5353, entry_length=3, begin_offset=68, end_offset=71, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5357, base_address=154321), RangeEntry(entry_offset=5366, entry_length=3, begin_offset=0, end_offset=13, is_absolute=False), RangeEntry(entry_offset=5369, entry_length=3, begin_offset=38, end_offset=41, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5373, base_address=154334), RangeEntry(entry_offset=5382, entry_length=3, begin_offset=0, end_offset=10, is_absolute=False), RangeEntry(entry_offset=5385, entry_length=3, begin_offset=14, end_offset=25, is_absolute=False), RangeEntry(entry_offset=5388, entry_length=3, begin_offset=28, end_offset=33, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5392, base_address=154784), RangeEntry(entry_offset=5401, entry_length=3, begin_offset=0, end_offset=9, is_absolute=False), RangeEntry(entry_offset=5404, entry_length=3, begin_offset=12, end_offset=12, is_absolute=False), RangeEntry(entry_offset=5407, entry_length=3, begin_offset=15, end_offset=45, is_absolute=False), RangeEntry(entry_offset=5410, entry_length=3, begin_offset=49, end_offset=54, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5414, base_address=154833), RangeEntry(entry_offset=5423, entry_length=3, begin_offset=0, end_offset=0, is_absolute=False), RangeEntry(entry_offset=5426, entry_length=3, begin_offset=5, end_offset=13, is_absolute=False), RangeEntry(entry_offset=5429, entry_length=3, begin_offset=31, end_offset=34, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5433, base_address=154846), RangeEntry(entry_offset=5442, entry_length=3, begin_offset=0, end_offset=18, is_absolute=False), RangeEntry(entry_offset=5445, entry_length=3, begin_offset=21, end_offset=26, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5173, base_address=152824), RangeEntry(entry_offset=5182, entry_length=3, begin_offset=0, end_offset=9, is_absolute=False), RangeEntry(entry_offset=5185, entry_length=3, begin_offset=9, end_offset=14, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5449, base_address=155147), RangeEntry(entry_offset=5458, entry_length=3, begin_offset=0, end_offset=4, is_absolute=False), RangeEntry(entry_offset=5461, entry_length=3, begin_offset=23, end_offset=28, is_absolute=False), RangeEntry(entry_offset=5464, entry_length=3, begin_offset=38, end_offset=68, is_absolute=False), RangeEntry(entry_offset=5467, entry_length=3, begin_offset=68, end_offset=77, is_absolute=False)]
#
#
#
#
#    DIE DW_TAG_inlined_subroutine. attr DW_AT_ranges.
# [BaseAddressEntry(entry_offset=5471, base_address=155147), RangeEntry(entry_offset=5480, entry_length=3, begin_offset=0, end_offset=4, is_absolute=False), RangeEntry(entry_offset=5483, entry_length=3, begin_offset=23, end_offset=28, is_absolute=False), RangeEntry(entry_offset=5486, entry_length=3, begin_offset=38, end_offset=43, is_absolute=False), RangeEntry(entry_offset=5489, entry_length=3, begin_offset=58, end_offset=58, is_absolute=False)]
#
#
#
#
#
#
#
#  534
