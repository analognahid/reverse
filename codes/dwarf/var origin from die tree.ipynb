# %%
import sys


from elftools.elf.elffile import ELFFile
from elftools.dwarf.descriptions import (
    describe_DWARF_expr, set_global_machine_arch)
from elftools.dwarf.locationlists import (
    LocationEntry, LocationExpr, LocationParser)



def show_loclist(loclist, dwarfinfo, indent, cu_offset):
    """ Display a location list nicely, decoding the DWARF expressions
        contained within.
    """
    d = []
    for loc_entity in loclist:
        if isinstance(loc_entity, LocationEntry):
            d.append('%s <<%s>>' % (
                loc_entity,
                describe_DWARF_expr(loc_entity.loc_expr, dwarfinfo.structs, cu_offset)))
        else:
            d.append(str(loc_entity))
    return '\n'.join(indent + s for s in d)

# %%
def get_DIE_at_offset(CU, offset):
        for die in CU.iter_DIEs():
            if die.offset == CU.cu_offset+offset:
                return die 
        return None

def get_type_name(CU, offset):#get_DIE_at_offset(CU,attr.value)
    die = get_DIE_at_offset(CU, offset)
    
    if die.tag == 'DW_TAG_pointer_type':
        for _attr in die.attributes.values():
            if _attr.name== "DW_AT_type":
                return "*"+get_type_name(CU,_attr.value) 
        
    
    for attr in die.attributes.values():
        if attr.name== "DW_AT_name":
            return attr.value.decode("utf-8")

# %%
from collections import defaultdict
def line_entry_mapping(line_program):
    filename_map = defaultdict(int)

    # The line program, when decoded, returns a list of line program
    # entries. Each entry contains a state, which we'll use to build
    # a reverse mapping of filename -> #entries.
    lp_entries = line_program.get_entries()
    for lpe in lp_entries:
        # We skip LPEs that don't have an associated file.
        # This can happen if instructions in the compiled binary
        # don't correspond directly to any original source file.
        if not lpe.state or lpe.state.file == 0:
            continue
        filename = lpe_filename(line_program, lpe.state.file)
        filename_map[filename] += 1

    # for filename, lpe_count in filename_map.items():
    #     print("    filename=%s -> %d entries" % (filename, lpe_count))
    return filename_map

def lpe_filename(line_program, file_index):

    lp_header = line_program.header
    file_entries = lp_header["file_entry"]
    

    # File and directory indices are 1-indexed.
    file_entry = file_entries[file_index - 1]
    dir_index = file_entry["dir_index"]

    # A dir_index of 0 indicates that no absolute directory was recorded during
    # compilation; return just the basename.
    if dir_index == 0:
        return file_entry.name.decode()

    directory = lp_header["include_directory"][dir_index - 1]
    return posixpath.join(directory, file_entry.name).decode()

# %%
FUNC_PARAMS = {}

FUNC_BOUNDARY = {}


def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        # get_dwarf_info returns a DWARFInfo context object, which is the
        # starting point for all DWARF-based processing in pyelftools.
        dwarfinfo = elffile.get_dwarf_info()

        # The location lists are extracted by DWARFInfo from the .debug_loc
        # section, and returned here as a LocationLists object.
        location_lists = dwarfinfo.location_lists()

        # This is required for the descriptions module to correctly decode
        # register names contained in DWARF expressions.
        set_global_machine_arch(elffile.get_machine_arch())

        # Create a LocationParser object that parses the DIE attributes and
        # creates objects representing the actual location information.
        loc_parser = LocationParser(location_lists)
        
        section_offset = dwarfinfo.debug_info_sec.global_offset
        # Offset of the .debug_info section in the stream
        

        
        for CU in dwarfinfo.iter_CUs():
            
            #get source file name
            line_program = dwarfinfo.line_program_for_CU(CU)
            filename_map = line_entry_mapping(line_program)
            CU_src_file =  list(filename_map.items())[0][0]
            
            CU_dictionary_key = CU_src_file + "_" + str(CU.cu_offset)
            
            FUNC_PARAMS[CU_dictionary_key] = {}
            FUNC_BOUNDARY[CU_dictionary_key] = {}
            
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # A CU provides a simple API to iterate over all the DIEs in it.
            die_depth = 0
            are_DIEs_of_function = False
            FUNC_name = None
            for DIE in CU.iter_DIEs():
                
                ############################################################
                #############   Prasing Function DIEs start ################
                
                if DIE.tag == 'DW_TAG_subprogram':
                    are_DIEs_of_function = True

                    for attr in DIE.attributes.values():
                        if attr.name == "DW_AT_name": #FUNC NAME
                            FUNC_name = attr.value.decode("utf-8")
                            print(FUNC_name)
                            FUNC_PARAMS[CU_dictionary_key][FUNC_name] ={}
                            print(DIE)
#                             FUNC_BOUNDARY[CU_dictionary_key][FUNC_name]['start']  =
#                             FUNC_BOUNDARY[CU_dictionary_key][FUNC_name]['end']    = 
                            
                            
                if DIE.tag == 'DW_TAG_formal_parameter':
                    tags = [attr.name for attr in DIE.attributes.values()]
                    PARAM_name = None
                    if "DW_AT_name" in tags:
                        for attr in DIE.attributes.values():
                            
                            if attr.name == "DW_AT_name": # VAR NAME 
                                PARAM_name = attr.value.decode("utf-8")
                                print('------------> Param:  ',PARAM_name)
                                FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {}
                                
                            if attr.name == "DW_AT_type":
                                print('------------------> type: ',get_type_name(CU,attr.value),'\n\n')
                                FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {'type':get_type_name(CU,attr.value) , 'kind':'parameter'}
                                
                                
                if DIE.tag == 'DW_TAG_variable':
                    PARAM_name = None
                    for attr in DIE.attributes.values():

                        if attr.name == "DW_AT_name": # VAR NAME 
                            PARAM_name = attr.value.decode("utf-8")
                            print('------------> Local: ',PARAM_name)
                            FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {}

                        if attr.name == "DW_AT_type":
                            print('------------------> type: ',get_type_name(CU,attr.value),'\n\n')
                            FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {'type':get_type_name(CU,attr.value) , 'kind':'parameter'}



                ###############################################
                #############  parsing  Function DIEs ends ################
                


                
                if DIE.is_null(): #https://chromium.googlesource.com/chromiumos/third_party/pyelftools/+/25a77f7738d7fe824f2ed4d33a123136b9d8e88a/scripts/readelf.py
                    are_DIEs_of_function = False
                    FUNC_name = None
                    
                    die_depth -= 1
                    continue
                if DIE.has_children:
                    die_depth += 1
                    

filename = './../../binaries/c_many/stacktest'
process_file(filename)
# Out:
# Processing file: ./../../binaries/c_many/stacktest
#   Found a compile unit at offset 0, length 457
# free
# DIE DW_TAG_subprogram, size=13, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=193)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'free', raw_value=35, offset=193)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=4, raw_value=4, offset=197)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data2', value=555, raw_value=555, offset=198)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=13, raw_value=13, offset=200)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=201)
#     |DW_AT_declaration :  AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=201)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=211, raw_value=211, offset=201)
#
# malloc
# DIE DW_TAG_subprogram, size=17, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=212)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'malloc', raw_value=283, offset=212)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=4, raw_value=4, offset=216)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data2', value=540, raw_value=540, offset=217)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=14, raw_value=14, offset=219)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=220)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=72, raw_value=72, offset=220)
#     |DW_AT_declaration :  AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=224)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=234, raw_value=234, offset=224)
#
# pop
# DIE DW_TAG_subprogram, size=34, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=235)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'pop', raw_value=b'pop', offset=235)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=239)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=20, raw_value=20, offset=240)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=241)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=242)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=102, raw_value=102, offset=242)
#     |DW_AT_low_pc      :  AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4622, raw_value=4622, offset=246)
#     |DW_AT_high_pc     :  AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=91, raw_value=91, offset=254)
#     |DW_AT_frame_base  :  AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=262)
#     |DW_AT_call_all_tail_calls:  AttributeValue(name='DW_AT_call_all_tail_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=264)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=339, raw_value=339, offset=264)
#
# ------------> Param:   stk_ptr
# ------------------> type:  **stack
#
#
# ------------> Local:  pop
# ------------------> type:  int
#
#
# ------------> Local:  number
# ------------------> type:  int
#
#
# ------------> Local:  stk
# ------------------> type:  *stack
#
#
# ------------> Local:  tmp
# ------------------> type:  *stack
#
#
# push
# DIE DW_TAG_subprogram, size=26, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=350)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'push', raw_value=268, offset=350)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=354)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=355)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=6, raw_value=6, offset=356)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=357)
#     |DW_AT_low_pc      :  AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4521, raw_value=4521, offset=357)
#     |DW_AT_high_pc     :  AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=101, raw_value=101, offset=365)
#     |DW_AT_frame_base  :  AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=373)
#     |DW_AT_call_all_tail_calls:  AttributeValue(name='DW_AT_call_all_tail_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=375)
#
# ------------> Param:   number
# ------------------> type:  int
#
#
# ------------> Param:   stk_ptr
# ------------------> type:  **stack
#
#
# ------------> Local:  pop
# ------------------> type:  int
#
#
# ------------> Local:  ming
# ------------------> type:  unsigned int
#
#
# ------------> Local:  stk
# ------------------> type:  *stack
#
#
# ------------> Local:  tmp
# ------------------> type:  *stack
#
#
#   Found a compile unit at offset 461, length 350
# printf
# DIE DW_TAG_subprogram, size=17, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=645)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'printf', raw_value=305, offset=645)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=4, raw_value=4, offset=649)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data2', value=356, raw_value=356, offset=650)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=12, raw_value=12, offset=652)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=653)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=653)
#     |DW_AT_declaration :  AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=657)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=207, raw_value=207, offset=657)
#
# pop
# DIE DW_TAG_subprogram, size=15, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=674)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'pop', raw_value=b'pop', offset=674)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=678)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=679)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_implicit_const', value=5, raw_value=5, offset=680)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=680)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=680)
#     |DW_AT_declaration :  AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=684)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=233, raw_value=233, offset=684)
#
# add
# DIE DW_TAG_subprogram, size=15, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=705)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'add', raw_value=b'add', offset=705)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=3, raw_value=3, offset=709)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=2, raw_value=2, offset=710)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_implicit_const', value=5, raw_value=5, offset=711)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=711)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=711)
#     |DW_AT_declaration :  AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=715)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=269, raw_value=269, offset=715)
#
# push
# DIE DW_TAG_subprogram, size=12, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=731)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'push', raw_value=268, offset=731)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=735)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=5, raw_value=5, offset=736)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=6, raw_value=6, offset=737)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=738)
#     |DW_AT_declaration :  AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=738)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=292, raw_value=292, offset=738)
#
# main
# DIE DW_TAG_subprogram, size=30, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=754)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'main', raw_value=300, offset=754)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=758)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=7, raw_value=7, offset=759)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=760)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=761)
#     |DW_AT_low_pc      :  AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4713, raw_value=4713, offset=765)
#     |DW_AT_high_pc     :  AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=318, raw_value=318, offset=773)
#     |DW_AT_frame_base  :  AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=781)
#     |DW_AT_call_all_tail_calls:  AttributeValue(name='DW_AT_call_all_tail_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=783)
#
# ------------> Local:  stk
# ------------------> type:  *stack
#
#
# ------------> Local:  temp
# ------------------> type:  int
#
#
#   Found a compile unit at offset 815, length 446
# substractf
# DIE DW_TAG_subprogram, size=33, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=939)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'substractf', raw_value=317, offset=939)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=943)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=26, raw_value=26, offset=943)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=7, raw_value=7, offset=944)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=945)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=945)
#     |DW_AT_low_pc      :  AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5201, raw_value=5201, offset=949)
#     |DW_AT_high_pc     :  AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=30, raw_value=30, offset=957)
#     |DW_AT_frame_base  :  AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=965)
#     |DW_AT_call_all_calls:  AttributeValue(name='DW_AT_call_all_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=967)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=181, raw_value=181, offset=967)
#
# ------------> Param:   a
# ------------------> type:  float
#
#
# ------------> Param:   b
# ------------------> type:  float
#
#
# substract
# DIE DW_TAG_subprogram, size=33, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1004)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'substract', raw_value=334, offset=1004)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1008)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=1008)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=1009)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1010)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1010)
#     |DW_AT_low_pc      :  AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5179, raw_value=5179, offset=1014)
#     |DW_AT_high_pc     :  AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=22, raw_value=22, offset=1022)
#     |DW_AT_frame_base  :  AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=1030)
#     |DW_AT_call_all_calls:  AttributeValue(name='DW_AT_call_all_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1032)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=246, raw_value=246, offset=1032)
#
# ------------> Param:   a
# ------------------> type:  int
#
#
# ------------> Param:   b
# ------------------> type:  int
#
#
# addf
# DIE DW_TAG_subprogram, size=33, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1062)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'addf', raw_value=312, offset=1062)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1066)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=18, raw_value=18, offset=1066)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=7, raw_value=7, offset=1067)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1068)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=1068)
#     |DW_AT_low_pc      :  AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5149, raw_value=5149, offset=1072)
#     |DW_AT_high_pc     :  AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=30, raw_value=30, offset=1080)
#     |DW_AT_frame_base  :  AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=1088)
#     |DW_AT_call_all_calls:  AttributeValue(name='DW_AT_call_all_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1090)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=304, raw_value=304, offset=1090)
#
# ------------> Param:   a
# ------------------> type:  float
#
#
# ------------> Param:   b
# ------------------> type:  float
#
#
# add
# DIE DW_TAG_subprogram, size=30, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1120)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'add', raw_value=b'add', offset=1120)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=1124)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=5, raw_value=5, offset=1125)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=1126)
#     |DW_AT_prototyped  :  AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1127)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1127)
#     |DW_AT_low_pc      :  AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5031, raw_value=5031, offset=1131)
#     |DW_AT_high_pc     :  AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=118, raw_value=118, offset=1139)
#     |DW_AT_frame_base  :  AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=1147)
#     |DW_AT_call_all_calls:  AttributeValue(name='DW_AT_call_all_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1149)
#
# ------------> Param:   a
# ------------------> type:  int
#
#
# ------------> Param:   b
# ------------------> type:  int
#
#
# ------------> Local:  ran
# ------------------> type:  int
#
#
# ------------> Local:  fran
# ------------------> type:  float
#
#
# ------------> Local:  i
# ------------------> type:  int
#
#
# ------------> Local:  fran
# ------------------> type:  int

# %%
FUNC_PARAMS
# Out:
# {'stack.c_0': {'free': {},
#   'malloc': {},
#   'pop': {'stk_ptr': {'type': '**stack', 'kind': 'parameter'},
#    'pop': {'type': 'int', 'kind': 'parameter'},
#    'number': {'type': 'int', 'kind': 'parameter'},
#    'stk': {'type': '*stack', 'kind': 'parameter'},
#    'tmp': {'type': '*stack', 'kind': 'parameter'}},
#   'push': {'number': {'type': 'int', 'kind': 'parameter'},
#    'stk_ptr': {'type': '**stack', 'kind': 'parameter'},
#    'pop': {'type': 'int', 'kind': 'parameter'},
#    'ming': {'type': 'unsigned int', 'kind': 'parameter'},
#    'stk': {'type': '*stack', 'kind': 'parameter'},
#    'tmp': {'type': '*stack', 'kind': 'parameter'}}},
#  'main.c_461': {'printf': {},
#   'pop': {},
#   'add': {},
#   'push': {},
#   'main': {'stk': {'type': '*stack', 'kind': 'parameter'},
#    'temp': {'type': 'int', 'kind': 'parameter'}}},
#  'calculate.c_815': {'substractf': {'a': {'type': 'float',
#     'kind': 'parameter'},
#    'b': {'type': 'float', 'kind': 'parameter'}},
#   'substract': {'a': {'type': 'int', 'kind': 'parameter'},
#    'b': {'type': 'int', 'kind': 'parameter'}},
#   'addf': {'a': {'type': 'float', 'kind': 'parameter'},
#    'b': {'type': 'float', 'kind': 'parameter'}},
#   'add': {'a': {'type': 'int', 'kind': 'parameter'},
#    'b': {'type': 'int', 'kind': 'parameter'},
#    'ran': {'type': 'int', 'kind': 'parameter'},
#    'fran': {'type': 'int', 'kind': 'parameter'},
#    'i': {'type': 'int', 'kind': 'parameter'}}}}
