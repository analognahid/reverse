# %%
# -------------------------------------------------------------------------------
# elftools example: dwarf_location_info.py
#
# Examine DIE entries which have either location list values or location
# expression values and decode that information.
#
# Location information can either be completely contained within a DIE
# (using 'DW_FORM_exprloc' in DWARFv4 or 'DW_FORM_block1' in earlier
# versions) or be a reference to a location list contained within
# the .debug_loc section (using 'DW_FORM_sec_offset' in DWARFv4 or
# 'DW_FORM_data4' / 'DW_FORM_data8' in earlier versions).
#
# The LocationParser object parses the DIE attributes and handles both
# formats.
#
# The directory 'test/testfiles_for_location_info' contains test files with
# location information represented in both DWARFv4 and DWARFv2 forms.
#
# Eli Bendersky (eliben@gmail.com)
# This code is in the public domain
#-------------------------------------------------------------------------------
from __future__ import print_function
import sys

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.
sys.path[0:0] = ['.', '..']

from elftools.elf.elffile import ELFFile
from elftools.dwarf.descriptions import (
    describe_DWARF_expr, set_global_machine_arch)
from elftools.dwarf.locationlists import (
    LocationEntry, LocationExpr, LocationParser)



def show_loclist(loclist, dwarfinfo, indent, cu_offset):
    """ Display a location list nicely, decoding the DWARF expressions
        contained within.
    """
    d = []
    for loc_entity in loclist:
        if isinstance(loc_entity, LocationEntry):
            d.append('%s <<%s>>' % (
                loc_entity,
                describe_DWARF_expr(loc_entity.loc_expr, dwarfinfo.structs, cu_offset)))
        else:
            d.append(str(loc_entity))
    return '\n'.join(indent + s for s in d)

# %%
def get_DIE_at_offset(CU, offset):
#         print('****'*5,CU.cu_offset)
        for die in CU.iter_DIEs():
            if die.offset == CU.cu_offset+offset:
                return die 
        return None

def get_type_name(CU, offset):#get_DIE_at_offset(CU,attr.value)
    die = get_DIE_at_offset(CU, offset)
    for attr in die.attributes.values():
        if attr.name== "DW_AT_name":
            return attr.value.decode("utf-8")

# %%
FUNC_PARAMS = {}


def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        # get_dwarf_info returns a DWARFInfo context object, which is the
        # starting point for all DWARF-based processing in pyelftools.
        dwarfinfo = elffile.get_dwarf_info()

        # The location lists are extracted by DWARFInfo from the .debug_loc
        # section, and returned here as a LocationLists object.
        location_lists = dwarfinfo.location_lists()

        # This is required for the descriptions module to correctly decode
        # register names contained in DWARF expressions.
        set_global_machine_arch(elffile.get_machine_arch())

        # Create a LocationParser object that parses the DIE attributes and
        # creates objects representing the actual location information.
        loc_parser = LocationParser(location_lists)
        
        section_offset = dwarfinfo.debug_info_sec.global_offset
        # Offset of the .debug_info section in the stream
        
        
        for CU in dwarfinfo.iter_CUs():
            # DWARFInfo allows to iterate over the compile units contained in
            # the .debug_info section. CU is a CompileUnit object, with some
            # computed attributes (such as its offset in the section) and
            # a header which conforms to the DWARF standard. The access to
            # header elements is, as usual, via item-lookup.
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # A CU provides a simple API to iterate over all the DIEs in it.
            die_depth = 0
            are_DIEs_of_function = False
            FUNC_name = ''
            for DIE in CU.iter_DIEs():
                # Go over all attributes of the DIE. Each attribute is an
                # AttributeValue object (from elftools.dwarf.die), which we
                # can examine.
                
                
                ###############################################
                #############   Prasing Function DIEs start ################
                if DIE.tag == 'DW_TAG_subprogram':
                    are_DIEs_of_function = True


                    for attr in DIE.attributes.values():
                        if attr.name == "DW_AT_name": #FUNC NAME
                            FUNC_name = attr.value.decode("utf-8")
                            print(FUNC_name)
                if DIE.tag == 'DW_TAG_formal_parameter':
                    print("\n\n")
                    print(DIE.attributes)
                    for attr in DIE.attributes.values():
                        if attr.name == "DW_AT_name": # VAR NAME 
                            PARAM_name = attr.value.decode("utf-8")
                            print('------------> ',PARAM_name)
#                         else:
#                             print(">>>>>>>>>>"*5,DIE , "<<<<<<<<<<<<<<<<<<"*5)
                            
                        if attr.name == "DW_AT_type":
                            print('\t\t\t',get_DIE_at_offset(CU,attr.value),'\n\n')
#                     for attr in DIE.attributes.values():
#                         print('\t\t',attr )
                    
                ###############################################
                #############  parsing  Function DIEs ends ################
                

#                 print(DIE.tag)
#                 for attr in DIE.attributes.values():
#                     print('\t\t',attr )
#                 print('\n\n\n')
                
                if DIE.is_null(): #https://chromium.googlesource.com/chromiumos/third_party/pyelftools/+/25a77f7738d7fe824f2ed4d33a123136b9d8e88a/scripts/readelf.py
                    are_DIEs_of_function = False
                    FUNC_name = None
                    
                    die_depth -= 1
                    continue
                if DIE.has_children:
                    die_depth += 1
                    
#             break



filename = './../../binaries/c_many/stacktest'
process_file(filename)
# Out:
# Processing file: ./../../binaries/c_many/stacktest
#   Found a compile unit at offset 0, length 416
# free
#
#
#
# OrderedDict([('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=72, raw_value=72, offset=206))])
# 			 DIE DW_TAG_pointer_type, size=2, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=73)
#
#
#
# malloc
#
#
#
# OrderedDict([('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=46, raw_value=46, offset=229))])
# 			 DIE DW_TAG_typedef, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'size_t', raw_value=14, offset=47)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=3, raw_value=3, offset=51)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=209, raw_value=209, offset=52)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=23, raw_value=23, offset=53)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=58, raw_value=58, offset=54)
#
#
#
# pop
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'stk_ptr', raw_value=78, offset=269)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=273)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=16, raw_value=16, offset=273)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=17, raw_value=17, offset=274)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=326, raw_value=326, offset=275)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 72], raw_value=[145, 72], offset=279))])
# ------------>  stk_ptr
# 			 DIE DW_TAG_pointer_type, size=5, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=327)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=331, raw_value=331, offset=327)
#
#
#
# push
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'number', raw_value=71, offset=363)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=367)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=367)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=15, raw_value=15, offset=368)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=102, raw_value=102, offset=369)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 92], raw_value=[145, 92], offset=373))])
# ------------>  number
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=103)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=104)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=105)
#
#
#
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'stk_ptr', raw_value=78, offset=377)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=381)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=381)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=31, raw_value=31, offset=382)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=326, raw_value=326, offset=383)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 80], raw_value=[145, 80], offset=387))])
# ------------>  stk_ptr
# 			 DIE DW_TAG_pointer_type, size=5, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=327)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=331, raw_value=331, offset=327)
#
#
#
#   Found a compile unit at offset 420, length 350
# printf
#
#
#
# OrderedDict([('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=207, raw_value=207, offset=621))])
# 			 DIE DW_TAG_pointer_type, size=5, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=628)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=109, raw_value=109, offset=628)
#
#
#
# pop
#
#
#
# OrderedDict([('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=233, raw_value=233, offset=648))])
# 			 DIE DW_TAG_pointer_type, size=5, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=654)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=238, raw_value=238, offset=654)
#
#
#
# add
#
#
#
# OrderedDict([('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=679))])
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=509)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=510)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=511)
#
#
#
#
#
#
# OrderedDict([('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=684))])
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=509)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=510)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=511)
#
#
#
# push
#
#
#
# OrderedDict([('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=702))])
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=509)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=510)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=511)
#
#
#
#
#
#
# OrderedDict([('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=233, raw_value=233, offset=707))])
# 			 DIE DW_TAG_pointer_type, size=5, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=654)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=238, raw_value=238, offset=654)
#
#
#
# main
#   Found a compile unit at offset 774, length 446
# substractf
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'a', raw_value=b'a', offset=931)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=933)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=26, raw_value=26, offset=933)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=24, raw_value=24, offset=934)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=935)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 108], raw_value=[145, 108], offset=939))])
# ------------>  a
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=956)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=4, raw_value=4, offset=957)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'float', raw_value=323, offset=958)
#
#
#
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'b', raw_value=b'b', offset=943)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=945)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=26, raw_value=26, offset=945)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=33, raw_value=33, offset=946)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=947)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 104], raw_value=[145, 104], offset=951))])
# ------------>  b
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=956)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=4, raw_value=4, offset=957)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'float', raw_value=323, offset=958)
#
#
#
# substract
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'a', raw_value=b'a', offset=996)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=998)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=998)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=19, raw_value=19, offset=999)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1000)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 108], raw_value=[145, 108], offset=1004))])
# ------------>  a
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=863)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=864)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=865)
#
#
#
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'b', raw_value=b'b', offset=1008)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1010)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=1010)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=26, raw_value=26, offset=1011)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1012)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 104], raw_value=[145, 104], offset=1016))])
# ------------>  b
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=863)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=864)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=865)
#
#
#
# addf
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'a', raw_value=b'a', offset=1054)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1056)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=18, raw_value=18, offset=1056)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=18, raw_value=18, offset=1057)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=1058)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 108], raw_value=[145, 108], offset=1062))])
# ------------>  a
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=956)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=4, raw_value=4, offset=957)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'float', raw_value=323, offset=958)
#
#
#
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'b', raw_value=b'b', offset=1066)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1068)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=18, raw_value=18, offset=1068)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=27, raw_value=27, offset=1069)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=1070)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 104], raw_value=[145, 104], offset=1074))])
# ------------>  b
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=956)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=4, raw_value=4, offset=957)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'float', raw_value=323, offset=958)
#
#
#
# add
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'a', raw_value=b'a', offset=1109)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1111)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=5, raw_value=5, offset=1111)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=13, raw_value=13, offset=1112)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1113)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 92], raw_value=[145, 92], offset=1117))])
# ------------>  a
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=863)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=864)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=865)
#
#
#
#
#
#
# OrderedDict([('DW_AT_name', AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'b', raw_value=b'b', offset=1121)), ('DW_AT_decl_file', AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1123)), ('DW_AT_decl_line', AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=5, raw_value=5, offset=1123)), ('DW_AT_decl_column', AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=20, raw_value=20, offset=1124)), ('DW_AT_type', AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1125)), ('DW_AT_location', AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 88], raw_value=[145, 88], offset=1129))])
# ------------>  b
# 			 DIE DW_TAG_base_type, size=7, has_children=False
#     |DW_AT_byte_size   :  AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=863)
#     |DW_AT_encoding    :  AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=864)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=865)

# %%
# from elftools.dwarf.descriptions import describe_attr_value, describe_form_class
