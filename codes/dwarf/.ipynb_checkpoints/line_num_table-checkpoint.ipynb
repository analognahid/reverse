# %%
#!/usr/bin/env python3

import sys,os
from elftools.elf.elffile import ELFFile
from elftools.elf.segments import Segment



filePath = '/home/nahid/reverse/binaries/c_many/stacktest'



with open(filePath, 'rb') as f:
    elffile =  ELFFile(f)
    
    for segment in elffile.iter_segments():
        if segment.header.p_filesz != segment.header.p_memsz:
            seg_head = segment.header
            print(f"Type: {seg_head.p_type}\nOffset: {hex(seg_head.p_offset)}\nSize in file:{hex(seg_head.p_filesz)}\nSize in memory:{hex(seg_head.p_memsz)}")
            
    dwarfinfo = elffile.get_dwarf_info()
    for CU in dwarfinfo.iter_CUs():
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))
        

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        # line_program = dwarfinfo.line_program_for_CU(CU)
        # if line_program is None:
        #     print('  DWARF info is missing a line program for this CU')
        #     continue
# Out:
# Type: PT_LOAD
# Offset: 0x2da0
# Size in file:0x270
# Size in memory:0x278
#   Found a compile unit at offset 0, length 416
#   Found a compile unit at offset 420, length 350
#   Found a compile unit at offset 774, length 356

# %%
def _format_hex( addr, fieldsize=None, fullhex=False, lead0x=True):
    """ Format an address into a hexadecimal string.
        fieldsize:
            Size of the hexadecimal field (with leading zeros to fit the
            address into. For example with fieldsize=8, the format will
            be %08x
            If None, the minimal required field size will be used.
        fullhex:
            If True, override fieldsize to set it to the maximal size
            needed for the elfclass
        lead0x:
            If True, leading 0x is added
    """
    s = '0x' if lead0x else ''
    if fullhex:
        fieldsize = 8 if elffile.elfclass == 32 else 16
    if fieldsize is None:
        field = '%x'
    else:
        field = '%' + '0%sx' % fieldsize
    return s + field % addr

from elftools.elf.descriptions import (
    describe_ei_class, describe_ei_data, describe_ei_version,
    describe_ei_osabi, describe_e_type, describe_e_machine,
    describe_e_version_numeric, describe_p_type, describe_p_flags,
    describe_sh_type, describe_sh_flags,
    describe_symbol_type, describe_symbol_bind, describe_symbol_visibility,
    describe_symbol_shndx, describe_reloc_type, describe_dyn_tag,
    )

# %%
with open(filePath, 'rb') as f:
    elffile =  ELFFile(f)
    for nsec, section in enumerate(elffile.iter_sections()):
                print('  [%2u] %-17.17s %-15.15s ' % (
                    nsec, (section.name), describe_sh_type(section['sh_type'])))

                # if elffile.elfclass == 32:
                #     print('%s %s %s %s %3s %2s %3s %2s' % (
                #         _format_hex(section['sh_addr'], fieldsize=8, lead0x=False),
                #         _format_hex(section['sh_offset'], fieldsize=6, lead0x=False),
                #         _format_hex(section['sh_size'], fieldsize=6, lead0x=False),
                #         _format_hex(section['sh_entsize'], fieldsize=2, lead0x=False),
                #         describe_sh_flags(section['sh_flags']),
                #         section['sh_link'], section['sh_info'],
                #         section['sh_addralign']))
                # else: # 64
                print(' sh_addr: %s  sh_offset: %s' % (
                    _format_hex(section['sh_addr'], fullhex=True, lead0x=False),
                    _format_hex(section['sh_offset'],
                        fieldsize=16 if section['sh_offset'] > 0xffffffff else 8,
                        lead0x=False)))
                print('       sh_size: %s  sh_entsize: %s sh_flags:%3s      sh_link:%2s   sh_info:%3s     sh_addralign:%s' % (
                    _format_hex(section['sh_size'], fullhex=True, lead0x=False),
                    _format_hex(section['sh_entsize'], fullhex=True, lead0x=False),
                    describe_sh_flags(section['sh_flags']),
                    section['sh_link'], section['sh_info'],
                    section['sh_addralign']))
# Out:
#   [ 0]                   NULL
#  sh_addr: 0000000000000000  sh_offset: 00000000
#        sh_size: 0000000000000000  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:0
#   [ 1] .interp           PROGBITS
#  sh_addr: 0000000000000318  sh_offset: 00000318
#        sh_size: 000000000000001c  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:1
#   [ 2] .note.gnu.propert NOTE
#  sh_addr: 0000000000000338  sh_offset: 00000338
#        sh_size: 0000000000000030  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:8
#   [ 3] .note.gnu.build-i NOTE
#  sh_addr: 0000000000000368  sh_offset: 00000368
#        sh_size: 0000000000000024  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:4
#   [ 4] .note.ABI-tag     NOTE
#  sh_addr: 000000000000038c  sh_offset: 0000038c
#        sh_size: 0000000000000020  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:4
#   [ 5] .gnu.hash         GNU_HASH
#  sh_addr: 00000000000003b0  sh_offset: 000003b0
#        sh_size: 0000000000000024  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 6   sh_info:  0     sh_addralign:8
#   [ 6] .dynsym           DYNSYM
#  sh_addr: 00000000000003d8  sh_offset: 000003d8
#        sh_size: 00000000000000f0  sh_entsize: 0000000000000018 sh_flags:  A      sh_link: 7   sh_info:  1     sh_addralign:8
#   [ 7] .dynstr           STRTAB
#  sh_addr: 00000000000004c8  sh_offset: 000004c8
#        sh_size: 00000000000000b6  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:1
#   [ 8] .gnu.version      VERSYM
#  sh_addr: 000000000000057e  sh_offset: 0000057e
#        sh_size: 0000000000000014  sh_entsize: 0000000000000002 sh_flags:  A      sh_link: 6   sh_info:  0     sh_addralign:2
#   [ 9] .gnu.version_r    VERNEED
#  sh_addr: 0000000000000598  sh_offset: 00000598
#        sh_size: 0000000000000040  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 7   sh_info:  1     sh_addralign:8
#   [10] .rela.dyn         RELA
#  sh_addr: 00000000000005d8  sh_offset: 000005d8
#        sh_size: 00000000000000c0  sh_entsize: 0000000000000018 sh_flags:  A      sh_link: 6   sh_info:  0     sh_addralign:8
#   [11] .rela.plt         RELA
#  sh_addr: 0000000000000698  sh_offset: 00000698
#        sh_size: 0000000000000060  sh_entsize: 0000000000000018 sh_flags: AI      sh_link: 6   sh_info: 24     sh_addralign:8
#   [12] .init             PROGBITS
#  sh_addr: 0000000000001000  sh_offset: 00001000
#        sh_size: 000000000000001b  sh_entsize: 0000000000000000 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:4
#   [13] .plt              PROGBITS
#  sh_addr: 0000000000001020  sh_offset: 00001020
#        sh_size: 0000000000000050  sh_entsize: 0000000000000010 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:16
#   [14] .plt.got          PROGBITS
#  sh_addr: 0000000000001070  sh_offset: 00001070
#        sh_size: 0000000000000010  sh_entsize: 0000000000000010 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:16
#   [15] .plt.sec          PROGBITS
#  sh_addr: 0000000000001080  sh_offset: 00001080
#        sh_size: 0000000000000040  sh_entsize: 0000000000000010 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:16
#   [16] .text             PROGBITS
#  sh_addr: 00000000000010c0  sh_offset: 000010c0
#        sh_size: 000000000000033c  sh_entsize: 0000000000000000 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:16
#   [17] .fini             PROGBITS
#  sh_addr: 00000000000013fc  sh_offset: 000013fc
#        sh_size: 000000000000000d  sh_entsize: 0000000000000000 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:4
#   [18] .rodata           PROGBITS
#  sh_addr: 0000000000002000  sh_offset: 00002000
#        sh_size: 0000000000000008  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:4
#   [19] .eh_frame_hdr     PROGBITS
#  sh_addr: 0000000000002008  sh_offset: 00002008
#        sh_size: 0000000000000064  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:4
#   [20] .eh_frame         PROGBITS
#  sh_addr: 0000000000002070  sh_offset: 00002070
#        sh_size: 000000000000016c  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:8
#   [21] .init_array       INIT_ARRAY
#  sh_addr: 0000000000003da0  sh_offset: 00002da0
#        sh_size: 0000000000000008  sh_entsize: 0000000000000008 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:8
#   [22] .fini_array       FINI_ARRAY
#  sh_addr: 0000000000003da8  sh_offset: 00002da8
#        sh_size: 0000000000000008  sh_entsize: 0000000000000008 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:8
#   [23] .dynamic          DYNAMIC
#  sh_addr: 0000000000003db0  sh_offset: 00002db0
#        sh_size: 00000000000001f0  sh_entsize: 0000000000000010 sh_flags: WA      sh_link: 7   sh_info:  0     sh_addralign:8
#   [24] .got              PROGBITS
#  sh_addr: 0000000000003fa0  sh_offset: 00002fa0
#        sh_size: 0000000000000060  sh_entsize: 0000000000000008 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:8
#   [25] .data             PROGBITS
#  sh_addr: 0000000000004000  sh_offset: 00003000
#        sh_size: 0000000000000010  sh_entsize: 0000000000000000 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:8
#   [26] .bss              NOBITS
#  sh_addr: 0000000000004010  sh_offset: 00003010
#        sh_size: 0000000000000008  sh_entsize: 0000000000000000 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:1
#   [27] .comment          PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003010
#        sh_size: 000000000000002b  sh_entsize: 0000000000000001 sh_flags: MS      sh_link: 0   sh_info:  0     sh_addralign:1
#   [28] .debug_aranges    PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 0000303b
#        sh_size: 0000000000000090  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [29] .debug_pubnames   PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 000030cb
#        sh_size: 00000000000000b6  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [30] .debug_info       PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003181
#        sh_size: 000000000000046e  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [31] .debug_abbrev     PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 000035ef
#        sh_size: 0000000000000281  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [32] .debug_line       PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003870
#        sh_size: 000000000000017e  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [33] .debug_str        PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 000039ee
#        sh_size: 0000000000000153  sh_entsize: 0000000000000001 sh_flags: MS      sh_link: 0   sh_info:  0     sh_addralign:1
#   [34] .debug_pubtypes   PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003b41
#        sh_size: 00000000000002a2  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [35] .debug_line_str   PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003de3
#        sh_size: 00000000000000a3  sh_entsize: 0000000000000001 sh_flags: MS      sh_link: 0   sh_info:  0     sh_addralign:1
#   [36] .symtab           SYMTAB
#  sh_addr: 0000000000000000  sh_offset: 00003e88
#        sh_size: 0000000000000468  sh_entsize: 0000000000000018 sh_flags:         sh_link:37   sh_info: 20     sh_addralign:8
#   [37] .strtab           STRTAB
#  sh_addr: 0000000000000000  sh_offset: 000042f0
#        sh_size: 0000000000000256  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [38] .shstrtab         STRTAB
#  sh_addr: 0000000000000000  sh_offset: 00004546
#        sh_size: 000000000000018a  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1

# %%
from capstone import *

address_inst = {}
with open(filePath, 'rb') as f:
    elf = ELFFile(f)
    code = elf.get_section_by_name('.text')
    ops = code.data()
    print('code data size: ',code.data_size)
    addr = code['sh_addr']
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    for i in md.disasm(ops, addr):        
        print(f'0x{i.address:x}:\t{i.mnemonic}\t{i.op_str}')
        address_inst[hex(i.address)] = i
# Out:
# code data size:  828
# 0x10c0:	endbr64
# 0x10c4:	xor	ebp, ebp
# 0x10c6:	mov	r9, rdx
# 0x10c9:	pop	rsi
# 0x10ca:	mov	rdx, rsp
# 0x10cd:	and	rsp, 0xfffffffffffffff0
# 0x10d1:	push	rax
# 0x10d2:	push	rsp
# 0x10d3:	xor	r8d, r8d
# 0x10d6:	xor	ecx, ecx
# 0x10d8:	lea	rdi, [rip + 0x175]
# 0x10df:	call	qword ptr [rip + 0x2ef3]
# 0x10e5:	hlt
# 0x10e6:	nop	word ptr cs:[rax + rax]
# 0x10f0:	lea	rdi, [rip + 0x2f19]
# 0x10f7:	lea	rax, [rip + 0x2f12]
# 0x10fe:	cmp	rax, rdi
# 0x1101:	je	0x1118
# 0x1103:	mov	rax, qword ptr [rip + 0x2ed6]
# 0x110a:	test	rax, rax
# 0x110d:	je	0x1118
# 0x110f:	jmp	rax
# 0x1111:	nop	dword ptr [rax]
# 0x1118:	ret
# 0x1119:	nop	dword ptr [rax]
# 0x1120:	lea	rdi, [rip + 0x2ee9]
# 0x1127:	lea	rsi, [rip + 0x2ee2]
# 0x112e:	sub	rsi, rdi
# 0x1131:	mov	rax, rsi
# 0x1134:	shr	rsi, 0x3f
# 0x1138:	sar	rax, 3
# 0x113c:	add	rsi, rax
# 0x113f:	sar	rsi, 1
# 0x1142:	je	0x1158
# 0x1144:	mov	rax, qword ptr [rip + 0x2ea5]
# 0x114b:	test	rax, rax
# 0x114e:	je	0x1158
# 0x1150:	jmp	rax
# 0x1152:	nop	word ptr [rax + rax]
# 0x1158:	ret
# 0x1159:	nop	dword ptr [rax]
# 0x1160:	endbr64
# 0x1164:	cmp	byte ptr [rip + 0x2ea5], 0
# 0x116b:	jne	0x1198
# 0x116d:	push	rbp
# 0x116e:	cmp	qword ptr [rip + 0x2e82], 0
# 0x1176:	mov	rbp, rsp
# 0x1179:	je	0x1187
# 0x117b:	mov	rdi, qword ptr [rip + 0x2e86]
# 0x1182:	call	0x1070
# 0x1187:	call	0x10f0
# 0x118c:	mov	byte ptr [rip + 0x2e7d], 1
# 0x1193:	pop	rbp
# 0x1194:	ret
# 0x1195:	nop	dword ptr [rax]
# 0x1198:	ret
# 0x1199:	nop	dword ptr [rax]
# 0x11a0:	endbr64
# 0x11a4:	jmp	0x1120
# 0x11a9:	endbr64
# 0x11ad:	push	rbp
# 0x11ae:	mov	rbp, rsp
# 0x11b1:	sub	rsp, 0x20
# 0x11b5:	mov	dword ptr [rbp - 0x14], edi
# 0x11b8:	mov	qword ptr [rbp - 0x20], rsi
# 0x11bc:	mov	rax, qword ptr [rbp - 0x20]
# 0x11c0:	mov	rax, qword ptr [rax]
# 0x11c3:	mov	qword ptr [rbp - 0x10], rax
# 0x11c7:	mov	edi, 0x10
# 0x11cc:	call	0x10b0
# 0x11d1:	mov	qword ptr [rbp - 8], rax
# 0x11d5:	mov	rax, qword ptr [rbp - 8]
# 0x11d9:	mov	edx, dword ptr [rbp - 0x14]
# 0x11dc:	mov	dword ptr [rax], edx
# 0x11de:	mov	rax, qword ptr [rbp - 8]
# 0x11e2:	mov	rdx, qword ptr [rbp - 0x10]
# 0x11e6:	mov	qword ptr [rax + 8], rdx
# 0x11ea:	mov	rax, qword ptr [rbp - 8]
# 0x11ee:	mov	qword ptr [rbp - 0x10], rax
# 0x11f2:	mov	rax, qword ptr [rbp - 0x20]
# 0x11f6:	mov	rdx, qword ptr [rbp - 0x10]
# 0x11fa:	mov	qword ptr [rax], rdx
# 0x11fd:	nop
# 0x11fe:	leave
# 0x11ff:	ret
# 0x1200:	endbr64
# 0x1204:	push	rbp
# 0x1205:	mov	rbp, rsp
# 0x1208:	sub	rsp, 0x30
# 0x120c:	mov	qword ptr [rbp - 0x28], rdi
# 0x1210:	mov	rax, qword ptr [rbp - 0x28]
# 0x1214:	mov	rax, qword ptr [rax]
# 0x1217:	mov	qword ptr [rbp - 0x10], rax
# 0x121b:	mov	rax, qword ptr [rbp - 0x10]
# 0x121f:	mov	qword ptr [rbp - 8], rax
# 0x1223:	mov	rax, qword ptr [rbp - 8]
# 0x1227:	mov	eax, dword ptr [rax]
# 0x1229:	mov	dword ptr [rbp - 0x14], eax
# 0x122c:	mov	rax, qword ptr [rbp - 0x10]
# 0x1230:	mov	rax, qword ptr [rax + 8]
# 0x1234:	mov	qword ptr [rbp - 0x10], rax
# 0x1238:	mov	rax, qword ptr [rbp - 8]
# 0x123c:	mov	rdi, rax
# 0x123f:	call	0x1080
# 0x1244:	mov	rax, qword ptr [rbp - 0x28]
# 0x1248:	mov	rdx, qword ptr [rbp - 0x10]
# 0x124c:	mov	qword ptr [rax], rdx
# 0x124f:	mov	eax, dword ptr [rbp - 0x14]
# 0x1252:	leave
# 0x1253:	ret
# 0x1254:	endbr64
# 0x1258:	push	rbp
# 0x1259:	mov	rbp, rsp
# 0x125c:	sub	rsp, 0x20
# 0x1260:	mov	rax, qword ptr fs:[0x28]
# 0x1269:	mov	qword ptr [rbp - 8], rax
# 0x126d:	xor	eax, eax
# 0x126f:	mov	qword ptr [rbp - 0x10], 0
# 0x1277:	lea	rax, [rbp - 0x10]
# 0x127b:	mov	rsi, rax
# 0x127e:	mov	edi, 7
# 0x1283:	call	0x11a9
# 0x1288:	mov	esi, 2
# 0x128d:	mov	edi, 1
# 0x1292:	call	0x1392
# 0x1297:	mov	dword ptr [rbp - 0x14], eax
# 0x129a:	lea	rdx, [rbp - 0x10]
# 0x129e:	mov	eax, dword ptr [rbp - 0x14]
# 0x12a1:	mov	rsi, rdx
# 0x12a4:	mov	edi, eax
# 0x12a6:	call	0x11a9
# 0x12ab:	lea	rax, [rbp - 0x10]
# 0x12af:	mov	rsi, rax
# 0x12b2:	mov	edi, 9
# 0x12b7:	call	0x11a9
# 0x12bc:	lea	rax, [rbp - 0x10]
# 0x12c0:	mov	rsi, rax
# 0x12c3:	mov	edi, 0xc
# 0x12c8:	call	0x11a9
# 0x12cd:	lea	rax, [rbp - 0x10]
# 0x12d1:	mov	rdi, rax
# 0x12d4:	call	0x1200
# 0x12d9:	mov	esi, eax
# 0x12db:	lea	rax, [rip + 0xd22]
# 0x12e2:	mov	rdi, rax
# 0x12e5:	mov	eax, 0
# 0x12ea:	call	0x10a0
# 0x12ef:	lea	rax, [rbp - 0x10]
# 0x12f3:	mov	rdi, rax
# 0x12f6:	call	0x1200
# 0x12fb:	mov	esi, eax
# 0x12fd:	lea	rax, [rip + 0xd00]
# 0x1304:	mov	rdi, rax
# 0x1307:	mov	eax, 0
# 0x130c:	call	0x10a0
# 0x1311:	lea	rax, [rbp - 0x10]
# 0x1315:	mov	rdi, rax
# 0x1318:	call	0x1200
# 0x131d:	mov	esi, eax
# 0x131f:	lea	rax, [rip + 0xcde]
# 0x1326:	mov	rdi, rax
# 0x1329:	mov	eax, 0
# 0x132e:	call	0x10a0
# 0x1333:	lea	rax, [rbp - 0x10]
# 0x1337:	mov	rdi, rax
# 0x133a:	call	0x1200
# 0x133f:	mov	esi, eax
# 0x1341:	lea	rax, [rip + 0xcbc]
# 0x1348:	mov	rdi, rax
# 0x134b:	mov	eax, 0
# 0x1350:	call	0x10a0
# 0x1355:	lea	rax, [rbp - 0x10]
# 0x1359:	mov	rdi, rax
# 0x135c:	call	0x1200
# 0x1361:	mov	esi, eax
# 0x1363:	lea	rax, [rip + 0xc9a]
# 0x136a:	mov	rdi, rax
# 0x136d:	mov	eax, 0
# 0x1372:	call	0x10a0
# 0x1377:	mov	eax, 0
# 0x137c:	mov	rdx, qword ptr [rbp - 8]
# 0x1380:	sub	rdx, qword ptr fs:[0x28]
# 0x1389:	je	0x1390
# 0x138b:	call	0x1090
# 0x1390:	leave
# 0x1391:	ret
# 0x1392:	endbr64
# 0x1396:	push	rbp
# 0x1397:	mov	rbp, rsp
# 0x139a:	mov	dword ptr [rbp - 4], edi
# 0x139d:	mov	dword ptr [rbp - 8], esi
# 0x13a0:	mov	edx, dword ptr [rbp - 4]
# 0x13a3:	mov	eax, dword ptr [rbp - 8]
# 0x13a6:	add	eax, edx
# 0x13a8:	pop	rbp
# 0x13a9:	ret
# 0x13aa:	endbr64
# 0x13ae:	push	rbp
# 0x13af:	mov	rbp, rsp
# 0x13b2:	movss	dword ptr [rbp - 4], xmm0
# 0x13b7:	movss	dword ptr [rbp - 8], xmm1
# 0x13bc:	movss	xmm0, dword ptr [rbp - 4]
# 0x13c1:	addss	xmm0, dword ptr [rbp - 8]
# 0x13c6:	pop	rbp
# 0x13c7:	ret
# 0x13c8:	endbr64
# 0x13cc:	push	rbp
# 0x13cd:	mov	rbp, rsp
# 0x13d0:	mov	dword ptr [rbp - 4], edi
# 0x13d3:	mov	dword ptr [rbp - 8], esi
# 0x13d6:	mov	eax, dword ptr [rbp - 4]
# 0x13d9:	sub	eax, dword ptr [rbp - 8]
# 0x13dc:	pop	rbp
# 0x13dd:	ret
# 0x13de:	endbr64
# 0x13e2:	push	rbp
# 0x13e3:	mov	rbp, rsp
# 0x13e6:	movss	dword ptr [rbp - 4], xmm0
# 0x13eb:	movss	dword ptr [rbp - 8], xmm1
# 0x13f0:	movss	xmm0, dword ptr [rbp - 4]
# 0x13f5:	subss	xmm0, dword ptr [rbp - 8]
# 0x13fa:	pop	rbp
# 0x13fb:	ret

# %%
# address_inst

# %%
#-------------------------------------------------------------------------------
# elftools example: dwarf_lineprogram_filenames.py
#
# In the .debug_line section, the Dwarf line program generates a matrix
# of address-source references. This example demonstrates accessing the state
# of each line program entry to retrieve the underlying filenames.
#
# William Woodruff (william@yossarian.net)
# This code is in the public domain
#-------------------------------------------------------------------------------
from __future__ import print_function
from collections import defaultdict
import os
import sys
import posixpath

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.
# sys.path[0:0] = ['.', '..']

from elftools.elf.elffile import ELFFile






def line_entry_mapping(line_program):
    filename_map = defaultdict(int)

    # The line program, when decoded, returns a list of line program
    # entries. Each entry contains a state, which we'll use to build
    # a reverse mapping of filename -> #entries.
    lp_entries = line_program.get_entries()
    for lpe in lp_entries:
        # We skip LPEs that don't have an associated file.
        # This can happen if instructions in the compiled binary
        # don't correspond directly to any original source file.
        if not lpe.state or lpe.state.file == 0:
            continue
        filename = lpe_filename(line_program, lpe.state.file)
        filename_map[filename] += 1

    for filename, lpe_count in filename_map.items():
        print("    filename=%s -> %d entries" % (filename, lpe_count))
    return filename_map

def lpe_filename(line_program, file_index):

    lp_header = line_program.header
    file_entries = lp_header["file_entry"]
    
    # print('lp_header', lp_header, '\n\n')
    # print("file_entries", file_entries,'\n\n__________________________________________\n\n')

    # File and directory indices are 1-indexed.
    file_entry = file_entries[file_index - 1]
    dir_index = file_entry["dir_index"]

    # A dir_index of 0 indicates that no absolute directory was recorded during
    # compilation; return just the basename.
    if dir_index == 0:
        return file_entry.name.decode()

    directory = lp_header["include_directory"][dir_index - 1]
    return posixpath.join(directory, file_entry.name).decode()



addr_lineProgram ={}
addr_sourceFile = {}
with open(filePath, 'rb') as f:
    elffile = ELFFile(f)

    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
        exit(0)

    dwarfinfo = elffile.get_dwarf_info()
    for CU in dwarfinfo.iter_CUs():
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        line_program = dwarfinfo.line_program_for_CU(CU)
        if line_program is None:
            print('  DWARF info is missing a line program for this CU')
            continue

        # Print a reverse mapping of filename -> #entries
        filename_map = line_entry_mapping(line_program)
        for line_entry in line_program.get_entries():
            print(line_entry)
            if line_entry.state!=None:
                addr_lineProgram[hex(line_entry.state.address)] = line_entry
                addr_sourceFile [hex(line_entry.state.address)] = filename_map
        print("_____________________________________________________")
# Out:
#   Found a compile unit at offset 0, length 416
#     filename=stack.c -> 18 entries
# LineProgramEntry(command=5, is_extended=False, args=[40], state=None)
# LineProgramEntry(command=2, is_extended=True, args=[4521], state=None)
# LineProgramEntry(command=23, is_extended=False, args=[5, 0, 0], state=<LineState 7f94892f1400:
#   address = 0x11a9
#   file = 1
#   line = 6
#   column = 40
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=48, is_extended=False, args=[2, 2, 0], state=<LineState 7f94892f1430:
#   address = 0x11bc
#   file = 1
#   line = 8
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[11], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f94892f1490:
#   address = 0x11c7
#   file = 1
#   line = 9
#   column = 11
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=215, is_extended=False, args=[1, 14, 0], state=<LineState 7f94892f14f0:
#   address = 0x11d5
#   file = 1
#   line = 10
#   column = 17
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[15], state=None)
# LineProgramEntry(command=145, is_extended=False, args=[1, 9, 0], state=<LineState 7f94892f1550:
#   address = 0x11de
#   file = 1
#   line = 11
#   column = 15
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=187, is_extended=False, args=[1, 12, 0], state=<LineState 7f94892f15b0:
#   address = 0x11ea
#   file = 1
#   line = 12
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[14], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f94892f1610:
#   address = 0x11f2
#   file = 1
#   line = 13
#   column = 14
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f94892f1640:
#   address = 0x11fd
#   file = 1
#   line = 14
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[26], state=None)
# LineProgramEntry(command=62, is_extended=False, args=[2, 3, 0], state=<LineState 7f94892f16a0:
#   address = 0x1200
#   file = 1
#   line = 16
#   column = 26
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=245, is_extended=False, args=[3, 16, 0], state=<LineState 7f94892f1700:
#   address = 0x1210
#   file = 1
#   line = 19
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f94892f1730:
#   address = 0x121b
#   file = 1
#   line = 20
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f94892f1760:
#   address = 0x1223
#   file = 1
#   line = 21
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=145, is_extended=False, args=[1, 9, 0], state=<LineState 7f94892f1790:
#   address = 0x122c
#   file = 1
#   line = 22
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=187, is_extended=False, args=[1, 12, 0], state=<LineState 7f94892f17c0:
#   address = 0x1238
#   file = 1
#   line = 23
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[14], state=None)
# LineProgramEntry(command=187, is_extended=False, args=[1, 12, 0], state=<LineState 7f94892f17f0:
#   address = 0x1244
#   file = 1
#   line = 24
#   column = 14
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f94892f1820:
#   address = 0x124f
#   file = 1
#   line = 25
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=61, is_extended=False, args=[1, 3, 0], state=<LineState 7f94892f1850:
#   address = 0x1252
#   file = 1
#   line = 26
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[2], state=None)
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f94892f1880:
#   address = 0x1254
#   file = 1
#   line = 26
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# _____________________________________________________
#   Found a compile unit at offset 420, length 350
#     filename=main.c -> 16 entries
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=2, is_extended=True, args=[4692], state=None)
# LineProgramEntry(command=24, is_extended=False, args=[6, 0, 0], state=<LineState 7f94892f11c0:
#   address = 0x1254
#   file = 1
#   line = 7
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=186, is_extended=False, args=[0, 12, 0], state=<LineState 7f94892f11f0:
#   address = 0x1260
#   file = 1
#   line = 7
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=229, is_extended=False, args=[1, 15, 0], state=<LineState 7f94892f1220:
#   address = 0x126f
#   file = 1
#   line = 8
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f94892f10d0:
#   address = 0x1277
#   file = 1
#   line = 9
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[16], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f94892f1100:
#   address = 0x1288
#   file = 1
#   line = 10
#   column = 16
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f94892f1130:
#   address = 0x129a
#   file = 1
#   line = 11
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=20, is_extended=False, args=[2, 0, 0], state=<LineState 7f94892f1190:
#   address = 0x12ab
#   file = 1
#   line = 13
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f94892f1070:
#   address = 0x12bc
#   file = 1
#   line = 14
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f94892f1040:
#   address = 0x12cd
#   file = 1
#   line = 15
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f94892eaee0:
#   address = 0x12ef
#   file = 1
#   line = 16
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f94892eae80:
#   address = 0x1311
#   file = 1
#   line = 17
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f94892eaf40:
#   address = 0x1333
#   file = 1
#   line = 18
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f94892eafa0:
#   address = 0x1355
#   file = 1
#   line = 19
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f94892eafd0:
#   address = 0x1377
#   file = 1
#   line = 20
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=89, is_extended=False, args=[1, 5, 0], state=<LineState 7f9489234430:
#   address = 0x137c
#   file = 1
#   line = 21
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[22], state=None)
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f9489234460:
#   address = 0x1392
#   file = 1
#   line = 21
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# _____________________________________________________
#   Found a compile unit at offset 774, length 356
#     filename=calculate.c -> 13 entries
# LineProgramEntry(command=5, is_extended=False, args=[22], state=None)
# LineProgramEntry(command=2, is_extended=True, args=[5010], state=None)
# LineProgramEntry(command=22, is_extended=False, args=[4, 0, 0], state=<LineState 7f94892341c0:
#   address = 0x1392
#   file = 1
#   line = 5
#   column = 22
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=215, is_extended=False, args=[1, 14, 0], state=<LineState 7f94892343a0:
#   address = 0x13a0
#   file = 1
#   line = 6
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f94892342e0:
#   address = 0x13a8
#   file = 1
#   line = 7
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[29], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f94892343d0:
#   address = 0x13aa
#   file = 1
#   line = 8
#   column = 29
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f9489234310:
#   address = 0x13bc
#   file = 1
#   line = 9
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=159, is_extended=False, args=[1, 10, 0], state=<LineState 7f9489234340:
#   address = 0x13c6
#   file = 1
#   line = 10
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[28], state=None)
# LineProgramEntry(command=49, is_extended=False, args=[3, 2, 0], state=<LineState 7f94892341f0:
#   address = 0x13c8
#   file = 1
#   line = 13
#   column = 28
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=215, is_extended=False, args=[1, 14, 0], state=<LineState 7f9489234220:
#   address = 0x13d6
#   file = 1
#   line = 14
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=103, is_extended=False, args=[1, 6, 0], state=<LineState 7f9489234280:
#   address = 0x13dc
#   file = 1
#   line = 15
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[35], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f94892340d0:
#   address = 0x13de
#   file = 1
#   line = 16
#   column = 35
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f9489234190:
#   address = 0x13f0
#   file = 1
#   line = 17
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=159, is_extended=False, args=[1, 10, 0], state=<LineState 7f9489234130:
#   address = 0x13fa
#   file = 1
#   line = 18
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[2], state=None)
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f9489234160:
#   address = 0x13fc
#   file = 1
#   line = 18
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# _____________________________________________________

# %%
# print(addr_lineProgram)
# address_inst

def getSource(sourceFileName="stack.c", row=5 , col=5):
    basePath = "/home/nahid/reverse/binaries/c_many/"
    sourceFilePath = os.path.join(basePath , sourceFileName)
    sourceFile = open(sourceFilePath, "r")
    fileContent = sourceFile.readlines()
    
    row_content =  fileContent[row-1]
    
    row_content = row_content[:(col-1)] + "@" +row_content[col:]
    
    # print(row_content)
    
    return row_content

# %%
with open(filePath, 'rb') as f:
    elffile = ELFFile(f)

    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
        exit(0)

    dwarfinfo = elffile.get_dwarf_info()
    arangesInfo = dwarfinfo.debug_aranges_sec
    pubTypes = dwarfinfo.debug_pubtypes_sec
    dwarfinfo.

# %%
with open('stacktest.s', 'w') as outFile:
    # outFile.write('file contents\n')
    lastSource = ""
    for address in address_inst:
        inst = address_inst[address]
        instrctionCode = (address+":\t"+ inst.mnemonic+" "+inst.op_str).ljust(45)
        if address in addr_lineProgram:
            line = addr_lineProgram[address]

            srcFileName =list(addr_sourceFile[address].keys())[0] #TODO not single file always 
            
            if srcFileName!=lastSource:
                outFile.write("\n"+ '#'*100+"\n"+ srcFileName.rjust(45) +'\n'+'#'*100+ "\n\n")
                lastSource = srcFileName
            
            sourceCode = getSource(srcFileName,addr_lineProgram[address].state.line, addr_lineProgram[address].state.column)
            if '\n' not in  sourceCode:
                sourceCode+=sourceCode+"\n"
            outFile.write(instrctionCode+"#"+ sourceCode  )
            print(instrctionCode+"#"+ sourceCode)
        else:
            outFile.write(instrctionCode+ '\n'  )
            print(instrctionCode)
