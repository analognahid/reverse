# %%
#-------------------------------------------------------------------------------
# elftools example: dwarf_lineprogram_filenames.py
#
# In the .debug_line section, the Dwarf line program generates a matrix
# of address-source references. This example demonstrates accessing the state
# of each line program entry to retrieve the underlying filenames.
#
# William Woodruff (william@yossarian.net)
# This code is in the public domain
#-------------------------------------------------------------------------------
from __future__ import print_function
from collections import defaultdict
import os
import sys
import posixpath

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.
# sys.path[0:0] = ['.', '..']

from elftools.elf.elffile import ELFFile


def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        dwarfinfo = elffile.get_dwarf_info()
        for CU in dwarfinfo.iter_CUs():
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # Every compilation unit in the DWARF information may or may not
            # have a corresponding line program in .debug_line.
            line_program = dwarfinfo.line_program_for_CU(CU)
            if line_program is None:
                print('  DWARF info is missing a line program for this CU')
                continue

            # Print a reverse mapping of filename -> #entries
            line_entry_mapping(line_program)
            
            for le in line_program.get_entries():
                print(le)

def line_entry_mapping(line_program):
    filename_map = defaultdict(int)

    # The line program, when decoded, returns a list of line program
    # entries. Each entry contains a state, which we'll use to build
    # a reverse mapping of filename -> #entries.
    lp_entries = line_program.get_entries()
    for lpe in lp_entries:
        # We skip LPEs that don't have an associated file.
        # This can happen if instructions in the compiled binary
        # don't correspond directly to any original source file.
        if not lpe.state or lpe.state.file == 0:
            continue
        filename = lpe_filename(line_program, lpe.state.file)
        filename_map[filename] += 1

    for filename, lpe_count in filename_map.items():
        print("    filename=%s -> %d entries" % (filename, lpe_count))


def lpe_filename(line_program, file_index):
    # Retrieving the filename associated with a line program entry
    # involves two levels of indirection: we take the file index from
    # the LPE to grab the file_entry from the line program header,
    # then take the directory index from the file_entry to grab the
    # directory name from the line program header. Finally, we
    # join the (base) filename from the file_entry to the directory
    # name to get the absolute filename.
    lp_header = line_program.header
    file_entries = lp_header["file_entry"]

    # File and directory indices are 1-indexed.
    file_entry = file_entries[file_index - 1]
    dir_index = file_entry["dir_index"]

    # A dir_index of 0 indicates that no absolute directory was recorded during
    # compilation; return just the basename.
    if dir_index == 0:
        return file_entry.name.decode()

    directory = lp_header["include_directory"][dir_index - 1]
    return posixpath.join(directory, file_entry.name).decode()



filePath = '/home/nahid/reverse/binaries/c_many/stacktest'
process_file(filePath)
# Out:
# Processing file: /home/nahid/reverse/binaries/c_many/stacktest
#   Found a compile unit at offset 0, length 457
#     filename=stack.c -> 21 entries
# LineProgramEntry(command=5, is_extended=False, args=[40], state=None)
# LineProgramEntry(command=2, is_extended=True, args=[4521], state=None)
# LineProgramEntry(command=23, is_extended=False, args=[5, 0, 0], state=<LineState 7f97f2b6bd00:
#   address = 0x11a9
#   file = 1
#   line = 6
#   column = 40
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f97f2b6bd30:
#   address = 0x11bc
#   file = 1
#   line = 7
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[18], state=None)
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f97f2b6bd60:
#   address = 0x11c3
#   file = 1
#   line = 8
#   column = 18
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=120, is_extended=False, args=[4, 7, 0], state=<LineState 7f97f2b6bd90:
#   address = 0x11ca
#   file = 1
#   line = 12
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[11], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f97f2b6bdc0:
#   address = 0x11d5
#   file = 1
#   line = 13
#   column = 11
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=215, is_extended=False, args=[1, 14, 0], state=<LineState 7f97f2b6bdf0:
#   address = 0x11e3
#   file = 1
#   line = 14
#   column = 17
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[15], state=None)
# LineProgramEntry(command=145, is_extended=False, args=[1, 9, 0], state=<LineState 7f97f2b6be20:
#   address = 0x11ec
#   file = 1
#   line = 15
#   column = 15
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=187, is_extended=False, args=[1, 12, 0], state=<LineState 7f97f2b6be50:
#   address = 0x11f8
#   file = 1
#   line = 16
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[14], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f97f2b6be80:
#   address = 0x1200
#   file = 1
#   line = 17
#   column = 14
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f97f2b6bee0:
#   address = 0x120b
#   file = 1
#   line = 18
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[26], state=None)
# LineProgramEntry(command=62, is_extended=False, args=[2, 3, 0], state=<LineState 7f97f2b6bf10:
#   address = 0x120e
#   file = 1
#   line = 20
#   column = 26
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=243, is_extended=False, args=[1, 16, 0], state=<LineState 7f97f2b6bf40:
#   address = 0x121e
#   file = 1
#   line = 21
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=119, is_extended=False, args=[3, 7, 0], state=<LineState 7f97f2b6bf70:
#   address = 0x1225
#   file = 1
#   line = 24
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f97f2b6bfa0:
#   address = 0x1230
#   file = 1
#   line = 25
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f97f2b6bfd0:
#   address = 0x1238
#   file = 1
#   line = 26
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=145, is_extended=False, args=[1, 9, 0], state=<LineState 7f97f2b75cd0:
#   address = 0x1241
#   file = 1
#   line = 27
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=187, is_extended=False, args=[1, 12, 0], state=<LineState 7f97f2b75d90:
#   address = 0x124d
#   file = 1
#   line = 28
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[14], state=None)
# LineProgramEntry(command=187, is_extended=False, args=[1, 12, 0], state=<LineState 7f97f2b75e50:
#   address = 0x1259
#   file = 1
#   line = 29
#   column = 14
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f97f2b75f10:
#   address = 0x1264
#   file = 1
#   line = 30
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=61, is_extended=False, args=[1, 3, 0], state=<LineState 7f97f2b75fd0:
#   address = 0x1267
#   file = 1
#   line = 31
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[2], state=None)
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f97f2b75040:
#   address = 0x1269
#   file = 1
#   line = 31
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
#   Found a compile unit at offset 461, length 350
#     filename=main.c -> 16 entries
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=2, is_extended=True, args=[4713], state=None)
# LineProgramEntry(command=24, is_extended=False, args=[6, 0, 0], state=<LineState 7f97f2b65b80:
#   address = 0x1269
#   file = 1
#   line = 7
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=186, is_extended=False, args=[0, 12, 0], state=<LineState 7f97f2b6bd00:
#   address = 0x1275
#   file = 1
#   line = 7
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=229, is_extended=False, args=[1, 15, 0], state=<LineState 7f97f2b6bd60:
#   address = 0x1284
#   file = 1
#   line = 8
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f97f2b6bd90:
#   address = 0x128c
#   file = 1
#   line = 9
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[16], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f97f2b6bdc0:
#   address = 0x129d
#   file = 1
#   line = 10
#   column = 16
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f97f2b6bdf0:
#   address = 0x12af
#   file = 1
#   line = 11
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=20, is_extended=False, args=[2, 0, 0], state=<LineState 7f97f2b6be50:
#   address = 0x12c0
#   file = 1
#   line = 13
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f97f2b6be80:
#   address = 0x12d1
#   file = 1
#   line = 14
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f97f2b6bee0:
#   address = 0x12e2
#   file = 1
#   line = 15
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f97f2b6bf10:
#   address = 0x1304
#   file = 1
#   line = 16
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f97f2b6bf40:
#   address = 0x1326
#   file = 1
#   line = 17
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f97f2b6bf70:
#   address = 0x1348
#   file = 1
#   line = 18
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f97f2b6bfa0:
#   address = 0x136a
#   file = 1
#   line = 19
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f97f2b6bfd0:
#   address = 0x138c
#   file = 1
#   line = 20
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=89, is_extended=False, args=[1, 5, 0], state=<LineState 7f97f2b6b550:
#   address = 0x1391
#   file = 1
#   line = 21
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[22], state=None)
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f97f2b6b7c0:
#   address = 0x13a7
#   file = 1
#   line = 21
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
#   Found a compile unit at offset 815, length 446
#     filename=calculate.c -> 26 entries
# LineProgramEntry(command=5, is_extended=False, args=[22], state=None)
# LineProgramEntry(command=2, is_extended=True, args=[5031], state=None)
# LineProgramEntry(command=22, is_extended=False, args=[4, 0, 0], state=<LineState 7f97f2b6bdf0:
#   address = 0x13a7
#   file = 1
#   line = 5
#   column = 22
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=215, is_extended=False, args=[1, 14, 0], state=<LineState 7f97f2b6be50:
#   address = 0x13b5
#   file = 1
#   line = 6
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f97f2b6be80:
#   address = 0x13bc
#   file = 1
#   line = 7
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=75, is_extended=False, args=[1, 4, 0], state=<LineState 7f97f2b6bee0:
#   address = 0x13c0
#   file = 1
#   line = 8
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[11], state=None)
# LineProgramEntry(command=145, is_extended=False, args=[1, 9, 0], state=<LineState 7f97f2b6bf10:
#   address = 0x13c9
#   file = 1
#   line = 9
#   column = 11
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[10], state=None)
# LineProgramEntry(command=201, is_extended=False, args=[1, 13, 0], state=<LineState 7f97f2b6bf70:
#   address = 0x13d6
#   file = 1
#   line = 10
#   column = 10
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[14], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=89, is_extended=False, args=[1, 5, 0], state=<LineState 7f97f2b6bfa0:
#   address = 0x13ec
#   file = 1
#   line = 11
#   column = 14
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=116, is_extended=False, args=[0, 7, 0], state=<LineState 7f97f2b6bfd0:
#   address = 0x13f3
#   file = 1
#   line = 11
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f97f2b6b550:
#   address = 0x13f5
#   file = 1
#   line = 12
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 3>
# )
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f97f2bdc400:
#   address = 0x13fc
#   file = 1
#   line = 13
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 3>
# )
# LineProgramEntry(command=5, is_extended=False, args=[27], state=None)
# LineProgramEntry(command=72, is_extended=False, args=[-2, 4, 0], state=<LineState 7f97f2bdc250:
#   address = 0x1400
#   file = 1
#   line = 11
#   column = 27
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 3>
# )
# LineProgramEntry(command=5, is_extended=False, args=[22], state=None)
# LineProgramEntry(command=74, is_extended=False, args=[0, 4, 0], state=<LineState 7f98101d5610:
#   address = 0x1404
#   file = 1
#   line = 11
#   column = 22
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 1>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=106, is_extended=False, args=[4, 6, 0], state=<LineState 7f98101d5940:
#   address = 0x140a
#   file = 1
#   line = 15
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=75, is_extended=False, args=[1, 4, 0], state=<LineState 7f98101d5760:
#   address = 0x140e
#   file = 1
#   line = 16
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[15], state=None)
# LineProgramEntry(command=130, is_extended=False, args=[0, 8, 0], state=<LineState 7f98101d58b0:
#   address = 0x1416
#   file = 1
#   line = 16
#   column = 15
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=89, is_extended=False, args=[1, 5, 0], state=<LineState 7f98101d59a0:
#   address = 0x141b
#   file = 1
#   line = 17
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[29], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f98101d58e0:
#   address = 0x141d
#   file = 1
#   line = 18
#   column = 29
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f98101d59d0:
#   address = 0x142f
#   file = 1
#   line = 19
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=159, is_extended=False, args=[1, 10, 0], state=<LineState 7f98101d55e0:
#   address = 0x1439
#   file = 1
#   line = 20
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[28], state=None)
# LineProgramEntry(command=49, is_extended=False, args=[3, 2, 0], state=<LineState 7f98101d57c0:
#   address = 0x143b
#   file = 1
#   line = 23
#   column = 28
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=215, is_extended=False, args=[1, 14, 0], state=<LineState 7f98101d57f0:
#   address = 0x1449
#   file = 1
#   line = 24
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=103, is_extended=False, args=[1, 6, 0], state=<LineState 7f98101d5820:
#   address = 0x144f
#   file = 1
#   line = 25
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[35], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f98101d5850:
#   address = 0x1451
#   file = 1
#   line = 26
#   column = 35
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f98101d5670:
#   address = 0x1463
#   file = 1
#   line = 27
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=159, is_extended=False, args=[1, 10, 0], state=<LineState 7f98101d5730:
#   address = 0x146d
#   file = 1
#   line = 28
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[2], state=None)
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f98101d56d0:
#   address = 0x146f
#   file = 1
#   line = 28
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
