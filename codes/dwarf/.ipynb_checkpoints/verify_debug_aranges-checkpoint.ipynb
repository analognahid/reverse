# %%
from elftools.elf.elffile import ELFFile
from elftools.dwarf.descriptions import (
    describe_DWARF_expr, set_global_machine_arch)
from elftools.dwarf.locationlists import (
    LocationEntry, LocationExpr, LocationParser)

import posixpath

# filePath = './../../binaries/gnuit/src/gitfm'

filePath = './../../binaries/c_many/stacktest'

# %%
def get_DIE_at_offset(CU, offset):
        for die in CU.iter_DIEs():
            if die.offset == CU.cu_offset+offset:
                return die 
        return None

def get_type_name(CU, offset):#get_DIE_at_offset(CU,attr.value)
    die = get_DIE_at_offset(CU, offset)
    
    if die.tag == 'DW_TAG_const_type':
        return "const"
    
    if die.tag == 'DW_TAG_pointer_type' :
        for _attr in die.attributes.values():
            if _attr.name== "DW_AT_type":
                
                return "*"+get_type_name(CU, _attr.value) 

    elif die.tag =='DW_TAG_subroutine_type':
        

        for _attr in die.attributes.values():
            if _attr.name== "DW_AT_sibling":
                return get_type_name(CU, _attr.value) 
            
            if _attr.name== "DW_AT_type":
                return "*"+get_type_name(CU, _attr.value) 

    for attr in die.attributes.values():
        if attr.name== "DW_AT_name":
            return attr.value.decode("utf-8")

#     print("producing none?")

# %%
from collections import defaultdict
def line_entry_mapping(line_program):
    filename_map = defaultdict(int)

    # The line program, when decoded, returns a list of line program
    # entries. Each entry contains a state, which we'll use to build
    # a reverse mapping of filename -> #entries.
    lp_entries = line_program.get_entries()
    if len(lp_entries)==0:
        return None
    for lpe in lp_entries:
        # We skip LPEs that don't have an associated file.
        # This can happen if instructions in the compiled binary
        # don't correspond directly to any original source file.
        if not lpe.state:# or lpe.state.file == 0
            continue
        filename = lpe_filename(line_program, lpe.state.file)[0]
        filename_map[filename] += 1

    # for filename, lpe_count in filename_map.items():
    #     print("    filename=%s -> %d entries" % (filename, lpe_count))
    return filename_map

def lpe_filename(line_program, file_index):
#     file_index+=1
    lp_header = line_program.header
    file_entries = lp_header["file_entry"]
    

    # File and directory indices are 1-indexed.
    file_entry = file_entries[file_index ]
    dir_index = file_entry["dir_index"]

    # A dir_index of 0 indicates that no absolute directory was recorded during
    # compilation; return just the basename.
    if dir_index == 0:
        return file_entry.name.decode(),dir_index
    
#     print(lp_header)
    directory = lp_header["include_directory"][dir_index ]
    return posixpath.join(directory, file_entry.name).decode(),dir_index

# %%
def show_loclist(loclist, dwarfinfo, indent, cu_offset):
    """ Display a location list nicely, decoding the DWARF expressions
        contained within.
    """
    d = []
    for loc_entity in loclist:
        if isinstance(loc_entity, LocationEntry):
            d.append('%s <<%s>>' % (
                loc_entity,
                describe_DWARF_expr(loc_entity.loc_expr, dwarfinfo.structs, cu_offset)))
        else:
            d.append(str(loc_entity))
    return '\n'.join(indent + s for s in d)

# %%
# https://github.com/eliben/pyelftools/blob/master/examples/dwarf_location_info.py


from elftools.dwarf.locationlists import LocationParser, LocationExpr
FUNC_PARAMS = {}
def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        # get_dwarf_info returns a DWARFInfo context object, which is the
        # starting point for all DWARF-based processing in pyelftools.
        dwarfinfo = elffile.get_dwarf_info()
        # The location lists are extracted by DWARFInfo from the .debug_loc
        # section, and returned here as a LocationLists object.
        location_lists = dwarfinfo.location_lists()

        # This is required for the descriptions module to correctly decode
        # register names contained in DWARF expressions.
        set_global_machine_arch(elffile.get_machine_arch())

        # Create a LocationParser object that parses the DIE attributes and
        # creates objects representing the actual location information.
        loc_parser = LocationParser(location_lists)
        
        section_offset = dwarfinfo.debug_info_sec.global_offset
        # Offset of the .debug_info section in the stream
        

        d =0
        for CU in dwarfinfo.iter_CUs():
            if d==0:
                d+=1
                continue
                
            #get source file name
            print(CU)
            line_program = dwarfinfo.line_program_for_CU(CU)
            print('TEST!!!')
            filename_map = line_entry_mapping(line_program)
            if filename_map==None:
                continue
            CU_src_file =  list(filename_map.items())[0][0]
            
            CU_dictionary_key = CU_src_file 
            
            FUNC_PARAMS[CU_dictionary_key] = {}
            
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # A CU provides a simple API to iterate over all the DIEs in it.
            die_depth = 0
            are_DIEs_of_function = False
            FUNC_name = None
            print('____'*10)
            for DIE in CU.iter_DIEs():
                
                ############################################################
                #############   Prasing Function DIEs start ################
                
                
                if DIE.tag == 'DW_TAG_subprogram':
                    are_DIEs_of_function = True
                    
                    for attr in DIE.attributes.values():
                        if attr.name == "DW_AT_name": #FUNC NAME
                            FUNC_name = attr.value.decode("utf-8")
                            FUNC_PARAMS[CU_dictionary_key][FUNC_name] ={}
                            print("SUBPROGRAM: ",FUNC_name)
                            
                if DIE.tag == 'DW_TAG_formal_parameter' or DIE.tag =='DW_TAG_variable':
                    tags = [attr.name for attr in DIE.attributes.values()]
                    PARAM_name = None
                    if FUNC_name==None:

                        FUNC_name ="global"
                        
                        if FUNC_name not in FUNC_PARAMS[CU_dictionary_key]:
                            FUNC_PARAMS[CU_dictionary_key][FUNC_name]={}
                        
                    if "DW_AT_name" in tags:
                        
                        
                        for attr in DIE.attributes.values():
                            
                            if attr.name == "DW_AT_name": # VAR NAME 
                                PARAM_name = attr.value.decode("utf-8")
                                FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {}

                            if attr.name == "DW_AT_type":
                                var_type = DIE.tag.split('_')[-1]
                                print('calling from here' ,DIE.tag,var_type)
                                FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {'type':get_type_name(CU,attr.value) , 'kind':var_type}

                            # Check if this attribute contains location information
                            if loc_parser.attribute_has_location(attr, CU['version']):
                                
                                try:
                                    loc = loc_parser.parse_from_attribute(attr,
                                                                          CU['version'])

    #                                 print(CU_dictionary_key,FUNC_name,PARAM_name)
                                    if isinstance(loc, LocationExpr):
    #                                     print('      %s' % (
    #                                         describe_DWARF_expr(loc.loc_expr,
    #                                                             dwarfinfo.structs, CU.cu_offset)))
    #                                     print(describe_DWARF_expr(loc.loc_expr, dwarfinfo.structs, CU.cu_offset))
                                        FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name]["location"]= describe_DWARF_expr(loc.loc_expr, dwarfinfo.structs, CU.cu_offset)
                                    elif isinstance(loc, list):
    #                                     print(show_loclist(loc,
    #                                                        dwarfinfo,
    #                                                        '      ', CU.cu_offset))
                                        FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name]["location"]= show_loclist(loc,
                                                           dwarfinfo,'      ', CU.cu_offset)
                                except:
                                    print("NO LOC INFO EVEN AFTER CHECKING. BUG> FIX")
#                     print("\n"*5)
                        

                ###############################################
                #############  parsing  Function DIEs ends ################
                


                
                if DIE.is_null(): #https://chromium.googlesource.com/chromiumos/third_party/pyelftools/+/25a77f7738d7fe824f2ed4d33a123136b9d8e88a/scripts/readelf.py
                    are_DIEs_of_function = False
                    FUNC_name = None
                    
                    die_depth -= 1
                    continue
                if DIE.has_children:
                    die_depth += 1
                    

process_file(filePath)
# Out:
# Processing file: ./../../binaries/c_many/stacktest
# <elftools.dwarf.compileunit.CompileUnit object at 0x7f1d1c4e77f0>
# TEST!!!
#   Found a compile unit at offset 901, length 518
# ________________________________________
# SUBPROGRAM:  printf
# SUBPROGRAM:  pop
# SUBPROGRAM:  dummy
# SUBPROGRAM:  fake
# SUBPROGRAM:  add
# SUBPROGRAM:  push
# SUBPROGRAM:  main
# calling from here DW_TAG_variable variable
# calling from here DW_TAG_variable variable
# calling from here DW_TAG_variable variable
# calling from here DW_TAG_variable variable
# calling from here DW_TAG_variable variable
# calling from here DW_TAG_variable variable
# calling from here DW_TAG_variable variable
# <elftools.dwarf.compileunit.CompileUnit object at 0x7f1d1c4549d0>
# TEST!!!
#   Found a compile unit at offset 1423, length 442
# ________________________________________
# SUBPROGRAM:  substractf
# calling from here DW_TAG_formal_parameter parameter
# calling from here DW_TAG_formal_parameter parameter
# SUBPROGRAM:  substract
# calling from here DW_TAG_formal_parameter parameter
# calling from here DW_TAG_formal_parameter parameter
# SUBPROGRAM:  addf
# calling from here DW_TAG_formal_parameter parameter
# calling from here DW_TAG_formal_parameter parameter
# SUBPROGRAM:  add
# calling from here DW_TAG_formal_parameter parameter
# calling from here DW_TAG_formal_parameter parameter
# calling from here DW_TAG_variable variable
# calling from here DW_TAG_variable variable
# calling from here DW_TAG_variable variable
# calling from here DW_TAG_variable variable

# %%
FUNC_PARAMS
# Out:
# {'main.c': {'printf': {},
#   'pop': {},
#   'dummy': {},
#   'fake': {},
#   'add': {},
#   'push': {},
#   'main': {'stk': {'type': '*stack',
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -48)'},
#    'temp': {'type': 'int',
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -68)'},
#    'fake_param1': {'type': 'int',
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -64)'},
#    'fake_param2': {'type': 'int',
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -60)'},
#    'fake_result': {'type': 'int',
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -56)'},
#    'dummy_str': {'type': None,
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -34)'},
#    'dummy_out': {'type': 'int',
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -52)'}}},
#  'calculate.c': {'substractf': {'a': {'type': 'float',
#     'kind': 'parameter',
#     'location': '(DW_OP_fbreg: -20)'},
#    'b': {'type': 'float',
#     'kind': 'parameter',
#     'location': '(DW_OP_fbreg: -24)'}},
#   'substract': {'a': {'type': 'int',
#     'kind': 'parameter',
#     'location': '(DW_OP_fbreg: -20)'},
#    'b': {'type': 'int',
#     'kind': 'parameter',
#     'location': '(DW_OP_fbreg: -24)'}},
#   'addf': {'a': {'type': 'float',
#     'kind': 'parameter',
#     'location': '(DW_OP_fbreg: -20)'},
#    'b': {'type': 'float',
#     'kind': 'parameter',
#     'location': '(DW_OP_fbreg: -24)'}},
#   'add': {'a': {'type': 'int',
#     'kind': 'parameter',
#     'location': '(DW_OP_fbreg: -36)'},
#    'b': {'type': 'int', 'kind': 'parameter', 'location': '(DW_OP_fbreg: -40)'},
#    'ran': {'type': 'int',
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -28)'},
#    'fran': {'type': 'int',
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -20)'},
#    'i': {'type': 'int',
#     'kind': 'variable',
#     'location': '(DW_OP_fbreg: -32)'}}}}

# %%
#!/usr/bin/env python3

import sys,os
from elftools.elf.elffile import ELFFile
from elftools.elf.segments import Segment

# %%
fh = open(filePath, 'rb')
bin_bytearray = bytearray(fh.read())

# %%
# https://www.capstone-engine.org/lang_python.html



from capstone import *

from capstone.x86 import *


address_inst = {}
with open(filePath, 'rb') as f:
    elf = ELFFile(f)
    dwarfinfo = elf.get_dwarf_info()
    aranges = dwarfinfo.get_aranges()
    print(len(aranges.entries))
    for arange in aranges.entries:
        print(arange)
    for arange in aranges.entries:

        entry = arange.begin_addr
        exit  = arange.begin_addr + arange.length
        ops = bin_bytearray[entry: exit]

        md = Cs(CS_ARCH_X86, CS_MODE_64)
        md.detail = True
        for inst in md.disasm(ops, entry):

            address_inst[hex(inst.address)] = inst


            print('\n'*3)
            print(inst.address, inst.mnemonic+"  "+inst.op_str)
            (regs_read, regs_write) = inst.regs_access()

#             if len(inst.operands) > 0:
#                 c=-1
#                 for o in inst.operands:
#                     c += 1
#                     if o.type == CS_OP_MEM:
#                         print("\t\toperands[%u].type: MEM" %c)
#                         if o.value.mem.base != 0:
#                             print("\t\t\toperands[%u].mem.base: REG = %s" \
#                                 %(c, inst.reg_name(o.value.mem.base)))
#                         if o.value.mem.index != 0:
#                             print("\t\t\toperands[%u].mem.index: REG = %s" \
#                                 %(c, inst.reg_name(o.value.mem.index)))
#                         if o.value.mem.disp != 0:
#                             print("\t\t\toperands[%u].mem.disp: 0x%x" \
#                                 %(c, o.value.mem.disp))
#                         print(hex(o.value.mem.disp),o.value.mem.disp)
# Out:
# 9
# ARangeEntry(begin_addr=4521, length=101, info_offset=0, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=4622, length=220, info_offset=0, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=4842, length=98, info_offset=0, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=4940, length=69, info_offset=0, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=5009, length=415, info_offset=901, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=5424, length=118, info_offset=1423, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=5542, length=30, info_offset=1423, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=5572, length=22, info_offset=1423, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=5594, length=30, info_offset=1423, unit_length=92, version=2, address_size=8, segment_size=0)
#
#
#
#
# 4521 endbr64
#
#
#
#
# 4525 push  rbp
#
#
#
#
# 4526 mov  rbp, rsp
#
#
#
#
# 4529 sub  rsp, 0x30
#
#
#
#
# 4533 mov  dword ptr [rbp - 0x24], edi
#
#
#
#
# 4536 mov  qword ptr [rbp - 0x30], rsi
#
#
#
#
# 4540 mov  dword ptr [rbp - 0x18], 0xa
#
#
#
#
# 4547 mov  dword ptr [rbp - 0x14], 0xc
#
#
#
#
# 4554 mov  rax, qword ptr [rbp - 0x30]
#
#
#
#
# 4558 mov  rax, qword ptr [rax]
#
#
#
#
# 4561 mov  qword ptr [rbp - 0x10], rax
#
#
#
#
# 4565 mov  edi, 0x10
#
#
#
#
# 4570 call  0x10b0
#
#
#
#
# 4575 mov  qword ptr [rbp - 8], rax
#
#
#
#
# 4579 mov  rax, qword ptr [rbp - 8]
#
#
#
#
# 4583 mov  edx, dword ptr [rbp - 0x24]
#
#
#
#
# 4586 mov  dword ptr [rax], edx
#
#
#
#
# 4588 mov  rax, qword ptr [rbp - 8]
#
#
#
#
# 4592 mov  rdx, qword ptr [rbp - 0x10]
#
#
#
#
# 4596 mov  qword ptr [rax + 8], rdx
#
#
#
#
# 4600 mov  rax, qword ptr [rbp - 8]
#
#
#
#
# 4604 mov  qword ptr [rbp - 0x10], rax
#
#
#
#
# 4608 mov  rax, qword ptr [rbp - 0x30]
#
#
#
#
# 4612 mov  rdx, qword ptr [rbp - 0x10]
#
#
#
#
# 4616 mov  qword ptr [rax], rdx
#
#
#
#
# 4619 nop
#
#
#
#
# 4620 leave
#
#
#
#
# 4621 ret
#
#
#
#
# 4622 endbr64
#
#
#
#
# 4626 push  rbp
#
#
#
#
# 4627 mov  rbp, rsp
#
#
#
#
# 4630 sub  rsp, 0xa0
#
#
#
#
# 4637 mov  dword ptr [rbp - 0x84], edi
#
#
#
#
# 4643 movss  dword ptr [rbp - 0x88], xmm0
#
#
#
#
# 4651 movsd  qword ptr [rbp - 0x90], xmm1
#
#
#
#
# 4659 mov  qword ptr [rbp - 0x98], rsi
#
#
#
#
# 4666 mov  rax, qword ptr fs:[0x28]
#
#
#
#
# 4675 mov  qword ptr [rbp - 8], rax
#
#
#
#
# 4679 xor  eax, eax
#
#
#
#
# 4681 mov  dword ptr [rbp - 0x74], 2
#
#
#
#
# 4688 movss  xmm0, dword ptr [rip + 0xdb0]
#
#
#
#
# 4696 movss  dword ptr [rbp - 0x70], xmm0
#
#
#
#
# 4701 movsd  xmm0, qword ptr [rip + 0xdab]
#
#
#
#
# 4709 movsd  qword ptr [rbp - 0x68], xmm0
#
#
#
#
# 4714 mov  eax, dword ptr [rbp - 0x84]
#
#
#
#
# 4720 add  eax, eax
#
#
#
#
# 4722 mov  dword ptr [rbp - 0x74], eax
#
#
#
#
# 4725 movss  xmm0, dword ptr [rbp - 0x70]
#
#
#
#
# 4730 mulss  xmm0, dword ptr [rbp - 0x88]
#
#
#
#
# 4738 movss  dword ptr [rbp - 0x70], xmm0
#
#
#
#
# 4743 mov  rax, qword ptr [rbp - 0x98]
#
#
#
#
# 4750 mov  rsi, rax
#
#
#
#
# 4753 mov  edi, 0x2573
#
#
#
#
# 4758 mov  eax, 0
#
#
#
#
# 4763 call  0x10a0
#
#
#
#
# 4768 mov  dword ptr [rbp - 0x6c], 0
#
#
#
#
# 4775 mov  dword ptr [rbp - 0x78], 0
#
#
#
#
# 4782 jmp  0x12c4
#
#
#
#
# 4784 mov  eax, dword ptr [rbp - 0x74]
#
#
#
#
# 4787 cdq
#
#
#
#
# 4788 idiv  dword ptr [rbp - 0x78]
#
#
#
#
# 4791 mov  eax, dword ptr [rbp - 0x78]
#
#
#
#
# 4794 cdqe
#
#
#
#
# 4796 mov  dword ptr [rbp + rax*4 - 0x60], edx
#
#
#
#
# 4800 add  dword ptr [rbp - 0x78], 1
#
#
#
#
# 4804 cmp  dword ptr [rbp - 0x78], 0x13
#
#
#
#
# 4808 jle  0x12b0
#
#
#
#
# 4810 mov  eax, dword ptr [rbp - 0x74]
#
#
#
#
# 4813 imul  eax, dword ptr [rbp - 0x84]
#
#
#
#
# 4820 mov  rdx, qword ptr [rbp - 8]
#
#
#
#
# 4824 sub  rdx, qword ptr fs:[0x28]
#
#
#
#
# 4833 je  0x12e8
#
#
#
#
# 4835 call  0x1090
#
#
#
#
# 4840 leave
#
#
#
#
# 4841 ret
#
#
#
#
# 4842 endbr64
#
#
#
#
# 4846 push  rbp
#
#
#
#
# 4847 mov  rbp, rsp
#
#
#
#
# 4850 sub  rsp, 0x30
#
#
#
#
# 4854 mov  qword ptr [rbp - 0x28], rdi
#
#
#
#
# 4858 mov  dword ptr [rbp - 0x1c], 0xb
#
#
#
#
# 4865 mov  dword ptr [rbp - 0x18], 0xc
#
#
#
#
# 4872 mov  rax, qword ptr [rbp - 0x28]
#
#
#
#
# 4876 mov  rax, qword ptr [rax]
#
#
#
#
# 4879 mov  qword ptr [rbp - 0x10], rax
#
#
#
#
# 4883 mov  rax, qword ptr [rbp - 0x10]
#
#
#
#
# 4887 mov  qword ptr [rbp - 8], rax
#
#
#
#
# 4891 mov  rax, qword ptr [rbp - 8]
#
#
#
#
# 4895 mov  eax, dword ptr [rax]
#
#
#
#
# 4897 mov  dword ptr [rbp - 0x14], eax
#
#
#
#
# 4900 mov  rax, qword ptr [rbp - 0x10]
#
#
#
#
# 4904 mov  rax, qword ptr [rax + 8]
#
#
#
#
# 4908 mov  qword ptr [rbp - 0x10], rax
#
#
#
#
# 4912 mov  rax, qword ptr [rbp - 8]
#
#
#
#
# 4916 mov  rdi, rax
#
#
#
#
# 4919 call  0x1080
#
#
#
#
# 4924 mov  rax, qword ptr [rbp - 0x28]
#
#
#
#
# 4928 mov  rdx, qword ptr [rbp - 0x10]
#
#
#
#
# 4932 mov  qword ptr [rax], rdx
#
#
#
#
# 4935 mov  eax, dword ptr [rbp - 0x14]
#
#
#
#
# 4938 leave
#
#
#
#
# 4939 ret
#
#
#
#
# 4940 endbr64
#
#
#
#
# 4944 push  rbp
#
#
#
#
# 4945 mov  rbp, rsp
#
#
#
#
# 4948 mov  dword ptr [rbp - 0x14], edi
#
#
#
#
# 4951 mov  dword ptr [rbp - 0x18], esi
#
#
#
#
# 4954 mov  dword ptr [rbp - 0x1c], edx
#
#
#
#
# 4957 mov  dword ptr [rbp - 0x10], 0xa
#
#
#
#
# 4964 mov  dword ptr [rbp - 0xc], 0xb
#
#
#
#
# 4971 mov  dword ptr [rbp - 8], 0xc
#
#
#
#
# 4978 mov  edx, dword ptr [rbp - 0x14]
#
#
#
#
# 4981 mov  eax, dword ptr [rbp - 0x18]
#
#
#
#
# 4984 add  edx, eax
#
#
#
#
# 4986 mov  eax, dword ptr [rbp - 0x10]
#
#
#
#
# 4989 add  edx, eax
#
#
#
#
# 4991 mov  eax, dword ptr [rbp - 0xc]
#
#
#
#
# 4994 add  edx, eax
#
#
#
#
# 4996 mov  eax, dword ptr [rbp - 8]
#
#
#
#
# 4999 add  eax, edx
#
#
#
#
# 5001 mov  dword ptr [rbp - 4], eax
#
#
#
#
# 5004 mov  eax, dword ptr [rbp - 4]
#
#
#
#
# 5007 pop  rbp
#
#
#
#
# 5008 ret
#
#
#
#
# 5009 endbr64
#
#
#
#
# 5013 push  rbp
#
#
#
#
# 5014 mov  rbp, rsp
#
#
#
#
# 5017 sub  rsp, 0x40
#
#
#
#
# 5021 mov  rax, qword ptr fs:[0x28]
#
#
#
#
# 5030 mov  qword ptr [rbp - 8], rax
#
#
#
#
# 5034 xor  eax, eax
#
#
#
#
# 5036 mov  qword ptr [rbp - 0x20], 0
#
#
#
#
# 5044 lea  rax, [rbp - 0x20]
#
#
#
#
# 5048 mov  rsi, rax
#
#
#
#
# 5051 mov  edi, 7
#
#
#
#
# 5056 call  0x11a9
#
#
#
#
# 5061 mov  esi, 2
#
#
#
#
# 5066 mov  edi, 1
#
#
#
#
# 5071 call  0x1530
#
#
#
#
# 5076 mov  dword ptr [rbp - 0x34], eax
#
#
#
#
# 5079 lea  rdx, [rbp - 0x20]
#
#
#
#
# 5083 mov  eax, dword ptr [rbp - 0x34]
#
#
#
#
# 5086 mov  rsi, rdx
#
#
#
#
# 5089 mov  edi, eax
#
#
#
#
# 5091 call  0x11a9
#
#
#
#
# 5096 mov  dword ptr [rbp - 0x30], 0
#
#
#
#
# 5103 mov  dword ptr [rbp - 0x2c], 1
#
#
#
#
# 5110 mov  ecx, dword ptr [rbp - 0x2c]
#
#
#
#
# 5113 mov  eax, dword ptr [rbp - 0x30]
#
#
#
#
# 5116 mov  edx, 0xa
#
#
#
#
# 5121 mov  esi, ecx
#
#
#
#
# 5123 mov  edi, eax
#
#
#
#
# 5125 call  0x134c
#
#
#
#
# 5130 mov  dword ptr [rbp - 0x28], eax
#
#
#
#
# 5133 movabs  rax, 0x745320796d6d7544
#
#
#
#
# 5143 mov  qword ptr [rbp - 0x12], rax
#
#
#
#
# 5147 mov  word ptr [rbp - 0xa], 0x72
#
#
#
#
# 5153 lea  rax, [rbp - 0x12]
#
#
#
#
# 5157 movsd  xmm0, qword ptr [rip + 0xbf3]
#
#
#
#
# 5165 mov  rsi, rax
#
#
#
#
# 5168 movapd  xmm1, xmm0
#
#
#
#
# 5172 mov  eax, dword ptr [rip + 0xbee]
#
#
#
#
# 5178 movd  xmm0, eax
#
#
#
#
# 5182 mov  edi, 1
#
#
#
#
# 5187 call  0x120e
#
#
#
#
# 5192 mov  dword ptr [rbp - 0x24], eax
#
#
#
#
# 5195 lea  rax, [rbp - 0x20]
#
#
#
#
# 5199 mov  rsi, rax
#
#
#
#
# 5202 mov  edi, 9
#
#
#
#
# 5207 call  0x11a9
#
#
#
#
# 5212 lea  rax, [rbp - 0x20]
#
#
#
#
# 5216 mov  rsi, rax
#
#
#
#
# 5219 mov  edi, 0xc
#
#
#
#
# 5224 call  0x11a9
#
#
#
#
# 5229 lea  rax, [rbp - 0x20]
#
#
#
#
# 5233 mov  rdi, rax
#
#
#
#
# 5236 call  0x12ea
#
#
#
#
# 5241 mov  esi, eax
#
#
#
#
# 5243 lea  rax, [rip + 0xb96]
#
#
#
#
# 5250 mov  rdi, rax
#
#
#
#
# 5253 mov  eax, 0
#
#
#
#
# 5258 call  0x10a0
#
#
#
#
# 5263 lea  rax, [rbp - 0x20]
#
#
#
#
# 5267 mov  rdi, rax
#
#
#
#
# 5270 call  0x12ea
#
#
#
#
# 5275 mov  esi, eax
#
#
#
#
# 5277 lea  rax, [rip + 0xb74]
#
#
#
#
# 5284 mov  rdi, rax
#
#
#
#
# 5287 mov  eax, 0
#
#
#
#
# 5292 call  0x10a0
#
#
#
#
# 5297 lea  rax, [rbp - 0x20]
#
#
#
#
# 5301 mov  rdi, rax
#
#
#
#
# 5304 call  0x12ea
#
#
#
#
# 5309 mov  esi, eax
#
#
#
#
# 5311 lea  rax, [rip + 0xb52]
#
#
#
#
# 5318 mov  rdi, rax
#
#
#
#
# 5321 mov  eax, 0
#
#
#
#
# 5326 call  0x10a0
#
#
#
#
# 5331 lea  rax, [rbp - 0x20]
#
#
#
#
# 5335 mov  rdi, rax
#
#
#
#
# 5338 call  0x12ea
#
#
#
#
# 5343 mov  esi, eax
#
#
#
#
# 5345 lea  rax, [rip + 0xb30]
#
#
#
#
# 5352 mov  rdi, rax
#
#
#
#
# 5355 mov  eax, 0
#
#
#
#
# 5360 call  0x10a0
#
#
#
#
# 5365 lea  rax, [rbp - 0x20]
#
#
#
#
# 5369 mov  rdi, rax
#
#
#
#
# 5372 call  0x12ea
#
#
#
#
# 5377 mov  esi, eax
#
#
#
#
# 5379 lea  rax, [rip + 0xb0e]
#
#
#
#
# 5386 mov  rdi, rax
#
#
#
#
# 5389 mov  eax, 0
#
#
#
#
# 5394 call  0x10a0
#
#
#
#
# 5399 mov  eax, dword ptr [rbp - 0x28]
#
#
#
#
# 5402 mov  rdx, qword ptr [rbp - 8]
#
#
#
#
# 5406 sub  rdx, qword ptr fs:[0x28]
#
#
#
#
# 5415 je  0x152e
#
#
#
#
# 5417 call  0x1090
#
#
#
#
# 5422 leave
#
#
#
#
# 5423 ret
#
#
#
#
# 5424 endbr64
#
#
#
#
# 5428 push  rbp
#
#
#
#
# 5429 mov  rbp, rsp
#
#
#
#
# 5432 mov  dword ptr [rbp - 0x14], edi
#
#
#
#
# 5435 mov  dword ptr [rbp - 0x18], esi
#
#
#
#
# 5438 mov  dword ptr [rbp - 0xc], 0xa
#
#
#
#
# 5445 add  dword ptr [rbp - 0xc], 0xc
#
#
#
#
# 5449 mov  eax, dword ptr [rbp - 0xc]
#
#
#
#
# 5452 imul  eax, eax
#
#
#
#
# 5455 mov  dword ptr [rbp - 0xc], eax
#
#
#
#
# 5458 movss  xmm0, dword ptr [rip + 0xad2]
#
#
#
#
# 5466 movss  dword ptr [rbp - 8], xmm0
#
#
#
#
# 5471 movss  xmm1, dword ptr [rbp - 8]
#
#
#
#
# 5476 movss  xmm0, dword ptr [rip + 0xac4]
#
#
#
#
# 5484 addss  xmm0, xmm1
#
#
#
#
# 5488 movss  dword ptr [rbp - 8], xmm0
#
#
#
#
# 5493 mov  dword ptr [rbp - 0x10], 0
#
#
#
#
# 5500 jmp  0x158d
#
#
#
#
# 5502 mov  dword ptr [rbp - 4], 0
#
#
#
#
# 5509 add  dword ptr [rbp - 4], 2
#
#
#
#
# 5513 add  dword ptr [rbp - 0x10], 1
#
#
#
#
# 5517 cmp  dword ptr [rbp - 0x10], 9
#
#
#
#
# 5521 jle  0x157e
#
#
#
#
# 5523 sub  dword ptr [rbp - 0xc], 0xa
#
#
#
#
# 5527 mov  edx, dword ptr [rbp - 0x14]
#
#
#
#
# 5530 mov  eax, dword ptr [rbp - 0x18]
#
#
#
#
# 5533 add  edx, eax
#
#
#
#
# 5535 mov  eax, dword ptr [rbp - 0xc]
#
#
#
#
# 5538 add  eax, edx
#
#
#
#
# 5540 pop  rbp
#
#
#
#
# 5541 ret
#
#
#
#
# 5542 endbr64
#
#
#
#
# 5546 push  rbp
#
#
#
#
# 5547 mov  rbp, rsp
#
#
#
#
# 5550 movss  dword ptr [rbp - 4], xmm0
#
#
#
#
# 5555 movss  dword ptr [rbp - 8], xmm1
#
#
#
#
# 5560 movss  xmm0, dword ptr [rbp - 4]
#
#
#
#
# 5565 addss  xmm0, dword ptr [rbp - 8]
#
#
#
#
# 5570 pop  rbp
#
#
#
#
# 5571 ret
#
#
#
#
# 5572 endbr64
#
#
#
#
# 5576 push  rbp
#
#
#
#
# 5577 mov  rbp, rsp
#
#
#
#
# 5580 mov  dword ptr [rbp - 4], edi
#
#
#
#
# 5583 mov  dword ptr [rbp - 8], esi
#
#
#
#
# 5586 mov  eax, dword ptr [rbp - 4]
#
#
#
#
# 5589 sub  eax, dword ptr [rbp - 8]
#
#
#
#
# 5592 pop  rbp
#
#
#
#
# 5593 ret
#
#
#
#
# 5594 endbr64
#
#
#
#
# 5598 push  rbp
#
#
#
#
# 5599 mov  rbp, rsp
#
#
#
#
# 5602 movss  dword ptr [rbp - 4], xmm0
#
#
#
#
# 5607 movss  dword ptr [rbp - 8], xmm1
#
#
#
#
# 5612 movss  xmm0, dword ptr [rbp - 4]
#
#
#
#
# 5617 subss  xmm0, dword ptr [rbp - 8]
#
#
#
#
# 5622 pop  rbp
#
#
#
#
# 5623 ret

# %%
from collections import defaultdict
import posixpath

# %%
addr_lineProgram ={}
addr_sourceFile = {}
with open(filePath, 'rb') as f:
    elffile = ELFFile(f)

    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
        exit(0)

    dwarfinfo = elffile.get_dwarf_info()
    for CU in dwarfinfo.iter_CUs():
#         print(CU.get_top_DIE()['DW_AT_comp_dir'])
        CU_DIR_PATH = None
        CU_FILENAME = None
        for attr in CU.get_top_DIE().attributes.values():
            if attr.name == 'DW_AT_comp_dir':
                CU_DIR_PATH = attr.value.decode("utf-8")
            if attr.name == 'DW_AT_name':
                CU_FILENAME = attr.value.decode("utf-8")
            
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        line_program = dwarfinfo.line_program_for_CU(CU)
        if line_program is None:
            print('  DWARF info is missing a line program for this CU')
            continue

        for line_entry in line_program.get_entries():
            real_source_path = None
            if line_entry.state!=None:
                    addr_lineProgram[hex(line_entry.state.address)] = line_entry

                    src_filename_from_lineentry, dir_index = (lpe_filename (line_program, line_entry.state.file))
                    
                    if src_filename_from_lineentry == CU_FILENAME:
                        real_source_path = os.path.join(CU_DIR_PATH,CU_FILENAME)
                    else:
                        if '/' in src_filename_from_lineentry:
                            real_source_path = src_filename_from_lineentry
                        elif dir_index==0:
                            real_source_path = os.path.join(CU_DIR_PATH,src_filename_from_lineentry)

                    addr_sourceFile [hex(line_entry.state.address)] = real_source_path
# Out:
#   Found a compile unit at offset 0, length 897
#   Found a compile unit at offset 901, length 518
#   Found a compile unit at offset 1423, length 442

# %%
# print(addr_lineProgram)
# address_inst

def getSource(sourceFilePath, row , col):
    sourceFile = open(sourceFilePath, "r")
    fileContent = sourceFile.readlines()
    
    print(sourceFilePath, 'row: ',row , 'col ',col )
    row_content =  fileContent[row-1]
    
    
#     if len(row_content)<col:
#         return row_content
#     print(sourceFilePath, row , 'col ',col , 'len: ',len(row_content))
#     print("*****",row_content,"))))")
#     print('_',row_content[:(col-1)])
#     print("_ _",row_content[col-1])
#     print("_ _ _",row_content[col:])

    
    row_content = row_content[:(col-1)] + '|'+row_content[(col-1)]+'|' +row_content[col:]
    
    return row_content

# %%
# FUNCTION_DECL
# https://stackoverflow.com/questions/43460605/function-boundary-identification-using-libclang
# https://eli.thegreenplace.net/2011/07/03/parsing-c-in-python-with-clang


import clang.cindex



def get_all_var_types(source_path):
    srcFileName = source_path.split('/')[-1]

    function_boundary_by_name = {}
    idx = clang.cindex.Index.create()
    tu = idx.parse(source_path)
    
    for f in tu.cursor.walk_preorder():
        if f.kind == clang.cindex.CursorKind.VAR_DECL:
            # print(dir(f))
            print(f.extent.start.file.name)
            originFileName = f.extent.start.file.name.split('/')[-1]
            print(originFileName)
            print(f.displayname)
            print(f.type.spelling)
            print(f.extent.start.line,f.extent.start.column)
            print('\n')
            
            

   

def get_all_function_types(source_path):
    function_boundary_by_name = {}
    idx = clang.cindex.Index.create()
    tu = idx.parse(source_path)
    
    for f in tu.cursor.walk_preorder():
        if f.kind == clang.cindex.CursorKind.FUNCTION_DECL:
            # print(dir(f))
            print(f.displayname)
            print('function name: ',( f.spelling))
            print('Returns: ',(f.result_type.spelling))
            
            
            arg_len = len(list(f.type.argument_types()))
            if arg_len>0:
                arg_types = list(f.type.argument_types())
                for arg_type in arg_types:
                    print('arg_type:',arg_type.spelling)
                args = list(f.get_arguments())
                for arg in args:
                    print('arg:',arg.spelling)


            print("\n\n\n")

            
def get_function_boundaries(source_path):
    
    function_boundary_by_name = {}
    idx = clang.cindex.Index.create()
    tu = idx.parse(source_path)
    
    for f in tu.cursor.walk_preorder():
        if f.kind == clang.cindex.CursorKind.FUNCTION_DECL:

            function_name = f.displayname.split('(')[0]
            function_boundary_by_name[function_name]={}
            function_boundary_by_name[function_name] = { 'src_path':f.extent.start.file.name,
                              'src_file':f.extent.start.file.name.split('/')[-1],
                              'start_line':f.extent.start.line,
                              'start_col':f.extent.start.column,
                              'end_line':f.extent.end.line,
                              'end_col':f.extent.end.column}
    return function_boundary_by_name

def get_containing_function(source_file_path, line, col=0):
    function_boundary_by_name = get_function_boundaries(source_file_path)
    
    for function_name, item in function_boundary_by_name.items():
        if item['src_path'] == source_file_path:
            if line>= item['start_line'] and line<= item['end_line']:
                return function_name

# %%
with open('gitfm.s', 'w') as outFile:
    # outFile.write('file contents\n')
    lastSource = ""
    for address in address_inst:
        inst = address_inst[address]
        instrctionCode = (address+":\t"+ inst.mnemonic+" "+inst.op_str).ljust(45)

        OFFSET = None
        if len(inst.operands) > 0 :
            c=-1
            for o in inst.operands:
                c += 1
                if o.type == CS_OP_MEM:
                    print("\t\toperands[%u].type: MEM" %c)
                    if o.value.mem.base != 0:
                        print("\t\t\toperands[%u].mem.base: REG = %s" \
                            %(c, inst.reg_name(o.value.mem.base)))
                    if o.value.mem.index != 0:
                        print("\t\t\toperands[%u].mem.index: REG = %s" \
                            %(c, inst.reg_name(o.value.mem.index)))
                    if o.value.mem.disp != 0:
                        print("\t\t\toperands[%u].mem.disp: 0x%x" \
                            %(c, o.value.mem.disp))
                        OFFSET = o.value.mem.disp
                    print(hex(o.value.mem.disp),o.value.mem.disp)
                    
        
        if address in addr_lineProgram:
            
            srcFilePath = addr_sourceFile[address] 
            if srcFilePath!=lastSource:
                outFile.write("\n"+ '#'*100+"\n"+ srcFilePath.rjust(45) +'\n'+'#'*100+ "\n\n")
                lastSource = srcFilePath
            print("add",address)
            

            sourceCode = getSource(srcFilePath,addr_lineProgram[address].state.line, addr_lineProgram[address].state.column)
            function_name = get_containing_function(srcFilePath ,addr_lineProgram[address].state.line , addr_lineProgram[address].state.column)


            if '\n' not in  sourceCode:
                sourceCode+=sourceCode+"\n"
            outFile.write(instrctionCode+"#"+ sourceCode  )
            print(instrctionCode+"#"+ sourceCode)

            
        else:
            
            outFile.write(instrctionCode+ '\n'  )
            print(instrctionCode)
        if OFFSET:
            outFile.write("MEMORY OFFSET:     "+str(hex(OFFSET))+"     "+str(OFFSET)+'\n')
            pass
# Out:
# add 0x11a9
# /home/nahid/reverse/binaries/c_many/stack.c row:  6 col  40
# 0x11a9:	endbr64                              #void push(int number, stack **stk_ptr) |{|
#
# 0x11ad:	push rbp
# 0x11ae:	mov rbp, rsp
# 0x11b1:	sub rsp, 0x30
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-24
# -0x24 -36
# 0x11b5:	mov dword ptr [rbp - 0x24], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-30
# -0x30 -48
# 0x11b8:	mov qword ptr [rbp - 0x30], rsi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# add 0x11bc
# /home/nahid/reverse/binaries/c_many/stack.c row:  7 col  9
# 0x11bc:	mov dword ptr [rbp - 0x18], 0xa      #    int |p|op = 10;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# add 0x11c3
# /home/nahid/reverse/binaries/c_many/stack.c row:  8 col  18
# 0x11c3:	mov dword ptr [rbp - 0x14], 0xc      #    unsigned int |m|ing = 12;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-30
# -0x30 -48
# add 0x11ca
# /home/nahid/reverse/binaries/c_many/stack.c row:  12 col  9
# 0x11ca:	mov rax, qword ptr [rbp - 0x30]      #    stk |=| *stk_ptr;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 0x0 0
# 0x11ce:	mov rax, qword ptr [rax]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# 0x11d1:	mov qword ptr [rbp - 0x10], rax
# add 0x11d5
# /home/nahid/reverse/binaries/c_many/stack.c row:  13 col  11
# 0x11d5:	mov edi, 0x10                        #    tmp = |m|alloc(sizeof(stack));
#
# 0x11da:	call 0x10b0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x11df:	mov qword ptr [rbp - 8], rax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x11e3
# /home/nahid/reverse/binaries/c_many/stack.c row:  14 col  17
# 0x11e3:	mov rax, qword ptr [rbp - 8]         #    tmp->number |=| number;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-24
# -0x24 -36
# 0x11e7:	mov edx, dword ptr [rbp - 0x24]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x11ea:	mov dword ptr [rax], edx
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x11ec
# /home/nahid/reverse/binaries/c_many/stack.c row:  15 col  15
# 0x11ec:	mov rax, qword ptr [rbp - 8]         #    tmp->next |=| stk;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# 0x11f0:	mov rdx, qword ptr [rbp - 0x10]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.disp: 0x8
# 0x8 8
# 0x11f4:	mov qword ptr [rax + 8], rdx
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x11f8
# /home/nahid/reverse/binaries/c_many/stack.c row:  16 col  9
# 0x11f8:	mov rax, qword ptr [rbp - 8]         #    stk |=| tmp;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# 0x11fc:	mov qword ptr [rbp - 0x10], rax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-30
# -0x30 -48
# add 0x1200
# /home/nahid/reverse/binaries/c_many/stack.c row:  17 col  14
# 0x1200:	mov rax, qword ptr [rbp - 0x30]      #    *stk_ptr |=| stk;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# 0x1204:	mov rdx, qword ptr [rbp - 0x10]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x1208:	mov qword ptr [rax], rdx
# add 0x120b
# /home/nahid/reverse/binaries/c_many/stack.c row:  18 col  1
# 0x120b:	nop                                  #|}|
#
# 0x120c:	leave
# 0x120d:	ret
# add 0x120e
# /home/nahid/reverse/binaries/c_many/stack.c row:  19 col  76
# 0x120e:	endbr64                              # int dummy(int a_int, float b_float, double c_double,  char * char_pointer)|{|
#
# 0x1212:	push rbp
# 0x1213:	mov rbp, rsp
# 0x1216:	sub rsp, 0xa0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-84
# -0x84 -132
# 0x121d:	mov dword ptr [rbp - 0x84], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-88
# -0x88 -136
# 0x1223:	movss dword ptr [rbp - 0x88], xmm0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-90
# -0x90 -144
# 0x122b:	movsd qword ptr [rbp - 0x90], xmm1
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-98
# -0x98 -152
# 0x1233:	mov qword ptr [rbp - 0x98], rsi
# 		operands[1].type: MEM
# 			operands[1].mem.disp: 0x28
# 0x28 40
# add 0x123a
# /home/nahid/reverse/binaries/c_many/stack.c row:  19 col  76
# 0x123a:	mov rax, qword ptr fs:[0x28]         # int dummy(int a_int, float b_float, double c_double,  char * char_pointer)|{|
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x1243:	mov qword ptr [rbp - 8], rax
# 0x1247:	xor eax, eax
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-74
# -0x74 -116
# add 0x1249
# /home/nahid/reverse/binaries/c_many/stack.c row:  21 col  13
# 0x1249:	mov dword ptr [rbp - 0x74], 2        #        int |e|_int =2;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xdb0
# 0xdb0 3504
# add 0x1250
# /home/nahid/reverse/binaries/c_many/stack.c row:  22 col  15
# 0x1250:	movss xmm0, dword ptr [rip + 0xdb0]  #        float |f|_float =1.0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-70
# -0x70 -112
# 0x1258:	movss dword ptr [rbp - 0x70], xmm0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xdab
# 0xdab 3499
# add 0x125d
# /home/nahid/reverse/binaries/c_many/stack.c row:  23 col  16
# 0x125d:	movsd xmm0, qword ptr [rip + 0xdab]  #        double |g|_double = 2.0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-68
# -0x68 -104
# 0x1265:	movsd qword ptr [rbp - 0x68], xmm0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-84
# -0x84 -132
# add 0x126a
# /home/nahid/reverse/binaries/c_many/stack.c row:  25 col  15
# 0x126a:	mov eax, dword ptr [rbp - 0x84]      #        e_int |=| a_int*2;
#
# 0x1270:	add eax, eax
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-74
# -0x74 -116
# 0x1272:	mov dword ptr [rbp - 0x74], eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-70
# -0x70 -112
# add 0x1275
# /home/nahid/reverse/binaries/c_many/stack.c row:  26 col  17
# 0x1275:	movss xmm0, dword ptr [rbp - 0x70]   #        f_float |=| f_float * b_float;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-88
# -0x88 -136
# 0x127a:	mulss xmm0, dword ptr [rbp - 0x88]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-70
# -0x70 -112
# 0x1282:	movss dword ptr [rbp - 0x70], xmm0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-98
# -0x98 -152
# add 0x1287
# /home/nahid/reverse/binaries/c_many/stack.c row:  27 col  9
# 0x1287:	mov rax, qword ptr [rbp - 0x98]      #        |p|rintf('%s',char_pointer);
#
# 0x128e:	mov rsi, rax
# 0x1291:	mov edi, 0x2573
# 0x1296:	mov eax, 0
# 0x129b:	call 0x10a0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-6c
# -0x6c -108
# add 0x12a0
# /home/nahid/reverse/binaries/c_many/stack.c row:  29 col  28
# 0x12a0:	mov dword ptr [rbp - 0x6c], 0        #        int x1,x2,x3,x4,x5,|x|6 = 0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-78
# -0x78 -120
# add 0x12a7
# /home/nahid/reverse/binaries/c_many/stack.c row:  31 col  18
# 0x12a7:	mov dword ptr [rbp - 0x78], 0        #        for (int |k|=0; k<20;k++){
#
# add 0x12ae
# /home/nahid/reverse/binaries/c_many/stack.c row:  31 col  9
# 0x12ae:	jmp 0x12c4                           #        |f|or (int k=0; k<20;k++){
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-74
# -0x74 -116
# add 0x12b0
# /home/nahid/reverse/binaries/c_many/stack.c row:  32 col  31
# 0x12b0:	mov eax, dword ptr [rbp - 0x74]      #            int_arr[k] = e_int|%|k;
#
# 0x12b3:	cdq
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-78
# -0x78 -120
# 0x12b4:	idiv dword ptr [rbp - 0x78]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-78
# -0x78 -120
# add 0x12b7
# /home/nahid/reverse/binaries/c_many/stack.c row:  32 col  24
# 0x12b7:	mov eax, dword ptr [rbp - 0x78]      #            int_arr[k] |=| e_int%k;
#
# 0x12ba:	cdqe
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.index: REG = rax
# 			operands[0].mem.disp: 0x-60
# -0x60 -96
# 0x12bc:	mov dword ptr [rbp + rax*4 - 0x60], edx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-78
# -0x78 -120
# add 0x12c0
# /home/nahid/reverse/binaries/c_many/stack.c row:  31 col  29
# 0x12c0:	add dword ptr [rbp - 0x78], 1        #        for (int k=0; k<20;k|+|+){
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-78
# -0x78 -120
# add 0x12c4
# /home/nahid/reverse/binaries/c_many/stack.c row:  31 col  24
# 0x12c4:	cmp dword ptr [rbp - 0x78], 0x13     #        for (int k=0; k|<|20;k++){
#
# 0x12c8:	jle 0x12b0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-74
# -0x74 -116
# add 0x12ca
# /home/nahid/reverse/binaries/c_many/stack.c row:  35 col  21
# 0x12ca:	mov eax, dword ptr [rbp - 0x74]      #        return e_int|*|a_int;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-84
# -0x84 -132
# 0x12cd:	imul eax, dword ptr [rbp - 0x84]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x12d4
# /home/nahid/reverse/binaries/c_many/stack.c row:  37 col  2
# 0x12d4:	mov rdx, qword ptr [rbp - 8]         # |}|
#
# 		operands[1].type: MEM
# 			operands[1].mem.disp: 0x28
# 0x28 40
# 0x12d8:	sub rdx, qword ptr fs:[0x28]
# 0x12e1:	je 0x12e8
# 0x12e3:	call 0x1090
# 0x12e8:	leave
# 0x12e9:	ret
# add 0x12ea
# /home/nahid/reverse/binaries/c_many/stack.c row:  39 col  26
# 0x12ea:	endbr64                              #int pop(stack **stk_ptr) |{|
#
# 0x12ee:	push rbp
# 0x12ef:	mov rbp, rsp
# 0x12f2:	sub rsp, 0x30
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-28
# -0x28 -40
# 0x12f6:	mov qword ptr [rbp - 0x28], rdi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-1c
# -0x1c -28
# add 0x12fa
# /home/nahid/reverse/binaries/c_many/stack.c row:  40 col  9
# 0x12fa:	mov dword ptr [rbp - 0x1c], 0xb      #    int |i|nt1 =11;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# add 0x1301
# /home/nahid/reverse/binaries/c_many/stack.c row:  41 col  9
# 0x1301:	mov dword ptr [rbp - 0x18], 0xc      #    int |i|nt2 =12;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-28
# -0x28 -40
# add 0x1308
# /home/nahid/reverse/binaries/c_many/stack.c row:  44 col  9
# 0x1308:	mov rax, qword ptr [rbp - 0x28]      #    stk |=| *stk_ptr;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 0x0 0
# 0x130c:	mov rax, qword ptr [rax]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# 0x130f:	mov qword ptr [rbp - 0x10], rax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x1313
# /home/nahid/reverse/binaries/c_many/stack.c row:  45 col  9
# 0x1313:	mov rax, qword ptr [rbp - 0x10]      #    tmp |=| stk;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x1317:	mov qword ptr [rbp - 8], rax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x131b
# /home/nahid/reverse/binaries/c_many/stack.c row:  46 col  12
# 0x131b:	mov rax, qword ptr [rbp - 8]         #    number |=| tmp->number;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 0x0 0
# 0x131f:	mov eax, dword ptr [rax]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# 0x1321:	mov dword ptr [rbp - 0x14], eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x1324
# /home/nahid/reverse/binaries/c_many/stack.c row:  47 col  9
# 0x1324:	mov rax, qword ptr [rbp - 0x10]      #    stk |=| stk->next;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 			operands[1].mem.disp: 0x8
# 0x8 8
# 0x1328:	mov rax, qword ptr [rax + 8]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# 0x132c:	mov qword ptr [rbp - 0x10], rax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x1330
# /home/nahid/reverse/binaries/c_many/stack.c row:  48 col  5
# 0x1330:	mov rax, qword ptr [rbp - 8]         #    |f|ree(tmp);
#
# 0x1334:	mov rdi, rax
# 0x1337:	call 0x1080
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-28
# -0x28 -40
# add 0x133c
# /home/nahid/reverse/binaries/c_many/stack.c row:  49 col  14
# 0x133c:	mov rax, qword ptr [rbp - 0x28]      #    *stk_ptr |=| stk;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# 0x1340:	mov rdx, qword ptr [rbp - 0x10]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x1344:	mov qword ptr [rax], rdx
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-14
# -0x14 -20
# add 0x1347
# /home/nahid/reverse/binaries/c_many/stack.c row:  50 col  12
# 0x1347:	mov eax, dword ptr [rbp - 0x14]      #    return |n|umber;
#
# add 0x134a
# /home/nahid/reverse/binaries/c_many/stack.c row:  51 col  1
# 0x134a:	leave                                #|}|
#
# 0x134b:	ret
# add 0x134c
# /home/nahid/reverse/binaries/c_many/stack.c row:  53 col  31
# 0x134c:	endbr64                              #int fake(int a , int b, int x)|{|
#
# 0x1350:	push rbp
# 0x1351:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# 0x1354:	mov dword ptr [rbp - 0x14], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# 0x1357:	mov dword ptr [rbp - 0x18], esi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-1c
# -0x1c -28
# 0x135a:	mov dword ptr [rbp - 0x1c], edx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# add 0x135d
# /home/nahid/reverse/binaries/c_many/stack.c row:  55 col  9
# 0x135d:	mov dword ptr [rbp - 0x10], 0xa      #    int |d| =10;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# add 0x1364
# /home/nahid/reverse/binaries/c_many/stack.c row:  56 col  9
# 0x1364:	mov dword ptr [rbp - 0xc], 0xb       #    int |e| =11;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# add 0x136b
# /home/nahid/reverse/binaries/c_many/stack.c row:  57 col  9
# 0x136b:	mov dword ptr [rbp - 8], 0xc         #    int |f| =12;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-14
# -0x14 -20
# add 0x1372
# /home/nahid/reverse/binaries/c_many/stack.c row:  59 col  14
# 0x1372:	mov edx, dword ptr [rbp - 0x14]      #    int g = a|+|b+d+e+f;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-18
# -0x18 -24
# 0x1375:	mov eax, dword ptr [rbp - 0x18]
# 0x1378:	add edx, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x137a
# /home/nahid/reverse/binaries/c_many/stack.c row:  59 col  16
# 0x137a:	mov eax, dword ptr [rbp - 0x10]      #    int g = a+b|+|d+e+f;
#
# 0x137d:	add edx, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-c
# -0xc -12
# add 0x137f
# /home/nahid/reverse/binaries/c_many/stack.c row:  59 col  18
# 0x137f:	mov eax, dword ptr [rbp - 0xc]       #    int g = a+b+d|+|e+f;
#
# 0x1382:	add edx, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x1384
# /home/nahid/reverse/binaries/c_many/stack.c row:  59 col  9
# 0x1384:	mov eax, dword ptr [rbp - 8]         #    int |g| = a+b+d+e+f;
#
# 0x1387:	add eax, edx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x1389:	mov dword ptr [rbp - 4], eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x138c
# /home/nahid/reverse/binaries/c_many/stack.c row:  60 col  12
# 0x138c:	mov eax, dword ptr [rbp - 4]         #    return |g|;
#
# add 0x138f
# /home/nahid/reverse/binaries/c_many/stack.c row:  65 col  1
# 0x138f:	pop rbp                              #|}|
#
# 0x1390:	ret
# add 0x1391
# /home/nahid/reverse/binaries/c_many/main.c row:  7 col  12
# 0x1391:	endbr64                              #int main() |{|
#
# 0x1395:	push rbp
# 0x1396:	mov rbp, rsp
# 0x1399:	sub rsp, 0x40
# 		operands[1].type: MEM
# 			operands[1].mem.disp: 0x28
# 0x28 40
# add 0x139d
# /home/nahid/reverse/binaries/c_many/main.c row:  7 col  12
# 0x139d:	mov rax, qword ptr fs:[0x28]         #int main() |{|
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x13a6:	mov qword ptr [rbp - 8], rax
# 0x13aa:	xor eax, eax
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-20
# -0x20 -32
# add 0x13ac
# /home/nahid/reverse/binaries/c_many/main.c row:  8 col  12
# 0x13ac:	mov qword ptr [rbp - 0x20], 0        #    stack *|s|tk = NULL;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x13b4
# /home/nahid/reverse/binaries/c_many/main.c row:  9 col  5
# 0x13b4:	lea rax, [rbp - 0x20]                #    |p|ush(7, &stk);
#
# 0x13b8:	mov rsi, rax
# 0x13bb:	mov edi, 7
# 0x13c0:	call 0x11a9
# add 0x13c5
# /home/nahid/reverse/binaries/c_many/main.c row:  10 col  16
# 0x13c5:	mov esi, 2                           #    int temp = |a|dd(1,2);
#
# 0x13ca:	mov edi, 1
# 0x13cf:	call 0x1530
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-34
# -0x34 -52
# 0x13d4:	mov dword ptr [rbp - 0x34], eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x13d7
# /home/nahid/reverse/binaries/c_many/main.c row:  11 col  5
# 0x13d7:	lea rdx, [rbp - 0x20]                #    |p|ush(temp, &stk);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-34
# -0x34 -52
# 0x13db:	mov eax, dword ptr [rbp - 0x34]
# 0x13de:	mov rsi, rdx
# 0x13e1:	mov edi, eax
# 0x13e3:	call 0x11a9
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-30
# -0x30 -48
# add 0x13e8
# /home/nahid/reverse/binaries/c_many/main.c row:  13 col  9
# 0x13e8:	mov dword ptr [rbp - 0x30], 0        #    int |f|ake_param1 = 0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-2c
# -0x2c -44
# add 0x13ef
# /home/nahid/reverse/binaries/c_many/main.c row:  14 col  9
# 0x13ef:	mov dword ptr [rbp - 0x2c], 1        #    int |f|ake_param2 = 1;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-2c
# -0x2c -44
# add 0x13f6
# /home/nahid/reverse/binaries/c_many/main.c row:  15 col  23
# 0x13f6:	mov ecx, dword ptr [rbp - 0x2c]      #    int fake_result = |f|ake(fake_param1 , fake_param2, 10);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-30
# -0x30 -48
# 0x13f9:	mov eax, dword ptr [rbp - 0x30]
# 0x13fc:	mov edx, 0xa
# 0x1401:	mov esi, ecx
# 0x1403:	mov edi, eax
# 0x1405:	call 0x134c
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-28
# -0x28 -40
# 0x140a:	mov dword ptr [rbp - 0x28], eax
# add 0x140d
# /home/nahid/reverse/binaries/c_many/main.c row:  19 col  10
# 0x140d:	movabs rax, 0x745320796d6d7544       #    char |d|ummy_str[] = "Dummy Str";
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-12
# -0x12 -18
# 0x1417:	mov qword ptr [rbp - 0x12], rax
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-a
# -0xa -10
# 0x141b:	mov word ptr [rbp - 0xa], 0x72
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-12
# -0x12 -18
# add 0x1421
# /home/nahid/reverse/binaries/c_many/main.c row:  20 col  21
# 0x1421:	lea rax, [rbp - 0x12]                #    int dummy_out = |d|ummy(1, 2.0, 3.0,  dummy_str);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xbf3
# 0xbf3 3059
# 0x1425:	movsd xmm0, qword ptr [rip + 0xbf3]
# 0x142d:	mov rsi, rax
# 0x1430:	movapd xmm1, xmm0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xbee
# 0xbee 3054
# 0x1434:	mov eax, dword ptr [rip + 0xbee]
# 0x143a:	movd xmm0, eax
# 0x143e:	mov edi, 1
# 0x1443:	call 0x120e
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-24
# -0x24 -36
# 0x1448:	mov dword ptr [rbp - 0x24], eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x144b
# /home/nahid/reverse/binaries/c_many/main.c row:  22 col  5
# 0x144b:	lea rax, [rbp - 0x20]                #    |p|ush(9, &stk);
#
# 0x144f:	mov rsi, rax
# 0x1452:	mov edi, 9
# 0x1457:	call 0x11a9
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x145c
# /home/nahid/reverse/binaries/c_many/main.c row:  23 col  5
# 0x145c:	lea rax, [rbp - 0x20]                #    |p|ush(12,&stk);
#
# 0x1460:	mov rsi, rax
# 0x1463:	mov edi, 0xc
# 0x1468:	call 0x11a9
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x146d
# /home/nahid/reverse/binaries/c_many/main.c row:  24 col  5
# 0x146d:	lea rax, [rbp - 0x20]                #    |p|rintf("%d\n",pop(&stk));
#
# 0x1471:	mov rdi, rax
# 0x1474:	call 0x12ea
# 0x1479:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xb96
# 0xb96 2966
# 0x147b:	lea rax, [rip + 0xb96]
# 0x1482:	mov rdi, rax
# 0x1485:	mov eax, 0
# 0x148a:	call 0x10a0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x148f
# /home/nahid/reverse/binaries/c_many/main.c row:  25 col  5
# 0x148f:	lea rax, [rbp - 0x20]                #    |p|rintf("%d\n",pop(&stk));
#
# 0x1493:	mov rdi, rax
# 0x1496:	call 0x12ea
# 0x149b:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xb74
# 0xb74 2932
# 0x149d:	lea rax, [rip + 0xb74]
# 0x14a4:	mov rdi, rax
# 0x14a7:	mov eax, 0
# 0x14ac:	call 0x10a0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x14b1
# /home/nahid/reverse/binaries/c_many/main.c row:  26 col  5
# 0x14b1:	lea rax, [rbp - 0x20]                #    |p|rintf("%d\n",pop(&stk));
#
# 0x14b5:	mov rdi, rax
# 0x14b8:	call 0x12ea
# 0x14bd:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xb52
# 0xb52 2898
# 0x14bf:	lea rax, [rip + 0xb52]
# 0x14c6:	mov rdi, rax
# 0x14c9:	mov eax, 0
# 0x14ce:	call 0x10a0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x14d3
# /home/nahid/reverse/binaries/c_many/main.c row:  27 col  5
# 0x14d3:	lea rax, [rbp - 0x20]                #    |p|rintf("%d\n",pop(&stk));
#
# 0x14d7:	mov rdi, rax
# 0x14da:	call 0x12ea
# 0x14df:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xb30
# 0xb30 2864
# 0x14e1:	lea rax, [rip + 0xb30]
# 0x14e8:	mov rdi, rax
# 0x14eb:	mov eax, 0
# 0x14f0:	call 0x10a0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x14f5
# /home/nahid/reverse/binaries/c_many/main.c row:  28 col  5
# 0x14f5:	lea rax, [rbp - 0x20]                #    |p|rintf("%d\n",pop(&stk));
#
# 0x14f9:	mov rdi, rax
# 0x14fc:	call 0x12ea
# 0x1501:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xb0e
# 0xb0e 2830
# 0x1503:	lea rax, [rip + 0xb0e]
# 0x150a:	mov rdi, rax
# 0x150d:	mov eax, 0
# 0x1512:	call 0x10a0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-28
# -0x28 -40
# add 0x1517
# /home/nahid/reverse/binaries/c_many/main.c row:  29 col  12
# 0x1517:	mov eax, dword ptr [rbp - 0x28]      #    return |f|ake_result;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x151a
# /home/nahid/reverse/binaries/c_many/main.c row:  30 col  1
# 0x151a:	mov rdx, qword ptr [rbp - 8]         #|}||}|
#
# 		operands[1].type: MEM
# 			operands[1].mem.disp: 0x28
# 0x28 40
# 0x151e:	sub rdx, qword ptr fs:[0x28]
# 0x1527:	je 0x152e
# 0x1529:	call 0x1090
# 0x152e:	leave
# 0x152f:	ret
# add 0x1530
# /home/nahid/reverse/binaries/c_many/calculate.c row:  5 col  22
# 0x1530:	endbr64                              #int add(int a, int b)|{|
#
# 0x1534:	push rbp
# 0x1535:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# 0x1538:	mov dword ptr [rbp - 0x14], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# 0x153b:	mov dword ptr [rbp - 0x18], esi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# add 0x153e
# /home/nahid/reverse/binaries/c_many/calculate.c row:  6 col  9
# 0x153e:	mov dword ptr [rbp - 0xc], 0xa       #    int |r|an = 10;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# add 0x1545
# /home/nahid/reverse/binaries/c_many/calculate.c row:  7 col  9
# 0x1545:	add dword ptr [rbp - 0xc], 0xc       #    ran |=| ran +12;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-c
# -0xc -12
# add 0x1549
# /home/nahid/reverse/binaries/c_many/calculate.c row:  8 col  9
# 0x1549:	mov eax, dword ptr [rbp - 0xc]       #    ran |=|ran*ran;
#
# 0x154c:	imul eax, eax
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# 0x154f:	mov dword ptr [rbp - 0xc], eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xad2
# 0xad2 2770
# add 0x1552
# /home/nahid/reverse/binaries/c_many/calculate.c row:  9 col  11
# 0x1552:	movss xmm0, dword ptr [rip + 0xad2]  #    float |f|ran =0.12;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x155a:	movss dword ptr [rbp - 8], xmm0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x155f
# /home/nahid/reverse/binaries/c_many/calculate.c row:  10 col  10
# 0x155f:	movss xmm1, dword ptr [rbp - 8]      #    fran |=| fran+1.0;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xac4
# 0xac4 2756
# 0x1564:	movss xmm0, dword ptr [rip + 0xac4]
# 0x156c:	addss xmm0, xmm1
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x1570:	movss dword ptr [rbp - 8], xmm0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# add 0x1575
# /home/nahid/reverse/binaries/c_many/calculate.c row:  11 col  14
# 0x1575:	mov dword ptr [rbp - 0x10], 0        #    for (int |i| = 0; i<10;i++){
#
# add 0x157c
# /home/nahid/reverse/binaries/c_many/calculate.c row:  11 col  5
# 0x157c:	jmp 0x158d                           #    |f|or (int i = 0; i<10;i++){
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# add 0x157e
# /home/nahid/reverse/binaries/c_many/calculate.c row:  12 col  13
# 0x157e:	mov dword ptr [rbp - 4], 0           #        int |f|ran = 0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# add 0x1585
# /home/nahid/reverse/binaries/c_many/calculate.c row:  13 col  13
# 0x1585:	add dword ptr [rbp - 4], 2           #        fran|=|fran+2;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# add 0x1589
# /home/nahid/reverse/binaries/c_many/calculate.c row:  11 col  27
# 0x1589:	add dword ptr [rbp - 0x10], 1        #    for (int i = 0; i<10;i|+|+){
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# add 0x158d
# /home/nahid/reverse/binaries/c_many/calculate.c row:  11 col  22
# 0x158d:	cmp dword ptr [rbp - 0x10], 9        #    for (int i = 0; i|<|10;i++){
#
# 0x1591:	jle 0x157e
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# add 0x1593
# /home/nahid/reverse/binaries/c_many/calculate.c row:  15 col  9
# 0x1593:	sub dword ptr [rbp - 0xc], 0xa       #    ran |=|ran -10;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-14
# -0x14 -20
# add 0x1597
# /home/nahid/reverse/binaries/c_many/calculate.c row:  16 col  13
# 0x1597:	mov edx, dword ptr [rbp - 0x14]      #    return a|+|b+ran;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-18
# -0x18 -24
# 0x159a:	mov eax, dword ptr [rbp - 0x18]
# 0x159d:	add edx, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-c
# -0xc -12
# add 0x159f
# /home/nahid/reverse/binaries/c_many/calculate.c row:  16 col  15
# 0x159f:	mov eax, dword ptr [rbp - 0xc]       #    return a+b|+|ran;
#
# 0x15a2:	add eax, edx
# add 0x15a4
# /home/nahid/reverse/binaries/c_many/calculate.c row:  17 col  1
# 0x15a4:	pop rbp                              #|}|
#
# 0x15a5:	ret
# add 0x15a6
# /home/nahid/reverse/binaries/c_many/calculate.c row:  18 col  29
# 0x15a6:	endbr64                              #float addf(float a, float b)|{|
#
# 0x15aa:	push rbp
# 0x15ab:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x15ae:	movss dword ptr [rbp - 4], xmm0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x15b3:	movss dword ptr [rbp - 8], xmm1
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x15b8
# /home/nahid/reverse/binaries/c_many/calculate.c row:  19 col  13
# 0x15b8:	movss xmm0, dword ptr [rbp - 4]      #    return a|+|b;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# 0x15bd:	addss xmm0, dword ptr [rbp - 8]
# add 0x15c2
# /home/nahid/reverse/binaries/c_many/calculate.c row:  20 col  1
# 0x15c2:	pop rbp                              #|}|
#
# 0x15c3:	ret
# add 0x15c4
# /home/nahid/reverse/binaries/c_many/calculate.c row:  23 col  28
# 0x15c4:	endbr64                              #int substract(int a, int b)|{|
#
# 0x15c8:	push rbp
# 0x15c9:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x15cc:	mov dword ptr [rbp - 4], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x15cf:	mov dword ptr [rbp - 8], esi
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x15d2
# /home/nahid/reverse/binaries/c_many/calculate.c row:  24 col  13
# 0x15d2:	mov eax, dword ptr [rbp - 4]         #    return a|-|b;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# 0x15d5:	sub eax, dword ptr [rbp - 8]
# add 0x15d8
# /home/nahid/reverse/binaries/c_many/calculate.c row:  25 col  1
# 0x15d8:	pop rbp                              #|}|
#
# 0x15d9:	ret
# add 0x15da
# /home/nahid/reverse/binaries/c_many/calculate.c row:  26 col  35
# 0x15da:	endbr64                              #float substractf(float a, float b)|{|
#
# 0x15de:	push rbp
# 0x15df:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x15e2:	movss dword ptr [rbp - 4], xmm0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x15e7:	movss dword ptr [rbp - 8], xmm1
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x15ec
# /home/nahid/reverse/binaries/c_many/calculate.c row:  27 col  13
# 0x15ec:	movss xmm0, dword ptr [rbp - 4]      #    return a|-|b;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# 0x15f1:	subss xmm0, dword ptr [rbp - 8]
# add 0x15f6
# /home/nahid/reverse/binaries/c_many/calculate.c row:  28 col  1
# 0x15f6:	pop rbp                              #|}|
#
# 0x15f7:	ret
