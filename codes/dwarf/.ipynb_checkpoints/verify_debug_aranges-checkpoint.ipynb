# %%
from elftools.elf.elffile import ELFFile
from elftools.dwarf.descriptions import (
    describe_DWARF_expr, set_global_machine_arch)
from elftools.dwarf.locationlists import (
    LocationEntry, LocationExpr, LocationParser)

import posixpath

# filePath = './../../binaries/gnuit/src/gitfm'

filePath = './../../binaries/c_many/stacktest'

# %%
def get_DIE_at_offset(CU, offset):
        for die in CU.iter_DIEs():
            if die.offset == CU.cu_offset+offset:
                return die 
        return None


##TODO FIX CONSTANT TYPE
def get_type_name(CU, offset):#get_DIE_at_offset(CU,attr.value)
    die = get_DIE_at_offset(CU, offset)
    
    if die.tag == 'DW_TAG_const_type':
        return "const"
    
    if die.tag == 'DW_TAG_pointer_type' :
        for _attr in die.attributes.values():
            if _attr.name== "DW_AT_type":
                
                return "*"+get_type_name(CU, _attr.value) 

    elif die.tag =='DW_TAG_subroutine_type':
        

        for _attr in die.attributes.values():
            if _attr.name== "DW_AT_sibling":
                return get_type_name(CU, _attr.value) 
            
            if _attr.name== "DW_AT_type":
                return "*"+get_type_name(CU, _attr.value) 

    for attr in die.attributes.values():
        if attr.name== "DW_AT_name":
            return attr.value.decode("utf-8")

#     print("producing none?")

# %%
from collections import defaultdict
def line_entry_mapping(line_program):
    filename_map = defaultdict(int)

    # The line program, when decoded, returns a list of line program
    # entries. Each entry contains a state, which we'll use to build
    # a reverse mapping of filename -> #entries.
    lp_entries = line_program.get_entries()
    if len(lp_entries)==0:
        return None
    for lpe in lp_entries:
        # We skip LPEs that don't have an associated file.
        # This can happen if instructions in the compiled binary
        # don't correspond directly to any original source file.
        if not lpe.state:# or lpe.state.file == 0
            continue
        filename = lpe_filename(line_program, lpe.state.file)[0]
        filename_map[filename] += 1

    # for filename, lpe_count in filename_map.items():
    #     print("    filename=%s -> %d entries" % (filename, lpe_count))
    return filename_map

def lpe_filename(line_program, file_index):
    COMPILER_SUBSTRACT = 1
    lp_header = line_program.header
    file_entries = lp_header["file_entry"]
    

    # File and directory indices are 1-indexed.
    file_entry = file_entries[file_index -COMPILER_SUBSTRACT]
    dir_index = file_entry["dir_index"]

    # A dir_index of 0 indicates that no absolute directory was recorded during
    # compilation; return just the basename.
    if dir_index == 0:
        return file_entry.name.decode(),dir_index
    directory = lp_header["include_directory"][dir_index -COMPILER_SUBSTRACT]
    return posixpath.join(directory, file_entry.name).decode(),dir_index

# %%
def show_loclist(loclist, dwarfinfo, indent, cu_offset):
    """ Display a location list nicely, decoding the DWARF expressions
        contained within.
    """
    d = []
    for loc_entity in loclist:
        if isinstance(loc_entity, LocationEntry):
            d.append('%s <<%s>>' % (
                loc_entity,
                describe_DWARF_expr(loc_entity.loc_expr, dwarfinfo.structs, cu_offset)))
        else:
            d.append(str(loc_entity))
    return '\n'.join(indent + s for s in d)

# %%
# https://github.com/eliben/pyelftools/blob/master/examples/dwarf_location_info.py

LOCATION_SUBSTRACT_FACTOR = 4

from elftools.dwarf.locationlists import LocationParser, LocationExpr
FUNC_PARAMS = {}
def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        # get_dwarf_info returns a DWARFInfo context object, which is the
        # starting point for all DWARF-based processing in pyelftools.
        dwarfinfo = elffile.get_dwarf_info()
        # The location lists are extracted by DWARFInfo from the .debug_loc
        # section, and returned here as a LocationLists object.
        location_lists = dwarfinfo.location_lists()

        # This is required for the descriptions module to correctly decode
        # register names contained in DWARF expressions.
        set_global_machine_arch(elffile.get_machine_arch())

        # Create a LocationParser object that parses the DIE attributes and
        # creates objects representing the actual location information.
        loc_parser = LocationParser(location_lists)
        
        section_offset = dwarfinfo.debug_info_sec.global_offset
        # Offset of the .debug_info section in the stream
        


        for CU in dwarfinfo.iter_CUs():

                
            #get source file name
            print(CU)
            line_program = dwarfinfo.line_program_for_CU(CU)
            print('TEST!!!')
            filename_map = line_entry_mapping(line_program)
            if filename_map==None:
                continue
            CU_src_file =  list(filename_map.items())[0][0]
            
            CU_dictionary_key = CU_src_file 
            
            FUNC_PARAMS[CU_dictionary_key] = {}
            
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # A CU provides a simple API to iterate over all the DIEs in it.
            die_depth = 0
            are_DIEs_of_function = False
            FUNC_name = None
            print('____'*10)
            for DIE in CU.iter_DIEs():
                
                ############################################################
                #############   Prasing Function DIEs start ################
                
                
                if DIE.tag == 'DW_TAG_subprogram':
                    are_DIEs_of_function = True
                    
                    for attr in DIE.attributes.values():
                        if attr.name == "DW_AT_name": #FUNC NAME
                            FUNC_name = attr.value.decode("utf-8")
                            FUNC_PARAMS[CU_dictionary_key][FUNC_name] ={}
                            print("SUBPROGRAM: ",FUNC_name)
                            
                if DIE.tag == 'DW_TAG_formal_parameter' or DIE.tag =='DW_TAG_variable':
                    tags = [attr.name for attr in DIE.attributes.values()]
                    PARAM_name = None
                    if FUNC_name==None:

                        FUNC_name ="global"
                        
                        if FUNC_name not in FUNC_PARAMS[CU_dictionary_key]:
                            FUNC_PARAMS[CU_dictionary_key][FUNC_name]={}
                        
                    if "DW_AT_name" in tags:
                        
                        
                        for attr in DIE.attributes.values():
                            
                            if attr.name == "DW_AT_name": # VAR NAME 
                                PARAM_name = attr.value.decode("utf-8")
                                FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {}
                                print(PARAM_name)

                            if attr.name == "DW_AT_type":
                                var_type = DIE.tag.split('_')[-1]
                                FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {'type':get_type_name(CU,attr.value) , 'kind':var_type}

                            # Check if this attribute contains location information
                            if loc_parser.attribute_has_location(attr, CU['version']):
                                
                                try:
                                    loc = loc_parser.parse_from_attribute(attr,
                                                                          CU['version'])
    #                                 print(CU_dictionary_key,FUNC_name,PARAM_name)
                                    if isinstance(loc, LocationExpr):
                                        loc_info_str = describe_DWARF_expr(loc.loc_expr, dwarfinfo.structs, CU.cu_offset)
                                        offset_temp = (loc_info_str.split('-')[-1]).split(')')[0]
                                        print(PARAM_name,loc_info_str, int(offset_temp)-LOCATION_SUBSTRACT_FACTOR)
                                        FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name]["location"]= loc_info_str
                                    
                                    elif isinstance(loc, list):
                                        print(PARAM_name,show_loclist(loc,dwarfinfo,'      ', CU.cu_offset))
                                        FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name]["location"]= show_loclist(loc,
                                                           dwarfinfo,'      ', CU.cu_offset)
                                except:
                                    
#                                     print(DIE)
                                    pass
#                     print("\n"*5)
                        

                ###############################################
                #############  parsing  Function DIEs ends ################
                


                
                if DIE.is_null(): #https://chromium.googlesource.com/chromiumos/third_party/pyelftools/+/25a77f7738d7fe824f2ed4d33a123136b9d8e88a/scripts/readelf.py
                    are_DIEs_of_function = False
                    FUNC_name = None
                    
                    die_depth -= 1
                    continue
                if DIE.has_children:
                    die_depth += 1
                    

process_file(filePath)
# Out:
# Processing file: ./../../binaries/c_many/stacktest
# <elftools.dwarf.compileunit.CompileUnit object at 0x7f7a003d3160>
# TEST!!!
#   Found a compile unit at offset 0, length 749
# ________________________________________
# SUBPROGRAM:  push
# None (DW_OP_fbreg: -4) 0
# number
# None (DW_OP_fbreg: -16) 12
# stk_ptr
# None (DW_OP_fbreg: -20) 16
# pop
# None (DW_OP_fbreg: -24) 20
# ming
# None (DW_OP_fbreg: -32) 28
# stk
# None (DW_OP_fbreg: -40) 36
# tmp
# SUBPROGRAM:  dummy
# None (DW_OP_fbreg: -4) 0
# a_int
# None (DW_OP_fbreg: -8) 4
# b_float
# None (DW_OP_fbreg: -16) 12
# c_double
# None (DW_OP_fbreg: -24) 20
# char_pointer
# None (DW_OP_fbreg: -28) 24
# e_int
# None (DW_OP_fbreg: -32) 28
# f_float
# None (DW_OP_fbreg: -40) 36
# g_double
# None (DW_OP_fbreg: -44) 40
# x1
# None (DW_OP_fbreg: -48) 44
# x2
# None (DW_OP_fbreg: -52) 48
# x3
# None (DW_OP_fbreg: -56) 52
# x4
# None (DW_OP_fbreg: -60) 56
# x5
# None (DW_OP_fbreg: -64) 60
# x6
# None (DW_OP_fbreg: -144) 140
# int_arr
# None (DW_OP_fbreg: -148) 144
# k
# SUBPROGRAM:  pop
# None (DW_OP_fbreg: -8) 4
# stk_ptr
# None (DW_OP_fbreg: -12) 8
# int1
# None (DW_OP_fbreg: -16) 12
# int2
# None (DW_OP_fbreg: -20) 16
# number
# None (DW_OP_fbreg: -32) 28
# stk
# None (DW_OP_fbreg: -40) 36
# tmp
# SUBPROGRAM:  fake
# None (DW_OP_fbreg: -4) 0
# a
# None (DW_OP_fbreg: -8) 4
# b
# None (DW_OP_fbreg: -12) 8
# x
# None (DW_OP_fbreg: -16) 12
# d
# None (DW_OP_fbreg: -20) 16
# e
# None (DW_OP_fbreg: -24) 20
# f
# None (DW_OP_fbreg: -28) 24
# g
# <elftools.dwarf.compileunit.CompileUnit object at 0x7f7a00395c70>
# TEST!!!
#   Found a compile unit at offset 753, length 250
# ________________________________________
# SUBPROGRAM:  main
# None (DW_OP_fbreg: -16) 12
# stk
# None (DW_OP_fbreg: -20) 16
# temp
# None (DW_OP_fbreg: -24) 20
# fake_param1
# None (DW_OP_fbreg: -28) 24
# fake_param2
# None (DW_OP_fbreg: -32) 28
# fake_result
# None (DW_OP_fbreg: -42) 38
# dummy_str
# None (DW_OP_fbreg: -48) 44
# dummy_out
# <elftools.dwarf.compileunit.CompileUnit object at 0x7f7a00346490>
# TEST!!!
#   Found a compile unit at offset 1007, length 353
# ________________________________________
# SUBPROGRAM:  add
# None (DW_OP_fbreg: -4) 0
# a
# None (DW_OP_fbreg: -8) 4
# b
# None (DW_OP_fbreg: -12) 8
# ran
# None (DW_OP_fbreg: -16) 12
# fran
# None (DW_OP_fbreg: -20) 16
# i
# None (DW_OP_fbreg: -24) 20
# fran
# SUBPROGRAM:  addf
# None (DW_OP_fbreg: -4) 0
# a
# None (DW_OP_fbreg: -8) 4
# b
# SUBPROGRAM:  substract
# None (DW_OP_fbreg: -4) 0
# a
# None (DW_OP_fbreg: -8) 4
# b
# SUBPROGRAM:  substractf
# None (DW_OP_fbreg: -4) 0
# a
# None (DW_OP_fbreg: -8) 4
# b

# %%
FUNC_PARAMS
# Out:
# {'stack.c': {'push': {'number': {'type': 'int', 'kind': 'parameter'},
#    'stk_ptr': {'type': '**stack', 'kind': 'parameter'},
#    'pop': {'type': 'int', 'kind': 'variable'},
#    'ming': {'type': 'unsigned int', 'kind': 'variable'},
#    'stk': {'type': '*stack', 'kind': 'variable'},
#    'tmp': {'type': '*stack', 'kind': 'variable'}},
#   'dummy': {'a_int': {'type': 'int', 'kind': 'parameter'},
#    'b_float': {'type': 'float', 'kind': 'parameter'},
#    'c_double': {'type': 'double', 'kind': 'parameter'},
#    'char_pointer': {'type': '*char', 'kind': 'parameter'},
#    'e_int': {'type': 'int', 'kind': 'variable'},
#    'f_float': {'type': 'float', 'kind': 'variable'},
#    'g_double': {'type': 'double', 'kind': 'variable'},
#    'x1': {'type': 'int', 'kind': 'variable'},
#    'x2': {'type': 'int', 'kind': 'variable'},
#    'x3': {'type': 'int', 'kind': 'variable'},
#    'x4': {'type': 'int', 'kind': 'variable'},
#    'x5': {'type': 'int', 'kind': 'variable'},
#    'x6': {'type': 'int', 'kind': 'variable'},
#    'int_arr': {'type': None, 'kind': 'variable'},
#    'k': {'type': 'int', 'kind': 'variable'}},
#   'pop': {'stk_ptr': {'type': '**stack', 'kind': 'parameter'},
#    'int1': {'type': 'int', 'kind': 'variable'},
#    'int2': {'type': 'int', 'kind': 'variable'},
#    'number': {'type': 'int', 'kind': 'variable'},
#    'stk': {'type': '*stack', 'kind': 'variable'},
#    'tmp': {'type': '*stack', 'kind': 'variable'}},
#   'fake': {'a': {'type': 'int', 'kind': 'parameter'},
#    'b': {'type': 'int', 'kind': 'parameter'},
#    'x': {'type': 'int', 'kind': 'parameter'},
#    'd': {'type': 'int', 'kind': 'variable'},
#    'e': {'type': 'int', 'kind': 'variable'},
#    'f': {'type': 'int', 'kind': 'variable'},
#    'g': {'type': 'int', 'kind': 'variable'}}},
#  'main.c': {'main': {'stk': {'type': '*stack', 'kind': 'variable'},
#    'temp': {'type': 'int', 'kind': 'variable'},
#    'fake_param1': {'type': 'int', 'kind': 'variable'},
#    'fake_param2': {'type': 'int', 'kind': 'variable'},
#    'fake_result': {'type': 'int', 'kind': 'variable'},
#    'dummy_str': {'type': None, 'kind': 'variable'},
#    'dummy_out': {'type': 'int', 'kind': 'variable'}}},
#  'calculate.c': {'add': {'a': {'type': 'int', 'kind': 'parameter'},
#    'b': {'type': 'int', 'kind': 'parameter'},
#    'ran': {'type': 'int', 'kind': 'variable'},
#    'fran': {'type': 'int', 'kind': 'variable'},
#    'i': {'type': 'int', 'kind': 'variable'}},
#   'addf': {'a': {'type': 'float', 'kind': 'parameter'},
#    'b': {'type': 'float', 'kind': 'parameter'}},
#   'substract': {'a': {'type': 'int', 'kind': 'parameter'},
#    'b': {'type': 'int', 'kind': 'parameter'}},
#   'substractf': {'a': {'type': 'float', 'kind': 'parameter'},
#    'b': {'type': 'float', 'kind': 'parameter'}}}}

# %%
#!/usr/bin/env python3

import sys,os
from elftools.elf.elffile import ELFFile
from elftools.elf.segments import Segment

# %%
fh = open(filePath, 'rb')
bin_bytearray = bytearray(fh.read())

# %%
# https://www.capstone-engine.org/lang_python.html



from capstone import *

from capstone.x86 import *


address_inst = {}
with open(filePath, 'rb') as f:
    elf = ELFFile(f)
    dwarfinfo = elf.get_dwarf_info()
    aranges = dwarfinfo.get_aranges()
    print(len(aranges.entries))
    for arange in aranges.entries:
        print(arange)
    for arange in aranges.entries:

        entry = arange.begin_addr
        exit  = arange.begin_addr + arange.length
        ops = bin_bytearray[entry: exit]

        md = Cs(CS_ARCH_X86, CS_MODE_64)
        md.detail = True
        for inst in md.disasm(ops, entry):

            address_inst[hex(inst.address)] = inst


            print('\n'*3)
            print(inst.address, inst.mnemonic+"  "+inst.op_str)
            (regs_read, regs_write) = inst.regs_access()
# Out:
# 3
# ARangeEntry(begin_addr=4448, length=457, info_offset=0, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=4912, length=317, info_offset=753, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=5232, length=250, info_offset=1007, unit_length=44, version=2, address_size=8, segment_size=0)
#
#
#
#
# 4448 push  rbp
#
#
#
#
# 4449 mov  rbp, rsp
#
#
#
#
# 4452 sub  rsp, 0x30
#
#
#
#
# 4456 mov  dword ptr [rbp - 4], edi
#
#
#
#
# 4459 mov  qword ptr [rbp - 0x10], rsi
#
#
#
#
# 4463 mov  dword ptr [rbp - 0x14], 0xa
#
#
#
#
# 4470 mov  dword ptr [rbp - 0x18], 0xc
#
#
#
#
# 4477 mov  rax, qword ptr [rbp - 0x10]
#
#
#
#
# 4481 mov  rax, qword ptr [rax]
#
#
#
#
# 4484 mov  qword ptr [rbp - 0x20], rax
#
#
#
#
# 4488 mov  edi, 0x10
#
#
#
#
# 4493 call  0x1050
#
#
#
#
# 4498 mov  qword ptr [rbp - 0x28], rax
#
#
#
#
# 4502 mov  ecx, dword ptr [rbp - 4]
#
#
#
#
# 4505 mov  rax, qword ptr [rbp - 0x28]
#
#
#
#
# 4509 mov  dword ptr [rax], ecx
#
#
#
#
# 4511 mov  rcx, qword ptr [rbp - 0x20]
#
#
#
#
# 4515 mov  rax, qword ptr [rbp - 0x28]
#
#
#
#
# 4519 mov  qword ptr [rax + 8], rcx
#
#
#
#
# 4523 mov  rax, qword ptr [rbp - 0x28]
#
#
#
#
# 4527 mov  qword ptr [rbp - 0x20], rax
#
#
#
#
# 4531 mov  rcx, qword ptr [rbp - 0x20]
#
#
#
#
# 4535 mov  rax, qword ptr [rbp - 0x10]
#
#
#
#
# 4539 mov  qword ptr [rax], rcx
#
#
#
#
# 4542 add  rsp, 0x30
#
#
#
#
# 4546 pop  rbp
#
#
#
#
# 4547 ret
#
#
#
#
# 4548 nop  word ptr cs:[rax + rax]
#
#
#
#
# 4558 nop
#
#
#
#
# 4560 push  rbp
#
#
#
#
# 4561 mov  rbp, rsp
#
#
#
#
# 4564 sub  rsp, 0xa0
#
#
#
#
# 4571 mov  dword ptr [rbp - 4], edi
#
#
#
#
# 4574 movss  dword ptr [rbp - 8], xmm0
#
#
#
#
# 4579 movsd  qword ptr [rbp - 0x10], xmm1
#
#
#
#
# 4584 mov  qword ptr [rbp - 0x18], rsi
#
#
#
#
# 4588 mov  dword ptr [rbp - 0x1c], 2
#
#
#
#
# 4595 movss  xmm0, dword ptr [rip + 0xe15]
#
#
#
#
# 4603 movss  dword ptr [rbp - 0x20], xmm0
#
#
#
#
# 4608 movsd  xmm0, qword ptr [rip + 0xe00]
#
#
#
#
# 4616 movsd  qword ptr [rbp - 0x28], xmm0
#
#
#
#
# 4621 mov  eax, dword ptr [rbp - 4]
#
#
#
#
# 4624 shl  eax, 1
#
#
#
#
# 4627 mov  dword ptr [rbp - 0x1c], eax
#
#
#
#
# 4630 movss  xmm0, dword ptr [rbp - 0x20]
#
#
#
#
# 4635 mulss  xmm0, dword ptr [rbp - 8]
#
#
#
#
# 4640 movss  dword ptr [rbp - 0x20], xmm0
#
#
#
#
# 4645 mov  rsi, qword ptr [rbp - 0x18]
#
#
#
#
# 4649 mov  edi, 0x2573
#
#
#
#
# 4654 mov  al, 0
#
#
#
#
# 4656 call  0x1040
#
#
#
#
# 4661 mov  dword ptr [rbp - 0x40], 0
#
#
#
#
# 4668 mov  dword ptr [rbp - 0x94], 0
#
#
#
#
# 4678 cmp  dword ptr [rbp - 0x94], 0x14
#
#
#
#
# 4685 jge  0x127f
#
#
#
#
# 4691 mov  eax, dword ptr [rbp - 0x1c]
#
#
#
#
# 4694 cdq
#
#
#
#
# 4695 idiv  dword ptr [rbp - 0x94]
#
#
#
#
# 4701 movsxd  rax, dword ptr [rbp - 0x94]
#
#
#
#
# 4708 mov  dword ptr [rbp + rax*4 - 0x90], edx
#
#
#
#
# 4715 mov  eax, dword ptr [rbp - 0x94]
#
#
#
#
# 4721 add  eax, 1
#
#
#
#
# 4724 mov  dword ptr [rbp - 0x94], eax
#
#
#
#
# 4730 jmp  0x1246
#
#
#
#
# 4735 mov  eax, dword ptr [rbp - 0x1c]
#
#
#
#
# 4738 imul  eax, dword ptr [rbp - 4]
#
#
#
#
# 4742 add  rsp, 0xa0
#
#
#
#
# 4749 pop  rbp
#
#
#
#
# 4750 ret
#
#
#
#
# 4751 nop
#
#
#
#
# 4752 push  rbp
#
#
#
#
# 4753 mov  rbp, rsp
#
#
#
#
# 4756 sub  rsp, 0x30
#
#
#
#
# 4760 mov  qword ptr [rbp - 8], rdi
#
#
#
#
# 4764 mov  dword ptr [rbp - 0xc], 0xb
#
#
#
#
# 4771 mov  dword ptr [rbp - 0x10], 0xc
#
#
#
#
# 4778 mov  rax, qword ptr [rbp - 8]
#
#
#
#
# 4782 mov  rax, qword ptr [rax]
#
#
#
#
# 4785 mov  qword ptr [rbp - 0x20], rax
#
#
#
#
# 4789 mov  rax, qword ptr [rbp - 0x20]
#
#
#
#
# 4793 mov  qword ptr [rbp - 0x28], rax
#
#
#
#
# 4797 mov  rax, qword ptr [rbp - 0x28]
#
#
#
#
# 4801 mov  eax, dword ptr [rax]
#
#
#
#
# 4803 mov  dword ptr [rbp - 0x14], eax
#
#
#
#
# 4806 mov  rax, qword ptr [rbp - 0x20]
#
#
#
#
# 4810 mov  rax, qword ptr [rax + 8]
#
#
#
#
# 4814 mov  qword ptr [rbp - 0x20], rax
#
#
#
#
# 4818 mov  rdi, qword ptr [rbp - 0x28]
#
#
#
#
# 4822 call  0x1030
#
#
#
#
# 4827 mov  rcx, qword ptr [rbp - 0x20]
#
#
#
#
# 4831 mov  rax, qword ptr [rbp - 8]
#
#
#
#
# 4835 mov  qword ptr [rax], rcx
#
#
#
#
# 4838 mov  eax, dword ptr [rbp - 0x14]
#
#
#
#
# 4841 add  rsp, 0x30
#
#
#
#
# 4845 pop  rbp
#
#
#
#
# 4846 ret
#
#
#
#
# 4847 nop
#
#
#
#
# 4848 push  rbp
#
#
#
#
# 4849 mov  rbp, rsp
#
#
#
#
# 4852 mov  dword ptr [rbp - 4], edi
#
#
#
#
# 4855 mov  dword ptr [rbp - 8], esi
#
#
#
#
# 4858 mov  dword ptr [rbp - 0xc], edx
#
#
#
#
# 4861 mov  dword ptr [rbp - 0x10], 0xa
#
#
#
#
# 4868 mov  dword ptr [rbp - 0x14], 0xb
#
#
#
#
# 4875 mov  dword ptr [rbp - 0x18], 0xc
#
#
#
#
# 4882 mov  eax, dword ptr [rbp - 4]
#
#
#
#
# 4885 add  eax, dword ptr [rbp - 8]
#
#
#
#
# 4888 add  eax, dword ptr [rbp - 0x10]
#
#
#
#
# 4891 add  eax, dword ptr [rbp - 0x14]
#
#
#
#
# 4894 add  eax, dword ptr [rbp - 0x18]
#
#
#
#
# 4897 mov  dword ptr [rbp - 0x1c], eax
#
#
#
#
# 4900 mov  eax, dword ptr [rbp - 0x1c]
#
#
#
#
# 4903 pop  rbp
#
#
#
#
# 4904 ret
#
#
#
#
# 4912 push  rbp
#
#
#
#
# 4913 mov  rbp, rsp
#
#
#
#
# 4916 sub  rsp, 0x30
#
#
#
#
# 4920 mov  dword ptr [rbp - 4], 0
#
#
#
#
# 4927 mov  qword ptr [rbp - 0x10], 0
#
#
#
#
# 4935 mov  edi, 7
#
#
#
#
# 4940 lea  rsi, [rbp - 0x10]
#
#
#
#
# 4944 call  0x1160
#
#
#
#
# 4949 mov  edi, 1
#
#
#
#
# 4954 mov  esi, 2
#
#
#
#
# 4959 call  0x1470
#
#
#
#
# 4964 mov  dword ptr [rbp - 0x14], eax
#
#
#
#
# 4967 mov  edi, dword ptr [rbp - 0x14]
#
#
#
#
# 4970 lea  rsi, [rbp - 0x10]
#
#
#
#
# 4974 call  0x1160
#
#
#
#
# 4979 mov  dword ptr [rbp - 0x18], 0
#
#
#
#
# 4986 mov  dword ptr [rbp - 0x1c], 1
#
#
#
#
# 4993 mov  edi, dword ptr [rbp - 0x18]
#
#
#
#
# 4996 mov  esi, dword ptr [rbp - 0x1c]
#
#
#
#
# 4999 mov  edx, 0xa
#
#
#
#
# 5004 call  0x12f0
#
#
#
#
# 5009 mov  dword ptr [rbp - 0x20], eax
#
#
#
#
# 5012 mov  rax, qword ptr [rip + 0xc85]
#
#
#
#
# 5019 mov  qword ptr [rbp - 0x2a], rax
#
#
#
#
# 5023 mov  ax, word ptr [rip + 0xc82]
#
#
#
#
# 5030 mov  word ptr [rbp - 0x22], ax
#
#
#
#
# 5034 lea  rsi, [rbp - 0x2a]
#
#
#
#
# 5038 mov  edi, 1
#
#
#
#
# 5043 movss  xmm0, dword ptr [rip + 0xc59]
#
#
#
#
# 5051 movsd  xmm1, qword ptr [rip + 0xc55]
#
#
#
#
# 5059 call  0x11d0
#
#
#
#
# 5064 mov  dword ptr [rbp - 0x30], eax
#
#
#
#
# 5067 mov  edi, 9
#
#
#
#
# 5072 lea  rsi, [rbp - 0x10]
#
#
#
#
# 5076 call  0x1160
#
#
#
#
# 5081 mov  edi, 0xc
#
#
#
#
# 5086 lea  rsi, [rbp - 0x10]
#
#
#
#
# 5090 call  0x1160
#
#
#
#
# 5095 lea  rdi, [rbp - 0x10]
#
#
#
#
# 5099 call  0x1290
#
#
#
#
# 5104 mov  esi, eax
#
#
#
#
# 5106 lea  rdi, [rip + 0xc31]
#
#
#
#
# 5113 mov  al, 0
#
#
#
#
# 5115 call  0x1040
#
#
#
#
# 5120 lea  rdi, [rbp - 0x10]
#
#
#
#
# 5124 call  0x1290
#
#
#
#
# 5129 mov  esi, eax
#
#
#
#
# 5131 lea  rdi, [rip + 0xc18]
#
#
#
#
# 5138 mov  al, 0
#
#
#
#
# 5140 call  0x1040
#
#
#
#
# 5145 lea  rdi, [rbp - 0x10]
#
#
#
#
# 5149 call  0x1290
#
#
#
#
# 5154 mov  esi, eax
#
#
#
#
# 5156 lea  rdi, [rip + 0xbff]
#
#
#
#
# 5163 mov  al, 0
#
#
#
#
# 5165 call  0x1040
#
#
#
#
# 5170 lea  rdi, [rbp - 0x10]
#
#
#
#
# 5174 call  0x1290
#
#
#
#
# 5179 mov  esi, eax
#
#
#
#
# 5181 lea  rdi, [rip + 0xbe6]
#
#
#
#
# 5188 mov  al, 0
#
#
#
#
# 5190 call  0x1040
#
#
#
#
# 5195 lea  rdi, [rbp - 0x10]
#
#
#
#
# 5199 call  0x1290
#
#
#
#
# 5204 mov  esi, eax
#
#
#
#
# 5206 lea  rdi, [rip + 0xbcd]
#
#
#
#
# 5213 mov  al, 0
#
#
#
#
# 5215 call  0x1040
#
#
#
#
# 5220 mov  eax, dword ptr [rbp - 0x20]
#
#
#
#
# 5223 add  rsp, 0x30
#
#
#
#
# 5227 pop  rbp
#
#
#
#
# 5228 ret
#
#
#
#
# 5232 push  rbp
#
#
#
#
# 5233 mov  rbp, rsp
#
#
#
#
# 5236 mov  dword ptr [rbp - 4], edi
#
#
#
#
# 5239 mov  dword ptr [rbp - 8], esi
#
#
#
#
# 5242 mov  dword ptr [rbp - 0xc], 0xa
#
#
#
#
# 5249 mov  eax, dword ptr [rbp - 0xc]
#
#
#
#
# 5252 add  eax, 0xc
#
#
#
#
# 5255 mov  dword ptr [rbp - 0xc], eax
#
#
#
#
# 5258 mov  eax, dword ptr [rbp - 0xc]
#
#
#
#
# 5261 imul  eax, dword ptr [rbp - 0xc]
#
#
#
#
# 5265 mov  dword ptr [rbp - 0xc], eax
#
#
#
#
# 5268 movss  xmm0, dword ptr [rip + 0xb9c]
#
#
#
#
# 5276 movss  dword ptr [rbp - 0x10], xmm0
#
#
#
#
# 5281 movss  xmm0, dword ptr [rbp - 0x10]
#
#
#
#
# 5286 cvtss2sd  xmm0, xmm0
#
#
#
#
# 5290 movsd  xmm1, qword ptr [rip + 0xb7e]
#
#
#
#
# 5298 addsd  xmm0, xmm1
#
#
#
#
# 5302 cvtsd2ss  xmm0, xmm0
#
#
#
#
# 5306 movss  dword ptr [rbp - 0x10], xmm0
#
#
#
#
# 5311 mov  dword ptr [rbp - 0x14], 0
#
#
#
#
# 5318 cmp  dword ptr [rbp - 0x14], 0xa
#
#
#
#
# 5322 jge  0x14ee
#
#
#
#
# 5328 mov  dword ptr [rbp - 0x18], 0
#
#
#
#
# 5335 mov  eax, dword ptr [rbp - 0x18]
#
#
#
#
# 5338 add  eax, 2
#
#
#
#
# 5341 mov  dword ptr [rbp - 0x18], eax
#
#
#
#
# 5344 mov  eax, dword ptr [rbp - 0x14]
#
#
#
#
# 5347 add  eax, 1
#
#
#
#
# 5350 mov  dword ptr [rbp - 0x14], eax
#
#
#
#
# 5353 jmp  0x14c6
#
#
#
#
# 5358 mov  eax, dword ptr [rbp - 0xc]
#
#
#
#
# 5361 sub  eax, 0xa
#
#
#
#
# 5364 mov  dword ptr [rbp - 0xc], eax
#
#
#
#
# 5367 mov  eax, dword ptr [rbp - 4]
#
#
#
#
# 5370 add  eax, dword ptr [rbp - 8]
#
#
#
#
# 5373 add  eax, dword ptr [rbp - 0xc]
#
#
#
#
# 5376 pop  rbp
#
#
#
#
# 5377 ret
#
#
#
#
# 5378 nop  word ptr cs:[rax + rax]
#
#
#
#
# 5388 nop  dword ptr [rax]
#
#
#
#
# 5392 push  rbp
#
#
#
#
# 5393 mov  rbp, rsp
#
#
#
#
# 5396 movss  dword ptr [rbp - 4], xmm0
#
#
#
#
# 5401 movss  dword ptr [rbp - 8], xmm1
#
#
#
#
# 5406 movss  xmm0, dword ptr [rbp - 4]
#
#
#
#
# 5411 addss  xmm0, dword ptr [rbp - 8]
#
#
#
#
# 5416 pop  rbp
#
#
#
#
# 5417 ret
#
#
#
#
# 5418 nop  word ptr [rax + rax]
#
#
#
#
# 5424 push  rbp
#
#
#
#
# 5425 mov  rbp, rsp
#
#
#
#
# 5428 mov  dword ptr [rbp - 4], edi
#
#
#
#
# 5431 mov  dword ptr [rbp - 8], esi
#
#
#
#
# 5434 mov  eax, dword ptr [rbp - 4]
#
#
#
#
# 5437 sub  eax, dword ptr [rbp - 8]
#
#
#
#
# 5440 pop  rbp
#
#
#
#
# 5441 ret
#
#
#
#
# 5442 nop  word ptr cs:[rax + rax]
#
#
#
#
# 5452 nop  dword ptr [rax]
#
#
#
#
# 5456 push  rbp
#
#
#
#
# 5457 mov  rbp, rsp
#
#
#
#
# 5460 movss  dword ptr [rbp - 4], xmm0
#
#
#
#
# 5465 movss  dword ptr [rbp - 8], xmm1
#
#
#
#
# 5470 movss  xmm0, dword ptr [rbp - 4]
#
#
#
#
# 5475 subss  xmm0, dword ptr [rbp - 8]
#
#
#
#
# 5480 pop  rbp
#
#
#
#
# 5481 ret

# %%
from collections import defaultdict
import posixpath

# %%
addr_lineProgram ={}
addr_sourceFile = {}
with open(filePath, 'rb') as f:
    elffile = ELFFile(f)

    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
        exit(0)

    dwarfinfo = elffile.get_dwarf_info()
    for CU in dwarfinfo.iter_CUs():
#         print(CU.get_top_DIE()['DW_AT_comp_dir'])
        CU_DIR_PATH = None
        CU_FILENAME = None
        for attr in CU.get_top_DIE().attributes.values():
            if attr.name == 'DW_AT_comp_dir':
                CU_DIR_PATH = attr.value.decode("utf-8")
            if attr.name == 'DW_AT_name':
                CU_FILENAME = attr.value.decode("utf-8")
            
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        line_program = dwarfinfo.line_program_for_CU(CU)
        if line_program is None:
            print('  DWARF info is missing a line program for this CU')
            continue

        for line_entry in line_program.get_entries():
            real_source_path = None
            if line_entry.state!=None:
                    addr_lineProgram[hex(line_entry.state.address)] = line_entry

                    src_filename_from_lineentry, dir_index = (lpe_filename (line_program, line_entry.state.file))
                    
                    if src_filename_from_lineentry == CU_FILENAME:
                        real_source_path = os.path.join(CU_DIR_PATH,CU_FILENAME)
                    else:
                        if '/' in src_filename_from_lineentry:
                            real_source_path = src_filename_from_lineentry
                        elif dir_index==0:
                            real_source_path = os.path.join(CU_DIR_PATH,src_filename_from_lineentry)

                    addr_sourceFile [hex(line_entry.state.address)] = real_source_path
# Out:
#   Found a compile unit at offset 0, length 749
#   Found a compile unit at offset 753, length 250
#   Found a compile unit at offset 1007, length 353

# %%
# print(addr_lineProgram)
# address_inst

def getSource(sourceFilePath, row , col):
    sourceFile = open(sourceFilePath, "r")
    fileContent = sourceFile.readlines()
    row_content =  fileContent[row-1]
    row_content = row_content[:(col-1)] + '|'+row_content[(col-1)]+'|' +row_content[col:]
    
    return row_content

# %%
# FUNCTION_DECL
# https://stackoverflow.com/questions/43460605/function-boundary-identification-using-libclang
# https://eli.thegreenplace.net/2011/07/03/parsing-c-in-python-with-clang


import clang.cindex



def get_all_var_types(source_path):
    srcFileName = source_path.split('/')[-1]

    function_boundary_by_name = {}
    idx = clang.cindex.Index.create()
    tu = idx.parse(source_path)
    
    for f in tu.cursor.walk_preorder():
        if f.kind == clang.cindex.CursorKind.VAR_DECL:
            # print(dir(f))
            print(f.extent.start.file.name)
            originFileName = f.extent.start.file.name.split('/')[-1]
            print(originFileName)
            print(f.displayname)
            print(f.type.spelling)
            print(f.extent.start.line,f.extent.start.column)
            print('\n')
            
            

   

def get_all_function_types(source_path):
    function_boundary_by_name = {}
    idx = clang.cindex.Index.create()
    tu = idx.parse(source_path)
    
    for f in tu.cursor.walk_preorder():
        if f.kind == clang.cindex.CursorKind.FUNCTION_DECL:
            # print(dir(f))
            print(f.displayname)
            print('function name: ',( f.spelling))
            print('Returns: ',(f.result_type.spelling))
            
            
            arg_len = len(list(f.type.argument_types()))
            if arg_len>0:
                arg_types = list(f.type.argument_types())
                for arg_type in arg_types:
                    print('arg_type:',arg_type.spelling)
                args = list(f.get_arguments())
                for arg in args:
                    print('arg:',arg.spelling)


            print("\n\n\n")

            
def get_function_boundaries(source_path):
    
    function_boundary_by_name = {}
    idx = clang.cindex.Index.create()
    tu = idx.parse(source_path)
    
    for f in tu.cursor.walk_preorder():
        if f.kind == clang.cindex.CursorKind.FUNCTION_DECL:

            function_name = f.displayname.split('(')[0]
            function_boundary_by_name[function_name]={}
            function_boundary_by_name[function_name] = { 'src_path':f.extent.start.file.name,
                              'src_file':f.extent.start.file.name.split('/')[-1],
                              'start_line':f.extent.start.line,
                              'start_col':f.extent.start.column,
                              'end_line':f.extent.end.line,
                              'end_col':f.extent.end.column}
    return function_boundary_by_name

def get_containing_function(source_file_path, line, col=0):
    function_boundary_by_name = get_function_boundaries(source_file_path)
    
    for function_name, item in function_boundary_by_name.items():
        if item['src_path'] == source_file_path:
            if line>= item['start_line'] and line<= item['end_line']:
                return function_name

# %%
REGISTER_SUBSTRACT_FACTOR = -4

with open('gitfm.s', 'w') as outFile:
    # outFile.write('file contents\n')
    lastSource = ""
    for address in address_inst:
        inst = address_inst[address]
        instrctionCode = (address+":\t"+ inst.mnemonic+" "+inst.op_str).ljust(45)

        OFFSET = None
        if len(inst.operands) > 0 :
            c=-1
            for o in inst.operands:
                c += 1
                if o.type == CS_OP_MEM:
                    print("\t\toperands[%u].type: MEM" %c)
                    if o.value.mem.base != 0:
                        print("\t\t\toperands[%u].mem.base: REG = %s" \
                            %(c, inst.reg_name(o.value.mem.base)))
                    if o.value.mem.index != 0:
                        print("\t\t\toperands[%u].mem.index: REG = %s" \
                            %(c, inst.reg_name(o.value.mem.index)))
                    if o.value.mem.disp != 0:
                        print("\t\t\toperands[%u].mem.disp: 0x%x" \
                            %(c, o.value.mem.disp))
                        OFFSET = o.value.mem.disp
                    print(hex(o.value.mem.disp),o.value.mem.disp)
                    
        
        if address in addr_lineProgram:
            
            srcFilePath = addr_sourceFile[address] 
            if srcFilePath!=lastSource:
                outFile.write("\n"+ '#'*100+"\n"+ srcFilePath.rjust(45) +'\n'+'#'*100+ "\n\n")
                lastSource = srcFilePath
            print("add",address)
            

            sourceCode = getSource(srcFilePath,addr_lineProgram[address].state.line, addr_lineProgram[address].state.column)
            function_name = get_containing_function(srcFilePath ,addr_lineProgram[address].state.line , addr_lineProgram[address].state.column)


            if '\n' not in  sourceCode:
                sourceCode+=sourceCode+"\n"
            outFile.write(instrctionCode+"#"+ sourceCode  )
            print(instrctionCode+"#"+ sourceCode)

            
        else:
            
            outFile.write(instrctionCode+ '\n'  )
            print(instrctionCode)
        if OFFSET:
            outFile.write("MEMORY OFFSET:     "+str(hex(OFFSET))+"     "+str(OFFSET)+ "  >>"+str(OFFSET-REGISTER_SUBSTRACT_FACTOR)+'\n\n')
            pass
# Out:
# add 0x1160
# 0x1160:	push rbp                             #void push(int number, stack **stk_ptr) {|
# |void push(int number, stack **stk_ptr) {
#
# 0x1161:	mov rbp, rsp
# 0x1164:	sub rsp, 0x30
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x1168:	mov dword ptr [rbp - 4], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# 0x116b:	mov qword ptr [rbp - 0x10], rsi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# add 0x116f
# 0x116f:	mov dword ptr [rbp - 0x14], 0xa      #    int |p|op = 10;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# add 0x1176
# 0x1176:	mov dword ptr [rbp - 0x18], 0xc      #    unsigned int |m|ing = 12;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x117d
# 0x117d:	mov rax, qword ptr [rbp - 0x10]      #    stk = *|s|tk_ptr;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 0x0 0
# add 0x1181
# 0x1181:	mov rax, qword ptr [rax]             #    stk = |*|stk_ptr;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-20
# -0x20 -32
# add 0x1184
# 0x1184:	mov qword ptr [rbp - 0x20], rax      #    stk |=| *stk_ptr;
#
# add 0x1188
# 0x1188:	mov edi, 0x10                        #    tmp = |m|alloc(sizeof(stack));
#
# 0x118d:	call 0x1050
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-28
# -0x28 -40
# add 0x1192
# 0x1192:	mov qword ptr [rbp - 0x28], rax      #    tmp |=| malloc(sizeof(stack));
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x1196
# 0x1196:	mov ecx, dword ptr [rbp - 4]         #    tmp->number = |n|umber;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-28
# -0x28 -40
# add 0x1199
# 0x1199:	mov rax, qword ptr [rbp - 0x28]      #    |t|mp->number = number;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# add 0x119d
# 0x119d:	mov dword ptr [rax], ecx             #    tmp->number |=| number;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x119f
# 0x119f:	mov rcx, qword ptr [rbp - 0x20]      #    tmp->next = |s|tk;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-28
# -0x28 -40
# add 0x11a3
# 0x11a3:	mov rax, qword ptr [rbp - 0x28]      #    |t|mp->next = stk;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.disp: 0x8
# 0x8 8
# add 0x11a7
# 0x11a7:	mov qword ptr [rax + 8], rcx         #    tmp->next |=| stk;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-28
# -0x28 -40
# add 0x11ab
# 0x11ab:	mov rax, qword ptr [rbp - 0x28]      #    stk = |t|mp;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-20
# -0x20 -32
# add 0x11af
# 0x11af:	mov qword ptr [rbp - 0x20], rax      #    stk |=| tmp;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x11b3
# 0x11b3:	mov rcx, qword ptr [rbp - 0x20]      #    *stk_ptr = |s|tk;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x11b7
# 0x11b7:	mov rax, qword ptr [rbp - 0x10]      #    *|s|tk_ptr = stk;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# add 0x11bb
# 0x11bb:	mov qword ptr [rax], rcx             #    *stk_ptr |=| stk;
#
# add 0x11be
# 0x11be:	add rsp, 0x30                        #|}|
#
# 0x11c2:	pop rbp
# 0x11c3:	ret
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x11c4:	nop word ptr cs:[rax + rax]
# 0x11ce:	nop
# add 0x11d0
# 0x11d0:	push rbp                             # int dummy(int a_int, float b_float, double c_double,  char * char_pointer){|
# | int dummy(int a_int, float b_float, double c_double,  char * char_pointer){
#
# 0x11d1:	mov rbp, rsp
# 0x11d4:	sub rsp, 0xa0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x11db:	mov dword ptr [rbp - 4], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x11de:	movss dword ptr [rbp - 8], xmm0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# 0x11e3:	movsd qword ptr [rbp - 0x10], xmm1
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# 0x11e8:	mov qword ptr [rbp - 0x18], rsi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-1c
# -0x1c -28
# add 0x11ec
# 0x11ec:	mov dword ptr [rbp - 0x1c], 2        #        int |e|_int =2;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xe15
# 0xe15 3605
# add 0x11f3
# 0x11f3:	movss xmm0, dword ptr [rip + 0xe15]  #        float |f|_float =1.0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-20
# -0x20 -32
# 0x11fb:	movss dword ptr [rbp - 0x20], xmm0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xe00
# 0xe00 3584
# add 0x1200
# 0x1200:	movsd xmm0, qword ptr [rip + 0xe00]  #        double |g|_double = 2.0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-28
# -0x28 -40
# 0x1208:	movsd qword ptr [rbp - 0x28], xmm0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x120d
# 0x120d:	mov eax, dword ptr [rbp - 4]         #        e_int = |a|_int*2;
#
# add 0x1210
# 0x1210:	shl eax, 1                           #        e_int = a_int|*|2;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-1c
# -0x1c -28
# add 0x1213
# 0x1213:	mov dword ptr [rbp - 0x1c], eax      #        e_int |=| a_int*2;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x1216
# 0x1216:	movss xmm0, dword ptr [rbp - 0x20]   #        f_float = |f|_float * b_float;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x121b
# 0x121b:	mulss xmm0, dword ptr [rbp - 8]      #        f_float = f_float |*| b_float;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-20
# -0x20 -32
# add 0x1220
# 0x1220:	movss dword ptr [rbp - 0x20], xmm0   #        f_float |=| f_float * b_float;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-18
# -0x18 -24
# add 0x1225
# 0x1225:	mov rsi, qword ptr [rbp - 0x18]      #        printf('%s',|c|har_pointer);
#
# add 0x1229
# 0x1229:	mov edi, 0x2573                      #        |p|rintf('%s',char_pointer);
#
# 0x122e:	mov al, 0
# 0x1230:	call 0x1040
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-40
# -0x40 -64
# add 0x1235
# 0x1235:	mov dword ptr [rbp - 0x40], 0        #        int x1,x2,x3,x4,x5,|x|6 = 0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-94
# -0x94 -148
# add 0x123c
# 0x123c:	mov dword ptr [rbp - 0x94], 0        #        for (int |k|=0; k<20;k++){
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-94
# -0x94 -148
# add 0x1246
# 0x1246:	cmp dword ptr [rbp - 0x94], 0x14     #        for (int k=0; k|<|20;k++){
#
# add 0x124d
# 0x124d:	jge 0x127f                           #        |f|or (int k=0; k<20;k++){
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-1c
# -0x1c -28
# add 0x1253
# 0x1253:	mov eax, dword ptr [rbp - 0x1c]      #            int_arr[k] = |e|_int%k;
#
# add 0x1256
# 0x1256:	cdq                                  #            int_arr[k] = e_int|%|k;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-94
# -0x94 -148
# 0x1257:	idiv dword ptr [rbp - 0x94]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-94
# -0x94 -148
# add 0x125d
# 0x125d:	movsxd rax, dword ptr [rbp - 0x94]   #            |i|nt_arr[k] = e_int%k;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.index: REG = rax
# 			operands[0].mem.disp: 0x-90
# -0x90 -144
# add 0x1264
# 0x1264:	mov dword ptr [rbp + rax*4 - 0x90], edx#            int_arr[k] |=| e_int%k;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-94
# -0x94 -148
# add 0x126b
# 0x126b:	mov eax, dword ptr [rbp - 0x94]      #        for (int k=0; k<20;k|+|+){
#
# 0x1271:	add eax, 1
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-94
# -0x94 -148
# 0x1274:	mov dword ptr [rbp - 0x94], eax
# add 0x127a
# 0x127a:	jmp 0x1246                           #        |f|or (int k=0; k<20;k++){
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-1c
# -0x1c -28
# add 0x127f
# 0x127f:	mov eax, dword ptr [rbp - 0x1c]      #        return |e|_int*a_int;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x1282
# 0x1282:	imul eax, dword ptr [rbp - 4]        #        return e_int|*|a_int;
#
# add 0x1286
# 0x1286:	add rsp, 0xa0                        #        |r|eturn e_int*a_int;
#
# 0x128d:	pop rbp
# 0x128e:	ret
# 0x128f:	nop
# add 0x1290
# 0x1290:	push rbp                             #int pop(stack **stk_ptr) {|
# |int pop(stack **stk_ptr) {
#
# 0x1291:	mov rbp, rsp
# 0x1294:	sub rsp, 0x30
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x1298:	mov qword ptr [rbp - 8], rdi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# add 0x129c
# 0x129c:	mov dword ptr [rbp - 0xc], 0xb       #    int |i|nt1 =11;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# add 0x12a3
# 0x12a3:	mov dword ptr [rbp - 0x10], 0xc      #    int |i|nt2 =12;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x12aa
# 0x12aa:	mov rax, qword ptr [rbp - 8]         #    stk = *|s|tk_ptr;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 0x0 0
# add 0x12ae
# 0x12ae:	mov rax, qword ptr [rax]             #    stk = |*|stk_ptr;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-20
# -0x20 -32
# add 0x12b1
# 0x12b1:	mov qword ptr [rbp - 0x20], rax      #    stk |=| *stk_ptr;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x12b5
# 0x12b5:	mov rax, qword ptr [rbp - 0x20]      #    tmp = |s|tk;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-28
# -0x28 -40
# add 0x12b9
# 0x12b9:	mov qword ptr [rbp - 0x28], rax      #    tmp |=| stk;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-28
# -0x28 -40
# add 0x12bd
# 0x12bd:	mov rax, qword ptr [rbp - 0x28]      #    number = |t|mp->number;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 0x0 0
# add 0x12c1
# 0x12c1:	mov eax, dword ptr [rax]             #    number = tmp->|n|umber;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# add 0x12c3
# 0x12c3:	mov dword ptr [rbp - 0x14], eax      #    number |=| tmp->number;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x12c6
# 0x12c6:	mov rax, qword ptr [rbp - 0x20]      #    stk = |s|tk->next;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 			operands[1].mem.disp: 0x8
# 0x8 8
# add 0x12ca
# 0x12ca:	mov rax, qword ptr [rax + 8]         #    stk = stk->|n|ext;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-20
# -0x20 -32
# add 0x12ce
# 0x12ce:	mov qword ptr [rbp - 0x20], rax      #    stk |=| stk->next;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-28
# -0x28 -40
# add 0x12d2
# 0x12d2:	mov rdi, qword ptr [rbp - 0x28]      #    free(|t|mp);
#
# add 0x12d6
# 0x12d6:	call 0x1030                          #    |f|ree(tmp);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x12db
# 0x12db:	mov rcx, qword ptr [rbp - 0x20]      #    *stk_ptr = |s|tk;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x12df
# 0x12df:	mov rax, qword ptr [rbp - 8]         #    *|s|tk_ptr = stk;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# add 0x12e3
# 0x12e3:	mov qword ptr [rax], rcx             #    *stk_ptr |=| stk;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-14
# -0x14 -20
# add 0x12e6
# 0x12e6:	mov eax, dword ptr [rbp - 0x14]      #    return |n|umber;
#
# add 0x12e9
# 0x12e9:	add rsp, 0x30                        #    |r|eturn number;
#
# 0x12ed:	pop rbp
# 0x12ee:	ret
# 0x12ef:	nop
# add 0x12f0
# 0x12f0:	push rbp                             #int fake(int a , int b, int x){|
# |int fake(int a , int b, int x){
#
# 0x12f1:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x12f4:	mov dword ptr [rbp - 4], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x12f7:	mov dword ptr [rbp - 8], esi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# 0x12fa:	mov dword ptr [rbp - 0xc], edx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# add 0x12fd
# 0x12fd:	mov dword ptr [rbp - 0x10], 0xa      #    int |d| =10;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# add 0x1304
# 0x1304:	mov dword ptr [rbp - 0x14], 0xb      #    int |e| =11;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# add 0x130b
# 0x130b:	mov dword ptr [rbp - 0x18], 0xc      #    int |f| =12;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x1312
# 0x1312:	mov eax, dword ptr [rbp - 4]         #    int g = |a|+b+d+e+f;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x1315
# 0x1315:	add eax, dword ptr [rbp - 8]         #    int g = a|+|b+d+e+f;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x1318
# 0x1318:	add eax, dword ptr [rbp - 0x10]      #    int g = a+b|+|d+e+f;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-14
# -0x14 -20
# add 0x131b
# 0x131b:	add eax, dword ptr [rbp - 0x14]      #    int g = a+b+d|+|e+f;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-18
# -0x18 -24
# add 0x131e
# 0x131e:	add eax, dword ptr [rbp - 0x18]      #    int g = a+b+d+e|+|f;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-1c
# -0x1c -28
# add 0x1321
# 0x1321:	mov dword ptr [rbp - 0x1c], eax      #    int |g| = a+b+d+e+f;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-1c
# -0x1c -28
# add 0x1324
# 0x1324:	mov eax, dword ptr [rbp - 0x1c]      #    return |g|;
#
# add 0x1327
# 0x1327:	pop rbp                              #    |r|eturn g;
#
# 0x1328:	ret
# add 0x1330
# 0x1330:	push rbp                             #int main() {|
# |int main() {
#
# 0x1331:	mov rbp, rsp
# 0x1334:	sub rsp, 0x30
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x1338:	mov dword ptr [rbp - 4], 0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# add 0x133f
# 0x133f:	mov qword ptr [rbp - 0x10], 0        #    stack *|s|tk = NULL;
#
# add 0x1347
# 0x1347:	mov edi, 7                           #    |p|ush(7, &stk);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# 0x134c:	lea rsi, [rbp - 0x10]
# 0x1350:	call 0x1160
# add 0x1355
# 0x1355:	mov edi, 1                           #    int temp = |a|dd(1,2);
#
# 0x135a:	mov esi, 2
# 0x135f:	call 0x1470
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# add 0x1364
# 0x1364:	mov dword ptr [rbp - 0x14], eax      #    int |t|emp = add(1,2);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-14
# -0x14 -20
# add 0x1367
# 0x1367:	mov edi, dword ptr [rbp - 0x14]      #    push(|t|emp, &stk);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x136a
# 0x136a:	lea rsi, [rbp - 0x10]                #    |p|ush(temp, &stk);
#
# 0x136e:	call 0x1160
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# add 0x1373
# 0x1373:	mov dword ptr [rbp - 0x18], 0        #    int |f|ake_param1 = 0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-1c
# -0x1c -28
# add 0x137a
# 0x137a:	mov dword ptr [rbp - 0x1c], 1        #    int |f|ake_param2 = 1;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-18
# -0x18 -24
# add 0x1381
# 0x1381:	mov edi, dword ptr [rbp - 0x18]      #    int fake_result = fake(|f|ake_param1 , fake_param2, 10);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-1c
# -0x1c -28
# add 0x1384
# 0x1384:	mov esi, dword ptr [rbp - 0x1c]      #    int fake_result = fake(fake_param1 , |f|ake_param2, 10);
#
# add 0x1387
# 0x1387:	mov edx, 0xa                         #    int fake_result = |f|ake(fake_param1 , fake_param2, 10);
#
# 0x138c:	call 0x12f0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-20
# -0x20 -32
# add 0x1391
# 0x1391:	mov dword ptr [rbp - 0x20], eax      #    int |f|ake_result = fake(fake_param1 , fake_param2, 10);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xc85
# 0xc85 3205
# add 0x1394
# 0x1394:	mov rax, qword ptr [rip + 0xc85]     #    char |d|ummy_str[] = "Dummy Str";
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-2a
# -0x2a -42
# 0x139b:	mov qword ptr [rbp - 0x2a], rax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xc82
# 0xc82 3202
# 0x139f:	mov ax, word ptr [rip + 0xc82]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-22
# -0x22 -34
# 0x13a6:	mov word ptr [rbp - 0x22], ax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-2a
# -0x2a -42
# add 0x13aa
# 0x13aa:	lea rsi, [rbp - 0x2a]                #    int dummy_out = dummy(1, 2.0, 3.0,  |d|ummy_str);
#
# add 0x13ae
# 0x13ae:	mov edi, 1                           #    int dummy_out = |d|ummy(1, 2.0, 3.0,  dummy_str);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xc59
# 0xc59 3161
# 0x13b3:	movss xmm0, dword ptr [rip + 0xc59]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xc55
# 0xc55 3157
# 0x13bb:	movsd xmm1, qword ptr [rip + 0xc55]
# 0x13c3:	call 0x11d0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-30
# -0x30 -48
# add 0x13c8
# 0x13c8:	mov dword ptr [rbp - 0x30], eax      #    int |d|ummy_out = dummy(1, 2.0, 3.0,  dummy_str);
#
# add 0x13cb
# 0x13cb:	mov edi, 9                           #    |p|ush(9, &stk);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# 0x13d0:	lea rsi, [rbp - 0x10]
# 0x13d4:	call 0x1160
# add 0x13d9
# 0x13d9:	mov edi, 0xc                         #    |p|ush(12,&stk);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# 0x13de:	lea rsi, [rbp - 0x10]
# 0x13e2:	call 0x1160
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x13e7
# 0x13e7:	lea rdi, [rbp - 0x10]                #    printf("%d\n",|p|op(&stk));
#
# 0x13eb:	call 0x1290
# 0x13f0:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xc31
# 0xc31 3121
# add 0x13f2
# 0x13f2:	lea rdi, [rip + 0xc31]               #    |p|rintf("%d\n",pop(&stk));
#
# 0x13f9:	mov al, 0
# 0x13fb:	call 0x1040
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x1400
# 0x1400:	lea rdi, [rbp - 0x10]                #    printf("%d\n",|p|op(&stk));
#
# 0x1404:	call 0x1290
# 0x1409:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xc18
# 0xc18 3096
# add 0x140b
# 0x140b:	lea rdi, [rip + 0xc18]               #    |p|rintf("%d\n",pop(&stk));
#
# 0x1412:	mov al, 0
# 0x1414:	call 0x1040
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x1419
# 0x1419:	lea rdi, [rbp - 0x10]                #    printf("%d\n",|p|op(&stk));
#
# 0x141d:	call 0x1290
# 0x1422:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xbff
# 0xbff 3071
# add 0x1424
# 0x1424:	lea rdi, [rip + 0xbff]               #    |p|rintf("%d\n",pop(&stk));
#
# 0x142b:	mov al, 0
# 0x142d:	call 0x1040
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x1432
# 0x1432:	lea rdi, [rbp - 0x10]                #    printf("%d\n",|p|op(&stk));
#
# 0x1436:	call 0x1290
# 0x143b:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xbe6
# 0xbe6 3046
# add 0x143d
# 0x143d:	lea rdi, [rip + 0xbe6]               #    |p|rintf("%d\n",pop(&stk));
#
# 0x1444:	mov al, 0
# 0x1446:	call 0x1040
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x144b
# 0x144b:	lea rdi, [rbp - 0x10]                #    printf("%d\n",|p|op(&stk));
#
# 0x144f:	call 0x1290
# 0x1454:	mov esi, eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xbcd
# 0xbcd 3021
# add 0x1456
# 0x1456:	lea rdi, [rip + 0xbcd]               #    |p|rintf("%d\n",pop(&stk));
#
# 0x145d:	mov al, 0
# 0x145f:	call 0x1040
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-20
# -0x20 -32
# add 0x1464
# 0x1464:	mov eax, dword ptr [rbp - 0x20]      #    return |f|ake_result;
#
# add 0x1467
# 0x1467:	add rsp, 0x30                        #    |r|eturn fake_result;
#
# 0x146b:	pop rbp
# 0x146c:	ret
# add 0x1470
# 0x1470:	push rbp                             #int add(int a, int b){|
# |int add(int a, int b){
#
# 0x1471:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x1474:	mov dword ptr [rbp - 4], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x1477:	mov dword ptr [rbp - 8], esi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# add 0x147a
# 0x147a:	mov dword ptr [rbp - 0xc], 0xa       #    int |r|an = 10;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-c
# -0xc -12
# add 0x1481
# 0x1481:	mov eax, dword ptr [rbp - 0xc]       #    ran = |r|an +12;
#
# add 0x1484
# 0x1484:	add eax, 0xc                         #    ran = ran |+|12;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# add 0x1487
# 0x1487:	mov dword ptr [rbp - 0xc], eax       #    ran |=| ran +12;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-c
# -0xc -12
# add 0x148a
# 0x148a:	mov eax, dword ptr [rbp - 0xc]       #    ran =|r|an*ran;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-c
# -0xc -12
# add 0x148d
# 0x148d:	imul eax, dword ptr [rbp - 0xc]      #    ran =ran|*|ran;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# add 0x1491
# 0x1491:	mov dword ptr [rbp - 0xc], eax       #    ran |=|ran*ran;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xb9c
# 0xb9c 2972
# add 0x1494
# 0x1494:	movss xmm0, dword ptr [rip + 0xb9c]  #    float |f|ran =0.12;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# 0x149c:	movss dword ptr [rbp - 0x10], xmm0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-10
# -0x10 -16
# add 0x14a1
# 0x14a1:	movss xmm0, dword ptr [rbp - 0x10]   #    fran = |f|ran+1.0;
#
# 0x14a6:	cvtss2sd xmm0, xmm0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xb7e
# 0xb7e 2942
# add 0x14aa
# 0x14aa:	movsd xmm1, qword ptr [rip + 0xb7e]  #    fran = fran|+|1.0;
#
# 0x14b2:	addsd xmm0, xmm1
# add 0x14b6
# 0x14b6:	cvtsd2ss xmm0, xmm0                  #    fran = |f|ran+1.0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-10
# -0x10 -16
# add 0x14ba
# 0x14ba:	movss dword ptr [rbp - 0x10], xmm0   #    fran |=| fran+1.0;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# add 0x14bf
# 0x14bf:	mov dword ptr [rbp - 0x14], 0        #    for (int |i| = 0; i<10;i++){
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# add 0x14c6
# 0x14c6:	cmp dword ptr [rbp - 0x14], 0xa      #    for (int i = 0; i|<|10;i++){
#
# add 0x14ca
# 0x14ca:	jge 0x14ee                           #    |f|or (int i = 0; i<10;i++){
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# add 0x14d0
# 0x14d0:	mov dword ptr [rbp - 0x18], 0        #        int |f|ran = 0;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-18
# -0x18 -24
# add 0x14d7
# 0x14d7:	mov eax, dword ptr [rbp - 0x18]      #        fran=|f|ran+2;
#
# add 0x14da
# 0x14da:	add eax, 2                           #        fran=fran|+|2;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-18
# -0x18 -24
# add 0x14dd
# 0x14dd:	mov dword ptr [rbp - 0x18], eax      #        fran|=|fran+2;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-14
# -0x14 -20
# add 0x14e0
# 0x14e0:	mov eax, dword ptr [rbp - 0x14]      #    for (int i = 0; i<10;i|+|+){
#
# 0x14e3:	add eax, 1
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-14
# -0x14 -20
# 0x14e6:	mov dword ptr [rbp - 0x14], eax
# add 0x14e9
# 0x14e9:	jmp 0x14c6                           #    |f|or (int i = 0; i<10;i++){
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-c
# -0xc -12
# add 0x14ee
# 0x14ee:	mov eax, dword ptr [rbp - 0xc]       #    ran =|r|an -10;
#
# add 0x14f1
# 0x14f1:	sub eax, 0xa                         #    ran =ran |-|10;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-c
# -0xc -12
# add 0x14f4
# 0x14f4:	mov dword ptr [rbp - 0xc], eax       #    ran |=|ran -10;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x14f7
# 0x14f7:	mov eax, dword ptr [rbp - 4]         #    return |a|+b+ran;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x14fa
# 0x14fa:	add eax, dword ptr [rbp - 8]         #    return a|+|b+ran;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-c
# -0xc -12
# add 0x14fd
# 0x14fd:	add eax, dword ptr [rbp - 0xc]       #    return a+b|+|ran;
#
# add 0x1500
# 0x1500:	pop rbp                              #    |r|eturn a+b+ran;
#
# 0x1501:	ret
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x1502:	nop word ptr cs:[rax + rax]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x150c:	nop dword ptr [rax]
# add 0x1510
# 0x1510:	push rbp                             #float addf(float a, float b){|
# |float addf(float a, float b){
#
# 0x1511:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x1514:	movss dword ptr [rbp - 4], xmm0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x1519:	movss dword ptr [rbp - 8], xmm1
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x151e
# 0x151e:	movss xmm0, dword ptr [rbp - 4]      #    return |a|+b;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x1523
# 0x1523:	addss xmm0, dword ptr [rbp - 8]      #    return a|+|b;
#
# add 0x1528
# 0x1528:	pop rbp                              #    |r|eturn a+b;
#
# 0x1529:	ret
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x152a:	nop word ptr [rax + rax]
# add 0x1530
# 0x1530:	push rbp                             #int substract(int a, int b){|
# |int substract(int a, int b){
#
# 0x1531:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x1534:	mov dword ptr [rbp - 4], edi
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x1537:	mov dword ptr [rbp - 8], esi
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x153a
# 0x153a:	mov eax, dword ptr [rbp - 4]         #    return |a|-b;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x153d
# 0x153d:	sub eax, dword ptr [rbp - 8]         #    return a|-|b;
#
# add 0x1540
# 0x1540:	pop rbp                              #    |r|eturn a-b;
#
# 0x1541:	ret
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x1542:	nop word ptr cs:[rax + rax]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x154c:	nop dword ptr [rax]
# add 0x1550
# 0x1550:	push rbp                             #float substractf(float a, float b){|
# |float substractf(float a, float b){
#
# 0x1551:	mov rbp, rsp
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-4
# -0x4 -4
# 0x1554:	movss dword ptr [rbp - 4], xmm0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbp
# 			operands[0].mem.disp: 0x-8
# -0x8 -8
# 0x1559:	movss dword ptr [rbp - 8], xmm1
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-4
# -0x4 -4
# add 0x155e
# 0x155e:	movss xmm0, dword ptr [rbp - 4]      #    return |a|-b;
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 			operands[1].mem.disp: 0x-8
# -0x8 -8
# add 0x1563
# 0x1563:	subss xmm0, dword ptr [rbp - 8]      #    return a|-|b;
#
# add 0x1568
# 0x1568:	pop rbp                              #    |r|eturn a-b;
#
# 0x1569:	ret

# %%
# 0x2382a
