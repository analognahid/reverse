# %%
#!/usr/bin/env python3

import sys,os
from elftools.elf.elffile import ELFFile
from elftools.elf.segments import Segment



filePath = './../../binaries/array'



with open(filePath, 'rb') as f:
    elffile =  ELFFile(f)
    
    for segment in elffile.iter_segments():
        if segment.header.p_filesz != segment.header.p_memsz:
            seg_head = segment.header
            print(f"Type: {seg_head.p_type}\nOffset: {hex(seg_head.p_offset)}\nSize in file:{hex(seg_head.p_filesz)}\nSize in memory:{hex(seg_head.p_memsz)}")
            
    dwarfinfo = elffile.get_dwarf_info()
    for CU in dwarfinfo.iter_CUs():
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))
        

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        # line_program = dwarfinfo.line_program_for_CU(CU)
        # if line_program is None:
        #     print('  DWARF info is missing a line program for this CU')
        #     continue
# Out:
# Type: PT_LOAD
# Offset: 0x2da8
# Size in file:0x268
# Size in memory:0x270
#   Found a compile unit at offset 0, length 325

# %%
def _format_hex( addr, fieldsize=None, fullhex=False, lead0x=True):
    """ Format an address into a hexadecimal string.
        fieldsize:
            Size of the hexadecimal field (with leading zeros to fit the
            address into. For example with fieldsize=8, the format will
            be %08x
            If None, the minimal required field size will be used.
        fullhex:
            If True, override fieldsize to set it to the maximal size
            needed for the elfclass
        lead0x:
            If True, leading 0x is added
    """
    s = '0x' if lead0x else ''
    if fullhex:
        fieldsize = 8 if elffile.elfclass == 32 else 16
    if fieldsize is None:
        field = '%x'
    else:
        field = '%' + '0%sx' % fieldsize
    return s + field % addr

from elftools.elf.descriptions import (
    describe_ei_class, describe_ei_data, describe_ei_version,
    describe_ei_osabi, describe_e_type, describe_e_machine,
    describe_e_version_numeric, describe_p_type, describe_p_flags,
    describe_sh_type, describe_sh_flags,
    describe_symbol_type, describe_symbol_bind, describe_symbol_visibility,
    describe_symbol_shndx, describe_reloc_type, describe_dyn_tag,
    )

# %%
# with open(filePath, 'rb') as f:
#     elffile =  ELFFile(f)
#     for nsec, section in enumerate(elffile.iter_sections()):
#                 print('  [%2u] %-17.17s %-15.15s ' % (
#                     nsec, (section.name), describe_sh_type(section['sh_type'])))

#                 # if elffile.elfclass == 32:
#                 #     print('%s %s %s %s %3s %2s %3s %2s' % (
#                 #         _format_hex(section['sh_addr'], fieldsize=8, lead0x=False),
#                 #         _format_hex(section['sh_offset'], fieldsize=6, lead0x=False),
#                 #         _format_hex(section['sh_size'], fieldsize=6, lead0x=False),
#                 #         _format_hex(section['sh_entsize'], fieldsize=2, lead0x=False),
#                 #         describe_sh_flags(section['sh_flags']),
#                 #         section['sh_link'], section['sh_info'],
#                 #         section['sh_addralign']))
#                 # else: # 64
#                 print(' sh_addr: %s  sh_offset: %s' % (
#                     _format_hex(section['sh_addr'], fullhex=True, lead0x=False),
#                     _format_hex(section['sh_offset'],
#                         fieldsize=16 if section['sh_offset'] > 0xffffffff else 8,
#                         lead0x=False)))
#                 print('       sh_size: %s  sh_entsize: %s sh_flags:%3s      sh_link:%2s   sh_info:%3s     sh_addralign:%s' % (
#                     _format_hex(section['sh_size'], fullhex=True, lead0x=False),
#                     _format_hex(section['sh_entsize'], fullhex=True, lead0x=False),
#                     describe_sh_flags(section['sh_flags']),
#                     section['sh_link'], section['sh_info'],
#                     section['sh_addralign']))

# %%
from capstone import *

address_inst = {}

with open(filePath, 'rb') as f:
    elf = ELFFile(f)
    code = elf.get_section_by_name('.text')
    ops = code.data()
    print('code data size: ',code.data_size)
    addr = code['sh_addr']
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    for i in md.disasm(ops, addr):        
        print(f'0x{i.address:x}:\t{i.mnemonic}\t{i.op_str}')
        address_inst[hex(i.address)] = i
# Out:
# code data size:  542
# 0x10a0:	endbr64
# 0x10a4:	xor	ebp, ebp
# 0x10a6:	mov	r9, rdx
# 0x10a9:	pop	rsi
# 0x10aa:	mov	rdx, rsp
# 0x10ad:	and	rsp, 0xfffffffffffffff0
# 0x10b1:	push	rax
# 0x10b2:	push	rsp
# 0x10b3:	xor	r8d, r8d
# 0x10b6:	xor	ecx, ecx
# 0x10b8:	lea	rdi, [rip + 0xca]
# 0x10bf:	call	qword ptr [rip + 0x2f13]
# 0x10c5:	hlt
# 0x10c6:	nop	word ptr cs:[rax + rax]
# 0x10d0:	lea	rdi, [rip + 0x2f39]
# 0x10d7:	lea	rax, [rip + 0x2f32]
# 0x10de:	cmp	rax, rdi
# 0x10e1:	je	0x10f8
# 0x10e3:	mov	rax, qword ptr [rip + 0x2ef6]
# 0x10ea:	test	rax, rax
# 0x10ed:	je	0x10f8
# 0x10ef:	jmp	rax
# 0x10f1:	nop	dword ptr [rax]
# 0x10f8:	ret
# 0x10f9:	nop	dword ptr [rax]
# 0x1100:	lea	rdi, [rip + 0x2f09]
# 0x1107:	lea	rsi, [rip + 0x2f02]
# 0x110e:	sub	rsi, rdi
# 0x1111:	mov	rax, rsi
# 0x1114:	shr	rsi, 0x3f
# 0x1118:	sar	rax, 3
# 0x111c:	add	rsi, rax
# 0x111f:	sar	rsi, 1
# 0x1122:	je	0x1138
# 0x1124:	mov	rax, qword ptr [rip + 0x2ec5]
# 0x112b:	test	rax, rax
# 0x112e:	je	0x1138
# 0x1130:	jmp	rax
# 0x1132:	nop	word ptr [rax + rax]
# 0x1138:	ret
# 0x1139:	nop	dword ptr [rax]
# 0x1140:	endbr64
# 0x1144:	cmp	byte ptr [rip + 0x2ec5], 0
# 0x114b:	jne	0x1178
# 0x114d:	push	rbp
# 0x114e:	cmp	qword ptr [rip + 0x2ea2], 0
# 0x1156:	mov	rbp, rsp
# 0x1159:	je	0x1167
# 0x115b:	mov	rdi, qword ptr [rip + 0x2ea6]
# 0x1162:	call	0x1060
# 0x1167:	call	0x10d0
# 0x116c:	mov	byte ptr [rip + 0x2e9d], 1
# 0x1173:	pop	rbp
# 0x1174:	ret
# 0x1175:	nop	dword ptr [rax]
# 0x1178:	ret
# 0x1179:	nop	dword ptr [rax]
# 0x1180:	endbr64
# 0x1184:	jmp	0x1100
# 0x1189:	endbr64
# 0x118d:	push	rbp
# 0x118e:	mov	rbp, rsp
# 0x1191:	sub	rsp, 0x30
# 0x1195:	mov	rax, qword ptr fs:[0x28]
# 0x119e:	mov	qword ptr [rbp - 8], rax
# 0x11a2:	xor	eax, eax
# 0x11a4:	lea	rax, [rip + 0xe59]
# 0x11ab:	mov	rdi, rax
# 0x11ae:	mov	eax, 0
# 0x11b3:	call	0x1080
# 0x11b8:	mov	dword ptr [rbp - 0x2c], 0
# 0x11bf:	jmp	0x11f8
# 0x11c1:	mov	eax, dword ptr [rbp - 0x2c]
# 0x11c4:	cdqe
# 0x11c6:	mov	edx, dword ptr [rbp - 0x2c]
# 0x11c9:	mov	dword ptr [rbp + rax*4 - 0x20], edx
# 0x11cd:	lea	rdx, [rbp - 0x20]
# 0x11d1:	mov	eax, dword ptr [rbp - 0x2c]
# 0x11d4:	cdqe
# 0x11d6:	shl	rax, 2
# 0x11da:	add	rax, rdx
# 0x11dd:	mov	rsi, rax
# 0x11e0:	lea	rax, [rip + 0xe30]
# 0x11e7:	mov	rdi, rax
# 0x11ea:	mov	eax, 0
# 0x11ef:	call	0x1090
# 0x11f4:	add	dword ptr [rbp - 0x2c], 1
# 0x11f8:	cmp	dword ptr [rbp - 0x2c], 4
# 0x11fc:	jle	0x11c1
# 0x11fe:	lea	rax, [rip + 0xe15]
# 0x1205:	mov	rdi, rax
# 0x1208:	mov	eax, 0
# 0x120d:	call	0x1080
# 0x1212:	mov	dword ptr [rbp - 0x28], 0
# 0x1219:	jmp	0x1299
# 0x121b:	mov	eax, dword ptr [rbp - 0x28]
# 0x121e:	cdqe
# 0x1220:	mov	edx, dword ptr [rbp - 0x28]
# 0x1223:	mov	dword ptr [rbp + rax*4 - 0x20], edx
# 0x1227:	mov	dword ptr [rbp - 0x24], 0
# 0x122e:	jmp	0x128f
# 0x1230:	mov	eax, dword ptr [rbp - 0x28]
# 0x1233:	imul	eax, dword ptr [rbp - 0x24]
# 0x1237:	mov	ecx, eax
# 0x1239:	mov	eax, dword ptr [rbp - 0x28]
# 0x123c:	imul	eax, dword ptr [rbp - 0x24]
# 0x1240:	movsxd	rdx, eax
# 0x1243:	imul	rdx, rdx, 0x66666667
# 0x124a:	shr	rdx, 0x20
# 0x124e:	sar	edx, 1
# 0x1250:	mov	esi, eax
# 0x1252:	sar	esi, 0x1f
# 0x1255:	sub	edx, esi
# 0x1257:	mov	esi, edx
# 0x1259:	shl	esi, 2
# 0x125c:	add	esi, edx
# 0x125e:	sub	eax, esi
# 0x1260:	mov	edx, eax
# 0x1262:	movsxd	rax, ecx
# 0x1265:	imul	rax, rax, 0x66666667
# 0x126c:	shr	rax, 0x20
# 0x1270:	sar	eax, 1
# 0x1272:	mov	esi, ecx
# 0x1274:	sar	esi, 0x1f
# 0x1277:	sub	eax, esi
# 0x1279:	mov	esi, eax
# 0x127b:	shl	esi, 2
# 0x127e:	add	esi, eax
# 0x1280:	mov	eax, ecx
# 0x1282:	sub	eax, esi
# 0x1284:	movsxd	rdx, edx
# 0x1287:	mov	dword ptr [rbp + rdx*4 - 0x20], eax
# 0x128b:	add	dword ptr [rbp - 0x24], 1
# 0x128f:	cmp	dword ptr [rbp - 0x24], 4
# 0x1293:	jle	0x1230
# 0x1295:	add	dword ptr [rbp - 0x28], 1
# 0x1299:	cmp	dword ptr [rbp - 0x28], 4
# 0x129d:	jle	0x121b
# 0x12a3:	mov	eax, 0
# 0x12a8:	mov	rdx, qword ptr [rbp - 8]
# 0x12ac:	sub	rdx, qword ptr fs:[0x28]
# 0x12b5:	je	0x12bc
# 0x12b7:	call	0x1070
# 0x12bc:	leave
# 0x12bd:	ret

# %%
# address_inst

# %%
#-------------------------------------------------------------------------------
# elftools example: dwarf_lineprogram_filenames.py
#
# In the .debug_line section, the Dwarf line program generates a matrix
# of address-source references. This example demonstrates accessing the state
# of each line program entry to retrieve the underlying filenames.
#
# William Woodruff (william@yossarian.net)
# This code is in the public domain
#-------------------------------------------------------------------------------
from __future__ import print_function
from collections import defaultdict
import os
import sys
import posixpath

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.
# sys.path[0:0] = ['.', '..']

from elftools.elf.elffile import ELFFile






def line_entry_mapping(line_program):
    filename_map = defaultdict(int)

    # The line program, when decoded, returns a list of line program
    # entries. Each entry contains a state, which we'll use to build
    # a reverse mapping of filename -> #entries.
    lp_entries = line_program.get_entries()
    for lpe in lp_entries:
        # We skip LPEs that don't have an associated file.
        # This can happen if instructions in the compiled binary
        # don't correspond directly to any original source file.
        if not lpe.state or lpe.state.file == 0:
            continue
        filename = lpe_filename(line_program, lpe.state.file)
        filename_map[filename] += 1

    for filename, lpe_count in filename_map.items():
        print("    filename=%s -> %d entries" % (filename, lpe_count))
    return filename_map

def lpe_filename(line_program, file_index):


    lp_header = line_program.header
    file_entries = lp_header["file_entry"]
    
    # print('lp_header', lp_header, '\n\n')
    # print("file_entries", file_entries,'\n\n__________________________________________\n\n')

    # File and directory indices are 1-indexed.
    file_entry = file_entries[file_index - 1]
    dir_index = file_entry["dir_index"]

    # A dir_index of 0 indicates that no absolute directory was recorded during
    # compilation; return just the basename.
    if dir_index == 0:
        return file_entry.name.decode()

    directory = lp_header["include_directory"][dir_index - 1]
    return posixpath.join(directory, file_entry.name).decode()



addr_lineProgram ={}
addr_sourceFile = {}

with open(filePath, 'rb') as f:
    elffile = ELFFile(f)

    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
        exit(0)

    dwarfinfo = elffile.get_dwarf_info()
    for CU in dwarfinfo.iter_CUs():
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        line_program = dwarfinfo.line_program_for_CU(CU)
        if line_program is None:
            print('  DWARF info is missing a line program for this CU')
            continue

        # Print a reverse mapping of filename -> #entries
        filename_map = line_entry_mapping(line_program)
        for line_entry in line_program.get_entries():
            # print(line_entry)
            if line_entry.state!=None:
                addr_lineProgram[hex(line_entry.state.address)] = line_entry
                addr_sourceFile [hex(line_entry.state.address)] = filename_map
        print("_____________________________________________________")
# Out:
#   Found a compile unit at offset 0, length 325
#     filename=array.c -> 27 entries
# _____________________________________________________

# %%
# line_entry

# %%
def getSource(sourceFileName, row, col):
    basePath = "/home/nahid/reverse/binaries/"
    sourceFilePath = os.path.join(basePath , sourceFileName)
    sourceFile = open(sourceFilePath, "r")
    fileContent = sourceFile.readlines()
    
    row_content =  fileContent[row-1]
    
    row_content = row_content[:(col-1)] + "@" +row_content[col:]
    
    # print(row_content)
    
    return row_content

# %%
with open(filePath, 'rb') as f:
    elffile = ELFFile(f)

    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
        exit(0)

    dwarfinfo = elffile.get_dwarf_info()
    arangesInfo = dwarfinfo.debug_aranges_sec
    pubTypes = dwarfinfo.debug_pubtypes_sec

# %%
# with open('stacktest.s', 'w') as outFile:
#     # outFile.write('file contents\n')
#     lastSource = ""
#     for address in address_inst:
#         inst = address_inst[address]
#         instrctionCode = (address+":\t"+ inst.mnemonic+" "+inst.op_str).ljust(45)
#         if address in addr_lineProgram:
#             line = addr_lineProgram[address]

#             srcFileName =list(addr_sourceFile[address].keys())[0] #TODO not single file always 
            
#             if srcFileName!=lastSource:
#                 outFile.write("\n"+ '#'*100+"\n"+ srcFileName.rjust(45) +'\n'+'#'*100+ "\n\n")
#                 lastSource = srcFileName
            
#             sourceCode = getSource(srcFileName,addr_lineProgram[address].state.line, addr_lineProgram[address].state.column)
#             if '\n' not in  sourceCode:
#                 sourceCode+=sourceCode+"\n"
#             outFile.write(instrctionCode+"#"+ sourceCode  )
#             print(instrctionCode+"#"+ sourceCode)
#         else:
#             outFile.write(instrctionCode+ '\n'  )
#             print(instrctionCode)

# %%
# address_inst = {}        add->instruction
# addr_lineProgram = {}    add-> lineInfo (row,col)
# addr_sourceFile =  {}    add-> sourceFIleName

# %%
def get_filename_lineinfo(die): # TODO find actual path, currently just returns filename
    lp_header = die.dwarfinfo.line_program_for_CU(die.cu).header
    files = lp_header["file_entry"]
    includes = lp_header["include_directory"]

    fileinfo = files[die.attributes["DW_AT_decl_file"].value - 1]
    filename = fileinfo.name.decode("utf-8")
    filedir = includes[fileinfo.dir_index - 1].decode("utf-8")

    path = os.path.join(filedir, filename)
    lineno = die.attributes["DW_AT_decl_line"].value
    columno = die.attributes["DW_AT_decl_column"].value
    return filename, path, lineno , columno

# %%
sourceLocation_die = {} #directory for DIE for C source line and col

import sys

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.

from elftools.elf.elffile import ELFFile
from elftools.dwarf.descriptions import (
    describe_DWARF_expr, set_global_machine_arch)
from elftools.dwarf.locationlists import (
    LocationEntry, LocationExpr, LocationParser)




def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        # get_dwarf_info returns a DWARFInfo context object, which is the
        # starting point for all DWARF-based processing in pyelftools.
        dwarfinfo = elffile.get_dwarf_info()

        # The location lists are extracted by DWARFInfo from the .debug_loc
        # section, and returned here as a LocationLists object.
        location_lists = dwarfinfo.location_lists()

        # This is required for the descriptions module to correctly decode
        # register names contained in DWARF expressions.
        set_global_machine_arch(elffile.get_machine_arch())

        # Create a LocationParser object that parses the DIE attributes and
        # creates objects representing the actual location information.
        loc_parser = LocationParser(location_lists)

        for CU in dwarfinfo.iter_CUs():
            # DWARFInfo allows to iterate over the compile units contained in
            # the .debug_info section. CU is a CompileUnit object, with some
            # computed attributes (such as its offset in the section) and
            # a header which conforms to the DWARF standard. The access to
            # header elements is, as usual, via item-lookup.
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # A CU provides a simple API to iterate over all the DIEs in it.
            die_depth = 0
            for DIE in CU.iter_DIEs():
                # Go over all attributes of the DIE. Each attribute is an
                # AttributeValue object (from elftools.dwarf.die), which we
                # can examine.
                
                
                print("TREE DEPTH: ",die_depth)

                for attr in DIE.attributes.values():
                    
                    print(attr)
                    
                    if attr.name == "DW_AT_decl_file":
                        src_file, _ , line,column = get_filename_lineinfo(DIE)
                        dict_key = src_file +"#"+str(line) #TODO column should be in key
                        if dict_key in sourceLocation_die.keys():
                            sourceLocation_die [dict_key ][column] = DIE
                        else:
                            sourceLocation_die [dict_key ] = {}
                            sourceLocation_die [dict_key ][column] = DIE
                            
                            
                print("\n\n\n")
                
                if DIE.is_null(): #https://chromium.googlesource.com/chromiumos/third_party/pyelftools/+/25a77f7738d7fe824f2ed4d33a123136b9d8e88a/scripts/readelf.py
                    die_depth -= 1
                    continue
                if DIE.has_children:
                    die_depth += 1
                    
            # break



process_file(filePath)
# Out:
# Processing file: ./../../binaries/array
#   Found a compile unit at offset 0, length 325
# TREE DEPTH:  0
# AttributeValue(name='DW_AT_producer', form='DW_FORM_strp', value=b'GNU C17 11.3.0 -mtune=generic -march=x86-64 -gdwarf -fasynchronous-unwind-tables -fstack-protector-strong -fstack-clash-protection -fcf-protection', raw_value=68, offset=13)
# AttributeValue(name='DW_AT_language', form='DW_FORM_data1', value=29, raw_value=29, offset=17)
# AttributeValue(name='DW_AT_name', form='DW_FORM_line_strp', value=b'array.c', raw_value=0, offset=18)
# AttributeValue(name='DW_AT_comp_dir', form='DW_FORM_line_strp', value=b'/home/nahid/reverse/binaries', raw_value=8, offset=22)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4489, raw_value=4489, offset=26)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=309, raw_value=309, offset=34)
# AttributeValue(name='DW_AT_stmt_list', form='DW_FORM_sec_offset', value=0, raw_value=0, offset=42)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=47)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=48)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long unsigned int', raw_value=7, offset=49)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=54)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=55)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned int', raw_value=12, offset=56)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=61)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=8, raw_value=8, offset=62)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned char', raw_value=40, offset=63)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=68)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=69)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short unsigned int', raw_value=215, offset=70)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=75)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=76)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'signed char', raw_value=42, offset=77)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=82)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=83)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short int', raw_value=241, offset=84)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=89)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=90)
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=91)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=96)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=97)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long int', raw_value=59, offset=98)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=103)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=104)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'char', raw_value=49, offset=105)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=102, raw_value=102, offset=110)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=115)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'scanf', raw_value=34, offset=115)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=119)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data2', value=437, raw_value=437, offset=120)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=12, raw_value=12, offset=122)
# AttributeValue(name='DW_AT_linkage_name', form='DW_FORM_strp', value=b'__isoc99_scanf', raw_value=25, offset=123)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=127)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=127)
# AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=131)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=142, raw_value=142, offset=131)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=142, raw_value=142, offset=136)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=143)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=109, raw_value=109, offset=144)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=149)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'printf', raw_value=234, offset=149)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=153)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data2', value=356, raw_value=356, offset=154)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=12, raw_value=12, offset=156)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=157)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=157)
# AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=161)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=172, raw_value=172, offset=161)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=142, raw_value=142, offset=166)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=173)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'main', raw_value=54, offset=173)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=177)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=178)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=179)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=180)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4489, raw_value=4489, offset=184)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=309, raw_value=309, offset=192)
# AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=200)
# AttributeValue(name='DW_AT_call_all_tail_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=202)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=316, raw_value=316, offset=202)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'values', raw_value=0, offset=207)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=211)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=8, raw_value=8, offset=212)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=7, raw_value=7, offset=213)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=316, raw_value=316, offset=214)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 80], raw_value=[145, 80], offset=218)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4536, raw_value=4536, offset=222)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=70, raw_value=70, offset=230)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=255, raw_value=255, offset=238)
#
#
#
#
# TREE DEPTH:  3
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=243)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=245)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=13, raw_value=13, offset=245)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=246)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=247)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 68], raw_value=[145, 68], offset=251)
#
#
#
#
# TREE DEPTH:  3
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4626, raw_value=4626, offset=256)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=145, raw_value=145, offset=264)
#
#
#
#
# TREE DEPTH:  3
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=273)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=275)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=21, raw_value=21, offset=275)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=276)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=277)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 72], raw_value=[145, 72], offset=281)
#
#
#
#
# TREE DEPTH:  3
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4647, raw_value=4647, offset=285)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=110, raw_value=110, offset=293)
#
#
#
#
# TREE DEPTH:  4
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'j', raw_value=b'j', offset=302)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=304)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=304)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=14, raw_value=14, offset=305)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=306)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 76], raw_value=[145, 76], offset=310)
#
#
#
#
# TREE DEPTH:  4
#
#
#
#
# TREE DEPTH:  3
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=317)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=46, raw_value=46, offset=322)
# AttributeValue(name='DW_AT_upper_bound', form='DW_FORM_data1', value=4, raw_value=4, offset=326)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1

# %%
with open('array.s', 'w') as outFile:
    # outFile.write('file contents\n')
    lastSource = ""
    for address in address_inst:
        inst = address_inst[address]
        instrctionCode = (address+":\t"+ inst.mnemonic+" "+inst.op_str).ljust(50)
        if address in addr_lineProgram:
#             print()
            line = addr_lineProgram[address]

            srcFileName =list(addr_sourceFile[address].keys())[0] #TODO not single file always 
            
            if srcFileName!=lastSource:
                outFile.write("\n"+ '#'*100+"\n"+ srcFileName.rjust(45) +'\n'+'#'*100+ "\n\n")
                lastSource = srcFileName
            
            sourceCode = getSource(srcFileName,addr_lineProgram[address].state.line, addr_lineProgram[address].state.column)
            src_key = srcFileName+"#"+str(addr_lineProgram[address].state.line)
            
            if src_key in sourceLocation_die.keys():
                die_info = sourceLocation_die[src_key]
                print('\n'*2,die_info,'\n'*2)
            else:
                print('\n'*2,"\nNONE\n",'\n'*2)
            
            if '\n' not in  sourceCode:
                sourceCode+=sourceCode+"\n"
            outFile.write(instrctionCode+"#"+ sourceCode  )
            print(instrctionCode+"#"+ sourceCode)
        else:
            outFile.write(instrctionCode+ '\n'  )
            print(instrctionCode)
# Out:
# 0x10a0:	endbr64
# 0x10a4:	xor ebp, ebp
# 0x10a6:	mov r9, rdx
# 0x10a9:	pop rsi
# 0x10aa:	mov rdx, rsp
# 0x10ad:	and rsp, 0xfffffffffffffff0
# 0x10b1:	push rax
# 0x10b2:	push rsp
# 0x10b3:	xor r8d, r8d
# 0x10b6:	xor ecx, ecx
# 0x10b8:	lea rdi, [rip + 0xca]
# 0x10bf:	call qword ptr [rip + 0x2f13]
# 0x10c5:	hlt
# 0x10c6:	nop word ptr cs:[rax + rax]
# 0x10d0:	lea rdi, [rip + 0x2f39]
# 0x10d7:	lea rax, [rip + 0x2f32]
# 0x10de:	cmp rax, rdi
# 0x10e1:	je 0x10f8
# 0x10e3:	mov rax, qword ptr [rip + 0x2ef6]
# 0x10ea:	test rax, rax
# 0x10ed:	je 0x10f8
# 0x10ef:	jmp rax
# 0x10f1:	nop dword ptr [rax]
# 0x10f8:	ret
# 0x10f9:	nop dword ptr [rax]
# 0x1100:	lea rdi, [rip + 0x2f09]
# 0x1107:	lea rsi, [rip + 0x2f02]
# 0x110e:	sub rsi, rdi
# 0x1111:	mov rax, rsi
# 0x1114:	shr rsi, 0x3f
# 0x1118:	sar rax, 3
# 0x111c:	add rsi, rax
# 0x111f:	sar rsi, 1
# 0x1122:	je 0x1138
# 0x1124:	mov rax, qword ptr [rip + 0x2ec5]
# 0x112b:	test rax, rax
# 0x112e:	je 0x1138
# 0x1130:	jmp rax
# 0x1132:	nop word ptr [rax + rax]
# 0x1138:	ret
# 0x1139:	nop dword ptr [rax]
# 0x1140:	endbr64
# 0x1144:	cmp byte ptr [rip + 0x2ec5], 0
# 0x114b:	jne 0x1178
# 0x114d:	push rbp
# 0x114e:	cmp qword ptr [rip + 0x2ea2], 0
# 0x1156:	mov rbp, rsp
# 0x1159:	je 0x1167
# 0x115b:	mov rdi, qword ptr [rip + 0x2ea6]
# 0x1162:	call 0x1060
# 0x1167:	call 0x10d0
# 0x116c:	mov byte ptr [rip + 0x2e9d], 1
# 0x1173:	pop rbp
# 0x1174:	ret
# 0x1175:	nop dword ptr [rax]
# 0x1178:	ret
# 0x1179:	nop dword ptr [rax]
# 0x1180:	endbr64
# 0x1184:	jmp 0x1100
#
#
#  {5: DIE DW_TAG_subprogram, size=34, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=173)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'main', raw_value=54, offset=173)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=177)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=178)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=179)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=180)
#     |DW_AT_low_pc      :  AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4489, raw_value=4489, offset=184)
#     |DW_AT_high_pc     :  AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=309, raw_value=309, offset=192)
#     |DW_AT_frame_base  :  AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=200)
#     |DW_AT_call_all_tail_calls:  AttributeValue(name='DW_AT_call_all_tail_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=202)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=316, raw_value=316, offset=202)
# }
#
#
# 0x1189:	endbr64                                   #int main() @
#
# 0x118d:	push rbp
# 0x118e:	mov rbp, rsp
# 0x1191:	sub rsp, 0x30
#
#
#  {5: DIE DW_TAG_subprogram, size=34, has_children=True
#     |DW_AT_external    :  AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=173)
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'main', raw_value=54, offset=173)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=177)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=178)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=179)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=180)
#     |DW_AT_low_pc      :  AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4489, raw_value=4489, offset=184)
#     |DW_AT_high_pc     :  AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=309, raw_value=309, offset=192)
#     |DW_AT_frame_base  :  AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=200)
#     |DW_AT_call_all_tail_calls:  AttributeValue(name='DW_AT_call_all_tail_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=202)
#     |DW_AT_sibling     :  AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=316, raw_value=316, offset=202)
# }
#
#
# 0x1195:	mov rax, qword ptr fs:[0x28]              #int main() @
#
# 0x119e:	mov qword ptr [rbp - 8], rax
# 0x11a2:	xor eax, eax
#
#
#
# NONE
#
#
#
# 0x11a4:	lea rax, [rip + 0xe59]                    #  @rintf("Enter 5 integers: ");
#
# 0x11ab:	mov rdi, rax
# 0x11ae:	mov eax, 0
# 0x11b3:	call 0x1080
#
#
#  {11: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=243)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=245)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=13, raw_value=13, offset=245)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=246)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=247)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 68], raw_value=[145, 68], offset=251)
# }
#
#
# 0x11b8:	mov dword ptr [rbp - 0x2c], 0             #  for(int @ = 0; i < 5; ++i) {// vanilla loop
#
#
#
#  {11: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=243)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=245)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=13, raw_value=13, offset=245)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=246)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=247)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 68], raw_value=[145, 68], offset=251)
# }
#
#
# 0x11bf:	jmp 0x11f8                                #  @or(int i = 0; i < 5; ++i) {// vanilla loop
#
#
#
#
# NONE
#
#
#
# 0x11c1:	mov eax, dword ptr [rbp - 0x2c]           #     values[i] @ i;
#
# 0x11c4:	cdqe
# 0x11c6:	mov edx, dword ptr [rbp - 0x2c]
# 0x11c9:	mov dword ptr [rbp + rax*4 - 0x20], edx
#
#
#
# NONE
#
#
#
# 0x11cd:	lea rdx, [rbp - 0x20]                     #     @canf("%d", &values[i]);
#
# 0x11d1:	mov eax, dword ptr [rbp - 0x2c]
# 0x11d4:	cdqe
# 0x11d6:	shl rax, 2
# 0x11da:	add rax, rdx
# 0x11dd:	mov rsi, rax
# 0x11e0:	lea rax, [rip + 0xe30]
# 0x11e7:	mov rdi, rax
# 0x11ea:	mov eax, 0
# 0x11ef:	call 0x1090
#
#
#  {11: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=243)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=245)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=13, raw_value=13, offset=245)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=246)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=247)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 68], raw_value=[145, 68], offset=251)
# }
#
#
# 0x11f4:	add dword ptr [rbp - 0x2c], 1             #  for(int i = 0; i < 5; @+i) {// vanilla loop
#
#
#
#  {11: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=243)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=245)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=13, raw_value=13, offset=245)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=246)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=247)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 68], raw_value=[145, 68], offset=251)
# }
#
#
# 0x11f8:	cmp dword ptr [rbp - 0x2c], 4             #  for(int i = 0; i @ 5; ++i) {// vanilla loop
#
# 0x11fc:	jle 0x11c1
#
#
#
# NONE
#
#
#
# 0x11fe:	lea rax, [rip + 0xe15]                    #  @rintf("Displaying integers: ");
#
# 0x1205:	mov rdi, rax
# 0x1208:	mov eax, 0
# 0x120d:	call 0x1080
#
#
#  {11: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=273)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=275)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=21, raw_value=21, offset=275)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=276)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=277)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 72], raw_value=[145, 72], offset=281)
# }
#
#
# 0x1212:	mov dword ptr [rbp - 0x28], 0             #  for(int @ = 0; i < 5; ++i) {//loop1
#
#
#
#  {11: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=273)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=275)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=21, raw_value=21, offset=275)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=276)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=277)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 72], raw_value=[145, 72], offset=281)
# }
#
#
# 0x1219:	jmp 0x1299                                #  @or(int i = 0; i < 5; ++i) {//loop1
#
#
#
#
# NONE
#
#
#
# 0x121b:	mov eax, dword ptr [rbp - 0x28]           #     values[i] @ i;
#
# 0x121e:	cdqe
# 0x1220:	mov edx, dword ptr [rbp - 0x28]
# 0x1223:	mov dword ptr [rbp + rax*4 - 0x20], edx
#
#
#  {14: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'j', raw_value=b'j', offset=302)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=304)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=304)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=14, raw_value=14, offset=305)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=306)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 76], raw_value=[145, 76], offset=310)
# }
#
#
# 0x1227:	mov dword ptr [rbp - 0x24], 0             #     for(int @ = 0; j < 5; ++j) {//loop2
#
#
#
#  {14: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'j', raw_value=b'j', offset=302)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=304)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=304)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=14, raw_value=14, offset=305)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=306)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 76], raw_value=[145, 76], offset=310)
# }
#
#
# 0x122e:	jmp 0x128f                                #     @or(int j = 0; j < 5; ++j) {//loop2
#
#
#
#
# NONE
#
#
#
# 0x1230:	mov eax, dword ptr [rbp - 0x28]           #         values[i*j%5] =  i@j%5;
#
# 0x1233:	imul eax, dword ptr [rbp - 0x24]
# 0x1237:	mov ecx, eax
#
#
#
# NONE
#
#
#
# 0x1239:	mov eax, dword ptr [rbp - 0x28]           #         values[i@j%5] =  i*j%5;
#
# 0x123c:	imul eax, dword ptr [rbp - 0x24]
#
#
#
# NONE
#
#
#
# 0x1240:	movsxd rdx, eax                           #         values[i*j@5] =  i*j%5;
#
# 0x1243:	imul rdx, rdx, 0x66666667
# 0x124a:	shr rdx, 0x20
# 0x124e:	sar edx, 1
# 0x1250:	mov esi, eax
# 0x1252:	sar esi, 0x1f
# 0x1255:	sub edx, esi
# 0x1257:	mov esi, edx
# 0x1259:	shl esi, 2
# 0x125c:	add esi, edx
# 0x125e:	sub eax, esi
# 0x1260:	mov edx, eax
#
#
#
# NONE
#
#
#
# 0x1262:	movsxd rax, ecx                           #         values[i*j%5] =  i*j@5;
#
# 0x1265:	imul rax, rax, 0x66666667
# 0x126c:	shr rax, 0x20
# 0x1270:	sar eax, 1
# 0x1272:	mov esi, ecx
# 0x1274:	sar esi, 0x1f
# 0x1277:	sub eax, esi
# 0x1279:	mov esi, eax
# 0x127b:	shl esi, 2
# 0x127e:	add esi, eax
# 0x1280:	mov eax, ecx
# 0x1282:	sub eax, esi
#
#
#
# NONE
#
#
#
# 0x1284:	movsxd rdx, edx                           #         values[i*j%5] @  i*j%5;
#
# 0x1287:	mov dword ptr [rbp + rdx*4 - 0x20], eax
#
#
#  {14: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'j', raw_value=b'j', offset=302)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=304)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=304)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=14, raw_value=14, offset=305)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=306)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 76], raw_value=[145, 76], offset=310)
# }
#
#
# 0x128b:	add dword ptr [rbp - 0x24], 1             #     for(int j = 0; j < 5; @+j) {//loop2
#
#
#
#  {14: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'j', raw_value=b'j', offset=302)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=304)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=304)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=14, raw_value=14, offset=305)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=306)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 76], raw_value=[145, 76], offset=310)
# }
#
#
# 0x128f:	cmp dword ptr [rbp - 0x24], 4             #     for(int j = 0; j @ 5; ++j) {//loop2
#
# 0x1293:	jle 0x1230
#
#
#  {11: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=273)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=275)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=21, raw_value=21, offset=275)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=276)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=277)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 72], raw_value=[145, 72], offset=281)
# }
#
#
# 0x1295:	add dword ptr [rbp - 0x28], 1             #  for(int i = 0; i < 5; @+i) {//loop1
#
#
#
#  {11: DIE DW_TAG_variable, size=12, has_children=False
#     |DW_AT_name        :  AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=273)
#     |DW_AT_decl_file   :  AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=275)
#     |DW_AT_decl_line   :  AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=21, raw_value=21, offset=275)
#     |DW_AT_decl_column :  AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=276)
#     |DW_AT_type        :  AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=277)
#     |DW_AT_location    :  AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 72], raw_value=[145, 72], offset=281)
# }
#
#
# 0x1299:	cmp dword ptr [rbp - 0x28], 4             #  for(int i = 0; i @ 5; ++i) {//loop1
#
# 0x129d:	jle 0x121b
#
#
#
# NONE
#
#
#
# 0x12a3:	mov eax, 0                                #  return @;
#
#
#
#
# NONE
#
#
#
# 0x12a8:	mov rdx, qword ptr [rbp - 8]              #@@
#
# 0x12ac:	sub rdx, qword ptr fs:[0x28]
# 0x12b5:	je 0x12bc
# 0x12b7:	call 0x1070
# 0x12bc:	leave
# 0x12bd:	ret

# %%
# sourceLocation_die
