# %%
#-------------------------------------------------------------------------------
# elftools example: dwarf_lineprogram_filenames.py
#
# In the .debug_line section, the Dwarf line program generates a matrix
# of address-source references. This example demonstrates accessing the state
# of each line program entry to retrieve the underlying filenames.
#
# William Woodruff (william@yossarian.net)
# This code is in the public domain
#-------------------------------------------------------------------------------
from __future__ import print_function
from collections import defaultdict
import os
import sys
import posixpath

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.
# sys.path[0:0] = ['.', '..']

from elftools.elf.elffile import ELFFile


def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        dwarfinfo = elffile.get_dwarf_info()
        for CU in dwarfinfo.iter_CUs():
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # Every compilation unit in the DWARF information may or may not
            # have a corresponding line program in .debug_line.
            line_program = dwarfinfo.line_program_for_CU(CU)
            if line_program is None:
                print('  DWARF info is missing a line program for this CU')
                continue

            # Print a reverse mapping of filename -> #entries
            line_entry_mapping(line_program)
            
            for le in line_program.get_entries():
                print(le)

def line_entry_mapping(line_program):
    filename_map = defaultdict(int)

    # The line program, when decoded, returns a list of line program
    # entries. Each entry contains a state, which we'll use to build
    # a reverse mapping of filename -> #entries.
    lp_entries = line_program.get_entries()
    for lpe in lp_entries:
        # We skip LPEs that don't have an associated file.
        # This can happen if instructions in the compiled binary
        # don't correspond directly to any original source file.
        if not lpe.state or lpe.state.file == 0:
            continue
        filename = lpe_filename(line_program, lpe.state.file)
        filename_map[filename] += 1

    for filename, lpe_count in filename_map.items():
        print("    filename=%s -> %d entries" % (filename, lpe_count))


def lpe_filename(line_program, file_index):
    # Retrieving the filename associated with a line program entry
    # involves two levels of indirection: we take the file index from
    # the LPE to grab the file_entry from the line program header,
    # then take the directory index from the file_entry to grab the
    # directory name from the line program header. Finally, we
    # join the (base) filename from the file_entry to the directory
    # name to get the absolute filename.
    lp_header = line_program.header
    file_entries = lp_header["file_entry"]

    # File and directory indices are 1-indexed.
    file_entry = file_entries[file_index - 1]
    dir_index = file_entry["dir_index"]

    # A dir_index of 0 indicates that no absolute directory was recorded during
    # compilation; return just the basename.
    if dir_index == 0:
        return file_entry.name.decode()

    directory = lp_header["include_directory"][dir_index - 1]
    return posixpath.join(directory, file_entry.name).decode()



filePath = '/home/nahid/reverse/binaries/c_many/stacktest_gcc'
process_file(filePath)
# Out:
# Processing file: /home/nahid/reverse/binaries/c_many/stacktest_gcc
#   Found a compile unit at offset 0, length 901
#     filename=stack.c -> 49 entries
# LineProgramEntry(command=5, is_extended=False, args=[40], state=None)
# LineProgramEntry(command=2, is_extended=True, args=[4521], state=None)
# LineProgramEntry(command=23, is_extended=False, args=[5, 0, 0], state=<LineState 7f5b99642580:
#   address = 0x11a9
#   file = 1
#   line = 6
#   column = 40
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f5b996425b0:
#   address = 0x11bc
#   file = 1
#   line = 7
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[18], state=None)
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f5b99642610:
#   address = 0x11c3
#   file = 1
#   line = 8
#   column = 18
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=120, is_extended=False, args=[4, 7, 0], state=<LineState 7f5b99642640:
#   address = 0x11ca
#   file = 1
#   line = 12
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[11], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f5b996426a0:
#   address = 0x11d5
#   file = 1
#   line = 13
#   column = 11
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=215, is_extended=False, args=[1, 14, 0], state=<LineState 7f5b99642700:
#   address = 0x11e3
#   file = 1
#   line = 14
#   column = 17
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[15], state=None)
# LineProgramEntry(command=145, is_extended=False, args=[1, 9, 0], state=<LineState 7f5b99642760:
#   address = 0x11ec
#   file = 1
#   line = 15
#   column = 15
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=187, is_extended=False, args=[1, 12, 0], state=<LineState 7f5b996427c0:
#   address = 0x11f8
#   file = 1
#   line = 16
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[14], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f5b99642820:
#   address = 0x1200
#   file = 1
#   line = 17
#   column = 14
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f5b99642850:
#   address = 0x120b
#   file = 1
#   line = 18
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[76], state=None)
# LineProgramEntry(command=61, is_extended=False, args=[1, 3, 0], state=<LineState 7f5b99642880:
#   address = 0x120e
#   file = 1
#   line = 19
#   column = 76
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[44], state=None)
# LineProgramEntry(command=18, is_extended=False, args=[0, 0, 0], state=<LineState 7f5b996428b0:
#   address = 0x123a
#   file = 1
#   line = 19
#   column = 76
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=230, is_extended=False, args=[2, 15, 0], state=<LineState 7f5b99642910:
#   address = 0x1249
#   file = 1
#   line = 21
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[15], state=None)
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f5b99642940:
#   address = 0x1250
#   file = 1
#   line = 22
#   column = 15
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[16], state=None)
# LineProgramEntry(command=201, is_extended=False, args=[1, 13, 0], state=<LineState 7f5b996429a0:
#   address = 0x125d
#   file = 1
#   line = 23
#   column = 16
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[15], state=None)
# LineProgramEntry(command=202, is_extended=False, args=[2, 13, 0], state=<LineState 7f5b99642a00:
#   address = 0x126a
#   file = 1
#   line = 25
#   column = 15
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f5b99642a30:
#   address = 0x1275
#   file = 1
#   line = 26
#   column = 17
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f5b99642a60:
#   address = 0x1287
#   file = 1
#   line = 27
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[28], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=132, is_extended=False, args=[2, 8, 0], state=<LineState 7f5b99642af0:
#   address = 0x12a0
#   file = 1
#   line = 29
#   column = 28
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[18], state=None)
# LineProgramEntry(command=118, is_extended=False, args=[2, 7, 0], state=<LineState 7f5b99642b50:
#   address = 0x12a7
#   file = 1
#   line = 31
#   column = 18
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=116, is_extended=False, args=[0, 7, 0], state=<LineState 7f5b99642bb0:
#   address = 0x12ae
#   file = 1
#   line = 31
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[31], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f5b99642be0:
#   address = 0x12b0
#   file = 1
#   line = 32
#   column = 31
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 3>
# )
# LineProgramEntry(command=5, is_extended=False, args=[24], state=None)
# LineProgramEntry(command=116, is_extended=False, args=[0, 7, 0], state=<LineState 7f5b99642c10:
#   address = 0x12b7
#   file = 1
#   line = 32
#   column = 24
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 3>
# )
# LineProgramEntry(command=5, is_extended=False, args=[29], state=None)
# LineProgramEntry(command=143, is_extended=False, args=[-1, 9, 0], state=<LineState 7f5b99642c70:
#   address = 0x12c0
#   file = 1
#   line = 31
#   column = 29
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 3>
# )
# LineProgramEntry(command=5, is_extended=False, args=[24], state=None)
# LineProgramEntry(command=74, is_extended=False, args=[0, 4, 0], state=<LineState 7f5b99642cd0:
#   address = 0x12c4
#   file = 1
#   line = 31
#   column = 24
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 1>
# )
# LineProgramEntry(command=5, is_extended=False, args=[21], state=None)
# LineProgramEntry(command=106, is_extended=False, args=[4, 6, 0], state=<LineState 7f5b99642d30:
#   address = 0x12ca
#   file = 1
#   line = 35
#   column = 21
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[2], state=None)
# LineProgramEntry(command=160, is_extended=False, args=[2, 10, 0], state=<LineState 7f5b99642d90:
#   address = 0x12d4
#   file = 1
#   line = 37
#   column = 2
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[26], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=90, is_extended=False, args=[2, 5, 0], state=<LineState 7f5b99642e20:
#   address = 0x12ea
#   file = 1
#   line = 39
#   column = 26
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=243, is_extended=False, args=[1, 16, 0], state=<LineState 7f5b99642e80:
#   address = 0x12fa
#   file = 1
#   line = 40
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f5b99642eb0:
#   address = 0x1301
#   file = 1
#   line = 41
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=119, is_extended=False, args=[3, 7, 0], state=<LineState 7f5b99642f10:
#   address = 0x1308
#   file = 1
#   line = 44
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f5b99642f40:
#   address = 0x1313
#   file = 1
#   line = 45
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f5b99642f70:
#   address = 0x131b
#   file = 1
#   line = 46
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=145, is_extended=False, args=[1, 9, 0], state=<LineState 7f5b99642fa0:
#   address = 0x1324
#   file = 1
#   line = 47
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=187, is_extended=False, args=[1, 12, 0], state=<LineState 7f5b99642fd0:
#   address = 0x1330
#   file = 1
#   line = 48
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[14], state=None)
# LineProgramEntry(command=187, is_extended=False, args=[1, 12, 0], state=<LineState 7f5b995cd040:
#   address = 0x133c
#   file = 1
#   line = 49
#   column = 14
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=173, is_extended=False, args=[1, 11, 0], state=<LineState 7f5b995cd070:
#   address = 0x1347
#   file = 1
#   line = 50
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=61, is_extended=False, args=[1, 3, 0], state=<LineState 7f5b995cd0a0:
#   address = 0x134a
#   file = 1
#   line = 51
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[31], state=None)
# LineProgramEntry(command=48, is_extended=False, args=[2, 2, 0], state=<LineState 7f5b995cd0d0:
#   address = 0x134c
#   file = 1
#   line = 53
#   column = 31
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=20, is_extended=False, args=[2, 0, 0], state=<LineState 7f5b995cd100:
#   address = 0x135d
#   file = 1
#   line = 55
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f5b995cd130:
#   address = 0x1364
#   file = 1
#   line = 56
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f5b995cd160:
#   address = 0x136b
#   file = 1
#   line = 57
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[14], state=None)
# LineProgramEntry(command=118, is_extended=False, args=[2, 7, 0], state=<LineState 7f5b995cd190:
#   address = 0x1372
#   file = 1
#   line = 59
#   column = 14
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[16], state=None)
# LineProgramEntry(command=130, is_extended=False, args=[0, 8, 0], state=<LineState 7f5b995cd1f0:
#   address = 0x137a
#   file = 1
#   line = 59
#   column = 16
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[18], state=None)
# LineProgramEntry(command=88, is_extended=False, args=[0, 5, 0], state=<LineState 7f5b995cd250:
#   address = 0x137f
#   file = 1
#   line = 59
#   column = 18
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=88, is_extended=False, args=[0, 5, 0], state=<LineState 7f5b995cd280:
#   address = 0x1384
#   file = 1
#   line = 59
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f5b995cd2b0:
#   address = 0x138c
#   file = 1
#   line = 60
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=65, is_extended=False, args=[5, 3, 0], state=<LineState 7f5b995cd310:
#   address = 0x138f
#   file = 1
#   line = 65
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[2], state=None)
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f5b995cd340:
#   address = 0x1391
#   file = 1
#   line = 65
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
#   Found a compile unit at offset 905, length 522
#     filename=main.c -> 21 entries
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=2, is_extended=True, args=[5009], state=None)
# LineProgramEntry(command=24, is_extended=False, args=[6, 0, 0], state=<LineState 7f5b995cd130:
#   address = 0x1391
#   file = 1
#   line = 7
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=186, is_extended=False, args=[0, 12, 0], state=<LineState 7f5b995cd190:
#   address = 0x139d
#   file = 1
#   line = 7
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=229, is_extended=False, args=[1, 15, 0], state=<LineState 7f5b995cd250:
#   address = 0x13ac
#   file = 1
#   line = 8
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=131, is_extended=False, args=[1, 8, 0], state=<LineState 7f5b995cd280:
#   address = 0x13b4
#   file = 1
#   line = 9
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[16], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f5b995cd2b0:
#   address = 0x13c5
#   file = 1
#   line = 10
#   column = 16
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f5b995cd310:
#   address = 0x13d7
#   file = 1
#   line = 11
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=20, is_extended=False, args=[2, 0, 0], state=<LineState 7f5b99628f10:
#   address = 0x13e8
#   file = 1
#   line = 13
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f5b99628fa0:
#   address = 0x13ef
#   file = 1
#   line = 14
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[23], state=None)
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f5b9963bd30:
#   address = 0x13f6
#   file = 1
#   line = 15
#   column = 23
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[10], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=106, is_extended=False, args=[4, 6, 0], state=<LineState 7f5b9963bfd0:
#   address = 0x140d
#   file = 1
#   line = 19
#   column = 10
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[21], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=61, is_extended=False, args=[1, 3, 0], state=<LineState 7f5b9963bf70:
#   address = 0x1421
#   file = 1
#   line = 20
#   column = 21
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=2, is_extended=False, args=[42], state=None)
# LineProgramEntry(command=20, is_extended=False, args=[2, 0, 0], state=<LineState 7f5b996425b0:
#   address = 0x144b
#   file = 1
#   line = 22
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f5b99642610:
#   address = 0x145c
#   file = 1
#   line = 23
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f5b99642640:
#   address = 0x146d
#   file = 1
#   line = 24
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f5b99642700:
#   address = 0x148f
#   file = 1
#   line = 25
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f5b99642760:
#   address = 0x14b1
#   file = 1
#   line = 26
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f5b996427c0:
#   address = 0x14d3
#   file = 1
#   line = 27
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f5b99642820:
#   address = 0x14f5
#   file = 1
#   line = 28
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[12], state=None)
# LineProgramEntry(command=2, is_extended=False, args=[34], state=None)
# LineProgramEntry(command=19, is_extended=False, args=[1, 0, 0], state=<LineState 7f5b99642850:
#   address = 0x1517
#   file = 1
#   line = 29
#   column = 12
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=61, is_extended=False, args=[1, 3, 0], state=<LineState 7f5b99642880:
#   address = 0x151a
#   file = 1
#   line = 30
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[22], state=None)
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f5b996428b0:
#   address = 0x1530
#   file = 1
#   line = 30
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
#   Found a compile unit at offset 1431, length 446
#     filename=calculate.c -> 26 entries
# LineProgramEntry(command=5, is_extended=False, args=[22], state=None)
# LineProgramEntry(command=2, is_extended=True, args=[5424], state=None)
# LineProgramEntry(command=22, is_extended=False, args=[4, 0, 0], state=<LineState 7f5b995cd2b0:
#   address = 0x1530
#   file = 1
#   line = 5
#   column = 22
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=215, is_extended=False, args=[1, 14, 0], state=<LineState 7f5b995cd310:
#   address = 0x153e
#   file = 1
#   line = 6
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f5b99628f10:
#   address = 0x1545
#   file = 1
#   line = 7
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=75, is_extended=False, args=[1, 4, 0], state=<LineState 7f5b9963bd30:
#   address = 0x1549
#   file = 1
#   line = 8
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[11], state=None)
# LineProgramEntry(command=145, is_extended=False, args=[1, 9, 0], state=<LineState 7f5b9963bfd0:
#   address = 0x1552
#   file = 1
#   line = 9
#   column = 11
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[10], state=None)
# LineProgramEntry(command=201, is_extended=False, args=[1, 13, 0], state=<LineState 7f5b9963bf70:
#   address = 0x155f
#   file = 1
#   line = 10
#   column = 10
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[14], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=89, is_extended=False, args=[1, 5, 0], state=<LineState 7f5b99642610:
#   address = 0x1575
#   file = 1
#   line = 11
#   column = 14
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[5], state=None)
# LineProgramEntry(command=116, is_extended=False, args=[0, 7, 0], state=<LineState 7f5b99642640:
#   address = 0x157c
#   file = 1
#   line = 11
#   column = 5
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f5b99642700:
#   address = 0x157e
#   file = 1
#   line = 12
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 3>
# )
# LineProgramEntry(command=117, is_extended=False, args=[1, 7, 0], state=<LineState 7f5b99642760:
#   address = 0x1585
#   file = 1
#   line = 13
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 3>
# )
# LineProgramEntry(command=5, is_extended=False, args=[27], state=None)
# LineProgramEntry(command=72, is_extended=False, args=[-2, 4, 0], state=<LineState 7f5b996427c0:
#   address = 0x1589
#   file = 1
#   line = 11
#   column = 27
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 3>
# )
# LineProgramEntry(command=5, is_extended=False, args=[22], state=None)
# LineProgramEntry(command=74, is_extended=False, args=[0, 4, 0], state=<LineState 7f5b99642820:
#   address = 0x158d
#   file = 1
#   line = 11
#   column = 22
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 1>
# )
# LineProgramEntry(command=5, is_extended=False, args=[9], state=None)
# LineProgramEntry(command=106, is_extended=False, args=[4, 6, 0], state=<LineState 7f5b99642850:
#   address = 0x1593
#   file = 1
#   line = 15
#   column = 9
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=75, is_extended=False, args=[1, 4, 0], state=<LineState 7f5b99642880:
#   address = 0x1597
#   file = 1
#   line = 16
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[15], state=None)
# LineProgramEntry(command=130, is_extended=False, args=[0, 8, 0], state=<LineState 7f5b99679d90:
#   address = 0x159f
#   file = 1
#   line = 16
#   column = 15
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=89, is_extended=False, args=[1, 5, 0], state=<LineState 7f5b995e87c0:
#   address = 0x15a4
#   file = 1
#   line = 17
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[29], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f5b995e8610:
#   address = 0x15a6
#   file = 1
#   line = 18
#   column = 29
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f5b995e82b0:
#   address = 0x15b8
#   file = 1
#   line = 19
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=159, is_extended=False, args=[1, 10, 0], state=<LineState 7f5b995e82e0:
#   address = 0x15c2
#   file = 1
#   line = 20
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[28], state=None)
# LineProgramEntry(command=49, is_extended=False, args=[3, 2, 0], state=<LineState 7f5b995e81c0:
#   address = 0x15c4
#   file = 1
#   line = 23
#   column = 28
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=215, is_extended=False, args=[1, 14, 0], state=<LineState 7f5b995e8310:
#   address = 0x15d2
#   file = 1
#   line = 24
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=103, is_extended=False, args=[1, 6, 0], state=<LineState 7f5b995e8340:
#   address = 0x15d8
#   file = 1
#   line = 25
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[35], state=None)
# LineProgramEntry(command=47, is_extended=False, args=[1, 2, 0], state=<LineState 7f5b995e8880:
#   address = 0x15da
#   file = 1
#   line = 26
#   column = 35
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[13], state=None)
# LineProgramEntry(command=8, is_extended=False, args=[17], state=None)
# LineProgramEntry(command=33, is_extended=False, args=[1, 1, 0], state=<LineState 7f5b995e84c0:
#   address = 0x15ec
#   file = 1
#   line = 27
#   column = 13
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=5, is_extended=False, args=[1], state=None)
# LineProgramEntry(command=159, is_extended=False, args=[1, 10, 0], state=<LineState 7f5b995e85b0:
#   address = 0x15f6
#   file = 1
#   line = 28
#   column = 1
#   is_stmt = 1
#   basic_block = False
#   end_sequence = False
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
# LineProgramEntry(command=2, is_extended=False, args=[2], state=None)
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f5b995e8130:
#   address = 0x15f8
#   file = 1
#   line = 28
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )
