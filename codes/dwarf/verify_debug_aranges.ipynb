# %%
from elftools.elf.elffile import ELFFile
from elftools.dwarf.descriptions import (
    describe_DWARF_expr, set_global_machine_arch)
from elftools.dwarf.locationlists import (
    LocationEntry, LocationExpr, LocationParser)


filePath = './../../binaries/gnuit/src/gitfm'

# filePath = './../../binaries/c_many/stacktest'

# %%
def get_DIE_at_offset(CU, offset):
        for die in CU.iter_DIEs():
            if die.offset == CU.cu_offset+offset:
                return die 
        return None

def get_type_name(CU, offset):#get_DIE_at_offset(CU,attr.value)
    die = get_DIE_at_offset(CU, offset)
    
    if die.tag == 'DW_TAG_pointer_type':
        for _attr in die.attributes.values():
            if _attr.name== "DW_AT_type":
                return "*"+get_type_name(CU,_attr.value) 
        
    
    for attr in die.attributes.values():
        if attr.name== "DW_AT_name":
            return attr.value.decode("utf-8")

# %%
from collections import defaultdict
def line_entry_mapping(line_program):
    filename_map = defaultdict(int)

    # The line program, when decoded, returns a list of line program
    # entries. Each entry contains a state, which we'll use to build
    # a reverse mapping of filename -> #entries.
    lp_entries = line_program.get_entries()
    for lpe in lp_entries:
        # We skip LPEs that don't have an associated file.
        # This can happen if instructions in the compiled binary
        # don't correspond directly to any original source file.
        if not lpe.state or lpe.state.file == 0:
            continue
        filename = lpe_filename(line_program, lpe.state.file)
        filename_map[filename] += 1

    # for filename, lpe_count in filename_map.items():
    #     print("    filename=%s -> %d entries" % (filename, lpe_count))
    return filename_map

def lpe_filename(line_program, file_index):

    lp_header = line_program.header
    file_entries = lp_header["file_entry"]
    

    # File and directory indices are 1-indexed.
    file_entry = file_entries[file_index - 1]
    dir_index = file_entry["dir_index"]

    # A dir_index of 0 indicates that no absolute directory was recorded during
    # compilation; return just the basename.
    if dir_index == 0:
        return file_entry.name.decode()
    
    
    directory = lp_header["include_directory"][dir_index - 1]
    return posixpath.join(directory, file_entry.name).decode()

# %%
def show_loclist(loclist, dwarfinfo, indent, cu_offset):
    """ Display a location list nicely, decoding the DWARF expressions
        contained within.
    """
    d = []
    for loc_entity in loclist:
        if isinstance(loc_entity, LocationEntry):
            d.append('%s <<%s>>' % (
                loc_entity,
                describe_DWARF_expr(loc_entity.loc_expr, dwarfinfo.structs, cu_offset)))
        else:
            d.append(str(loc_entity))
    return '\n'.join(indent + s for s in d)

# %%
# https://github.com/eliben/pyelftools/blob/master/examples/dwarf_location_info.py


from elftools.dwarf.locationlists import LocationParser, LocationExpr
FUNC_PARAMS = {}
def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        # get_dwarf_info returns a DWARFInfo context object, which is the
        # starting point for all DWARF-based processing in pyelftools.
        dwarfinfo = elffile.get_dwarf_info()
        # The location lists are extracted by DWARFInfo from the .debug_loc
        # section, and returned here as a LocationLists object.
        location_lists = dwarfinfo.location_lists()

        # This is required for the descriptions module to correctly decode
        # register names contained in DWARF expressions.
        set_global_machine_arch(elffile.get_machine_arch())

        # Create a LocationParser object that parses the DIE attributes and
        # creates objects representing the actual location information.
        loc_parser = LocationParser(location_lists)
        
        section_offset = dwarfinfo.debug_info_sec.global_offset
        # Offset of the .debug_info section in the stream
        

        cc=0
        for CU in dwarfinfo.iter_CUs():
            if cc>0:
                continue
            cc+=1
            #get source file name
            print(CU)
            line_program = dwarfinfo.line_program_for_CU(CU)
            print('TEST!!!')
            filename_map = line_entry_mapping(line_program)
            CU_src_file =  list(filename_map.items())[0][0]
            
            CU_dictionary_key = CU_src_file 
            
            FUNC_PARAMS[CU_dictionary_key] = {}
            
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # A CU provides a simple API to iterate over all the DIEs in it.
            die_depth = 0
            are_DIEs_of_function = False
            FUNC_name = None
            print('____'*10)
            for DIE in CU.iter_DIEs():
                
                ############################################################
                #############   Prasing Function DIEs start ################
                
                
                if DIE.tag == 'DW_TAG_subprogram':
                    are_DIEs_of_function = True
                    
                    for attr in DIE.attributes.values():
                        if attr.name == "DW_AT_name": #FUNC NAME
                            FUNC_name = attr.value.decode("utf-8")
                            FUNC_PARAMS[CU_dictionary_key][FUNC_name] ={}
                            print("SUBPROGRAM: ",FUNC_name)
                            
                if DIE.tag == 'DW_TAG_formal_parameter' or DIE.tag =='DW_TAG_variable':
                    tags = [attr.name for attr in DIE.attributes.values()]
                    PARAM_name = None
                    if FUNC_name==None:

                        FUNC_name ="global"
                        
                        if FUNC_name not in FUNC_PARAMS[CU_dictionary_key]:
                            FUNC_PARAMS[CU_dictionary_key][FUNC_name]={}
                        
                    if "DW_AT_name" in tags:
                        
                        
                        for attr in DIE.attributes.values():
                            
                            if attr.name == "DW_AT_name": # VAR NAME 
                                PARAM_name = attr.value.decode("utf-8")
                                FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {}

                            if attr.name == "DW_AT_type":
                                var_type = DIE.tag.split('_')[-1]
                                FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name] = {'type':get_type_name(CU,attr.value) , 'kind':var_type}

                            # Check if this attribute contains location information
                            if loc_parser.attribute_has_location(attr, CU['version']):
                                loc = loc_parser.parse_from_attribute(attr,
                                                                      CU['version'])
    
#                                 print(CU_dictionary_key,FUNC_name,PARAM_name)
                                if isinstance(loc, LocationExpr):
#                                     print('      %s' % (
#                                         describe_DWARF_expr(loc.loc_expr,
#                                                             dwarfinfo.structs, CU.cu_offset)))
#                                     print(describe_DWARF_expr(loc.loc_expr, dwarfinfo.structs, CU.cu_offset))
                                    FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name]["location"]= describe_DWARF_expr(loc.loc_expr, dwarfinfo.structs, CU.cu_offset)
                                elif isinstance(loc, list):
#                                     print(show_loclist(loc,
#                                                        dwarfinfo,
#                                                        '      ', CU.cu_offset))
                                    FUNC_PARAMS[CU_dictionary_key][FUNC_name][PARAM_name]["location"]= show_loclist(loc,
                                                       dwarfinfo,'      ', CU.cu_offset)
                        
                        

                ###############################################
                #############  parsing  Function DIEs ends ################
                


                
                if DIE.is_null(): #https://chromium.googlesource.com/chromiumos/third_party/pyelftools/+/25a77f7738d7fe824f2ed4d33a123136b9d8e88a/scripts/readelf.py
                    are_DIEs_of_function = False
                    FUNC_name = None
                    
                    die_depth -= 1
                    continue
                if DIE.has_children:
                    die_depth += 1
                    

process_file(filePath)
# Out:
# Processing file: ./../../binaries/gnuit/src/gitfm
# <elftools.dwarf.compileunit.CompileUnit object at 0x7fd0567c23d0>
# TEST!!!
#   Found a compile unit at offset 0, length 10410
# ________________________________________
# SUBPROGRAM:  write
# SUBPROGRAM:  il_end
# SUBPROGRAM:  panel_end
# SUBPROGRAM:  il_echo
# SUBPROGRAM:  panel_deactivate
# SUBPROGRAM:  panel_activate
# SUBPROGRAM:  panel_set_wrapped_isearch_flag
# SUBPROGRAM:  strdup
# SUBPROGRAM:  toprintable
# SUBPROGRAM:  needs_quotes
# SUBPROGRAM:  il_point
# SUBPROGRAM:  il_history
# SUBPROGRAM:  is_an_empty_command
# SUBPROGRAM:  history_expand
# SUBPROGRAM:  il_free
# SUBPROGRAM:  panel_unselect_all
# SUBPROGRAM:  tilde_expand
# SUBPROGRAM:  tty_touch
# SUBPROGRAM:  display_errors
# SUBPROGRAM:  start
# SUBPROGRAM:  is_a_bg_command
# SUBPROGRAM:  il_message
# SUBPROGRAM:  panel_set_focus
# SUBPROGRAM:  get_local_time
# SUBPROGRAM:  tty_goto
# SUBPROGRAM:  alarm
# SUBPROGRAM:  signal_handlers
# SUBPROGRAM:  tty_get_screen
# SUBPROGRAM:  panel_init
# SUBPROGRAM:  status_init
# SUBPROGRAM:  il_init
# SUBPROGRAM:  title_init
# SUBPROGRAM:  tty_start_cursorapp
# SUBPROGRAM:  xgetcwd
# SUBPROGRAM:  getuid
# SUBPROGRAM:  get_colorset_var
# SUBPROGRAM:  get_string_var
# SUBPROGRAM:  tty_set_last_char_flag
# SUBPROGRAM:  get_flag_var
# SUBPROGRAM:  getpid
# SUBPROGRAM:  rand
# SUBPROGRAM:  srand
# SUBPROGRAM:  time
# SUBPROGRAM:  specific_configuration_init
# SUBPROGRAM:  configuration_end
# SUBPROGRAM:  get_file_type_info
# SUBPROGRAM:  use_section
# SUBPROGRAM:  common_configuration_init
# SUBPROGRAM:  tty_init
# SUBPROGRAM:  getopt
# SUBPROGRAM:  get_login_name
# SUBPROGRAM:  update_path
# SUBPROGRAM:  compute_directories
# SUBPROGRAM:  setlocale
# SUBPROGRAM:  signals_init
# SUBPROGRAM:  printf
# SUBPROGRAM:  truncate_string
# SUBPROGRAM:  tty_key_list_insert
# SUBPROGRAM:  tty_key_human2machine
# SUBPROGRAM:  tolower
# SUBPROGRAM:  xstack_init
# SUBPROGRAM:  xcalloc
# SUBPROGRAM:  tty_get_symbol_key_seq
# SUBPROGRAM:  configuration_getvarinfo
# SUBPROGRAM:  xsetenv
# SUBPROGRAM:  getenv
# SUBPROGRAM:  strcat
# SUBPROGRAM:  panel_get_next
# SUBPROGRAM:  strcpy
# SUBPROGRAM:  panel_init_iterator
# SUBPROGRAM:  strrchr
# SUBPROGRAM:  getgrgid
# SUBPROGRAM:  panel_get_current_file_gid
# SUBPROGRAM:  getpwuid
# SUBPROGRAM:  panel_get_current_file_uid
# SUBPROGRAM:  panel_get_current_file_mode
# SUBPROGRAM:  panel_get_current_file_name
# SUBPROGRAM:  panel_get_current_file_type
# SUBPROGRAM:  exit
# SUBPROGRAM:  fprintf
# SUBPROGRAM:  tty_get_mode
# SUBPROGRAM:  remove_log
# SUBPROGRAM:  status_end
# SUBPROGRAM:  tty_end
# SUBPROGRAM:  panel_action
# SUBPROGRAM:  il_is_empty
# SUBPROGRAM:  il_get_contents
# SUBPROGRAM:  il_set_static_text
# SUBPROGRAM:  il_restore
# SUBPROGRAM:  strchr
# SUBPROGRAM:  tty_get_key
# SUBPROGRAM:  il_set_error_flag
# SUBPROGRAM:  il_insert_text
# SUBPROGRAM:  il_reset_line
# SUBPROGRAM:  il_save
# SUBPROGRAM:  memcpy
# SUBPROGRAM:  il_insert_char
# SUBPROGRAM:  __ctype_b_loc
# SUBPROGRAM:  il_exchange_point_and_mark
# SUBPROGRAM:  il_yank
# SUBPROGRAM:  il_kill_ring_save
# SUBPROGRAM:  il_kill_region
# SUBPROGRAM:  il_set_mark
# SUBPROGRAM:  il_capitalize_word
# SUBPROGRAM:  il_upcase_word
# SUBPROGRAM:  il_downcase_word
# SUBPROGRAM:  il_delete_horizontal_space
# SUBPROGRAM:  il_just_one_space
# SUBPROGRAM:  il_kill_to_end_of_line
# SUBPROGRAM:  il_kill_to_beginning_of_line
# SUBPROGRAM:  il_kill_line
# SUBPROGRAM:  il_backward_kill_word
# SUBPROGRAM:  il_kill_word
# SUBPROGRAM:  il_backward_delete_char
# SUBPROGRAM:  il_delete_char
# SUBPROGRAM:  il_end_of_line
# SUBPROGRAM:  il_beginning_of_line
# SUBPROGRAM:  il_forward_word
# SUBPROGRAM:  il_backward_word
# SUBPROGRAM:  il_forward_char
# SUBPROGRAM:  il_backward_char
# SUBPROGRAM:  xstack_push
# SUBPROGRAM:  xstrdup
# SUBPROGRAM:  strcmp
# SUBPROGRAM:  xstack_preview
# SUBPROGRAM:  status_default
# SUBPROGRAM:  sleep
# SUBPROGRAM:  tty_beep
# SUBPROGRAM:  xfree
# SUBPROGRAM:  status
# SUBPROGRAM:  sprintf
# SUBPROGRAM:  xmalloc
# SUBPROGRAM:  tty_key_machine2human
# SUBPROGRAM:  strlen
# SUBPROGRAM:  tty_get_previous_key_seq
# SUBPROGRAM:  tty_update_title
# SUBPROGRAM:  panel_get_path
# SUBPROGRAM:  tty_update
# SUBPROGRAM:  il_update_point
# SUBPROGRAM:  il_update
# SUBPROGRAM:  status_update
# SUBPROGRAM:  tty_put_screen
# SUBPROGRAM:  panel_update
# SUBPROGRAM:  title_update
# SUBPROGRAM:  tty_clear
# SUBPROGRAM:  panel_center_current_entry
# SUBPROGRAM:  panel_no_optimizations
# SUBPROGRAM:  tty_defaults
# SUBPROGRAM:  tty_set_mode
# SUBPROGRAM:  il_resize
# SUBPROGRAM:  status_resize
# SUBPROGRAM:  title_resize
# SUBPROGRAM:  panel_resize
# SUBPROGRAM:  window_x
# SUBPROGRAM:  panel_window
# SUBPROGRAM:  xrealloc
# SUBPROGRAM:  tty_resize
# SUBPROGRAM:  main
# SUBPROGRAM:  usage
# SUBPROGRAM:  reread
# SUBPROGRAM:  set_prompt
# SUBPROGRAM:  hide
# SUBPROGRAM:  read_keys
# SUBPROGRAM:  add_to_environment
# SUBPROGRAM:  command_expand
# SUBPROGRAM:  fatal
# SUBPROGRAM:  clean_up
# SUBPROGRAM:  dir_history_prev
# SUBPROGRAM:  dir_history_next
# SUBPROGRAM:  dir_history_add
# SUBPROGRAM:  dir_history_reset
# SUBPROGRAM:  il_isearch
# SUBPROGRAM:  il_read_line
# SUBPROGRAM:  il_read_char
# SUBPROGRAM:  il_build_help_from_string
# SUBPROGRAM:  il_fix_text
# SUBPROGRAM:  il_dispatch_commands
# SUBPROGRAM:  il_history_view_entry
# SUBPROGRAM:  il_history_add_entry
# SUBPROGRAM:  report_undefined_key
# SUBPROGRAM:  refresh
# SUBPROGRAM:  resize
# SUBPROGRAM:  in_terminal_mode
# SUBPROGRAM:  panels_can_be_displayed

# %%
# FUNC_PARAMS

# %%
#!/usr/bin/env python3

import sys,os
from elftools.elf.elffile import ELFFile
from elftools.elf.segments import Segment

# %%
fh = open(filePath, 'rb')
bin_bytearray = bytearray(fh.read())

# %%
# https://www.capstone-engine.org/lang_python.html



from capstone import *

from capstone.x86 import *


address_inst = {}
with open(filePath, 'rb') as f:
    elf = ELFFile(f)
    dwarfinfo = elf.get_dwarf_info()
    aranges = dwarfinfo.get_aranges()
    print(len(aranges.entries))
    for arange in aranges.entries:
        print(arange)
    for arange in aranges.entries:

        entry = arange.begin_addr
        exit  = arange.begin_addr + arange.length
        ops = bin_bytearray[entry: exit]

        md = Cs(CS_ARCH_X86, CS_MODE_64)
        md.detail = True
        for inst in md.disasm(ops, entry):

            address_inst[hex(inst.address)] = inst


            print('\n'*3)
            print(inst.address, inst.mnemonic+"  "+inst.op_str)
            (regs_read, regs_write) = inst.regs_access()

#             if len(inst.operands) > 0:
#                 c=-1
#                 for o in inst.operands:
#                     c += 1
#                     if o.type == CS_OP_MEM:
#                         print("\t\toperands[%u].type: MEM" %c)
#                         if o.value.mem.base != 0:
#                             print("\t\t\toperands[%u].mem.base: REG = %s" \
#                                 %(c, inst.reg_name(o.value.mem.base)))
#                         if o.value.mem.index != 0:
#                             print("\t\t\toperands[%u].mem.index: REG = %s" \
#                                 %(c, inst.reg_name(o.value.mem.index)))
#                         if o.value.mem.disp != 0:
#                             print("\t\t\toperands[%u].mem.disp: 0x%x" \
#                                 %(c, o.value.mem.disp))
#                         print(hex(o.value.mem.disp),o.value.mem.disp)
# Out:
# 341
# ARangeEntry(begin_addr=20192, length=5, info_offset=76698, unit_length=60, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=20441, length=72, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=20513, length=25, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=20538, length=813, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=21351, length=315, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=21666, length=298, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=21964, length=147, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=22111, length=94, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=22205, length=729, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=22934, length=339, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=23273, length=288, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=23561, length=754, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=24315, length=876, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=25191, length=690, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=25881, length=127, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=26008, length=130, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=26138, length=121, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=26259, length=112, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=26371, length=41, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=26412, length=89, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=26501, length=2663, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=29164, length=114, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=29278, length=1039, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=30317, length=46, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=30363, length=145, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=30508, length=91, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=30599, length=131, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=30730, length=13707, info_offset=0, unit_length=460, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=44437, length=23, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=44460, length=439, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=44899, length=16, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=44915, length=111, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=45026, length=106, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=45132, length=77, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=45209, length=51, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=45260, length=54, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=45314, length=54, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=45368, length=127, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=45495, length=271, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=45766, length=497, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=46263, length=483, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=46746, length=108, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=46854, length=228, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=47082, length=75, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=47157, length=112, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=47269, length=193, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=47462, length=104, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=47566, length=49, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=47615, length=188, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=47803, length=205, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48008, length=211, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48219, length=255, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48474, length=252, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48726, length=63, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48789, length=35, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48824, length=43, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48867, length=40, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48907, length=43, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48950, length=43, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=48993, length=40, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49033, length=54, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49087, length=36, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49123, length=104, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49227, length=28, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49255, length=28, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49283, length=126, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49409, length=129, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49538, length=161, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49699, length=98, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=49797, length=232, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=50029, length=25, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=50054, length=192, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=50246, length=372, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=50618, length=621, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=51239, length=46, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=51285, length=17, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=51302, length=839, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=52141, length=625, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=52766, length=57, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=52823, length=159, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=52982, length=104, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=53086, length=109, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=53195, length=1936, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=55131, length=282, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=55413, length=302, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=55715, length=205, info_offset=10414, unit_length=956, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=55920, length=65, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=55985, length=38, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56023, length=67, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56090, length=162, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56252, length=98, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56350, length=77, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56427, length=20, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56447, length=21, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56468, length=21, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56489, length=21, info_offset=18213, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56510, length=75, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=56585, length=512, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=57097, length=98, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=57195, length=83, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=57278, length=412, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=57690, length=79, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=57769, length=92, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=57861, length=276, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58137, length=103, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58240, length=38, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58278, length=42, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58320, length=30, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58350, length=33, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58383, length=40, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58423, length=40, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58463, length=60, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58523, length=64, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58587, length=71, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58658, length=71, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58729, length=236, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=58965, length=228, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=59193, length=47, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=59240, length=47, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=59287, length=362, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=59649, length=289, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=59938, length=308, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=60246, length=198, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=60444, length=198, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=60642, length=182, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=60824, length=102, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=60926, length=169, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=61095, length=112, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=61207, length=77, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=61284, length=165, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=61449, length=166, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=61615, length=166, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=61781, length=304, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=62085, length=430, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=62515, length=454, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=62969, length=186, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=63155, length=181, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=63336, length=387, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=63723, length=852, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=64575, length=127, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=64702, length=77, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=64779, length=27, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=64806, length=893, info_offset=19148, unit_length=780, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=65699, length=170, info_offset=22967, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=65869, length=26, info_offset=22967, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=65895, length=109, info_offset=22967, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=66004, length=1280, info_offset=22967, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=67284, length=252, info_offset=22967, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=67536, length=135, info_offset=22967, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=67671, length=44, info_offset=22967, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=67715, length=49, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=67764, length=827, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=68591, length=254, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=68845, length=22, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=68867, length=219, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=69086, length=722, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=69808, length=26, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=69834, length=52, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=69886, length=52, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=69938, length=52, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=69990, length=52, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70042, length=56, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70098, length=107, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70205, length=122, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70327, length=56, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70383, length=43, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70426, length=23, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70449, length=23, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70472, length=280, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70752, length=30, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70782, length=114, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=70896, length=120, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=71016, length=149, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=71165, length=170, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=71335, length=201, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=71536, length=459, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=71995, length=2301, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=74296, length=3817, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=78113, length=40, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=78153, length=218, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=78371, length=351, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=78722, length=307, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=79029, length=81, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=79110, length=608, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=79718, length=500, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=80218, length=1871, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=82089, length=834, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=82923, length=90, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=83013, length=2143, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=85156, length=454, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=85610, length=104, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=85714, length=117, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=85831, length=178, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=86009, length=86, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=86095, length=22, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=86117, length=161, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=86278, length=174, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=86452, length=209, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=86661, length=122, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=86783, length=126, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=86909, length=3053, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=89962, length=2166, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=92128, length=749, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=92877, length=850, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=93727, length=1737, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=95464, length=1322, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=96786, length=117, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=96903, length=176, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=97079, length=772, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=97851, length=1788, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=99639, length=412, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=100051, length=317, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=100368, length=2149, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=102517, length=1395, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=103912, length=1092, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=105004, length=1017, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=106021, length=472, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=106493, length=48, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=106541, length=1601, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=108142, length=480, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=108622, length=76, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=108698, length=6857, info_offset=24795, unit_length=1180, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=115555, length=58, info_offset=40414, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=115613, length=306, info_offset=40414, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=115919, length=26, info_offset=40414, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=115945, length=63, info_offset=40414, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=116008, length=459, info_offset=40414, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=116467, length=769, info_offset=40414, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=117236, length=824, info_offset=40414, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=118060, length=95, info_offset=43797, unit_length=108, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=118155, length=38, info_offset=43797, unit_length=108, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=118193, length=244, info_offset=43797, unit_length=108, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=118437, length=130, info_offset=43797, unit_length=108, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=118567, length=1157, info_offset=43797, unit_length=108, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=119724, length=181, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=119905, length=191, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=120096, length=145, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=120241, length=210, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=120451, length=94, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=120545, length=316, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=120861, length=197, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=121058, length=738, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=121796, length=313, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=122109, length=108, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=122217, length=227, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=122444, length=210, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=122654, length=110, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=122764, length=255, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=123019, length=398, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=123417, length=191, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=123608, length=281, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=123889, length=115, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=124004, length=91, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=124095, length=75, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=124170, length=167, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=124337, length=110, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=124447, length=395, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=124842, length=127, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=124969, length=66, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=125035, length=480, info_offset=45386, unit_length=444, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=125515, length=162, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=125677, length=47, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=125724, length=112, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=125836, length=90, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=125926, length=58, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=125984, length=122, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=126106, length=48, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=126154, length=143, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=126297, length=146, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=126443, length=167, info_offset=49669, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=126610, length=28, info_offset=50775, unit_length=60, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=126638, length=55, info_offset=50775, unit_length=60, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=126693, length=103, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=126796, length=103, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=126899, length=106, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127005, length=117, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127122, length=82, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127204, length=85, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127289, length=85, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127374, length=162, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127536, length=104, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127640, length=116, info_offset=51028, unit_length=188, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127756, length=50, info_offset=52942, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127806, length=67, info_offset=52942, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=127873, length=143, info_offset=52942, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=128016, length=161, info_offset=52942, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=128177, length=119, info_offset=52942, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=128296, length=77, info_offset=52942, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=128373, length=21, info_offset=52942, unit_length=140, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=128394, length=358, info_offset=53656, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=128752, length=215, info_offset=53656, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=128967, length=65, info_offset=53656, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=129032, length=347, info_offset=53656, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=129379, length=273, info_offset=55380, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=129652, length=221, info_offset=55380, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=129873, length=463, info_offset=55380, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=130336, length=884, info_offset=55380, unit_length=92, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=131220, length=85, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=131305, length=68, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=131373, length=23, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=131396, length=113, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=131509, length=498, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=132007, length=174, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=132181, length=16, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=132197, length=504, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=132701, length=48, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=132749, length=48, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=132797, length=156, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=132953, length=266, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=133219, length=45, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=133264, length=233, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=133497, length=45, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=133542, length=676, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=134218, length=519, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=134737, length=463, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135200, length=48, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135248, length=48, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135296, length=70, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135366, length=67, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135433, length=73, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135506, length=17, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135523, length=85, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135608, length=132, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135740, length=63, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=135803, length=915, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=136718, length=302, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=137020, length=343, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=137363, length=390, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=137753, length=2782, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=140535, length=1340, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=141875, length=911, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=142786, length=529, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=143315, length=1175, info_offset=56767, unit_length=604, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=144496, length=144, info_offset=62507, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=144640, length=3554, info_offset=63195, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=148208, length=858, info_offset=67526, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=149072, length=366, info_offset=69466, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=149440, length=1145, info_offset=71310, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=150592, length=917, info_offset=73283, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=151520, length=51, info_offset=76232, unit_length=44, version=2, address_size=8, segment_size=0)
# ARangeEntry(begin_addr=151584, length=4094, info_offset=76698, unit_length=60, version=2, address_size=8, segment_size=0)
#
#
#
#
# 20192 call  0x4810
#
#
#
#
# 20441 endbr64
#
#
#
#
# 20445 push  rbp
#
#
#
#
# 20446 mov  rbp, rsp
#
#
#
#
# 20449 mov  eax, dword ptr [rip + 0x2b9f5]
#
#
#
#
# 20455 cmp  eax, 6
#
#
#
#
# 20458 jle  0x501a
#
#
#
#
# 20460 mov  eax, dword ptr [rip + 0x2a036]
#
#
#
#
# 20466 test  eax, eax
#
#
#
#
# 20468 je  0x5008
#
#
#
#
# 20470 mov  eax, dword ptr [rip + 0x2b9e4]
#
#
#
#
# 20476 cmp  eax, 0xb
#
#
#
#
# 20479 jle  0x501a
#
#
#
#
# 20481 mov  eax, 1
#
#
#
#
# 20486 jmp  0x501f
#
#
#
#
# 20488 mov  eax, dword ptr [rip + 0x2b9d2]
#
#
#
#
# 20494 cmp  eax, 5
#
#
#
#
# 20497 jle  0x501a
#
#
#
#
# 20499 mov  eax, 1
#
#
#
#
# 20504 jmp  0x501f
#
#
#
#
# 20506 mov  eax, 0
#
#
#
#
# 20511 pop  rbp
#
#
#
#
# 20512 ret
#
#
#
#
# 20513 endbr64
#
#
#
#
# 20517 push  rbp
#
#
#
#
# 20518 mov  rbp, rsp
#
#
#
#
# 20521 mov  eax, dword ptr [rip + 0x2b8b1]
#
#
#
#
# 20527 cmp  eax, 1
#
#
#
#
# 20530 sete  al
#
#
#
#
# 20533 movzx  eax, al
#
#
#
#
# 20536 pop  rbp
#
#
#
#
# 20537 ret
#
#
#
#
# 20538 endbr64
#
#
#
#
# 20542 push  rbp
#
#
#
#
# 20543 mov  rbp, rsp
#
#
#
#
# 20546 push  rbx
#
#
#
#
# 20547 sub  rsp, 0x38
#
#
#
#
# 20551 mov  dword ptr [rbp - 0x34], edi
#
#
#
#
# 20554 mov  dword ptr [rbp - 0x28], 0
#
#
#
#
# 20561 mov  dword ptr [rbp - 0x24], 0
#
#
#
#
# 20568 mov  eax, dword ptr [rip + 0x2b97e]
#
#
#
#
# 20574 mov  dword ptr [rbp - 0x20], eax
#
#
#
#
# 20577 mov  eax, dword ptr [rip + 0x2b979]
#
#
#
#
# 20583 mov  dword ptr [rbp - 0x1c], eax
#
#
#
#
# 20586 mov  eax, 0
#
#
#
#
# 20591 call  0xc866
#
#
#
#
# 20596 cmp  dword ptr [rbp - 0x34], 0
#
#
#
#
# 20600 jne  0x5094
#
#
#
#
# 20602 mov  eax, dword ptr [rip + 0x2b95c]
#
#
#
#
# 20608 cmp  dword ptr [rbp - 0x20], eax
#
#
#
#
# 20611 jne  0x5094
#
#
#
#
# 20613 mov  eax, dword ptr [rip + 0x2b955]
#
#
#
#
# 20619 cmp  dword ptr [rbp - 0x1c], eax
#
#
#
#
# 20622 je  0x5360
#
#
#
#
# 20628 mov  eax, dword ptr [rip + 0x2b9a6]
#
#
#
#
# 20634 test  eax, eax
#
#
#
#
# 20636 je  0x50ce
#
#
#
#
# 20638 mov  edx, dword ptr [rip + 0x2b93c]
#
#
#
#
# 20644 mov  eax, dword ptr [rip + 0x2b932]
#
#
#
#
# 20650 imul  eax, edx
#
#
#
#
# 20653 add  eax, 2
#
#
#
#
# 20656 add  eax, eax
#
#
#
#
# 20658 movsxd  rdx, eax
#
#
#
#
# 20661 mov  rax, qword ptr [rip + 0x2b83c]
#
#
#
#
# 20668 mov  rsi, rdx
#
#
#
#
# 20671 mov  rdi, rax
#
#
#
#
# 20674 call  0x24670
#
#
#
#
# 20679 mov  qword ptr [rip + 0x2b82a], rax
#
#
#
#
# 20686 mov  eax, dword ptr [rip + 0x2b908]
#
#
#
#
# 20692 cmp  eax, 1
#
#
#
#
# 20695 jle  0x50e0
#
#
#
#
# 20697 mov  dword ptr [rbp - 0x24], 1
#
#
#
#
# 20704 mov  eax, dword ptr [rip + 0x2b8f6]
#
#
#
#
# 20710 cmp  eax, 2
#
#
#
#
# 20713 jle  0x50f2
#
#
#
#
# 20715 mov  dword ptr [rbp - 0x28], 1
#
#
#
#
# 20722 mov  eax, 0
#
#
#
#
# 20727 call  0x4fd9
#
#
#
#
# 20732 test  eax, eax
#
#
#
#
# 20734 je  0x529e
#
#
#
#
# 20740 mov  eax, dword ptr [rip + 0x29f1e]
#
#
#
#
# 20746 test  eax, eax
#
#
#
#
# 20748 je  0x5234
#
#
#
#
# 20754 mov  eax, dword ptr [rip + 0x2b8c8]
#
#
#
#
# 20760 sar  eax, 1
#
#
#
#
# 20762 mov  dword ptr [rbp - 0x18], eax
#
#
#
#
# 20765 mov  eax, dword ptr [rip + 0x2b8bd]
#
#
#
#
# 20771 and  eax, 1
#
#
#
#
# 20774 mov  edx, eax
#
#
#
#
# 20776 mov  eax, dword ptr [rbp - 0x18]
#
#
#
#
# 20779 add  eax, edx
#
#
#
#
# 20781 mov  dword ptr [rbp - 0x14], eax
#
#
#
#
# 20784 mov  rax, qword ptr [rip + 0x2b7d9]
#
#
#
#
# 20791 mov  rdi, rax
#
#
#
#
# 20794 call  0x10ced
#
#
#
#
# 20799 mov  rdi, rax
#
#
#
#
# 20802 call  0xdc6b
#
#
#
#
# 20807 mov  ebx, eax
#
#
#
#
# 20809 mov  rax, qword ptr [rip + 0x2b7c8]
#
#
#
#
# 20816 mov  rdi, rax
#
#
#
#
# 20819 call  0x10ced
#
#
#
#
# 20824 mov  rdi, rax
#
#
#
#
# 20827 call  0xdc6b
#
#
#
#
# 20832 cmp  ebx, eax
#
#
#
#
# 20834 jg  0x51cc
#
#
#
#
# 20836 mov  eax, dword ptr [rbp - 0x14]
#
#
#
#
# 20839 movsxd  rcx, eax
#
#
#
#
# 20842 mov  eax, dword ptr [rip + 0x2b86c]
#
#
#
#
# 20848 sub  eax, 3
#
#
#
#
# 20851 movsxd  rdx, eax
#
#
#
#
# 20854 mov  rax, qword ptr [rip + 0x2b793]
#
#
#
#
# 20861 mov  r8, rcx
#
#
#
#
# 20864 mov  rcx, rdx
#
#
#
#
# 20867 mov  edx, 1
#
#
#
#
# 20872 mov  esi, 0
#
#
#
#
# 20877 mov  rdi, rax
#
#
#
#
# 20880 call  0x11348
#
#
#
#
# 20885 mov  eax, dword ptr [rbp - 0x18]
#
#
#
#
# 20888 movsxd  rcx, eax
#
#
#
#
# 20891 mov  eax, dword ptr [rip + 0x2b83b]
#
#
#
#
# 20897 sub  eax, 3
#
#
#
#
# 20900 movsxd  rdx, eax
#
#
#
#
# 20903 mov  eax, dword ptr [rbp - 0x14]
#
#
#
#
# 20906 movsxd  rsi, eax
#
#
#
#
# 20909 mov  rax, qword ptr [rip + 0x2b764]
#
#
#
#
# 20916 mov  r8, rcx
#
#
#
#
# 20919 mov  rcx, rdx
#
#
#
#
# 20922 mov  edx, 1
#
#
#
#
# 20927 mov  rdi, rax
#
#
#
#
# 20930 call  0x11348
#
#
#
#
# 20935 jmp  0x52e6
#
#
#
#
# 20940 mov  eax, dword ptr [rbp - 0x18]
#
#
#
#
# 20943 movsxd  rcx, eax
#
#
#
#
# 20946 mov  eax, dword ptr [rip + 0x2b804]
#
#
#
#
# 20952 sub  eax, 3
#
#
#
#
# 20955 movsxd  rdx, eax
#
#
#
#
# 20958 mov  eax, dword ptr [rbp - 0x14]
#
#
#
#
# 20961 movsxd  rsi, eax
#
#
#
#
# 20964 mov  rax, qword ptr [rip + 0x2b725]
#
#
#
#
# 20971 mov  r8, rcx
#
#
#
#
# 20974 mov  rcx, rdx
#
#
#
#
# 20977 mov  edx, 1
#
#
#
#
# 20982 mov  rdi, rax
#
#
#
#
# 20985 call  0x11348
#
#
#
#
# 20990 mov  eax, dword ptr [rbp - 0x14]
#
#
#
#
# 20993 movsxd  rcx, eax
#
#
#
#
# 20996 mov  eax, dword ptr [rip + 0x2b7d2]
#
#
#
#
# 21002 sub  eax, 3
#
#
#
#
# 21005 movsxd  rdx, eax
#
#
#
#
# 21008 mov  rax, qword ptr [rip + 0x2b701]
#
#
#
#
# 21015 mov  r8, rcx
#
#
#
#
# 21018 mov  rcx, rdx
#
#
#
#
# 21021 mov  edx, 1
#
#
#
#
# 21026 mov  esi, 0
#
#
#
#
# 21031 mov  rdi, rax
#
#
#
#
# 21034 call  0x11348
#
#
#
#
# 21039 jmp  0x52e6
#
#
#
#
# 21044 mov  eax, dword ptr [rip + 0x2b7a6]
#
#
#
#
# 21050 movsxd  rcx, eax
#
#
#
#
# 21053 mov  eax, dword ptr [rip + 0x2b799]
#
#
#
#
# 21059 sub  eax, 3
#
#
#
#
# 21062 movsxd  rdx, eax
#
#
#
#
# 21065 mov  rax, qword ptr [rip + 0x2b6c0]
#
#
#
#
# 21072 mov  r8, rcx
#
#
#
#
# 21075 mov  rcx, rdx
#
#
#
#
# 21078 mov  edx, 1
#
#
#
#
# 21083 mov  esi, 0
#
#
#
#
# 21088 mov  rdi, rax
#
#
#
#
# 21091 call  0x11348
#
#
#
#
# 21096 mov  eax, dword ptr [rip + 0x2b772]
#
#
#
#
# 21102 movsxd  rcx, eax
#
#
#
#
# 21105 mov  eax, dword ptr [rip + 0x2b765]
#
#
#
#
# 21111 sub  eax, 3
#
#
#
#
# 21114 movsxd  rdx, eax
#
#
#
#
# 21117 mov  rax, qword ptr [rip + 0x2b694]
#
#
#
#
# 21124 mov  r8, rcx
#
#
#
#
# 21127 mov  rcx, rdx
#
#
#
#
# 21130 mov  edx, 1
#
#
#
#
# 21135 mov  esi, 0
#
#
#
#
# 21140 mov  rdi, rax
#
#
#
#
# 21143 call  0x11348
#
#
#
#
# 21148 jmp  0x52e6
#
#
#
#
# 21150 mov  rax, qword ptr [rip + 0x2b66b]
#
#
#
#
# 21157 mov  r8d, 0x50
#
#
#
#
# 21163 mov  ecx, 2
#
#
#
#
# 21168 mov  edx, 0x10000
#
#
#
#
# 21173 mov  esi, 0x10000
#
#
#
#
# 21178 mov  rdi, rax
#
#
#
#
# 21181 call  0x11348
#
#
#
#
# 21186 mov  rax, qword ptr [rip + 0x2b64f]
#
#
#
#
# 21193 mov  r8d, 0x50
#
#
#
#
# 21199 mov  ecx, 2
#
#
#
#
# 21204 mov  edx, 0x10000
#
#
#
#
# 21209 mov  esi, 0x10000
#
#
#
#
# 21214 mov  rdi, rax
#
#
#
#
# 21217 call  0x11348
#
#
#
#
# 21222 cmp  dword ptr [rbp - 0x28], 0
#
#
#
#
# 21226 je  0x52f6
#
#
#
#
# 21228 mov  eax, dword ptr [rip + 0x2b6ee]
#
#
#
#
# 21234 cdqe
#
#
#
#
# 21236 jmp  0x52fb
#
#
#
#
# 21238 mov  eax, 0
#
#
#
#
# 21243 mov  esi, 0
#
#
#
#
# 21248 mov  rdi, rax
#
#
#
#
# 21251 call  0x1c4e9
#
#
#
#
# 21256 mov  eax, dword ptr [rip + 0x2b6ce]
#
#
#
#
# 21262 sub  eax, 1
#
#
#
#
# 21265 movsxd  rdx, eax
#
#
#
#
# 21268 cmp  dword ptr [rbp - 0x24], 0
#
#
#
#
# 21272 je  0x5324
#
#
#
#
# 21274 mov  eax, dword ptr [rip + 0x2b6c0]
#
#
#
#
# 21280 cdqe
#
#
#
#
# 21282 jmp  0x5329
#
#
#
#
# 21284 mov  eax, 0
#
#
#
#
# 21289 mov  rsi, rdx
#
#
#
#
# 21292 mov  rdi, rax
#
#
#
#
# 21295 call  0x10167
#
#
#
#
# 21300 mov  eax, dword ptr [rip + 0x2b6a2]
#
#
#
#
# 21306 cmp  eax, 1
#
#
#
#
# 21309 je  0x534a
#
#
#
#
# 21311 mov  eax, dword ptr [rip + 0x2b697]
#
#
#
#
# 21317 lea  edx, [rax - 2]
#
#
#
#
# 21320 jmp  0x534f
#
#
#
#
# 21322 mov  edx, 0
#
#
#
#
# 21327 mov  eax, dword ptr [rip + 0x2b68b]
#
#
#
#
# 21333 mov  esi, edx
#
#
#
#
# 21335 mov  edi, eax
#
#
#
#
# 21337 call  0xe1a9
#
#
#
#
# 21342 jmp  0x5361
#
#
#
#
# 21344 nop
#
#
#
#
# 21345 mov  rbx, qword ptr [rbp - 8]
#
#
#
#
# ...
#
#
#
#
# 153556 cmp  rax, r10
#
#
#
#
# 153559 jae  0x257e2
#
#
#
#
# 153561 mov  rsi, qword ptr [rsp + 8]
#
#
#
#
# 153566 mov  byte ptr [rsi + rax], 0
#
#
#
#
# 153570 mov  rdx, qword ptr [rsp + 0x78]
#
#
#
#
# 153575 sub  rdx, qword ptr fs:[0x28]
#
#
#
#
# 153584 jne  0x259aa
#
#
#
#
# 153590 add  rsp, 0x88
#
#
#
#
# 153597 pop  rbx
#
#
#
#
# 153598 pop  rbp
#
#
#
#
# 153599 pop  r12
#
#
#
#
# 153601 pop  r13
#
#
#
#
# 153603 pop  r14
#
#
#
#
# 153605 pop  r15
#
#
#
#
# 153607 ret
#
#
#
#
# 153608 mov  eax, r8d
#
#
#
#
# 153611 xor  ecx, ecx
#
#
#
#
# 153613 jmp  0x25279
#
#
#
#
# 153618 mov  eax, dword ptr [rsp + 0x10]
#
#
#
#
# 153622 jbe  0x2586a
#
#
#
#
# 153624 sub  eax, 5
#
#
#
#
# 153627 cmp  eax, 1
#
#
#
#
# 153630 ja  0x258a8
#
#
#
#
# 153636 cmp  dword ptr [rsp + 0x10], 6
#
#
#
#
# 153641 mov  edx, 0x60
#
#
#
#
# 153646 mov  eax, 0x22
#
#
#
#
# 153651 cmovne  eax, edx
#
#
#
#
# 153654 lea  rcx, [rip + 0x4071]
#
#
#
#
# 153661 lea  rdx, [rip + 0x4068]
#
#
#
#
# 153668 cmove  rdx, rcx
#
#
#
#
# 153672 mov  qword ptr [rsp + 0x20], rdx
#
#
#
#
# 153677 test  r10, r10
#
#
#
#
# 153680 je  0x25859
#
#
#
#
# 153682 mov  rsi, qword ptr [rsp + 8]
#
#
#
#
# 153687 mov  byte ptr [rsi], al
#
#
#
#
# 153689 mov  r8d, 1
#
#
#
#
# 153695 mov  r9d, 1
#
#
#
#
# 153701 jmp  0x25090
#
#
#
#
# 153706 cmp  eax, 2
#
#
#
#
# 153709 je  0x2537e
#
#
#
#
# 153715 cmp  eax, 3
#
#
#
#
# 153718 jne  0x258a8
#
#
#
#
# 153720 test  r10, r10
#
#
#
#
# 153723 je  0x258bc
#
#
#
#
# 153725 mov  rax, qword ptr [rsp + 8]
#
#
#
#
# 153730 mov  r8d, 1
#
#
#
#
# 153736 mov  r9d, 1
#
#
#
#
# 153742 mov  byte ptr [rax], 0x22
#
#
#
#
# 153745 lea  rax, [rip + 0x4016]
#
#
#
#
# 153752 mov  qword ptr [rsp + 0x20], rax
#
#
#
#
# 153757 jmp  0x25090
#
#
#
#
# 153762 nop  word ptr [rax + rax]
#
#
#
#
# 153768 mov  qword ptr [rsp + 0x20], 0
#
#
#
#
# 153777 xor  r8d, r8d
#
#
#
#
# 153780 xor  r9d, r9d
#
#
#
#
# 153783 jmp  0x25090
#
#
#
#
# 153788 lea  rax, [rip + 0x3feb]
#
#
#
#
# 153795 mov  r8d, 1
#
#
#
#
# 153801 mov  r9d, 1
#
#
#
#
# 153807 mov  qword ptr [rsp + 0x20], rax
#
#
#
#
# 153812 jmp  0x25090
#
#
#
#
# 153817 cmp  r10, rbx
#
#
#
#
# 153820 jbe  0x258e7
#
#
#
#
# 153822 mov  rax, qword ptr [rsp + 8]
#
#
#
#
# 153827 mov  byte ptr [rax + rbx], 0x3f
#
#
#
#
# 153831 lea  rax, [rbx + 1]
#
#
#
#
# 153835 cmp  r10, rax
#
#
#
#
# 153838 jbe  0x258fa
#
#
#
#
# 153840 mov  rax, qword ptr [rsp + 8]
#
#
#
#
# 153845 mov  byte ptr [rax + rbx + 1], 0x5c
#
#
#
#
# 153850 lea  rax, [rbx + 2]
#
#
#
#
# 153854 cmp  r10, rax
#
#
#
#
# 153857 jbe  0x2590d
#
#
#
#
# 153859 mov  rax, qword ptr [rsp + 8]
#
#
#
#
# 153864 mov  byte ptr [rax + rbx + 2], 0x3f
#
#
#
#
# 153869 add  rbx, 3
#
#
#
#
# 153873 lea  r15, [r12 + 3]
#
#
#
#
# 153878 jmp  0x25184
#
#
#
#
# 153883 xor  ecx, ecx
#
#
#
#
# 153885 cmp  r13, r12
#
#
#
#
# 153888 ja  0x25931
#
#
#
#
# 153890 jmp  0x259a2
#
#
#
#
# 153892 nop  dword ptr [rax]
#
#
#
#
# 153896 add  rcx, 1
#
#
#
#
# 153900 cmp  rdx, rcx
#
#
#
#
# 153903 je  0x25937
#
#
#
#
# 153905 cmp  byte ptr [rsi + rcx], 0
#
#
#
#
# 153909 jne  0x25928
#
#
#
#
# 153911 mov  eax, r8d
#
#
#
#
# 153914 jmp  0x25610
#
#
#
#
# 153919 cmp  rax, 1
#
#
#
#
# 153923 je  0x255cc
#
#
#
#
# 153929 lea  rdx, [r11 + r14]
#
#
#
#
# 153933 add  rsi, rax
#
#
#
#
# 153936 jmp  0x25965
#
#
#
#
# 153938 nop  word ptr [rax + rax]
#
#
#
#
# 153944 add  rdx, 1
#
#
#
#
# 153948 cmp  rsi, rdx
#
#
#
#
# 153951 je  0x255cc
#
#
#
#
# 153957 movzx  eax, byte ptr [rdx]
#
#
#
#
# 153960 sub  eax, 0x5b
#
#
#
#
# 153963 cmp  al, 0x21
#
#
#
#
# 153965 ja  0x25958
#
#
#
#
# 153967 movabs  rdi, 0x20000002b
#
#
#
#
# 153977 bt  rdi, rax
#
#
#
#
# 153981 jae  0x25958
#
#
#
#
# 153983 mov  qword ptr [rsp + 0x20], r10
#
#
#
#
# 153988 mov  qword ptr [rsp + 0x10], r11
#
#
#
#
# 153993 call  0x4950
#
#
#
#
# 153998 mov  r11, qword ptr [rsp + 0x10]
#
#
#
#
# 154003 mov  r10, qword ptr [rsp + 0x20]
#
#
#
#
# 154008 mov  qword ptr [rsp + 0x28], rax
#
#
#
#
# 154013 jmp  0x2537e
#
#
#
#
# 154018 mov  eax, r8d
#
#
#
#
# 154021 jmp  0x25279
#
#
#
#
# 154026 call  0x4980
#
#
#
#
# 154031 mov  r12, r15
#
#
#
#
# 154034 jmp  0x251c1
#
#
#
#
# 154039 nop  word ptr [rax + rax]
#
#
#
#
# 154048 push  r15
#
#
#
#
# 154050 mov  r15d, edi
#
#
#
#
# 154053 push  r14
#
#
#
#
# 154055 push  r13
#
#
#
#
# 154057 mov  r13, rdx
#
#
#
#
# 154060 push  r12
#
#
#
#
# 154062 mov  r12, rsi
#
#
#
#
# 154065 push  rbp
#
#
#
#
# 154066 mov  rbp, rcx
#
#
#
#
# 154069 push  rbx
#
#
#
#
# 154070 sub  rsp, 0x28
#
#
#
#
# 154074 call  0x4820
#
#
#
#
# 154079 mov  r14, qword ptr [rip + 0xae7a]
#
#
#
#
# 154086 mov  rbx, rax
#
#
#
#
# 154089 mov  eax, dword ptr [rax]
#
#
#
#
# 154091 mov  dword ptr [rsp + 0xc], eax
#
#
#
#
# 154095 test  r15d, r15d
#
#
#
#
# 154098 js  0x4ee0
#
#
#
#
# 154104 cmp  dword ptr [rip + 0xae5d], r15d
#
#
#
#
# 154111 mov  r10d, dword ptr [rsp + 0xc]
#
#
#
#
# 154116 ja  0x25a69
#
#
#
#
# 154118 lea  edx, [r15 + 1]
#
#
#
#
# 154122 lea  rax, [rip + 0xae5f]
#
#
#
#
# 154129 mov  rsi, rdx
#
#
#
#
# 154132 mov  dword ptr [rsp + 0x10], edx
#
#
#
#
# 154136 shl  rsi, 4
#
#
#
#
# 154140 cmp  r14, rax
#
#
#
#
# 154143 je  0x25b20
#
#
#
#
# 154149 mov  rdi, r14
#
#
#
#
# 154152 mov  qword ptr [rsp + 0x18], rdx
#
#
#
#
# 154157 call  0x24670
#
#
#
#
# 154162 mov  rdx, qword ptr [rsp + 0x18]
#
#
#
#
# 154167 mov  qword ptr [rip + 0xae22], rax
#
#
#
#
# 154174 mov  r14, rax
#
#
#
#
# 154177 mov  edi, dword ptr [rip + 0xae15]
#
#
#
#
# 154183 xor  esi, esi
#
#
#
#
# 154185 sub  rdx, rdi
#
#
#
#
# 154188 shl  rdi, 4
#
#
#
#
# 154192 shl  rdx, 4
#
#
#
#
# 154196 add  rdi, r14
#
#
#
#
# 154199 call  0x4a10
#
#
#
#
# 154204 mov  eax, dword ptr [rsp + 0x10]
#
#
#
#
# 154208 mov  r10d, dword ptr [rbx]
#
#
#
#
# 154211 mov  dword ptr [rip + 0xadf3], eax
#
#
#
#
# 154217 movsxd  r8, r15d
#
#
#
#
# 154220 mov  r9, rbp
#
#
#
#
# 154223 mov  rcx, r13
#
#
#
#
# 154226 mov  rdx, r12
#
#
#
#
# 154229 shl  r8, 4
#
#
#
#
# 154233 mov  dword ptr [rsp + 0x18], r10d
#
#
#
#
# 154238 lea  r15, [r14 + r8]
#
#
#
#
# 154242 mov  r8d, dword ptr [rbp]
#
#
#
#
# 154246 mov  r14, qword ptr [r15 + 8]
#
#
#
#
# 154250 mov  rsi, qword ptr [r15]
#
#
#
#
# 154253 mov  rdi, r14
#
#
#
#
# 154256 mov  qword ptr [rsp + 0x10], rsi
#
#
#
#
# 154261 call  0x25020
#
#
#
#
# 154266 mov  r10d, dword ptr [rsp + 0x18]
#
#
#
#
# 154271 mov  rsi, qword ptr [rsp + 0x10]
#
#
#
#
# 154276 mov  dword ptr [rbx], r10d
#
#
#
#
# 154279 cmp  rax, rsi
#
#
#
#
# 154282 jb  0x25aff
#
#
#
#
# 154284 lea  rsi, [rax + 1]
#
#
#
#
# 154288 lea  rax, [rip + 0xc0a9]
#
#
#
#
# 154295 mov  qword ptr [r15], rsi
#
#
#
#
# 154298 cmp  r14, rax
#
#
#
#
# 154301 je  0x25ad1
#
#
#
#
# 154303 mov  rdi, r14
#
#
#
#
# 154306 mov  qword ptr [rsp + 0x10], rsi
#
#
#
#
# 154311 call  0x47c0
#
#
#
#
# 154316 mov  rsi, qword ptr [rsp + 0x10]
#
#
#
#
# 154321 mov  rdi, rsi
#
#
#
#
# 154324 mov  qword ptr [rsp + 0x10], rsi
#
#
#
#
# 154329 call  0x24650
#
#
#
#
# 154334 mov  r8d, dword ptr [rbp]
#
#
#
#
# 154338 mov  r9, rbp
#
#
#
#
# 154341 mov  rcx, r13
#
#
#
#
# 154344 mov  qword ptr [r15 + 8], rax
#
#
#
#
# 154348 mov  rsi, qword ptr [rsp + 0x10]
#
#
#
#
# 154353 mov  rdx, r12
#
#
#
#
# 154356 mov  rdi, rax
#
#
#
#
# 154359 mov  r14, rax
#
#
#
#
# 154362 call  0x25020
#
#
#
#
# 154367 mov  eax, dword ptr [rsp + 0xc]
#
#
#
#
# 154371 mov  dword ptr [rbx], eax
#
#
#
#
# 154373 add  rsp, 0x28
#
#
#
#
# 154377 mov  rax, r14
#
#
#
#
# 154380 pop  rbx
#
#
#
#
# 154381 pop  rbp
#
#
#
#
# 154382 pop  r12
#
#
#
#
# 154384 pop  r13
#
#
#
#
# 154386 pop  r14
#
#
#
#
# 154388 pop  r15
#
#
#
#
# 154390 ret
#
#
#
#
# 154391 nop  word ptr [rax + rax]
#
#
#
#
# 154400 xor  edi, edi
#
#
#
#
# 154402 mov  qword ptr [rsp + 0x18], rdx
#
#
#
#
# 154407 call  0x24670
#
#
#
#
# 154412 movdqa  xmm0, xmmword ptr [rip + 0xad3c]
#
#
#
#
# 154420 mov  rdx, qword ptr [rsp + 0x18]
#
#
#
#
# 154425 mov  qword ptr [rip + 0xad20], rax
#
#
#
#
# 154432 mov  r14, rax
#
#
#
#
# 154435 movups  xmmword ptr [rax], xmm0
#
#
#
#
# 154438 jmp  0x25a41
#
#
#
#
# 154443 nop  dword ptr [rax + rax]
#
#
#
#
# 154448 endbr64
#
#
#
#
# 154452 push  r12
#
#
#
#
# 154454 push  rbp
#
#
#
#
# 154455 mov  rbp, rdi
#
#
#
#
# 154458 push  rbx
#
#
#
#
# 154459 call  0x4820
#
#
#
#
# 154464 test  rbp, rbp
#
#
#
#
# 154467 mov  esi, 0x24
#
#
#
#
# 154472 mov  r12d, dword ptr [rax]
#
#
#
#
# 154475 mov  rbx, rax
#
#
#
#
# 154478 lea  rax, [rip + 0xc0eb]
#
#
#
#
# 154485 cmove  rbp, rax
#
#
#
#
# 154489 mov  rdi, rbp
#
#
#
#
# 154492 call  0x24740
#
#
#
#
# 154497 mov  dword ptr [rbx], r12d
#
#
#
#
# 154500 pop  rbx
#
#
#
#
# 154501 pop  rbp
#
#
#
#
# 154502 pop  r12
#
#
#
#
# 154504 ret
#
#
#
#
# 154505 nop  dword ptr [rax]
#
#
#
#
# 154512 endbr64
#
#
#
#
# 154516 test  rdi, rdi
#
#
#
#
# 154519 lea  rax, [rip + 0xc0c2]
#
#
#
#
# 154526 cmove  rdi, rax
#
#
#
#
# 154530 mov  eax, dword ptr [rdi]
#
#
#
#
# 154532 ret
#
#
#
#
# 154533 nop  word ptr cs:[rax + rax]
#
#
#
#
# 154544 endbr64
#
#
#
#
# 154548 test  rdi, rdi
#
#
#
#
# 154551 lea  rax, [rip + 0xc0a2]
#
#
#
#
# 154558 cmove  rdi, rax
#
#
#
#
# 154562 mov  dword ptr [rdi], esi
#
#
#
#
# 154564 ret
#
#
#
#
# 154565 nop  word ptr cs:[rax + rax]
#
#
#
#
# 154576 endbr64
#
#
#
#
# 154580 test  rdi, rdi
#
#
#
#
# 154583 lea  rax, [rip + 0xc082]
#
#
#
#
# 154590 mov  ecx, esi
#
#
#
#
# 154592 cmove  rdi, rax
#
#
#
#
# 154596 mov  eax, esi
#
#
#
#
# 154598 and  ecx, 0x1f
#
#
#
#
# 154601 shr  al, 5
#
#
#
#
# 154604 movzx  eax, al
#
#
#
#
# 154607 lea  rsi, [rdi + rax*4 + 4]
#
#
#
#
# 154612 mov  edi, dword ptr [rsi]
#
#
#
#
# 154614 mov  eax, edi
#
#
#
#
# 154616 shr  eax, cl
#
#
#
#
# 154618 xor  edx, eax
#
#
#
#
# 154620 and  eax, 1
#
#
#
#
# 154623 and  edx, 1
#
#
#
#
# 154626 shl  edx, cl
#
#
#
#
# 154628 xor  edx, edi
#
#
#
#
# 154630 mov  dword ptr [rsi], edx
#
#
#
#
# 154632 ret
#
#
#
#
# 154633 nop  dword ptr [rax]
#
#
#
#
# 154640 endbr64
#
#
#
#
# 154644 push  r15
#
#
#
#
# 154646 lea  rax, [rip + 0xc043]
#
#
#
#
# 154653 push  r14
#
#
#
#
# 154655 mov  r14, rdx
#
#
#
#
# 154658 push  r13
#
#
#
#
# 154660 mov  r13, rsi
#
#
#
#
# 154663 push  r12
#
#
#
#
# 154665 mov  r12, rdi
#
#
#
#
# 154668 push  rbp
#
#
#
#
# 154669 push  rbx
#
#
#
#
# 154670 mov  rbx, r8
#
#
#
#
# 154673 sub  rsp, 0x18
#
#
#
#
# 154677 test  r8, r8
#
#
#
#
# 154680 cmove  rbx, rax
#
#
#
#
# 154684 mov  qword ptr [rsp + 8], rcx
#
#
#
#
# 154689 call  0x4820
#
#
#
#
# 154694 mov  rcx, qword ptr [rsp + 8]
#
#
#
#
# 154699 mov  rdx, r14
#
#
#
#
# 154702 mov  rsi, r13
#
#
#
#
# 154705 mov  r15d, dword ptr [rax]
#
#
#
#
# 154708 mov  r8d, dword ptr [rbx]
#
#
#
#
# 154711 mov  rbp, rax
#
#
#
#
# 154714 mov  r9, rbx
#
#
#
#
# 154717 mov  rdi, r12
#
#
#
#
# 154720 call  0x25020
#
#
#
#
# 154725 mov  dword ptr [rbp], r15d
#
#
#
#
# 154729 add  rsp, 0x18
#
#
#
#
# 154733 pop  rbx
#
#
#
#
# 154734 pop  rbp
#
#
#
#
# 154735 pop  r12
#
#
#
#
# 154737 pop  r13
#
#
#
#
# 154739 pop  r14
#
#
#
#
# 154741 pop  r15
#
#
#
#
# 154743 ret
#
#
#
#
# 154744 nop  dword ptr [rax + rax]
#
#
#
#
# 154752 endbr64
#
#
#
#
# 154756 push  r15
# 154758 mov  r15, rdi
#
#
#
#
# 154761 push  r14
#
#
#
#
# 154763 mov  r14, rsi
#
#
#
#
# 154766 push  r13
#
#
#
#
# 154768 push  r12
#
#
#
#
# 154770 push  rbp
#
#
#
#
# 154771 push  rbx
#
#
#
#
# 154772 mov  rbx, rdx
#
#
#
#
# 154775 sub  rsp, 0x18
#
#
#
#
# 154779 call  0x4820
#
#
#
#
# 154784 test  rbx, rbx
#
#
#
#
# 154787 mov  rcx, r14
#
#
#
#
# 154790 mov  rdx, r15
#
#
#
#
# 154793 mov  r12d, dword ptr [rax]
#
#
#
#
# 154796 mov  rbp, rax
#
#
#
#
# 154799 lea  rax, [rip + 0xbfaa]
#
#
#
#
# 154806 cmove  rbx, rax
#
#
#
#
# 154810 xor  esi, esi
#
#
#
#
# 154812 xor  edi, edi
#
#
#
#
# 154814 mov  r8d, dword ptr [rbx]
#
#
#
#
# 154817 mov  r9, rbx
#
#
#
#
# 154820 call  0x25020
#
#
#
#
# 154825 mov  dword ptr [rbp], r12d
#
#
#
#
# 154829 lea  r13, [rax + 1]
#
#
#
#
# 154833 mov  dword ptr [rsp + 0xc], r12d
#
#
#
#
# 154838 mov  rdi, r13
#
#
#
#
# 154841 call  0x24650
#
#
#
#
# 154846 mov  r8d, dword ptr [rbx]
#
#
#
#
# 154849 mov  r9, rbx
#
#
#
#
# 154852 mov  rcx, r14
#
#
#
#
# 154855 mov  rdx, r15
#
#
#
#
# 154858 mov  rsi, r13
#
#
#
#
# 154861 mov  rdi, rax
#
#
#
#
# 154864 mov  r12, rax
#
#
#
#
# 154867 call  0x25020
#
#
#
#
# 154872 mov  eax, dword ptr [rsp + 0xc]
#
#
#
#
# 154876 mov  dword ptr [rbp], eax
#
#
#
#
# 154879 add  rsp, 0x18
#
#
#
#
# 154883 mov  rax, r12
#
#
#
#
# 154886 pop  rbx
#
#
#
#
# 154887 pop  rbp
#
#
#
#
# 154888 pop  r12
#
#
#
#
# 154890 pop  r13
#
#
#
#
# 154892 pop  r14
#
#
#
#
# 154894 pop  r15
#
#
#
#
# 154896 ret
#
#
#
#
# 154897 nop  word ptr cs:[rax + rax]
#
#
#
#
# 154908 nop  dword ptr [rax]
#
#
#
#
# 154912 endbr64
#
#
#
#
# 154916 mov  eax, dword ptr [rip + 0xab32]
#
#
#
#
# 154922 push  r12
#
#
#
#
# 154924 mov  r12, qword ptr [rip + 0xab2d]
#
#
#
#
# 154931 push  rbp
#
#
#
#
# 154932 push  rbx
#
#
#
#
# 154933 cmp  eax, 1
#
#
#
#
# 154936 jbe  0x25d61
#
#
#
#
# 154938 sub  eax, 2
#
#
#
#
# 154941 lea  rbx, [r12 + 0x18]
#
#
#
#
# 154946 shl  rax, 4
#
#
#
#
# 154950 lea  rbp, [r12 + rax + 0x28]
#
#
#
#
# 154955 nop  dword ptr [rax + rax]
#
#
#
#
# 154960 mov  rdi, qword ptr [rbx]
#
#
#
#
# 154963 add  rbx, 0x10
#
#
#
#
# 154967 call  0x47c0
#
#
#
#
# 154972 cmp  rbx, rbp
#
#
#
#
# 154975 jne  0x25d50
#
#
#
#
# 154977 mov  rdi, qword ptr [r12 + 8]
#
#
#
#
# 154982 lea  rbx, [rip + 0xbdf3]
#
#
#
#
# 154989 cmp  rdi, rbx
#
#
#
#
# 154992 je  0x25d89
#
#
#
#
# 154994 call  0x47c0
#
#
#
#
# 154999 mov  qword ptr [rip + 0xaafa], rbx
#
#
#
#
# 155006 mov  qword ptr [rip + 0xaae7], 0x100
#
#
#
#
# 155017 lea  rbx, [rip + 0xaae0]
#
#
#
#
# 155024 cmp  r12, rbx
#
#
#
#
# 155027 je  0x25da4
#
#
#
#
# 155029 mov  rdi, r12
#
#
#
#
# 155032 call  0x47c0
#
#
#
#
# 155037 mov  qword ptr [rip + 0xaabc], rbx
#
#
#
#
# 155044 mov  dword ptr [rip + 0xaaae], 1
#
#
#
#
# 155054 pop  rbx
#
#
#
#
# 155055 pop  rbp
#
#
#
#
# 155056 pop  r12
#
#
#
#
# 155058 ret
#
#
#
#
# 155059 nop  word ptr cs:[rax + rax]
#
#
#
#
# 155070 nop
#
#
#
#
# 155072 endbr64
#
#
#
#
# 155076 lea  rcx, [rip + 0xbe95]
#
#
#
#
# 155083 mov  rdx, -1
#
#
#
#
# 155090 jmp  0x259c0
#
#
#
#
# 155095 nop  word ptr [rax + rax]
#
#
#
#
# 155104 endbr64
#
#
#
#
# 155108 mov  rsi, rdi
#
#
#
#
# 155111 lea  rcx, [rip + 0xbe72]
#
#
#
#
# 155118 mov  rdx, -1
#
#
#
#
# 155125 xor  edi, edi
#
#
#
#
# 155127 jmp  0x259c0
#
#
#
#
# 155132 nop  dword ptr [rax]
#
#
#
#
# 155136 endbr64
#
#
#
#
# 155140 sub  rsp, 0x68
#
#
#
#
# 155144 mov  r8d, esi
#
#
#
#
# 155147 pxor  xmm0, xmm0
#
#
#
#
# 155151 mov  rsi, rdx
#
#
#
#
# 155154 mov  rax, qword ptr fs:[0x28]
#
#
#
#
# 155163 mov  qword ptr [rsp + 0x58], rax
#
#
#
#
# 155168 xor  eax, eax
#
#
#
#
# 155170 movups  xmmword ptr [rsp + 0x34], xmm0
#
#
#
#
# 155175 mov  rdx, -1
#
#
#
#
# 155182 mov  rcx, rsp
#
#
#
#
# 155185 movups  xmmword ptr [rsp + 0x44], xmm0
#
#
#
#
# 155190 movdqa  xmm2, xmmword ptr [rsp + 0x40]
#
#
#
#
# 155196 mov  eax, dword ptr [rsp + 0x50]
#
#
#
#
# 155200 mov  dword ptr [rsp + 0x30], r8d
#
#
#
#
# 155205 movdqa  xmm1, xmmword ptr [rsp + 0x30]
#
#
#
#
# 155211 mov  dword ptr [rsp + 0x20], eax
#
#
#
#
# 155215 movaps  xmmword ptr [rsp], xmm1
#
#
#
#
# 155219 movaps  xmmword ptr [rsp + 0x10], xmm2
#
#
#
#
# 155224 call  0x259c0
#
#
#
#
# 155229 mov  rdx, qword ptr [rsp + 0x58]
#
#
#
#
# 155234 sub  rdx, qword ptr fs:[0x28]
#
#
#
#
# 155243 jne  0x25e72
#
#
#
#
# 155245 add  rsp, 0x68
#
#
#
#
# 155249 ret
#
#
#
#
# 155250 call  0x4980
#
#
#
#
# 155255 nop  word ptr [rax + rax]
#
#
#
#
# 155264 endbr64
#
#
#
#
# 155268 sub  rsp, 0x68
#
#
#
#
# 155272 mov  r8d, esi
#
#
#
#
# 155275 pxor  xmm0, xmm0
#
#
#
#
# 155279 mov  rsi, rdx
#
#
#
#
# 155282 mov  rax, qword ptr fs:[0x28]
#
#
#
#
# 155291 mov  qword ptr [rsp + 0x58], rax
#
#
#
#
# 155296 xor  eax, eax
#
#
#
#
# 155298 movups  xmmword ptr [rsp + 0x34], xmm0
#
#
#
#
# 155303 mov  rdx, rcx
#
#
#
#
# 155306 mov  rcx, rsp
#
#
#
#
# 155309 movups  xmmword ptr [rsp + 0x44], xmm0
#
#
#
#
# 155314 movdqa  xmm2, xmmword ptr [rsp + 0x40]
#
#
#
#
# 155320 mov  eax, dword ptr [rsp + 0x50]
#
#
#
#
# 155324 mov  dword ptr [rsp + 0x30], r8d
#
#
#
#
# 155329 movdqa  xmm1, xmmword ptr [rsp + 0x30]
#
#
#
#
# 155335 mov  dword ptr [rsp + 0x20], eax
#
#
#
#
# 155339 movaps  xmmword ptr [rsp], xmm1
#
#
#
#
# 155343 movaps  xmmword ptr [rsp + 0x10], xmm2
#
#
#
#
# 155348 call  0x259c0
#
#
#
#
# 155353 mov  rdx, qword ptr [rsp + 0x58]
#
#
#
#
# 155358 sub  rdx, qword ptr fs:[0x28]
#
#
#
#
# 155367 jne  0x25eee
#
#
#
#
# 155369 add  rsp, 0x68
#
#
#
#
# 155373 ret
#
#
#
#
# 155374 call  0x4980
#
#
#
#
# 155379 nop  word ptr cs:[rax + rax]
#
#
#
#
# 155390 nop
#
#
#
#
# 155392 endbr64
#
#
#
#
# 155396 sub  rsp, 0x68
#
#
#
#
# 155400 pxor  xmm0, xmm0
#
#
#
#
# 155404 mov  rdx, -1
#
#
#
#
# 155411 mov  rax, qword ptr fs:[0x28]
#
#
#
#
# 155420 mov  qword ptr [rsp + 0x58], rax
#
#
#
#
# 155425 xor  eax, eax
#
#
#
#
# 155427 mov  dword ptr [rsp + 0x30], edi
#
#
#
#
# 155431 mov  rcx, rsp
#
#
#
#
# 155434 xor  edi, edi
#
#
#
#
# 155436 movups  xmmword ptr [rsp + 0x34], xmm0
#
#
#
#
# 155441 movdqa  xmm1, xmmword ptr [rsp + 0x30]
#
#
#
#
# 155447 movups  xmmword ptr [rsp + 0x44], xmm0
#
#
#
#
# 155452 movdqa  xmm2, xmmword ptr [rsp + 0x40]
#
#
#
#
# 155458 mov  eax, dword ptr [rsp + 0x50]
#
#
#
#
# 155462 movaps  xmmword ptr [rsp], xmm1
#
#
#
#
# 155466 mov  dword ptr [rsp + 0x20], eax
#
#
#
#
# 155470 movaps  xmmword ptr [rsp + 0x10], xmm2
#
#
#
#
# 155475 call  0x259c0
#
#
#
#
# 155480 mov  rdx, qword ptr [rsp + 0x58]
#
#
#
#
# 155485 sub  rdx, qword ptr fs:[0x28]
#
#
#
#
# 155494 jne  0x25f6d
#
#
#
#
# 155496 add  rsp, 0x68
#
#
#
#
# 155500 ret
#
#
#
#
# 155501 call  0x4980
#
#
#
#
# 155506 nop  word ptr cs:[rax + rax]
#
#
#
#
# 155517 nop  dword ptr [rax]
#
#
#
#
# 155520 endbr64
#
#
#
#
# 155524 sub  rsp, 0x38
#
#
#
#
# 155528 movdqa  xmm0, xmmword ptr [rip + 0xbcd0]
#
#
#
#
# 155536 movdqa  xmm1, xmmword ptr [rip + 0xbcd8]
#
#
#
#
# 155544 mov  ecx, esi
#
#
#
#
# 155546 mov  rax, qword ptr fs:[0x28]
#
#
#
#
# 155555 mov  qword ptr [rsp + 0x28], rax
#
#
#
#
# 155560 xor  eax, eax
#
#
#
#
# 155562 mov  eax, dword ptr [rip + 0xbcd0]
#
#
#
#
# 155568 and  ecx, 0x1f
#
#
#
#
# 155571 mov  r9, rsp
#
#
#
#
# 155574 movaps  xmmword ptr [rsp], xmm0
#
#
#
#
# 155578 mov  dword ptr [rsp + 0x20], eax
#
#
#
#
# 155582 mov  eax, esi
#
#
#
#
# 155584 shr  al, 5
#
#
#
#
# 155587 movaps  xmmword ptr [rsp + 0x10], xmm1
#
#
#
#
# 155592 movzx  eax, al
#
#
#
#
# 155595 lea  rdx, [rsp + rax*4 + 4]
#
#
#
#
# 155600 mov  esi, dword ptr [rdx]
#
#
#
#
# 155602 mov  eax, esi
#
#
#
#
# 155604 shr  eax, cl
#
#
#
#
# 155606 not  eax
#
#
#
#
# 155608 and  eax, 1
#
#
#
#
# 155611 shl  eax, cl
#
#
#
#
# 155613 mov  rcx, r9
#
#
#
#
# 155616 xor  eax, esi
#
#
#
#
# 155618 mov  rsi, rdi
#
#
#
#
# 155621 xor  edi, edi
#
#
#
#
# 155623 mov  dword ptr [rdx], eax
#
#
#
#
# 155625 mov  rdx, -1
#
#
#
#
# 155632 call  0x259c0
#
#
#
#
# 155637 mov  rdx, qword ptr [rsp + 0x28]
#
#
#
#
# 155642 sub  rdx, qword ptr fs:[0x28]
#
#
#
#
# 155651 jne  0x2600a
#
#
#
#
# 155653 add  rsp, 0x38
#
#
#
#
# 155657 ret
#
#
#
#
# 155658 call  0x4980
#
#
#
#
# 155663 nop
#
#
#
#
# 155664 endbr64
#
#
#
#
# 155668 mov  esi, 0x3a
#
#
#
#
# 155673 jmp  0x25f80

# %%
from collections import defaultdict
import posixpath

# %%
addr_lineProgram ={}
addr_sourceFile = {}
with open(filePath, 'rb') as f:
    elffile = ELFFile(f)

    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
        exit(0)

    dwarfinfo = elffile.get_dwarf_info()
    for CU in dwarfinfo.iter_CUs():
#         print(CU.get_top_DIE()['DW_AT_comp_dir'])
        CU_DIR_PATH = None
        CU_FILENAME = None
        for attr in CU.get_top_DIE().attributes.values():
            if attr.name == 'DW_AT_comp_dir':
                CU_DIR_PATH = attr.value.decode("utf-8")
            if attr.name == 'DW_AT_name':
                CU_FILENAME = attr.value.decode("utf-8")
            
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        line_program = dwarfinfo.line_program_for_CU(CU)
        if line_program is None:
            print('  DWARF info is missing a line program for this CU')
            continue

        for line_entry in line_program.get_entries():
            real_source_path = None
            if line_entry.state!=None:
                if line_entry.state.is_stmt!=0:

                    addr_lineProgram[hex(line_entry.state.address)] = line_entry

                    src_filename_from_lineentry = lpe_filename (line_program, line_entry.state.file)
                    if src_filename_from_lineentry == CU_FILENAME:
                        real_source_path = os.path.join(CU_DIR_PATH,CU_FILENAME)
                    else:
                        real_source_path = src_filename_from_lineentry
                    addr_sourceFile [hex(line_entry.state.address)] = real_source_path
# Out:
#   Found a compile unit at offset 0, length 10410
#   Found a compile unit at offset 10414, length 7795
#   Found a compile unit at offset 18213, length 931
#   Found a compile unit at offset 19148, length 3815
#   Found a compile unit at offset 22967, length 1824
#   Found a compile unit at offset 24795, length 15615
#   Found a compile unit at offset 40414, length 3379
#   Found a compile unit at offset 43797, length 1585
#   Found a compile unit at offset 45386, length 4279
#   Found a compile unit at offset 49669, length 1102
#   Found a compile unit at offset 50775, length 249
#   Found a compile unit at offset 51028, length 1910
#   Found a compile unit at offset 52942, length 710
#   Found a compile unit at offset 53656, length 1720
#   Found a compile unit at offset 55380, length 1383
#   Found a compile unit at offset 56767, length 5736
#   Found a compile unit at offset 62507, length 684
#   Found a compile unit at offset 63195, length 4327
#   Found a compile unit at offset 67526, length 1936
#   Found a compile unit at offset 69466, length 1840
#   Found a compile unit at offset 71310, length 1969
#   Found a compile unit at offset 73283, length 2802
#   Found a compile unit at offset 76089, length 139
#   Found a compile unit at offset 76232, length 462
#   Found a compile unit at offset 76698, length 6168

# %%
# print(addr_lineProgram)
# address_inst

def getSource(sourceFilePath, row , col):
    sourceFile = open(sourceFilePath, "r")
    fileContent = sourceFile.readlines()
    
    print(sourceFilePath, 'row: ',row , 'col ',col )
    row_content =  fileContent[row-1]
    
    
    if len(row_content)<col:
        return row_content
#     print(sourceFilePath, row , 'col ',col , 'len: ',len(row_content))
    print("*****",row_content,"))))")
    print('_',row_content[:(col-1)])
    print("_ _",row_content[col-1])
    print("_ _ _",row_content[col:])

    
    row_content = row_content[:(col-1)] + '|'+row_content[(col-1)]+'|' +row_content[col:]
    
    return row_content

# %%
# FUNCTION_DECL
# https://stackoverflow.com/questions/43460605/function-boundary-identification-using-libclang
# https://eli.thegreenplace.net/2011/07/03/parsing-c-in-python-with-clang


import clang.cindex



def get_all_var_types(source_path):
    srcFileName = source_path.split('/')[-1]

    function_boundary_by_name = {}
    idx = clang.cindex.Index.create()
    tu = idx.parse(source_path)
    
    for f in tu.cursor.walk_preorder():
        if f.kind == clang.cindex.CursorKind.VAR_DECL:
            # print(dir(f))
            print(f.extent.start.file.name)
            originFileName = f.extent.start.file.name.split('/')[-1]
            print(originFileName)
            print(f.displayname)
            print(f.type.spelling)
            print(f.extent.start.line,f.extent.start.column)
            print('\n')
            
            

   

def get_all_function_types(source_path):
    function_boundary_by_name = {}
    idx = clang.cindex.Index.create()
    tu = idx.parse(source_path)
    
    for f in tu.cursor.walk_preorder():
        if f.kind == clang.cindex.CursorKind.FUNCTION_DECL:
            # print(dir(f))
            print(f.displayname)
            print('function name: ',( f.spelling))
            print('Returns: ',(f.result_type.spelling))
            
            
            arg_len = len(list(f.type.argument_types()))
            if arg_len>0:
                arg_types = list(f.type.argument_types())
                for arg_type in arg_types:
                    print('arg_type:',arg_type.spelling)
                args = list(f.get_arguments())
                for arg in args:
                    print('arg:',arg.spelling)


            print("\n\n\n")

            
def get_function_boundaries(source_path):
    
    function_boundary_by_name = {}
    idx = clang.cindex.Index.create()
    tu = idx.parse(source_path)
    
    for f in tu.cursor.walk_preorder():
        if f.kind == clang.cindex.CursorKind.FUNCTION_DECL:

            function_name = f.displayname.split('(')[0]
            function_boundary_by_name[function_name]={}
            function_boundary_by_name[function_name] = { 'src_path':f.extent.start.file.name,
                              'src_file':f.extent.start.file.name.split('/')[-1],
                              'start_line':f.extent.start.line,
                              'start_col':f.extent.start.column,
                              'end_line':f.extent.end.line,
                              'end_col':f.extent.end.column}
    return function_boundary_by_name

def get_containing_function(source_file_path, line, col=0):
    function_boundary_by_name = get_function_boundaries(source_file_path)
    
    for function_name, item in function_boundary_by_name.items():
        if item['src_path'] == source_file_path:
            if line>= item['start_line'] and line<= item['end_line']:
                return function_name

# %%
with open('gitfm.s', 'w') as outFile:
    # outFile.write('file contents\n')
    lastSource = ""
    for address in address_inst:
        inst = address_inst[address]
        instrctionCode = (address+":\t"+ inst.mnemonic+" "+inst.op_str).ljust(45)
        

        if int(address,0)< 0x24357:#0x23122:
            continue
        
        OFFSET = None
        if len(inst.operands) > 0 :
            c=-1
            for o in inst.operands:
                c += 1
                if o.type == CS_OP_MEM:
                    print("\t\toperands[%u].type: MEM" %c)
                    if o.value.mem.base != 0:
                        print("\t\t\toperands[%u].mem.base: REG = %s" \
                            %(c, inst.reg_name(o.value.mem.base)))
                    if o.value.mem.index != 0:
                        print("\t\t\toperands[%u].mem.index: REG = %s" \
                            %(c, inst.reg_name(o.value.mem.index)))
                    if o.value.mem.disp != 0:
                        print("\t\t\toperands[%u].mem.disp: 0x%x" \
                            %(c, o.value.mem.disp))
                        OFFSET = o.value.mem.disp
                    print(hex(o.value.mem.disp),o.value.mem.disp)
                    
        
        if address in addr_lineProgram:
            
            srcFilePath =addr_sourceFile[address] 
#             srcFileName = srcFilePath.split('/')[-1]
            if srcFilePath!=lastSource:
                outFile.write("\n"+ '#'*100+"\n"+ srcFilePath.rjust(45) +'\n'+'#'*100+ "\n\n")
                lastSource = srcFilePath
            print("add",address)
            sourceCode = getSource(srcFilePath,addr_lineProgram[address].state.line, addr_lineProgram[address].state.column)
            function_name = get_containing_function(srcFilePath ,addr_lineProgram[address].state.line , addr_lineProgram[address].state.column)
#             print(function_name)
            
            if '\n' not in  sourceCode:
                sourceCode+=sourceCode+"\n"
            outFile.write(instrctionCode+"#"+ sourceCode  )
            print(instrctionCode+"#"+ sourceCode)
            
        else:
            
            outFile.write(instrctionCode+ '\n'  )
            print(instrctionCode)
        if OFFSET:
#             outFile.write("MEMORY OFFSET:     "+str(hex(OFFSET))+"     "+str(OFFSET)+'\n')
            pass
# Out:
# add 0x24357
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  86 col  7
# *****       match = xmalloc (offsetof (struct userid, name) + strlen (name) + 1);
#  ))))
# _
# _ _ m
# _ _ _ atch = xmalloc (offsetof (struct userid, name) + strlen (name) + 1);
#
# 0x24357:	call 0x24650                        #      |m|atch = xmalloc (offsetof (struct userid, name) + strlen (name) + 1);
#
# 0x2435c:	mov rsi, r12
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x2435f:	mov dword ptr [rax], ebp
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 			operands[1].mem.disp: 0x10
# 0x10 16
# 0x24361:	lea rdi, [rax + 0x10]
# 0x24365:	mov rbx, rax
# add 0x24368
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  79 col  3
# ***** 	}
#  ))))
# _ 	}
# _ _
#
# _ _ _
# 0x24368:	call 0x4870                         #	}|
# |
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd7dc
# 0xd7dc 55260
# add 0x2436d
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  91 col  7
# *****       match->next = user_alist;
#  ))))
# _
# _ _ m
# _ _ _ atch->next = user_alist;
#
# 0x2436d:	mov rax, qword ptr [rip + 0xd7dc]   #      |m|atch->next = user_alist;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rip
# 			operands[0].mem.disp: 0xd7d5
# 0xd7d5 55253
# 0x24374:	mov qword ptr [rip + 0xd7d5], rbx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x8
# 0x8 8
# 0x2437b:	mov qword ptr [rbx + 8], rax
# add 0x2437f
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  92 col  7
# *****       user_alist = match;
#  ))))
# _
# _ _ u
# _ _ _ ser_alist = match;
#
# 0x2437f:	jmp 0x2431d                         #      |u|ser_alist = match;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x24381:	nop word ptr cs:[rax + rax]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x2438c:	nop dword ptr [rax]
# add 0x24390
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  105 col  1
# ***** {
#  ))))
# _
# _ _ {
# _ _ _
#
# 0x24390:	endbr64                             #|{|
#
# add 0x24394
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  109 col  3
# *****   for (tail = user_alist; tail; tail = tail->next)
#  ))))
# _
# _ _ f
# _ _ _ or (tail = user_alist; tail; tail = tail->next)
#
# 0x24394:	push r12                            #  |f|or (tail = user_alist; tail; tail = tail->next)
#
# 0x24396:	push rbp
# 0x24397:	mov rbp, rdi
# 0x2439a:	push rbx
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd7ae
# 0xd7ae 55214
# 0x2439b:	mov rbx, qword ptr [rip + 0xd7ae]
# add 0x243a2
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  109 col  27
# *****   for (tail = user_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = user_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x243a2:	test rbx, rbx                       #  for (tail = user_alist; |t|ail; tail = tail->next)
#
# 0x243a5:	je 0x243e0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rdi
# 0x0 0
# 0x243a7:	movzx r12d, byte ptr [rdi]
# 0x243ab:	jmp 0x243b9
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x243ad:	nop dword ptr [rax]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x8
# 0x8 8
# add 0x243b0
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  109 col  38
# *****   for (tail = user_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = user_alist; tail; tail
# _ _ =
# _ _ _  tail->next)
#
# 0x243b0:	mov rbx, qword ptr [rbx + 8]        #  for (tail = user_alist; tail; tail |=| tail->next)
#
# add 0x243b4
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  109 col  27
# *****   for (tail = user_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = user_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x243b4:	test rbx, rbx                       #  for (tail = user_alist; |t|ail; tail = tail->next)
#
# 0x243b7:	je 0x243e0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x10
# 0x10 16
# add 0x243b9
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  111 col  5
# *****     if (*tail->name == *user && !strcmp (tail->name, user))
#  ))))
# _
# _ _ i
# _ _ _ f (*tail->name == *user && !strcmp (tail->name, user))
#
# 0x243b9:	cmp byte ptr [rbx + 0x10], r12b     #    |i|f (*tail->name == *user && !strcmp (tail->name, user))
#
# 0x243bd:	jne 0x243b0
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x10
# 0x10 16
# 0x243bf:	lea rdi, [rbx + 0x10]
# 0x243c3:	mov rsi, rbp
# 0x243c6:	call 0x4af0
# 0x243cb:	test eax, eax
# 0x243cd:	jne 0x243b0
# add 0x243cf
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  139 col  7
# *****       return &tail->id.u;
#  ))))
# _
# _ _ r
# _ _ _ eturn &tail->id.u;
#
# 0x243cf:	mov r12, rbx                        #      |r|eturn &tail->id.u;
#
# 0x243d2:	pop rbx
# 0x243d3:	pop rbp
# 0x243d4:	mov rax, r12
# 0x243d7:	pop r12
# 0x243d9:	ret
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x243da:	nop word ptr [rax + rax]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd761
# 0xd761 55137
# add 0x243e0
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  114 col  3
# *****   for (tail = nouser_alist; tail; tail = tail->next)
#  ))))
# _
# _ _ f
# _ _ _ or (tail = nouser_alist; tail; tail = tail->next)
#
# 0x243e0:	mov rbx, qword ptr [rip + 0xd761]   #  |f|or (tail = nouser_alist; tail; tail = tail->next)
#
# add 0x243e7
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  114 col  29
# *****   for (tail = nouser_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = nouser_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x243e7:	test rbx, rbx                       #  for (tail = nouser_alist; |t|ail; tail = tail->next)
#
# 0x243ea:	je 0x24428
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 0x0 0
# 0x243ec:	movzx r12d, byte ptr [rbp]
# 0x243f1:	jmp 0x24401
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x243f3:	nop dword ptr [rax + rax]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x8
# 0x8 8
# add 0x243f8
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  114 col  40
# *****   for (tail = nouser_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = nouser_alist; tail; tail
# _ _ =
# _ _ _  tail->next)
#
# 0x243f8:	mov rbx, qword ptr [rbx + 8]        #  for (tail = nouser_alist; tail; tail |=| tail->next)
#
# add 0x243fc
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  114 col  29
# *****   for (tail = nouser_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = nouser_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x243fc:	test rbx, rbx                       #  for (tail = nouser_alist; |t|ail; tail = tail->next)
#
# 0x243ff:	je 0x24428
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x10
# 0x10 16
# add 0x24401
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  116 col  5
# *****     if (*tail->name == *user && !strcmp (tail->name, user))
#  ))))
# _
# _ _ i
# _ _ _ f (*tail->name == *user && !strcmp (tail->name, user))
#
# 0x24401:	cmp byte ptr [rbx + 0x10], r12b     #    |i|f (*tail->name == *user && !strcmp (tail->name, user))
#
# 0x24405:	jne 0x243f8
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x10
# 0x10 16
# 0x24407:	lea rdi, [rbx + 0x10]
# 0x2440b:	mov rsi, rbp
# 0x2440e:	call 0x4af0
# 0x24413:	test eax, eax
# 0x24415:	jne 0x243f8
# 0x24417:	xor r12d, r12d
# 0x2441a:	pop rbx
# 0x2441b:	pop rbp
# 0x2441c:	mov rax, r12
# 0x2441f:	pop r12
# 0x24421:	ret
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x24422:	nop word ptr [rax + rax]
# add 0x24428
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  119 col  3
# *****   pwent = getpwnam (user);
#  ))))
# _
# _ _ p
# _ _ _ went = getpwnam (user);
#
# 0x24428:	mov rdi, rbp                        #  |p|went = getpwnam (user);
#
# 0x2442b:	call 0x4b20
# 0x24430:	mov rdi, rbp
# 0x24433:	mov r12, rax
# add 0x24436
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  130 col  3
# *****   tail = xmalloc (offsetof (struct userid, name) + strlen (user) + 1);
#  ))))
# _
# _ _ t
# _ _ _ ail = xmalloc (offsetof (struct userid, name) + strlen (user) + 1);
#
# 0x24436:	call 0x4960                         #  |t|ail = xmalloc (offsetof (struct userid, name) + strlen (user) + 1);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 			operands[1].mem.disp: 0x11
# 0x11 17
# 0x2443b:	lea rdi, [rax + 0x11]
# 0x2443f:	call 0x24650
# 0x24444:	mov rsi, rbp
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 			operands[1].mem.disp: 0x10
# 0x10 16
# 0x24447:	lea rdi, [rax + 0x10]
# 0x2444b:	mov rbx, rax
# add 0x2444e
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  79 col  3
# ***** 	}
#  ))))
# _ 	}
# _ _
#
# _ _ _
# 0x2444e:	call 0x4870                         #	}|
# |
# add 0x24453
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  134 col  3
# *****   if (pwent)
#  ))))
# _
# _ _ i
# _ _ _ f (pwent)
#
# 0x24453:	test r12, r12                       #  |i|f (pwent)
#
# 0x24456:	je 0x24480
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = r12
# 			operands[1].mem.disp: 0x10
# 0x10 16
# add 0x24458
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  136 col  7
# *****       tail->id.u = pwent->pw_uid;
#  ))))
# _
# _ _ t
# _ _ _ ail->id.u = pwent->pw_uid;
#
# 0x24458:	mov eax, dword ptr [r12 + 0x10]     #      |t|ail->id.u = pwent->pw_uid;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 0x0 0
# 0x2445d:	mov dword ptr [rbx], eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd6ea
# 0xd6ea 55018
# add 0x2445f
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  137 col  7
# *****       tail->next = user_alist;
#  ))))
# _
# _ _ t
# _ _ _ ail->next = user_alist;
#
# 0x2445f:	mov rax, qword ptr [rip + 0xd6ea]   #      |t|ail->next = user_alist;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rip
# 			operands[0].mem.disp: 0xd6e3
# 0xd6e3 55011
# 0x24466:	mov qword ptr [rip + 0xd6e3], rbx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x8
# 0x8 8
# 0x2446d:	mov qword ptr [rbx + 8], rax
# add 0x24471
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  138 col  7
# *****       user_alist = tail;
#  ))))
# _
# _ _ u
# _ _ _ ser_alist = tail;
#
# 0x24471:	jmp 0x243cf                         #      |u|ser_alist = tail;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x24476:	nop word ptr cs:[rax + rax]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd6c1
# 0xd6c1 54977
# add 0x24480
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  142 col  3
# *****   tail->next = nouser_alist;
#  ))))
# _
# _ _ t
# _ _ _ ail->next = nouser_alist;
#
# 0x24480:	mov rax, qword ptr [rip + 0xd6c1]   #  |t|ail->next = nouser_alist;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rip
# 			operands[0].mem.disp: 0xd6ba
# 0xd6ba 54970
# 0x24487:	mov qword ptr [rip + 0xd6ba], rbx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x8
# 0x8 8
# 0x2448e:	mov qword ptr [rbx + 8], rax
# add 0x24492
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  144 col  3
# *****   return NULL;
#  ))))
# _
# _ _ r
# _ _ _ eturn NULL;
#
# 0x24492:	mov rax, r12                        #  |r|eturn NULL;
#
# 0x24495:	pop rbx
# 0x24496:	pop rbp
# 0x24497:	pop r12
# 0x24499:	ret
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x2449a:	nop word ptr [rax + rax]
# add 0x244a0
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  151 col  1
# ***** {
#  ))))
# _
# _ _ {
# _ _ _
#
# 0x244a0:	endbr64                             #|{|
#
# add 0x244a4
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  155 col  3
# *****   for (tail = group_alist; tail; tail = tail->next)
#  ))))
# _
# _ _ f
# _ _ _ or (tail = group_alist; tail; tail = tail->next)
#
# 0x244a4:	push r12                            #  |f|or (tail = group_alist; tail; tail = tail->next)
#
# 0x244a6:	push rbp
# 0x244a7:	mov ebp, edi
# 0x244a9:	push rbx
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd68f
# 0xd68f 54927
# 0x244aa:	mov rbx, qword ptr [rip + 0xd68f]
# add 0x244b1
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  155 col  28
# *****   for (tail = group_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = group_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x244b1:	test rbx, rbx                       #  for (tail = group_alist; |t|ail; tail = tail->next)
#
# 0x244b4:	jne 0x244c9
# 0x244b6:	jmp 0x244e0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x244b8:	nop dword ptr [rax + rax]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x8
# 0x8 8
# add 0x244c0
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  155 col  39
# *****   for (tail = group_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = group_alist; tail; tail
# _ _ =
# _ _ _  tail->next)
#
# 0x244c0:	mov rbx, qword ptr [rbx + 8]        #  for (tail = group_alist; tail; tail |=| tail->next)
#
# add 0x244c4
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  155 col  28
# *****   for (tail = group_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = group_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x244c4:	test rbx, rbx                       #  for (tail = group_alist; |t|ail; tail = tail->next)
#
# 0x244c7:	je 0x244e0
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 0x0 0
# add 0x244c9
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  157 col  7
# *****       if (tail->id.g == gid)
#  ))))
# _
# _ _ i
# _ _ _ f (tail->id.g == gid)
#
# 0x244c9:	cmp dword ptr [rbx], ebp            #      |i|f (tail->id.g == gid)
#
# 0x244cb:	jne 0x244c0
# add 0x244cd
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  177 col  3
# *****   return match->name[0] ? match->name : NULL;
#  ))))
# _
# _ _ r
# _ _ _ eturn match->name[0] ? match->name : NULL;
#
# 0x244cd:	xor eax, eax                        #  |r|eturn match->name[0] ? match->name : NULL;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x10
# 0x10 16
# 0x244cf:	cmp byte ptr [rbx + 0x10], 0
# 0x244d3:	je 0x244d9
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x10
# 0x10 16
# 0x244d5:	lea rax, [rbx + 0x10]
# 0x244d9:	pop rbx
# 0x244da:	pop rbp
# 0x244db:	pop r12
# 0x244dd:	ret
# 0x244de:	nop
# add 0x244e0
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  166 col  7
# *****       struct group *grent = getgrgid (gid);
#  ))))
# _
# _ _ s
# _ _ _ truct group *grent = getgrgid (gid);
#
# 0x244e0:	mov edi, ebp                        #      |s|truct group *grent = getgrgid (gid);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0x53c6
# 0x53c6 21446
# 0x244e2:	lea r12, [rip + 0x53c6]
# 0x244e9:	call 0x49d0
# add 0x244ee
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  167 col  7
# *****       char const *name = grent ? grent->gr_name : "";
#  ))))
# _
# _ _ c
# _ _ _ har const *name = grent ? grent->gr_name : "";
#
# 0x244ee:	mov edi, 0x11                       #      |c|har const *name = grent ? grent->gr_name : "";
#
# 0x244f3:	test rax, rax
# 0x244f6:	je 0x24507
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 0x0 0
# 0x244f8:	mov r12, qword ptr [rax]
# 0x244fb:	mov rdi, r12
# 0x244fe:	call 0x4960
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 			operands[1].mem.disp: 0x11
# 0x11 17
# 0x24503:	lea rdi, [rax + 0x11]
# add 0x24507
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  168 col  7
# *****       match = xmalloc (offsetof (struct userid, name) + strlen (name) + 1);
#  ))))
# _
# _ _ m
# _ _ _ atch = xmalloc (offsetof (struct userid, name) + strlen (name) + 1);
#
# 0x24507:	call 0x24650                        #      |m|atch = xmalloc (offsetof (struct userid, name) + strlen (name) + 1);
#
# 0x2450c:	mov rsi, r12
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x2450f:	mov dword ptr [rax], ebp
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 			operands[1].mem.disp: 0x10
# 0x10 16
# 0x24511:	lea rdi, [rax + 0x10]
# 0x24515:	mov rbx, rax
# add 0x24518
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  79 col  3
# ***** 	}
#  ))))
# _ 	}
# _ _
#
# _ _ _
# 0x24518:	call 0x4870                         #	}|
# |
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd61c
# 0xd61c 54812
# add 0x2451d
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  173 col  7
# *****       match->next = group_alist;
#  ))))
# _
# _ _ m
# _ _ _ atch->next = group_alist;
#
# 0x2451d:	mov rax, qword ptr [rip + 0xd61c]   #      |m|atch->next = group_alist;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rip
# 			operands[0].mem.disp: 0xd615
# 0xd615 54805
# 0x24524:	mov qword ptr [rip + 0xd615], rbx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x8
# 0x8 8
# 0x2452b:	mov qword ptr [rbx + 8], rax
# add 0x2452f
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  174 col  7
# *****       group_alist = match;
#  ))))
# _
# _ _ g
# _ _ _ roup_alist = match;
#
# 0x2452f:	jmp 0x244cd                         #      |g|roup_alist = match;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x24531:	nop word ptr cs:[rax + rax]
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x2453c:	nop dword ptr [rax]
# add 0x24540
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  187 col  1
# ***** {
#  ))))
# _
# _ _ {
# _ _ _
#
# 0x24540:	endbr64                             #|{|
#
# add 0x24544
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  191 col  3
# *****   for (tail = group_alist; tail; tail = tail->next)
#  ))))
# _
# _ _ f
# _ _ _ or (tail = group_alist; tail; tail = tail->next)
#
# 0x24544:	push r12                            #  |f|or (tail = group_alist; tail; tail = tail->next)
#
# 0x24546:	push rbp
# 0x24547:	mov rbp, rdi
# 0x2454a:	push rbx
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd5ee
# 0xd5ee 54766
# 0x2454b:	mov rbx, qword ptr [rip + 0xd5ee]
# add 0x24552
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  191 col  28
# *****   for (tail = group_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = group_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x24552:	test rbx, rbx                       #  for (tail = group_alist; |t|ail; tail = tail->next)
#
# 0x24555:	je 0x24590
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rdi
# 0x0 0
# 0x24557:	movzx r12d, byte ptr [rdi]
# 0x2455b:	jmp 0x24569
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 0x0 0
# 0x2455d:	nop dword ptr [rax]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x8
# 0x8 8
# add 0x24560
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  191 col  39
# *****   for (tail = group_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = group_alist; tail; tail
# _ _ =
# _ _ _  tail->next)
#
# 0x24560:	mov rbx, qword ptr [rbx + 8]        #  for (tail = group_alist; tail; tail |=| tail->next)
#
# add 0x24564
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  191 col  28
# *****   for (tail = group_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = group_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x24564:	test rbx, rbx                       #  for (tail = group_alist; |t|ail; tail = tail->next)
#
# 0x24567:	je 0x24590
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x10
# 0x10 16
# add 0x24569
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  193 col  5
# *****     if (*tail->name == *group && !strcmp (tail->name, group))
#  ))))
# _
# _ _ i
# _ _ _ f (*tail->name == *group && !strcmp (tail->name, group))
#
# 0x24569:	cmp byte ptr [rbx + 0x10], r12b     #    |i|f (*tail->name == *group && !strcmp (tail->name, group))
#
# 0x2456d:	jne 0x24560
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x10
# 0x10 16
# 0x2456f:	lea rdi, [rbx + 0x10]
# 0x24573:	mov rsi, rbp
# 0x24576:	call 0x4af0
# 0x2457b:	test eax, eax
# 0x2457d:	jne 0x24560
# add 0x2457f
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  221 col  7
# *****       return &tail->id.g;
#  ))))
# _
# _ _ r
# _ _ _ eturn &tail->id.g;
#
# 0x2457f:	mov r12, rbx                        #      |r|eturn &tail->id.g;
#
# 0x24582:	pop rbx
# 0x24583:	pop rbp
# 0x24584:	mov rax, r12
# 0x24587:	pop r12
# 0x24589:	ret
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x2458a:	nop word ptr [rax + rax]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd5a1
# 0xd5a1 54689
# add 0x24590
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  196 col  3
# *****   for (tail = nogroup_alist; tail; tail = tail->next)
#  ))))
# _
# _ _ f
# _ _ _ or (tail = nogroup_alist; tail; tail = tail->next)
#
# 0x24590:	mov rbx, qword ptr [rip + 0xd5a1]   #  |f|or (tail = nogroup_alist; tail; tail = tail->next)
#
# add 0x24597
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  196 col  30
# *****   for (tail = nogroup_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = nogroup_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x24597:	test rbx, rbx                       #  for (tail = nogroup_alist; |t|ail; tail = tail->next)
#
# 0x2459a:	je 0x245d8
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbp
# 0x0 0
# 0x2459c:	movzx r12d, byte ptr [rbp]
# 0x245a1:	jmp 0x245b1
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x245a3:	nop dword ptr [rax + rax]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x8
# 0x8 8
# add 0x245a8
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  196 col  41
# *****   for (tail = nogroup_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = nogroup_alist; tail; tail
# _ _ =
# _ _ _  tail->next)
#
# 0x245a8:	mov rbx, qword ptr [rbx + 8]        #  for (tail = nogroup_alist; tail; tail |=| tail->next)
#
# add 0x245ac
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  196 col  30
# *****   for (tail = nogroup_alist; tail; tail = tail->next)
#  ))))
# _   for (tail = nogroup_alist;
# _ _ t
# _ _ _ ail; tail = tail->next)
#
# 0x245ac:	test rbx, rbx                       #  for (tail = nogroup_alist; |t|ail; tail = tail->next)
#
# 0x245af:	je 0x245d8
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x10
# 0x10 16
# add 0x245b1
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  198 col  5
# *****     if (*tail->name == *group && !strcmp (tail->name, group))
#  ))))
# _
# _ _ i
# _ _ _ f (*tail->name == *group && !strcmp (tail->name, group))
#
# 0x245b1:	cmp byte ptr [rbx + 0x10], r12b     #    |i|f (*tail->name == *group && !strcmp (tail->name, group))
#
# 0x245b5:	jne 0x245a8
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rbx
# 			operands[1].mem.disp: 0x10
# 0x10 16
# 0x245b7:	lea rdi, [rbx + 0x10]
# 0x245bb:	mov rsi, rbp
# 0x245be:	call 0x4af0
# 0x245c3:	test eax, eax
# 0x245c5:	jne 0x245a8
# 0x245c7:	xor r12d, r12d
# 0x245ca:	pop rbx
# 0x245cb:	pop rbp
# 0x245cc:	mov rax, r12
# 0x245cf:	pop r12
# 0x245d1:	ret
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x245d2:	nop word ptr [rax + rax]
# add 0x245d8
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  201 col  3
# *****   grent = getgrnam (group);
#  ))))
# _
# _ _ g
# _ _ _ rent = getgrnam (group);
#
# 0x245d8:	mov rdi, rbp                        #  |g|rent = getgrnam (group);
#
# 0x245db:	call 0x4b80
# 0x245e0:	mov rdi, rbp
# 0x245e3:	mov r12, rax
# add 0x245e6
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  212 col  3
# *****   tail = xmalloc (offsetof (struct userid, name) + strlen (group) + 1);
#  ))))
# _
# _ _ t
# _ _ _ ail = xmalloc (offsetof (struct userid, name) + strlen (group) + 1);
#
# 0x245e6:	call 0x4960                         #  |t|ail = xmalloc (offsetof (struct userid, name) + strlen (group) + 1);
#
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 			operands[1].mem.disp: 0x11
# 0x11 17
# 0x245eb:	lea rdi, [rax + 0x11]
# 0x245ef:	call 0x24650
# 0x245f4:	mov rsi, rbp
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rax
# 			operands[1].mem.disp: 0x10
# 0x10 16
# 0x245f7:	lea rdi, [rax + 0x10]
# 0x245fb:	mov rbx, rax
# add 0x245fe
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  79 col  3
# ***** 	}
#  ))))
# _ 	}
# _ _
#
# _ _ _
# 0x245fe:	call 0x4870                         #	}|
# |
# add 0x24603
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  216 col  3
# *****   if (grent)
#  ))))
# _
# _ _ i
# _ _ _ f (grent)
# 0x24603:	test r12, r12                       #  |i|f (grent)
#
# 0x24606:	je 0x24630
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = r12
# 			operands[1].mem.disp: 0x10
# 0x10 16
# add 0x24608
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  218 col  7
# *****       tail->id.g = grent->gr_gid;
#  ))))
# _
# _ _ t
# _ _ _ ail->id.g = grent->gr_gid;
#
# 0x24608:	mov eax, dword ptr [r12 + 0x10]     #      |t|ail->id.g = grent->gr_gid;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 0x0 0
# 0x2460d:	mov dword ptr [rbx], eax
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd52a
# 0xd52a 54570
# add 0x2460f
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  219 col  7
# *****       tail->next = group_alist;
#  ))))
# _
# _ _ t
# _ _ _ ail->next = group_alist;
#
# 0x2460f:	mov rax, qword ptr [rip + 0xd52a]   #      |t|ail->next = group_alist;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rip
# 			operands[0].mem.disp: 0xd523
# 0xd523 54563
# 0x24616:	mov qword ptr [rip + 0xd523], rbx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x8
# 0x8 8
# 0x2461d:	mov qword ptr [rbx + 8], rax
# add 0x24621
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  220 col  7
# *****       group_alist = tail;
#  ))))
# _
# _ _ g
# _ _ _ roup_alist = tail;
#
# 0x24621:	jmp 0x2457f                         #      |g|roup_alist = tail;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rax
# 			operands[0].mem.index: REG = rax
# 0x0 0
# 0x24626:	nop word ptr cs:[rax + rax]
# 		operands[1].type: MEM
# 			operands[1].mem.base: REG = rip
# 			operands[1].mem.disp: 0xd501
# 0xd501 54529
# add 0x24630
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  224 col  3
# *****   tail->next = nogroup_alist;
#  ))))
# _
# _ _ t
# _ _ _ ail->next = nogroup_alist;
#
# 0x24630:	mov rax, qword ptr [rip + 0xd501]   #  |t|ail->next = nogroup_alist;
#
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rip
# 			operands[0].mem.disp: 0xd4fa
# 0xd4fa 54522
# 0x24637:	mov qword ptr [rip + 0xd4fa], rbx
# 		operands[0].type: MEM
# 			operands[0].mem.base: REG = rbx
# 			operands[0].mem.disp: 0x8
# 0x8 8
# 0x2463e:	mov qword ptr [rbx + 8], rax
# add 0x24642
# /home/nahid/reverse/binaries/gnuit/lib/idcache.c row:  226 col  3
# *****   return NULL;
#  ))))
# _
# _ _ r
# _ _ _ eturn NULL;
#
# 0x24642:	mov rax, r12                        #  |r|eturn NULL;
#
# 0x24645:	pop rbx
# 0x24646:	pop rbp
# 0x24647:	pop r12
# 0x24649:	ret
# add 0x24650
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  48 col  1
# ***** {
#  ))))
# _
# _ _ {
# _ _ _
#
# 0x24650:	endbr64                             #|{|
#
# add 0x24654
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  49 col  3
# *****   void *p = malloc (n);
#  ))))
# _
# _ _ v
# _ _ _ oid *p = malloc (n);
#
# 0x24654:	push rbx                            #  |v|oid *p = malloc (n);
#
# 0x24655:	mov rbx, rdi
# 0x24658:	call 0x4bf0
# add 0x2465d
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  50 col  3
# *****   if (!p && n != 0)
#  ))))
# _
# _ _ i
# _ _ _ f (!p && n != 0)
#
# 0x2465d:	test rax, rax                       #  |i|f (!p && n != 0)
#
# 0x24660:	jne 0x24667
# 0x24662:	test rbx, rbx
# 0x24665:	jne 0x24669
# 0x24667:	pop rbx
# 0x24668:	ret
# add 0x24669
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  51 col  5
# *****     xalloc_die ();
#  ))))
# _
# _ _ x
# _ _ _ alloc_die ();
#
# 0x24669:	call 0x1ee92                        #    |x|alloc_die ();
#
# 0x2466e:	nop
# add 0x24670
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  60 col  1
# ***** {
#  ))))
# _
# _ _ {
# _ _ _
#
# 0x24670:	endbr64                             #|{|
#
# add 0x24674
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  61 col  3
# *****   p = realloc (p, n);
#  ))))
# _
# _ _ p
# _ _ _  = realloc (p, n);
#
# 0x24674:	push rbx                            #  |p| = realloc (p, n);
#
# 0x24675:	mov rbx, rsi
# 0x24678:	call 0x4cb0
# add 0x2467d
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  62 col  3
# *****   if (!p && n != 0)
#  ))))
# _
# _ _ i
# _ _ _ f (!p && n != 0)
#
# 0x2467d:	test rax, rax                       #  |i|f (!p && n != 0)
#
# 0x24680:	jne 0x24687
# 0x24682:	test rbx, rbx
# 0x24685:	jne 0x24689
# 0x24687:	pop rbx
# 0x24688:	ret
# add 0x24689
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  63 col  5
# *****     xalloc_die ();
#  ))))
# _
# _ _ x
# _ _ _ alloc_die ();
#
# 0x24689:	call 0x1ee92                        #    |x|alloc_die ();
#
# 0x2468e:	nop
# add 0x24690
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  75 col  1
# ***** {
#  ))))
# _
# _ _ {
# _ _ _
#
# 0x24690:	endbr64                             #|{|
#
# add 0x24694
# /home/nahid/reverse/binaries/gnuit/lib/xmalloc.c row:  188 col  3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 40
#      38                 lastSource = srcFilePath
#      39             print("add",address)
# ---> 40             sourceCode = getSource(srcFilePath,addr_lineProgram[address].state.line, addr_lineProgram[address].state.column)
#      41             function_name = get_containing_function(srcFilePath ,addr_lineProgram[address].state.line , addr_lineProgram[address].state.column)
#      42 #             print(function_name)
#
# Cell In[12], line 9, in getSource(sourceFilePath, row, col)
#       6 fileContent = sourceFile.readlines()
#       8 print(sourceFilePath, 'row: ',row , 'col ',col )
# ----> 9 row_content =  fileContent[row-1]
#      12 if len(row_content)<col:
#      13     return row_content
#
# IndexError: list index out of range

# %%
0x24698
