# %%
# -------------------------------------------------------------------------------
# elftools example: dwarf_location_info.py
#
# Examine DIE entries which have either location list values or location
# expression values and decode that information.
#
# Location information can either be completely contained within a DIE
# (using 'DW_FORM_exprloc' in DWARFv4 or 'DW_FORM_block1' in earlier
# versions) or be a reference to a location list contained within
# the .debug_loc section (using 'DW_FORM_sec_offset' in DWARFv4 or
# 'DW_FORM_data4' / 'DW_FORM_data8' in earlier versions).
#
# The LocationParser object parses the DIE attributes and handles both
# formats.
#
# The directory 'test/testfiles_for_location_info' contains test files with
# location information represented in both DWARFv4 and DWARFv2 forms.
#
# Eli Bendersky (eliben@gmail.com)
# This code is in the public domain
#-------------------------------------------------------------------------------
from __future__ import print_function
import sys

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.
sys.path[0:0] = ['.', '..']

from elftools.elf.elffile import ELFFile
from elftools.dwarf.descriptions import (
    describe_DWARF_expr, set_global_machine_arch)
from elftools.dwarf.locationlists import (
    LocationEntry, LocationExpr, LocationParser)



def show_loclist(loclist, dwarfinfo, indent, cu_offset):
    """ Display a location list nicely, decoding the DWARF expressions
        contained within.
    """
    d = []
    for loc_entity in loclist:
        if isinstance(loc_entity, LocationEntry):
            d.append('%s <<%s>>' % (
                loc_entity,
                describe_DWARF_expr(loc_entity.loc_expr, dwarfinfo.structs, cu_offset)))
        else:
            d.append(str(loc_entity))
    return '\n'.join(indent + s for s in d)

def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        # get_dwarf_info returns a DWARFInfo context object, which is the
        # starting point for all DWARF-based processing in pyelftools.
        dwarfinfo = elffile.get_dwarf_info()

        # The location lists are extracted by DWARFInfo from the .debug_loc
        # section, and returned here as a LocationLists object.
        location_lists = dwarfinfo.location_lists()

        # This is required for the descriptions module to correctly decode
        # register names contained in DWARF expressions.
        set_global_machine_arch(elffile.get_machine_arch())

        # Create a LocationParser object that parses the DIE attributes and
        # creates objects representing the actual location information.
        loc_parser = LocationParser(location_lists)

        for CU in dwarfinfo.iter_CUs():
            print("#  #  "*20)
            # DWARFInfo allows to iterate over the compile units contained in
            # the .debug_info section. CU is a CompileUnit object, with some
            # computed attributes (such as its offset in the section) and
            # a header which conforms to the DWARF standard. The access to
            # header elements is, as usual, via item-lookup.
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # A CU provides a simple API to iterate over all the DIEs in it.
            for DIE in CU.iter_DIEs():
                print("- - "*20)
                
                if DIE.tag == 'DW_TAG_subprogram':
                    for attr in DIE.attributes.values():
                        if attr.name == "DW_AT_name": #FUNC NAME
                            FUNC_name = attr.value.decode("utf-8")
                            print("FUNCTION NAME >>>>>>>>>  ",FUNC_name)
                            
                if DIE.tag in[ 'DW_TAG_formal_parameter','DW_TAG_variable' , 'DW_TAG_member']:
                    for attr in DIE.attributes.values():
                        if attr.name == "DW_AT_name": 
                            print(  "  {}  :::  {} ".format(DIE.tag , attr.value.decode("utf-8")) )
                            
                if DIE.tag in ['DW_TAG_structure_type' , 'DW_TAG_union_type' , 'DW_TAG_enumeration_type']:
                    for attr in DIE.attributes.values():
                        if attr.name == "DW_AT_name": 
                            print(  "  {}  [ STRUCT ]  {} ".format(DIE.tag , attr.value.decode("utf-8")) )
                    
                # Go over all attributes of the DIE. Each attribute is an
                # AttributeValue object (from elftools.dwarf.die), which we
                # can examine.
                for attr in DIE.attributes.values():
                    # Check if this attribute contains location information
                    
                    name = None
                    loc_found = False
                    if attr.name == "DW_AT_name":
                        name = attr.value.decode("utf-8")
                    if loc_parser.attribute_has_location(attr, CU['version']):
                        print('   DIE %s. attr %s.' % (DIE.tag, attr.name))
                        loc = loc_parser.parse_from_attribute(attr,
                                                              CU['version'])
                        # We either get a list (in case the attribute is a
                        # reference to the .debug_loc section) or a LocationExpr
                        # object (in case the attribute itself contains location
                        # information).
                        loc_found = True
                        print(DIE.tag)
                        if isinstance(loc, LocationExpr):
                            print('######      %s' % (
                                describe_DWARF_expr(loc.loc_expr,
                                                    dwarfinfo.structs, CU.cu_offset)))
                        elif isinstance(loc, list):
                            print('$$$$$    ',show_loclist(loc,
                                               dwarfinfo,
                                               '      ', CU.cu_offset))
                    if loc_found and name is not None :
                        print ("Name :>>>>>>>>>>>>>> ",name)
                        
filename = './../../binaries/c_many/stacktest'
process_file(filename)
# Out:
# Processing file: ./../../binaries/c_many/stacktest
# #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #
#   Found a compile unit at offset 0, length 986
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_structure_type  [ STRUCT ]  S_stack
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  number
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 0)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  next
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 8)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   free
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   printf
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   malloc
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   fake
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=0, entry_length=20, begin_offset=419, end_offset=424, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=20, entry_length=20, begin_offset=424, end_offset=427, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=40, entry_length=20, begin_offset=427, end_offset=487, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=60, entry_length=20, begin_offset=487, end_offset=488, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  a
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -36)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  b
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -40)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  x
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -44)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  d
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -32)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  e
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -28)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  f
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -24)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  g
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -20)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   pop
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=96, entry_length=20, begin_offset=321, end_offset=326, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=116, entry_length=20, begin_offset=326, end_offset=329, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=136, entry_length=20, begin_offset=329, end_offset=418, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=156, entry_length=20, begin_offset=418, end_offset=419, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  stk_ptr
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -56)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  int1
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -44)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  int2
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -40)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  number
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -36)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  stk
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -32)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  tmp
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -24)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   dummy
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=192, entry_length=20, begin_offset=101, end_offset=106, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=212, entry_length=20, begin_offset=106, end_offset=109, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=232, entry_length=20, begin_offset=109, end_offset=320, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=252, entry_length=20, begin_offset=320, end_offset=321, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  a_int
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -148)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  b_float
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -152)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  c_double
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -160)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  char_pointer
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -168)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  e_int
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -132)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  f_float
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -128)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  g_double
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -120)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  x1
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  x2
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  x3
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  x4
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  x5
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  x6
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -124)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  int_arr
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -112)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  k
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -136)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   push
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=288, entry_length=20, begin_offset=0, end_offset=5, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=308, entry_length=20, begin_offset=5, end_offset=8, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=328, entry_length=20, begin_offset=8, end_offset=100, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=348, entry_length=20, begin_offset=100, end_offset=101, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  number
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -52)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  stk_ptr
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -64)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  pop
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -40)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  ming
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -36)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  stk
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -32)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  tmp
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -24)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #
#   Found a compile unit at offset 990, length 1196
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_structure_type  [ STRUCT ]  S_stack
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  number
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 0)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  next
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 8)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_structure_type  [ STRUCT ]  Student
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  roll_no
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 0)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  name
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 4)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  branch
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 34)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  batch
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 76)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_enumeration_type  [ STRUCT ]  types_tag
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_union_type  [ STRUCT ]  value_tag
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  c
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  i
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  f
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_structure_type  [ STRUCT ]  store_tag
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  type
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 0)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  value
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 4)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  mem_int
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 8)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_member  :::  mem_float
#    DIE DW_TAG_member. attr DW_AT_data_member_location.
# DW_TAG_member
# ######      (DW_OP_plus_uconst: 12)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  test_global
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_addr: 4010)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   pop
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   dummy
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   fake
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   add
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   push
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   exit
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   printf
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   main
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=384, entry_length=20, begin_offset=613, end_offset=618, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=404, entry_length=20, begin_offset=618, end_offset=621, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=424, entry_length=20, begin_offset=621, end_offset=1151, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=444, entry_length=20, begin_offset=1151, end_offset=1152, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  stk
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -72)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  temp
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -96)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  fake_param1
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -92)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  fake_param2
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -88)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  fake_result
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -84)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  dummy_str
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -34)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  dummy_out
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -80)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  store
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -64)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  enum_test
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -76)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  union_test
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -100)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   printValue
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=480, entry_length=20, begin_offset=442, end_offset=447, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=500, entry_length=20, begin_offset=447, end_offset=450, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=520, entry_length=20, begin_offset=450, end_offset=612, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=540, entry_length=20, begin_offset=612, end_offset=613, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  o
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -24)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   test_array
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=576, entry_length=20, begin_offset=292, end_offset=297, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=596, entry_length=20, begin_offset=297, end_offset=300, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=616, entry_length=20, begin_offset=300, end_offset=441, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=636, entry_length=20, begin_offset=441, end_offset=442, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  intArr
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -64)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  floatArray
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -48)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   test_structs
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=672, entry_length=20, begin_offset=0, end_offset=5, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=692, entry_length=20, begin_offset=5, end_offset=8, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=712, entry_length=20, begin_offset=8, end_offset=291, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=732, entry_length=20, begin_offset=291, end_offset=292, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  s1
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -112)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  ptr
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -120)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #  #
#   Found a compile unit at offset 2190, length 484
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   substractf
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=768, entry_length=20, begin_offset=170, end_offset=175, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=788, entry_length=20, begin_offset=175, end_offset=178, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=808, entry_length=20, begin_offset=178, end_offset=199, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=828, entry_length=20, begin_offset=199, end_offset=200, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  a
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -20)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  b
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -24)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   substract
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=864, entry_length=20, begin_offset=148, end_offset=153, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=884, entry_length=20, begin_offset=153, end_offset=156, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=904, entry_length=20, begin_offset=156, end_offset=169, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=924, entry_length=20, begin_offset=169, end_offset=170, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  a
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -20)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  b
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -24)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   addf
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=960, entry_length=20, begin_offset=118, end_offset=123, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=980, entry_length=20, begin_offset=123, end_offset=126, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=1000, entry_length=20, begin_offset=126, end_offset=147, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=1020, entry_length=20, begin_offset=147, end_offset=148, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  a
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -20)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  b
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -24)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# FUNCTION NAME >>>>>>>>>   add
#    DIE DW_TAG_subprogram. attr DW_AT_frame_base.
# DW_TAG_subprogram
# $$$$$           LocationEntry(entry_offset=1056, entry_length=20, begin_offset=0, end_offset=5, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
#       LocationEntry(entry_offset=1076, entry_length=20, begin_offset=5, end_offset=8, loc_expr=[119, 16], is_absolute=False) <<(DW_OP_breg7 (rsp): 16)>>
#       LocationEntry(entry_offset=1096, entry_length=20, begin_offset=8, end_offset=117, loc_expr=[118, 16], is_absolute=False) <<(DW_OP_breg6 (rbp): 16)>>
#       LocationEntry(entry_offset=1116, entry_length=20, begin_offset=117, end_offset=118, loc_expr=[119, 8], is_absolute=False) <<(DW_OP_breg7 (rsp): 8)>>
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  a
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -36)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_formal_parameter  :::  b
#    DIE DW_TAG_formal_parameter. attr DW_AT_location.
# DW_TAG_formal_parameter
# ######      (DW_OP_fbreg: -40)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  ran
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -28)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  fran
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -24)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  i
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -32)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   DW_TAG_variable  :::  fran
#    DIE DW_TAG_variable. attr DW_AT_location.
# DW_TAG_variable
# ######      (DW_OP_fbreg: -20)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
