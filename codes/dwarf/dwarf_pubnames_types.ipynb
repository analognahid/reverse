# %%
#-------------------------------------------------------------------------------
# elftools example: dwarf_pubnames_types.py
#
# Dump the contents of .debug_pubnames and .debug_pubtypes sections from the
# ELF file.
#
# Note: sample_exe64.elf doesn't have a .debug_pubtypes section.
#
# Vijay Ramasami (rvijayc@gmail.com)
# This code is in the public domain
#-------------------------------------------------------------------------------
from __future__ import print_function
import sys

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.
sys.path[0:0] = ['.', '..']

from elftools.elf.elffile import ELFFile
# from elftools.common.utils import bytes2str

def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        # get_dwarf_info returns a DWARFInfo context object, which is the
        # starting point for all DWARF-based processing in pyelftools.
        dwarfinfo = elffile.get_dwarf_info()

        # get .debug_pubtypes section.
        pubnames = dwarfinfo.get_pubnames()
        if pubnames is None:
            print('ERROR: No .debug_pubnames section found in ELF.')
        else:
            print('%d entries found in .debug_pubnames' % len(pubnames))

            print('Trying pubnames example ...')
            for name, entry in pubnames.items():
                print('%s: cu_ofs = %d, die_ofs = %d' %
                        (name, entry.cu_ofs, entry.die_ofs))

                # get the actual CU/DIE that has this information.
                print('Fetching the actual die for %s ...' % name)
                for cu in dwarfinfo.iter_CUs():
                    if cu.cu_offset == entry.cu_ofs:
                        for die in cu.iter_DIEs():
                            if die.offset == entry.die_ofs:
                                print('Die Name: %s' %
                                        (die.attributes['DW_AT_name'].value))

            # dump all entries in .debug_pubnames section.
            print('Dumping .debug_pubnames table ...')
            print('-' * 66)
            print('%50s%8s%8s' % ('Symbol', 'CU_OFS', 'DIE_OFS'))
            print('-' * 66)
            for (name, entry) in pubnames.items():
                print('%50s%8d%8d' % (name, entry.cu_ofs, entry.die_ofs))
            print('-' * 66)

        # get .debug_pubtypes section.
        pubtypes = dwarfinfo.get_pubtypes()
        if pubtypes is None:
            print('ERROR: No .debug_pubtypes section found in ELF')
        else:
            print('%d entries found in .debug_pubtypes' % len(pubtypes))

            for name, entry in pubtypes.items():
                print('%s: cu_ofs = %d, die_ofs = %d' %
                        (name, entry.cu_ofs, entry.die_ofs))

                # get the actual CU/DIE that has this information.
                print('Fetching the actual die for %s ...' % name)
                for cu in dwarfinfo.iter_CUs():
                    if cu.cu_offset == entry.cu_ofs:
                        for die in cu.iter_DIEs():
                            if die.offset == entry.die_ofs:
                                print('Die Name: %s' %
                                        (die.attributes['DW_AT_name'].value))
                                die_info_rec(die)
                                
            print("#########################################################\n"*5)

            # dump all entries in .debug_pubtypes section.
            print('Dumping .debug_pubtypes table ...')
            print('-' * 66)
            print('%50s%8s%8s' % ('Symbol', 'CU_OFS', 'DIE_OFS'))
            print('-' * 66)
            for (name, entry) in pubtypes.items():
                print('%50s%8d%8d' % (name, entry.cu_ofs, entry.die_ofs))
            print('-' * 66)


def die_info_rec(die, indent_level='    '):
    """ A recursive function for showing information about a DIE and its
        children.
    """
    print(indent_level + 'DIE tag=%s, attrs=' % die.tag)
    for name, val in die.attributes.items():
        print(indent_level + '  %s = %s' % (name, val))
    child_indent = indent_level + '  '
    for child in die.iter_children():
        die_info_rec(child, child_indent)




filePath = './../../binaries/c_many/stacktest'
process_file(filePath)
# Out:
# Processing file: ./../../binaries/c_many/stacktest
# 10 entries found in .debug_pubnames
# Trying pubnames example ...
# free: cu_ofs = 0, die_ofs = 192
# Fetching the actual die for free ...
# Die Name: b'free'
# malloc: cu_ofs = 0, die_ofs = 211
# Fetching the actual die for malloc ...
# Die Name: b'malloc'
# pop: cu_ofs = 420, die_ofs = 632
# Fetching the actual die for pop ...
# Die Name: b'pop'
# push: cu_ofs = 420, die_ofs = 689
# Fetching the actual die for push ...
# Die Name: b'push'
# printf: cu_ofs = 420, die_ofs = 603
# Fetching the actual die for printf ...
# Die Name: b'printf'
# add: cu_ofs = 774, die_ofs = 1078
# Fetching the actual die for add ...
# Die Name: b'add'
# main: cu_ofs = 420, die_ofs = 712
# Fetching the actual die for main ...
# Die Name: b'main'
# substractf: cu_ofs = 774, die_ofs = 897
# Fetching the actual die for substractf ...
# Die Name: b'substractf'
# substract: cu_ofs = 774, die_ofs = 962
# Fetching the actual die for substract ...
# Die Name: b'substract'
# addf: cu_ofs = 774, die_ofs = 1020
# Fetching the actual die for addf ...
# Die Name: b'addf'
# Dumping .debug_pubnames table ...
# ------------------------------------------------------------------
#                                             Symbol  CU_OFS DIE_OFS
# ------------------------------------------------------------------
#                                               free       0     192
#                                             malloc       0     211
#                                                pop     420     632
#                                               push     420     689
#                                             printf     420     603
#                                                add     774    1078
#                                               main     420     712
#                                         substractf     774     897
#                                          substract     774     962
#                                               addf     774    1020
# ------------------------------------------------------------------
# 15 entries found in .debug_pubtypes
# long unsigned int: cu_ofs = 774, die_ofs = 820
# Fetching the actual die for long unsigned int ...
# Die Name: b'long unsigned int'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=821)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=822)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long unsigned int', raw_value=53, offset=823)
# size_t: cu_ofs = 0, die_ofs = 46
# Fetching the actual die for size_t ...
# Die Name: b'size_t'
#     DIE tag=DW_TAG_typedef, attrs=
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'size_t', raw_value=14, offset=47)
#       DW_AT_decl_file = AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=3, raw_value=3, offset=51)
#       DW_AT_decl_line = AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=209, raw_value=209, offset=52)
#       DW_AT_decl_column = AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=23, raw_value=23, offset=53)
#       DW_AT_type = AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=58, raw_value=58, offset=54)
# unsigned int: cu_ofs = 774, die_ofs = 827
# Fetching the actual die for unsigned int ...
# Die Name: b'unsigned int'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=828)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=829)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned int', raw_value=58, offset=830)
# unsigned char: cu_ofs = 774, die_ofs = 834
# Fetching the actual die for unsigned char ...
# Die Name: b'unsigned char'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=835)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=8, raw_value=8, offset=836)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned char', raw_value=21, offset=837)
# short unsigned int: cu_ofs = 774, die_ofs = 841
# Fetching the actual die for short unsigned int ...
# Die Name: b'short unsigned int'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=842)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=843)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short unsigned int', raw_value=244, offset=844)
# signed char: cu_ofs = 774, die_ofs = 848
# Fetching the actual die for signed char ...
# Die Name: b'signed char'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=849)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=850)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'signed char', raw_value=23, offset=851)
# short int: cu_ofs = 774, die_ofs = 855
# Fetching the actual die for short int ...
# Die Name: b'short int'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=856)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=857)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short int', raw_value=268, offset=858)
# int: cu_ofs = 774, die_ofs = 862
# Fetching the actual die for int ...
# Die Name: b'int'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=863)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=864)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=865)
# long int: cu_ofs = 774, die_ofs = 869
# Fetching the actual die for long int ...
# Die Name: b'long int'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=870)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=871)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long int', raw_value=5, offset=872)
# char: cu_ofs = 774, die_ofs = 876
# Fetching the actual die for char ...
# Die Name: b'char'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=877)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=878)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'char', raw_value=30, offset=879)
# long long int: cu_ofs = 774, die_ofs = 883
# Fetching the actual die for long long int ...
# Die Name: b'long long int'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=884)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=885)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long long int', raw_value=0, offset=886)
# long long unsigned int: cu_ofs = 774, die_ofs = 890
# Fetching the actual die for long long unsigned int ...
# Die Name: b'long long unsigned int'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=891)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=892)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long long unsigned int', raw_value=48, offset=893)
# S_stack: cu_ofs = 420, die_ofs = 548
# Fetching the actual die for S_stack ...
# Die Name: b'S_stack'
#     DIE tag=DW_TAG_structure_type, attrs=
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'S_stack', raw_value=40, offset=549)
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=16, raw_value=16, offset=553)
#       DW_AT_decl_file = AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=554)
#       DW_AT_decl_line = AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=1, raw_value=1, offset=555)
#       DW_AT_decl_column = AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=16, raw_value=16, offset=556)
#       DW_AT_sibling = AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=166, raw_value=166, offset=557)
#       DIE tag=DW_TAG_member, attrs=
#         DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'number', raw_value=71, offset=562)
#         DW_AT_decl_file = AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=2, raw_value=2, offset=566)
#         DW_AT_decl_line = AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=2, raw_value=2, offset=566)
#         DW_AT_decl_column = AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=9, raw_value=9, offset=567)
#         DW_AT_type = AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=568)
#         DW_AT_data_member_location = AttributeValue(name='DW_AT_data_member_location', form='DW_FORM_data1', value=0, raw_value=0, offset=572)
#       DIE tag=DW_TAG_member, attrs=
#         DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'next', raw_value=285, offset=574)
#         DW_AT_decl_file = AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=2, raw_value=2, offset=578)
#         DW_AT_decl_line = AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=3, raw_value=3, offset=578)
#         DW_AT_decl_column = AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=21, raw_value=21, offset=579)
#         DW_AT_type = AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=166, raw_value=166, offset=580)
#         DW_AT_data_member_location = AttributeValue(name='DW_AT_data_member_location', form='DW_FORM_data1', value=8, raw_value=8, offset=584)
# stack: cu_ofs = 420, die_ofs = 591
# Fetching the actual die for stack ...
# Die Name: b'stack'
#     DIE tag=DW_TAG_typedef, attrs=
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'stack', raw_value=42, offset=592)
#       DW_AT_decl_file = AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=596)
#       DW_AT_decl_line = AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=4, raw_value=4, offset=597)
#       DW_AT_decl_column = AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=3, raw_value=3, offset=598)
#       DW_AT_type = AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=128, raw_value=128, offset=599)
# float: cu_ofs = 774, die_ofs = 955
# Fetching the actual die for float ...
# Die Name: b'float'
#     DIE tag=DW_TAG_base_type, attrs=
#       DW_AT_byte_size = AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=956)
#       DW_AT_encoding = AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=4, raw_value=4, offset=957)
#       DW_AT_name = AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'float', raw_value=323, offset=958)
# #########################################################
# #########################################################
# #########################################################
# #########################################################
# #########################################################
#
# Dumping .debug_pubtypes table ...
# ------------------------------------------------------------------
#                                             Symbol  CU_OFS DIE_OFS
# ------------------------------------------------------------------
#                                  long unsigned int     774     820
#                                             size_t       0      46
#                                       unsigned int     774     827
#                                      unsigned char     774     834
#                                 short unsigned int     774     841
#                                        signed char     774     848
#                                          short int     774     855
#                                                int     774     862
#                                           long int     774     869
#                                               char     774     876
#                                      long long int     774     883
#                             long long unsigned int     774     890
#                                            S_stack     420     548
#                                              stack     420     591
#                                              float     774     955
# ------------------------------------------------------------------
