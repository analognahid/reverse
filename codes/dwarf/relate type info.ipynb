# %%
#!/usr/bin/env python3

import sys,os
from elftools.elf.elffile import ELFFile
from elftools.elf.segments import Segment



filePath = './../../binaries/c_many/stacktest'



with open(filePath, 'rb') as f:
    elffile =  ELFFile(f)
    
    for segment in elffile.iter_segments():
        if segment.header.p_filesz != segment.header.p_memsz:
            seg_head = segment.header
            print(f"Type: {seg_head.p_type}\nOffset: {hex(seg_head.p_offset)}\nSize in file:{hex(seg_head.p_filesz)}\nSize in memory:{hex(seg_head.p_memsz)}")
            
    dwarfinfo = elffile.get_dwarf_info()
    for CU in dwarfinfo.iter_CUs():
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))
        

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        # line_program = dwarfinfo.line_program_for_CU(CU)
        # if line_program is None:
        #     print('  DWARF info is missing a line program for this CU')
        #     continue
# Out:
# Type: PT_LOAD
# Offset: 0x2da0
# Size in file:0x270
# Size in memory:0x278
#   Found a compile unit at offset 0, length 416
#   Found a compile unit at offset 420, length 350
#   Found a compile unit at offset 774, length 446

# %%
def _format_hex( addr, fieldsize=None, fullhex=False, lead0x=True):
    """ Format an address into a hexadecimal string.
        fieldsize:
            Size of the hexadecimal field (with leading zeros to fit the
            address into. For example with fieldsize=8, the format will
            be %08x
            If None, the minimal required field size will be used.
        fullhex:
            If True, override fieldsize to set it to the maximal size
            needed for the elfclass
        lead0x:
            If True, leading 0x is added
    """
    s = '0x' if lead0x else ''
    if fullhex:
        fieldsize = 8 if elffile.elfclass == 32 else 16
    if fieldsize is None:
        field = '%x'
    else:
        field = '%' + '0%sx' % fieldsize
    return s + field % addr

from elftools.elf.descriptions import (
    describe_ei_class, describe_ei_data, describe_ei_version,
    describe_ei_osabi, describe_e_type, describe_e_machine,
    describe_e_version_numeric, describe_p_type, describe_p_flags,
    describe_sh_type, describe_sh_flags,
    describe_symbol_type, describe_symbol_bind, describe_symbol_visibility,
    describe_symbol_shndx, describe_reloc_type, describe_dyn_tag,
    )

# %%
with open(filePath, 'rb') as f:
    elffile =  ELFFile(f)
    for nsec, section in enumerate(elffile.iter_sections()):
                print('  [%2u] %-17.17s %-15.15s ' % (
                    nsec, (section.name), describe_sh_type(section['sh_type'])))

                # if elffile.elfclass == 32:
                #     print('%s %s %s %s %3s %2s %3s %2s' % (
                #         _format_hex(section['sh_addr'], fieldsize=8, lead0x=False),
                #         _format_hex(section['sh_offset'], fieldsize=6, lead0x=False),
                #         _format_hex(section['sh_size'], fieldsize=6, lead0x=False),
                #         _format_hex(section['sh_entsize'], fieldsize=2, lead0x=False),
                #         describe_sh_flags(section['sh_flags']),
                #         section['sh_link'], section['sh_info'],
                #         section['sh_addralign']))
                # else: # 64
                print(' sh_addr: %s  sh_offset: %s' % (
                    _format_hex(section['sh_addr'], fullhex=True, lead0x=False),
                    _format_hex(section['sh_offset'],
                        fieldsize=16 if section['sh_offset'] > 0xffffffff else 8,
                        lead0x=False)))
                print('       sh_size: %s  sh_entsize: %s sh_flags:%3s      sh_link:%2s   sh_info:%3s     sh_addralign:%s' % (
                    _format_hex(section['sh_size'], fullhex=True, lead0x=False),
                    _format_hex(section['sh_entsize'], fullhex=True, lead0x=False),
                    describe_sh_flags(section['sh_flags']),
                    section['sh_link'], section['sh_info'],
                    section['sh_addralign']))
# Out:
#   [ 0]                   NULL
#  sh_addr: 0000000000000000  sh_offset: 00000000
#        sh_size: 0000000000000000  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:0
#   [ 1] .interp           PROGBITS
#  sh_addr: 0000000000000318  sh_offset: 00000318
#        sh_size: 000000000000001c  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:1
#   [ 2] .note.gnu.propert NOTE
#  sh_addr: 0000000000000338  sh_offset: 00000338
#        sh_size: 0000000000000030  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:8
#   [ 3] .note.gnu.build-i NOTE
#  sh_addr: 0000000000000368  sh_offset: 00000368
#        sh_size: 0000000000000024  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:4
#   [ 4] .note.ABI-tag     NOTE
#  sh_addr: 000000000000038c  sh_offset: 0000038c
#        sh_size: 0000000000000020  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:4
#   [ 5] .gnu.hash         GNU_HASH
#  sh_addr: 00000000000003b0  sh_offset: 000003b0
#        sh_size: 0000000000000024  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 6   sh_info:  0     sh_addralign:8
#   [ 6] .dynsym           DYNSYM
#  sh_addr: 00000000000003d8  sh_offset: 000003d8
#        sh_size: 00000000000000f0  sh_entsize: 0000000000000018 sh_flags:  A      sh_link: 7   sh_info:  1     sh_addralign:8
#   [ 7] .dynstr           STRTAB
#  sh_addr: 00000000000004c8  sh_offset: 000004c8
#        sh_size: 00000000000000b6  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:1
#   [ 8] .gnu.version      VERSYM
#  sh_addr: 000000000000057e  sh_offset: 0000057e
#        sh_size: 0000000000000014  sh_entsize: 0000000000000002 sh_flags:  A      sh_link: 6   sh_info:  0     sh_addralign:2
#   [ 9] .gnu.version_r    VERNEED
#  sh_addr: 0000000000000598  sh_offset: 00000598
#        sh_size: 0000000000000040  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 7   sh_info:  1     sh_addralign:8
#   [10] .rela.dyn         RELA
#  sh_addr: 00000000000005d8  sh_offset: 000005d8
#        sh_size: 00000000000000c0  sh_entsize: 0000000000000018 sh_flags:  A      sh_link: 6   sh_info:  0     sh_addralign:8
#   [11] .rela.plt         RELA
#  sh_addr: 0000000000000698  sh_offset: 00000698
#        sh_size: 0000000000000060  sh_entsize: 0000000000000018 sh_flags: AI      sh_link: 6   sh_info: 24     sh_addralign:8
#   [12] .init             PROGBITS
#  sh_addr: 0000000000001000  sh_offset: 00001000
#        sh_size: 000000000000001b  sh_entsize: 0000000000000000 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:4
#   [13] .plt              PROGBITS
#  sh_addr: 0000000000001020  sh_offset: 00001020
#        sh_size: 0000000000000050  sh_entsize: 0000000000000010 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:16
#   [14] .plt.got          PROGBITS
#  sh_addr: 0000000000001070  sh_offset: 00001070
#        sh_size: 0000000000000010  sh_entsize: 0000000000000010 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:16
#   [15] .plt.sec          PROGBITS
#  sh_addr: 0000000000001080  sh_offset: 00001080
#        sh_size: 0000000000000040  sh_entsize: 0000000000000010 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:16
#   [16] .text             PROGBITS
#  sh_addr: 00000000000010c0  sh_offset: 000010c0
#        sh_size: 000000000000039a  sh_entsize: 0000000000000000 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:16
#   [17] .fini             PROGBITS
#  sh_addr: 000000000000145c  sh_offset: 0000145c
#        sh_size: 000000000000000d  sh_entsize: 0000000000000000 sh_flags: AX      sh_link: 0   sh_info:  0     sh_addralign:4
#   [18] .rodata           PROGBITS
#  sh_addr: 0000000000002000  sh_offset: 00002000
#        sh_size: 0000000000000010  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:4
#   [19] .eh_frame_hdr     PROGBITS
#  sh_addr: 0000000000002010  sh_offset: 00002010
#        sh_size: 0000000000000064  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:4
#   [20] .eh_frame         PROGBITS
#  sh_addr: 0000000000002078  sh_offset: 00002078
#        sh_size: 000000000000016c  sh_entsize: 0000000000000000 sh_flags:  A      sh_link: 0   sh_info:  0     sh_addralign:8
#   [21] .init_array       INIT_ARRAY
#  sh_addr: 0000000000003da0  sh_offset: 00002da0
#        sh_size: 0000000000000008  sh_entsize: 0000000000000008 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:8
#   [22] .fini_array       FINI_ARRAY
#  sh_addr: 0000000000003da8  sh_offset: 00002da8
#        sh_size: 0000000000000008  sh_entsize: 0000000000000008 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:8
#   [23] .dynamic          DYNAMIC
#  sh_addr: 0000000000003db0  sh_offset: 00002db0
#        sh_size: 00000000000001f0  sh_entsize: 0000000000000010 sh_flags: WA      sh_link: 7   sh_info:  0     sh_addralign:8
#   [24] .got              PROGBITS
#  sh_addr: 0000000000003fa0  sh_offset: 00002fa0
#        sh_size: 0000000000000060  sh_entsize: 0000000000000008 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:8
#   [25] .data             PROGBITS
#  sh_addr: 0000000000004000  sh_offset: 00003000
#        sh_size: 0000000000000010  sh_entsize: 0000000000000000 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:8
#   [26] .bss              NOBITS
#  sh_addr: 0000000000004010  sh_offset: 00003010
#        sh_size: 0000000000000008  sh_entsize: 0000000000000000 sh_flags: WA      sh_link: 0   sh_info:  0     sh_addralign:1
#   [27] .comment          PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003010
#        sh_size: 000000000000002b  sh_entsize: 0000000000000001 sh_flags: MS      sh_link: 0   sh_info:  0     sh_addralign:1
#   [28] .debug_aranges    PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 0000303b
#        sh_size: 0000000000000090  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [29] .debug_pubnames   PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 000030cb
#        sh_size: 00000000000000b6  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [30] .debug_info       PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003181
#        sh_size: 00000000000004c8  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [31] .debug_abbrev     PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003649
#        sh_size: 00000000000002ae  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [32] .debug_line       PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 000038f7
#        sh_size: 00000000000001b0  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [33] .debug_str        PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003aa7
#        sh_size: 0000000000000158  sh_entsize: 0000000000000001 sh_flags: MS      sh_link: 0   sh_info:  0     sh_addralign:1
#   [34] .debug_pubtypes   PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003bff
#        sh_size: 00000000000002a2  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [35] .debug_line_str   PROGBITS
#  sh_addr: 0000000000000000  sh_offset: 00003ea1
#        sh_size: 00000000000000a3  sh_entsize: 0000000000000001 sh_flags: MS      sh_link: 0   sh_info:  0     sh_addralign:1
#   [36] .symtab           SYMTAB
#  sh_addr: 0000000000000000  sh_offset: 00003f48
#        sh_size: 0000000000000468  sh_entsize: 0000000000000018 sh_flags:         sh_link:37   sh_info: 20     sh_addralign:8
#   [37] .strtab           STRTAB
#  sh_addr: 0000000000000000  sh_offset: 000043b0
#        sh_size: 0000000000000256  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1
#   [38] .shstrtab         STRTAB
#  sh_addr: 0000000000000000  sh_offset: 00004606
#        sh_size: 000000000000018a  sh_entsize: 0000000000000000 sh_flags:         sh_link: 0   sh_info:  0     sh_addralign:1

# %%
from capstone import *

address_inst = {}

with open(filePath, 'rb') as f:
    elf = ELFFile(f)
    code = elf.get_section_by_name('.text')
    ops = code.data()
    print('code data size: ',code.data_size)
    addr = code['sh_addr']
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    for i in md.disasm(ops, addr):        
        print(f'0x{i.address:x}:\t{i.mnemonic}\t{i.op_str}')
        address_inst[hex(i.address)] = i
# Out:
# code data size:  922
# 0x10c0:	endbr64
# 0x10c4:	xor	ebp, ebp
# 0x10c6:	mov	r9, rdx
# 0x10c9:	pop	rsi
# 0x10ca:	mov	rdx, rsp
# 0x10cd:	and	rsp, 0xfffffffffffffff0
# 0x10d1:	push	rax
# 0x10d2:	push	rsp
# 0x10d3:	xor	r8d, r8d
# 0x10d6:	xor	ecx, ecx
# 0x10d8:	lea	rdi, [rip + 0x175]
# 0x10df:	call	qword ptr [rip + 0x2ef3]
# 0x10e5:	hlt
# 0x10e6:	nop	word ptr cs:[rax + rax]
# 0x10f0:	lea	rdi, [rip + 0x2f19]
# 0x10f7:	lea	rax, [rip + 0x2f12]
# 0x10fe:	cmp	rax, rdi
# 0x1101:	je	0x1118
# 0x1103:	mov	rax, qword ptr [rip + 0x2ed6]
# 0x110a:	test	rax, rax
# 0x110d:	je	0x1118
# 0x110f:	jmp	rax
# 0x1111:	nop	dword ptr [rax]
# 0x1118:	ret
# 0x1119:	nop	dword ptr [rax]
# 0x1120:	lea	rdi, [rip + 0x2ee9]
# 0x1127:	lea	rsi, [rip + 0x2ee2]
# 0x112e:	sub	rsi, rdi
# 0x1131:	mov	rax, rsi
# 0x1134:	shr	rsi, 0x3f
# 0x1138:	sar	rax, 3
# 0x113c:	add	rsi, rax
# 0x113f:	sar	rsi, 1
# 0x1142:	je	0x1158
# 0x1144:	mov	rax, qword ptr [rip + 0x2ea5]
# 0x114b:	test	rax, rax
# 0x114e:	je	0x1158
# 0x1150:	jmp	rax
# 0x1152:	nop	word ptr [rax + rax]
# 0x1158:	ret
# 0x1159:	nop	dword ptr [rax]
# 0x1160:	endbr64
# 0x1164:	cmp	byte ptr [rip + 0x2ea5], 0
# 0x116b:	jne	0x1198
# 0x116d:	push	rbp
# 0x116e:	cmp	qword ptr [rip + 0x2e82], 0
# 0x1176:	mov	rbp, rsp
# 0x1179:	je	0x1187
# 0x117b:	mov	rdi, qword ptr [rip + 0x2e86]
# 0x1182:	call	0x1070
# 0x1187:	call	0x10f0
# 0x118c:	mov	byte ptr [rip + 0x2e7d], 1
# 0x1193:	pop	rbp
# 0x1194:	ret
# 0x1195:	nop	dword ptr [rax]
# 0x1198:	ret
# 0x1199:	nop	dword ptr [rax]
# 0x11a0:	endbr64
# 0x11a4:	jmp	0x1120
# 0x11a9:	endbr64
# 0x11ad:	push	rbp
# 0x11ae:	mov	rbp, rsp
# 0x11b1:	sub	rsp, 0x20
# 0x11b5:	mov	dword ptr [rbp - 0x14], edi
# 0x11b8:	mov	qword ptr [rbp - 0x20], rsi
# 0x11bc:	mov	rax, qword ptr [rbp - 0x20]
# 0x11c0:	mov	rax, qword ptr [rax]
# 0x11c3:	mov	qword ptr [rbp - 0x10], rax
# 0x11c7:	mov	edi, 0x10
# 0x11cc:	call	0x10b0
# 0x11d1:	mov	qword ptr [rbp - 8], rax
# 0x11d5:	mov	rax, qword ptr [rbp - 8]
# 0x11d9:	mov	edx, dword ptr [rbp - 0x14]
# 0x11dc:	mov	dword ptr [rax], edx
# 0x11de:	mov	rax, qword ptr [rbp - 8]
# 0x11e2:	mov	rdx, qword ptr [rbp - 0x10]
# 0x11e6:	mov	qword ptr [rax + 8], rdx
# 0x11ea:	mov	rax, qword ptr [rbp - 8]
# 0x11ee:	mov	qword ptr [rbp - 0x10], rax
# 0x11f2:	mov	rax, qword ptr [rbp - 0x20]
# 0x11f6:	mov	rdx, qword ptr [rbp - 0x10]
# 0x11fa:	mov	qword ptr [rax], rdx
# 0x11fd:	nop
# 0x11fe:	leave
# 0x11ff:	ret
# 0x1200:	endbr64
# 0x1204:	push	rbp
# 0x1205:	mov	rbp, rsp
# 0x1208:	sub	rsp, 0x30
# 0x120c:	mov	qword ptr [rbp - 0x28], rdi
# 0x1210:	mov	rax, qword ptr [rbp - 0x28]
# 0x1214:	mov	rax, qword ptr [rax]
# 0x1217:	mov	qword ptr [rbp - 0x10], rax
# 0x121b:	mov	rax, qword ptr [rbp - 0x10]
# 0x121f:	mov	qword ptr [rbp - 8], rax
# 0x1223:	mov	rax, qword ptr [rbp - 8]
# 0x1227:	mov	eax, dword ptr [rax]
# 0x1229:	mov	dword ptr [rbp - 0x14], eax
# 0x122c:	mov	rax, qword ptr [rbp - 0x10]
# 0x1230:	mov	rax, qword ptr [rax + 8]
# 0x1234:	mov	qword ptr [rbp - 0x10], rax
# 0x1238:	mov	rax, qword ptr [rbp - 8]
# 0x123c:	mov	rdi, rax
# 0x123f:	call	0x1080
# 0x1244:	mov	rax, qword ptr [rbp - 0x28]
# 0x1248:	mov	rdx, qword ptr [rbp - 0x10]
# 0x124c:	mov	qword ptr [rax], rdx
# 0x124f:	mov	eax, dword ptr [rbp - 0x14]
# 0x1252:	leave
# 0x1253:	ret
# 0x1254:	endbr64
# 0x1258:	push	rbp
# 0x1259:	mov	rbp, rsp
# 0x125c:	sub	rsp, 0x20
# 0x1260:	mov	rax, qword ptr fs:[0x28]
# 0x1269:	mov	qword ptr [rbp - 8], rax
# 0x126d:	xor	eax, eax
# 0x126f:	mov	qword ptr [rbp - 0x10], 0
# 0x1277:	lea	rax, [rbp - 0x10]
# 0x127b:	mov	rsi, rax
# 0x127e:	mov	edi, 7
# 0x1283:	call	0x11a9
# 0x1288:	mov	esi, 2
# 0x128d:	mov	edi, 1
# 0x1292:	call	0x1392
# 0x1297:	mov	dword ptr [rbp - 0x14], eax
# 0x129a:	lea	rdx, [rbp - 0x10]
# 0x129e:	mov	eax, dword ptr [rbp - 0x14]
# 0x12a1:	mov	rsi, rdx
# 0x12a4:	mov	edi, eax
# 0x12a6:	call	0x11a9
# 0x12ab:	lea	rax, [rbp - 0x10]
# 0x12af:	mov	rsi, rax
# 0x12b2:	mov	edi, 9
# 0x12b7:	call	0x11a9
# 0x12bc:	lea	rax, [rbp - 0x10]
# 0x12c0:	mov	rsi, rax
# 0x12c3:	mov	edi, 0xc
# 0x12c8:	call	0x11a9
# 0x12cd:	lea	rax, [rbp - 0x10]
# 0x12d1:	mov	rdi, rax
# 0x12d4:	call	0x1200
# 0x12d9:	mov	esi, eax
# 0x12db:	lea	rax, [rip + 0xd22]
# 0x12e2:	mov	rdi, rax
# 0x12e5:	mov	eax, 0
# 0x12ea:	call	0x10a0
# 0x12ef:	lea	rax, [rbp - 0x10]
# 0x12f3:	mov	rdi, rax
# 0x12f6:	call	0x1200
# 0x12fb:	mov	esi, eax
# 0x12fd:	lea	rax, [rip + 0xd00]
# 0x1304:	mov	rdi, rax
# 0x1307:	mov	eax, 0
# 0x130c:	call	0x10a0
# 0x1311:	lea	rax, [rbp - 0x10]
# 0x1315:	mov	rdi, rax
# 0x1318:	call	0x1200
# 0x131d:	mov	esi, eax
# 0x131f:	lea	rax, [rip + 0xcde]
# 0x1326:	mov	rdi, rax
# 0x1329:	mov	eax, 0
# 0x132e:	call	0x10a0
# 0x1333:	lea	rax, [rbp - 0x10]
# 0x1337:	mov	rdi, rax
# 0x133a:	call	0x1200
# 0x133f:	mov	esi, eax
# 0x1341:	lea	rax, [rip + 0xcbc]
# 0x1348:	mov	rdi, rax
# 0x134b:	mov	eax, 0
# 0x1350:	call	0x10a0
# 0x1355:	lea	rax, [rbp - 0x10]
# 0x1359:	mov	rdi, rax
# 0x135c:	call	0x1200
# 0x1361:	mov	esi, eax
# 0x1363:	lea	rax, [rip + 0xc9a]
# 0x136a:	mov	rdi, rax
# 0x136d:	mov	eax, 0
# 0x1372:	call	0x10a0
# 0x1377:	mov	eax, 0
# 0x137c:	mov	rdx, qword ptr [rbp - 8]
# 0x1380:	sub	rdx, qword ptr fs:[0x28]
# 0x1389:	je	0x1390
# 0x138b:	call	0x1090
# 0x1390:	leave
# 0x1391:	ret
# 0x1392:	endbr64
# 0x1396:	push	rbp
# 0x1397:	mov	rbp, rsp
# 0x139a:	mov	dword ptr [rbp - 0x14], edi
# 0x139d:	mov	dword ptr [rbp - 0x18], esi
# 0x13a0:	mov	dword ptr [rbp - 0xc], 0xa
# 0x13a7:	add	dword ptr [rbp - 0xc], 0xc
# 0x13ab:	mov	eax, dword ptr [rbp - 0xc]
# 0x13ae:	imul	eax, eax
# 0x13b1:	mov	dword ptr [rbp - 0xc], eax
# 0x13b4:	movss	xmm0, dword ptr [rip + 0xc4c]
# 0x13bc:	movss	dword ptr [rbp - 8], xmm0
# 0x13c1:	movss	xmm1, dword ptr [rbp - 8]
# 0x13c6:	movss	xmm0, dword ptr [rip + 0xc3e]
# 0x13ce:	addss	xmm0, xmm1
# 0x13d2:	movss	dword ptr [rbp - 8], xmm0
# 0x13d7:	mov	dword ptr [rbp - 0x10], 0
# 0x13de:	jmp	0x13ef
# 0x13e0:	mov	dword ptr [rbp - 4], 0
# 0x13e7:	add	dword ptr [rbp - 4], 2
# 0x13eb:	add	dword ptr [rbp - 0x10], 1
# 0x13ef:	cmp	dword ptr [rbp - 0x10], 9
# 0x13f3:	jle	0x13e0
# 0x13f5:	sub	dword ptr [rbp - 0xc], 0xa
# 0x13f9:	mov	edx, dword ptr [rbp - 0x14]
# 0x13fc:	mov	eax, dword ptr [rbp - 0x18]
# 0x13ff:	add	edx, eax
# 0x1401:	mov	eax, dword ptr [rbp - 0xc]
# 0x1404:	add	eax, edx
# 0x1406:	pop	rbp
# 0x1407:	ret
# 0x1408:	endbr64
# 0x140c:	push	rbp
# 0x140d:	mov	rbp, rsp
# 0x1410:	movss	dword ptr [rbp - 4], xmm0
# 0x1415:	movss	dword ptr [rbp - 8], xmm1
# 0x141a:	movss	xmm0, dword ptr [rbp - 4]
# 0x141f:	addss	xmm0, dword ptr [rbp - 8]
# 0x1424:	pop	rbp
# 0x1425:	ret
# 0x1426:	endbr64
# 0x142a:	push	rbp
# 0x142b:	mov	rbp, rsp
# 0x142e:	mov	dword ptr [rbp - 4], edi
# 0x1431:	mov	dword ptr [rbp - 8], esi
# 0x1434:	mov	eax, dword ptr [rbp - 4]
# 0x1437:	sub	eax, dword ptr [rbp - 8]
# 0x143a:	pop	rbp
# 0x143b:	ret
# 0x143c:	endbr64
# 0x1440:	push	rbp
# 0x1441:	mov	rbp, rsp
# 0x1444:	movss	dword ptr [rbp - 4], xmm0
# 0x1449:	movss	dword ptr [rbp - 8], xmm1
# 0x144e:	movss	xmm0, dword ptr [rbp - 4]
# 0x1453:	subss	xmm0, dword ptr [rbp - 8]
# 0x1458:	pop	rbp
# 0x1459:	ret

# %%
# address_inst

# %%
#-------------------------------------------------------------------------------
# elftools example: dwarf_lineprogram_filenames.py
#
# In the .debug_line section, the Dwarf line program generates a matrix
# of address-source references. This example demonstrates accessing the state
# of each line program entry to retrieve the underlying filenames.
#
# William Woodruff (william@yossarian.net)
# This code is in the public domain
#-------------------------------------------------------------------------------
from __future__ import print_function
from collections import defaultdict
import os
import sys
import posixpath

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.
# sys.path[0:0] = ['.', '..']

from elftools.elf.elffile import ELFFile






def line_entry_mapping(line_program):
    filename_map = defaultdict(int)

    # The line program, when decoded, returns a list of line program
    # entries. Each entry contains a state, which we'll use to build
    # a reverse mapping of filename -> #entries.
    lp_entries = line_program.get_entries()
    for lpe in lp_entries:
        # We skip LPEs that don't have an associated file.
        # This can happen if instructions in the compiled binary
        # don't correspond directly to any original source file.
        if not lpe.state or lpe.state.file == 0:
            continue
        filename = lpe_filename(line_program, lpe.state.file)
        filename_map[filename] += 1

    for filename, lpe_count in filename_map.items():
        print("    filename=%s -> %d entries" % (filename, lpe_count))
    return filename_map

def lpe_filename(line_program, file_index):


    lp_header = line_program.header
    file_entries = lp_header["file_entry"]
    
    # print('lp_header', lp_header, '\n\n')
    # print("file_entries", file_entries,'\n\n__________________________________________\n\n')

    # File and directory indices are 1-indexed.
    file_entry = file_entries[file_index - 1]
    dir_index = file_entry["dir_index"]

    # A dir_index of 0 indicates that no absolute directory was recorded during
    # compilation; return just the basename.
    if dir_index == 0:
        return file_entry.name.decode()

    directory = lp_header["include_directory"][dir_index - 1]
    return posixpath.join(directory, file_entry.name).decode()



addr_lineProgram ={}
addr_sourceFile = {}

with open(filePath, 'rb') as f:
    elffile = ELFFile(f)

    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
        exit(0)

    dwarfinfo = elffile.get_dwarf_info()
    for CU in dwarfinfo.iter_CUs():
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        line_program = dwarfinfo.line_program_for_CU(CU)
        if line_program is None:
            print('  DWARF info is missing a line program for this CU')
            continue

        # Print a reverse mapping of filename -> #entries
        filename_map = line_entry_mapping(line_program)
        for line_entry in line_program.get_entries():
            # print(line_entry)
            if line_entry.state!=None:
                addr_lineProgram[hex(line_entry.state.address)] = line_entry
                addr_sourceFile [hex(line_entry.state.address)] = filename_map
        print("_____________________________________________________")
# Out:
#   Found a compile unit at offset 0, length 416
#     filename=stack.c -> 18 entries
# _____________________________________________________
#   Found a compile unit at offset 420, length 350
#     filename=main.c -> 16 entries
# _____________________________________________________
#   Found a compile unit at offset 774, length 446
#     filename=calculate.c -> 26 entries
# _____________________________________________________

# %%
line_entry
# Out:
# LineProgramEntry(command=1, is_extended=True, args=[], state=<LineState 7f6af098a3a0:
#   address = 0x145a
#   file = 1
#   line = 28
#   column = 1
#   is_stmt = 0
#   basic_block = False
#   end_sequence = True
#   prologue_end = False
#   epilogue_begin = False
#   isa = 0
#   discriminator = 0>
# )

# %%
def getSource(sourceFileName, row, col):
    basePath = "/home/nahid/reverse/binaries/c_many/"
    sourceFilePath = os.path.join(basePath , sourceFileName)
    sourceFile = open(sourceFilePath, "r")
    fileContent = sourceFile.readlines()
    
    row_content =  fileContent[row-1]
    
    row_content = row_content[:(col-1)] + "@" +row_content[col:]
    
    # print(row_content)
    
    return row_content

# %%
with open(filePath, 'rb') as f:
    elffile = ELFFile(f)

    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
        exit(0)

    dwarfinfo = elffile.get_dwarf_info()
    arangesInfo = dwarfinfo.debug_aranges_sec
    pubTypes = dwarfinfo.debug_pubtypes_sec

# %%
# with open('stacktest.s', 'w') as outFile:
#     # outFile.write('file contents\n')
#     lastSource = ""
#     for address in address_inst:
#         inst = address_inst[address]
#         instrctionCode = (address+":\t"+ inst.mnemonic+" "+inst.op_str).ljust(45)
#         if address in addr_lineProgram:
#             line = addr_lineProgram[address]

#             srcFileName =list(addr_sourceFile[address].keys())[0] #TODO not single file always 
            
#             if srcFileName!=lastSource:
#                 outFile.write("\n"+ '#'*100+"\n"+ srcFileName.rjust(45) +'\n'+'#'*100+ "\n\n")
#                 lastSource = srcFileName
            
#             sourceCode = getSource(srcFileName,addr_lineProgram[address].state.line, addr_lineProgram[address].state.column)
#             if '\n' not in  sourceCode:
#                 sourceCode+=sourceCode+"\n"
#             outFile.write(instrctionCode+"#"+ sourceCode  )
#             print(instrctionCode+"#"+ sourceCode)
#         else:
#             outFile.write(instrctionCode+ '\n'  )
#             print(instrctionCode)

# %%
# address_inst = {}        add->instruction
# addr_lineProgram = {}    add-> lineInfo (row,col)
# addr_sourceFile =  {}    add-> sourceFIleName

# %%
def get_filename_lineinfo(die): # TODO find actual path, currently just returns filename
    lp_header = die.dwarfinfo.line_program_for_CU(die.cu).header
    files = lp_header["file_entry"]
    includes = lp_header["include_directory"]

    fileinfo = files[die.attributes["DW_AT_decl_file"].value - 1]
    filename = fileinfo.name.decode("utf-8")
    filedir = includes[fileinfo.dir_index - 1].decode("utf-8")

    path = os.path.join(filedir, filename)
    lineno = die.attributes["DW_AT_decl_line"].value
    columno = die.attributes["DW_AT_decl_column"].value
    return filename, path, lineno , columno

# %%
sourceLocation_die = {} #directory for DIE for C source line and col

import sys

# If pyelftools is not installed, the example can also run from the root or
# examples/ dir of the source distribution.

from elftools.elf.elffile import ELFFile
from elftools.dwarf.descriptions import (
    describe_DWARF_expr, set_global_machine_arch)
from elftools.dwarf.locationlists import (
    LocationEntry, LocationExpr, LocationParser)




def process_file(filename):
    print('Processing file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        if not elffile.has_dwarf_info():
            print('  file has no DWARF info')
            return

        # get_dwarf_info returns a DWARFInfo context object, which is the
        # starting point for all DWARF-based processing in pyelftools.
        dwarfinfo = elffile.get_dwarf_info()

        # The location lists are extracted by DWARFInfo from the .debug_loc
        # section, and returned here as a LocationLists object.
        location_lists = dwarfinfo.location_lists()

        # This is required for the descriptions module to correctly decode
        # register names contained in DWARF expressions.
        set_global_machine_arch(elffile.get_machine_arch())

        # Create a LocationParser object that parses the DIE attributes and
        # creates objects representing the actual location information.
        loc_parser = LocationParser(location_lists)

        for CU in dwarfinfo.iter_CUs():
            # DWARFInfo allows to iterate over the compile units contained in
            # the .debug_info section. CU is a CompileUnit object, with some
            # computed attributes (such as its offset in the section) and
            # a header which conforms to the DWARF standard. The access to
            # header elements is, as usual, via item-lookup.
            print('  Found a compile unit at offset %s, length %s' % (
                CU.cu_offset, CU['unit_length']))

            # A CU provides a simple API to iterate over all the DIEs in it.
            die_depth = 0
            for DIE in CU.iter_DIEs():
                # Go over all attributes of the DIE. Each attribute is an
                # AttributeValue object (from elftools.dwarf.die), which we
                # can examine.
                
                
                print("TREE DEPTH: ",die_depth)

                for attr in DIE.attributes.values():
                    
                    print(attr)
                    
                    if attr.name == "DW_AT_decl_file":
                        src_file, _ , line,column = get_filename_lineinfo(DIE)
                        dict_key = src_file +"#"+str(line) #TODO column should be in key
                        if dict_key in sourceLocation_die.keys():
                            sourceLocation_die [dict_key ][column] = DIE
                        else:
                            sourceLocation_die [dict_key ] = {}
                            sourceLocation_die [dict_key ][column] = DIE
                            
                            
                print("\n\n\n")
                
                if DIE.is_null(): #https://chromium.googlesource.com/chromiumos/third_party/pyelftools/+/25a77f7738d7fe824f2ed4d33a123136b9d8e88a/scripts/readelf.py
                    die_depth -= 1
                    continue
                if DIE.has_children:
                    die_depth += 1
                    
            # break



process_file(filePath)
# Out:
# Processing file: ./../../binaries/c_many/stacktest
#   Found a compile unit at offset 0, length 416
# TREE DEPTH:  0
# AttributeValue(name='DW_AT_producer', form='DW_FORM_strp', value=b'GNU C17 11.3.0 -mtune=generic -march=x86-64 -gdwarf -gpubnames -fasynchronous-unwind-tables -fstack-protector-strong -fstack-clash-protection -fcf-protection', raw_value=86, offset=13)
# AttributeValue(name='DW_AT_language', form='DW_FORM_data1', value=29, raw_value=29, offset=17)
# AttributeValue(name='DW_AT_name', form='DW_FORM_line_strp', value=b'stack.c', raw_value=36, offset=18)
# AttributeValue(name='DW_AT_comp_dir', form='DW_FORM_line_strp', value=b'/home/nahid/reverse/binaries/c_many', raw_value=0, offset=22)
# AttributeValue(name='DW_AT_GNU_pubnames', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=26)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4521, raw_value=4521, offset=26)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=171, raw_value=171, offset=34)
# AttributeValue(name='DW_AT_stmt_list', form='DW_FORM_sec_offset', value=0, raw_value=0, offset=42)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'size_t', raw_value=14, offset=47)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=3, raw_value=3, offset=51)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=209, raw_value=209, offset=52)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=23, raw_value=23, offset=53)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=58, raw_value=58, offset=54)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=59)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=60)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long unsigned int', raw_value=53, offset=61)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=66)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=67)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned int', raw_value=58, offset=68)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=73)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=75)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=8, raw_value=8, offset=76)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned char', raw_value=21, offset=77)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=82)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=83)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short unsigned int', raw_value=244, offset=84)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=89)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=90)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'signed char', raw_value=23, offset=91)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=96)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=97)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short int', raw_value=268, offset=98)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=103)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=104)
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=105)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=110)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=111)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long int', raw_value=5, offset=112)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=117)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=118)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'char', raw_value=30, offset=119)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=124)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=125)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long long int', raw_value=0, offset=126)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=131)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=132)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long long unsigned int', raw_value=48, offset=133)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'S_stack', raw_value=40, offset=138)
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=16, raw_value=16, offset=142)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=143)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=1, raw_value=1, offset=144)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=16, raw_value=16, offset=145)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=175, raw_value=175, offset=146)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'number', raw_value=71, offset=151)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=2, raw_value=2, offset=155)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=2, raw_value=2, offset=155)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=9, raw_value=9, offset=156)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=102, raw_value=102, offset=157)
# AttributeValue(name='DW_AT_data_member_location', form='DW_FORM_data1', value=0, raw_value=0, offset=161)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'next', raw_value=285, offset=163)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=2, raw_value=2, offset=167)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=3, raw_value=3, offset=167)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=21, raw_value=21, offset=168)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=175, raw_value=175, offset=169)
# AttributeValue(name='DW_AT_data_member_location', form='DW_FORM_data1', value=8, raw_value=8, offset=173)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=176)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=137, raw_value=137, offset=176)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'stack', raw_value=42, offset=181)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=185)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=4, raw_value=4, offset=186)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=3, raw_value=3, offset=187)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=137, raw_value=137, offset=188)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=193)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'free', raw_value=35, offset=193)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=4, raw_value=4, offset=197)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data2', value=555, raw_value=555, offset=198)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=13, raw_value=13, offset=200)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=201)
# AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=201)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=211, raw_value=211, offset=201)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=72, raw_value=72, offset=206)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=212)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'malloc', raw_value=278, offset=212)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=4, raw_value=4, offset=216)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data2', value=540, raw_value=540, offset=217)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=14, raw_value=14, offset=219)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=220)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=72, raw_value=72, offset=220)
# AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=224)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=234, raw_value=234, offset=224)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=46, raw_value=46, offset=229)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=235)
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'pop', raw_value=b'pop', offset=235)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=239)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=16, raw_value=16, offset=240)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=241)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=242)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=102, raw_value=102, offset=242)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4608, raw_value=4608, offset=246)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=84, raw_value=84, offset=254)
# AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=262)
# AttributeValue(name='DW_AT_call_all_tail_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=264)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=326, raw_value=326, offset=264)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'stk_ptr', raw_value=78, offset=269)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=273)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=16, raw_value=16, offset=273)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=17, raw_value=17, offset=274)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=326, raw_value=326, offset=275)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 72], raw_value=[145, 72], offset=279)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'number', raw_value=71, offset=283)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=287)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=17, raw_value=17, offset=288)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=9, raw_value=9, offset=289)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=102, raw_value=102, offset=290)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 92], raw_value=[145, 92], offset=294)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'stk', raw_value=b'stk', offset=298)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=302)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=18, raw_value=18, offset=302)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=12, raw_value=12, offset=303)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=331, raw_value=331, offset=304)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 96], raw_value=[145, 96], offset=308)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'tmp', raw_value=b'tmp', offset=312)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=316)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=18, raw_value=18, offset=316)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=18, raw_value=18, offset=317)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=331, raw_value=331, offset=318)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 104], raw_value=[145, 104], offset=322)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=327)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=331, raw_value=331, offset=327)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=332)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=180, raw_value=180, offset=332)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=337)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'push', raw_value=263, offset=337)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=341)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=342)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=6, raw_value=6, offset=343)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=344)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4521, raw_value=4521, offset=344)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=87, raw_value=87, offset=352)
# AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=360)
# AttributeValue(name='DW_AT_call_all_tail_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=362)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'number', raw_value=71, offset=363)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=367)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=367)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=15, raw_value=15, offset=368)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=102, raw_value=102, offset=369)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 92], raw_value=[145, 92], offset=373)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'stk_ptr', raw_value=78, offset=377)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=381)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=381)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=31, raw_value=31, offset=382)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=326, raw_value=326, offset=383)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 80], raw_value=[145, 80], offset=387)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'stk', raw_value=b'stk', offset=391)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=395)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=7, raw_value=7, offset=395)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=12, raw_value=12, offset=396)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=331, raw_value=331, offset=397)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 96], raw_value=[145, 96], offset=401)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'tmp', raw_value=b'tmp', offset=405)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=409)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=7, raw_value=7, offset=409)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=18, raw_value=18, offset=410)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=331, raw_value=331, offset=411)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 104], raw_value=[145, 104], offset=415)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
#
#
#
#
#   Found a compile unit at offset 420, length 350
# TREE DEPTH:  0
# AttributeValue(name='DW_AT_producer', form='DW_FORM_strp', value=b'GNU C17 11.3.0 -mtune=generic -march=x86-64 -gdwarf -gpubnames -fasynchronous-unwind-tables -fstack-protector-strong -fstack-clash-protection -fcf-protection', raw_value=86, offset=433)
# AttributeValue(name='DW_AT_language', form='DW_FORM_data1', value=29, raw_value=29, offset=437)
# AttributeValue(name='DW_AT_name', form='DW_FORM_line_strp', value=b'main.c', raw_value=124, offset=438)
# AttributeValue(name='DW_AT_comp_dir', form='DW_FORM_line_strp', value=b'/home/nahid/reverse/binaries/c_many', raw_value=0, offset=442)
# AttributeValue(name='DW_AT_GNU_pubnames', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=446)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4692, raw_value=4692, offset=446)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=318, raw_value=318, offset=454)
# AttributeValue(name='DW_AT_stmt_list', form='DW_FORM_sec_offset', value=143, raw_value=143, offset=462)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=467)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=468)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long unsigned int', raw_value=53, offset=469)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=474)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=475)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned int', raw_value=58, offset=476)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=481)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=8, raw_value=8, offset=482)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned char', raw_value=21, offset=483)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=488)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=489)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short unsigned int', raw_value=244, offset=490)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=495)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=496)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'signed char', raw_value=23, offset=497)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=502)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=503)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short int', raw_value=268, offset=504)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=509)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=510)
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=511)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=516)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=517)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long int', raw_value=5, offset=518)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=523)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=524)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'char', raw_value=30, offset=525)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=102, raw_value=102, offset=530)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=535)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=536)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long long int', raw_value=0, offset=537)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=542)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=543)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long long unsigned int', raw_value=48, offset=544)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'S_stack', raw_value=40, offset=549)
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=16, raw_value=16, offset=553)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=554)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=1, raw_value=1, offset=555)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=16, raw_value=16, offset=556)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=166, raw_value=166, offset=557)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'number', raw_value=71, offset=562)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=2, raw_value=2, offset=566)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=2, raw_value=2, offset=566)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=9, raw_value=9, offset=567)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=568)
# AttributeValue(name='DW_AT_data_member_location', form='DW_FORM_data1', value=0, raw_value=0, offset=572)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'next', raw_value=285, offset=574)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=2, raw_value=2, offset=578)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=3, raw_value=3, offset=578)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=21, raw_value=21, offset=579)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=166, raw_value=166, offset=580)
# AttributeValue(name='DW_AT_data_member_location', form='DW_FORM_data1', value=8, raw_value=8, offset=584)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=587)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=128, raw_value=128, offset=587)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'stack', raw_value=42, offset=592)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=596)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=4, raw_value=4, offset=597)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=3, raw_value=3, offset=598)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=128, raw_value=128, offset=599)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=604)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'printf', raw_value=300, offset=604)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=4, raw_value=4, offset=608)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data2', value=356, raw_value=356, offset=609)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=12, raw_value=12, offset=611)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=612)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=612)
# AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=616)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=207, raw_value=207, offset=616)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=207, raw_value=207, offset=621)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=628)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=109, raw_value=109, offset=628)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=633)
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'pop', raw_value=b'pop', offset=633)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=637)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=638)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_implicit_const', value=5, raw_value=5, offset=639)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=639)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=639)
# AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=643)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=233, raw_value=233, offset=643)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=233, raw_value=233, offset=648)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=654)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=238, raw_value=238, offset=654)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_implicit_const', value=8, raw_value=8, offset=659)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=171, raw_value=171, offset=659)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=664)
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'add', raw_value=b'add', offset=664)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=3, raw_value=3, offset=668)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=2, raw_value=2, offset=669)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_implicit_const', value=5, raw_value=5, offset=670)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=670)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=670)
# AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=674)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=269, raw_value=269, offset=674)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=679)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=684)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=690)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'push', raw_value=263, offset=690)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=2, raw_value=2, offset=694)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=5, raw_value=5, offset=695)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=6, raw_value=6, offset=696)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=697)
# AttributeValue(name='DW_AT_declaration', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=697)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=292, raw_value=292, offset=697)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=702)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=233, raw_value=233, offset=707)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=713)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'main', raw_value=295, offset=713)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=717)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=7, raw_value=7, offset=718)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=719)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=720)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=4692, raw_value=4692, offset=724)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=318, raw_value=318, offset=732)
# AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=740)
# AttributeValue(name='DW_AT_call_all_tail_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=742)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'stk', raw_value=b'stk', offset=743)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=747)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=8, raw_value=8, offset=748)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=12, raw_value=12, offset=749)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=238, raw_value=238, offset=750)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 96], raw_value=[145, 96], offset=754)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'temp', raw_value=290, offset=758)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=762)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=10, raw_value=10, offset=763)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=9, raw_value=9, offset=764)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=765)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 92], raw_value=[145, 92], offset=769)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
#
#
#
#
#   Found a compile unit at offset 774, length 446
# TREE DEPTH:  0
# AttributeValue(name='DW_AT_producer', form='DW_FORM_strp', value=b'GNU C17 11.3.0 -mtune=generic -march=x86-64 -gdwarf -gpubnames -fasynchronous-unwind-tables -fstack-protector-strong -fstack-clash-protection -fcf-protection', raw_value=86, offset=787)
# AttributeValue(name='DW_AT_language', form='DW_FORM_data1', value=29, raw_value=29, offset=791)
# AttributeValue(name='DW_AT_name', form='DW_FORM_line_strp', value=b'calculate.c', raw_value=151, offset=792)
# AttributeValue(name='DW_AT_comp_dir', form='DW_FORM_line_strp', value=b'/home/nahid/reverse/binaries/c_many', raw_value=0, offset=796)
# AttributeValue(name='DW_AT_GNU_pubnames', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=800)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5010, raw_value=5010, offset=800)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=200, raw_value=200, offset=808)
# AttributeValue(name='DW_AT_stmt_list', form='DW_FORM_sec_offset', value=274, raw_value=274, offset=816)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=821)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=822)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long unsigned int', raw_value=53, offset=823)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=828)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=829)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned int', raw_value=58, offset=830)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=835)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=8, raw_value=8, offset=836)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'unsigned char', raw_value=21, offset=837)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=842)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=843)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short unsigned int', raw_value=244, offset=844)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=849)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=850)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'signed char', raw_value=23, offset=851)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=2, raw_value=2, offset=856)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=857)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'short int', raw_value=268, offset=858)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=863)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=864)
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'int', raw_value=b'int', offset=865)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=870)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=871)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long int', raw_value=5, offset=872)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=1, raw_value=1, offset=877)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=6, raw_value=6, offset=878)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'char', raw_value=30, offset=879)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=884)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=5, raw_value=5, offset=885)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long long int', raw_value=0, offset=886)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=8, raw_value=8, offset=891)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=7, raw_value=7, offset=892)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'long long unsigned int', raw_value=48, offset=893)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=898)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'substractf', raw_value=312, offset=898)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=902)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=26, raw_value=26, offset=902)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=7, raw_value=7, offset=903)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=904)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=904)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5180, raw_value=5180, offset=908)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=30, raw_value=30, offset=916)
# AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=924)
# AttributeValue(name='DW_AT_call_all_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=926)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=181, raw_value=181, offset=926)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'a', raw_value=b'a', offset=931)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=933)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=26, raw_value=26, offset=933)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=24, raw_value=24, offset=934)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=935)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 108], raw_value=[145, 108], offset=939)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'b', raw_value=b'b', offset=943)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=945)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=26, raw_value=26, offset=945)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=33, raw_value=33, offset=946)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=947)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 104], raw_value=[145, 104], offset=951)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_byte_size', form='DW_FORM_data1', value=4, raw_value=4, offset=956)
# AttributeValue(name='DW_AT_encoding', form='DW_FORM_data1', value=4, raw_value=4, offset=957)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'float', raw_value=323, offset=958)
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=963)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'substract', raw_value=329, offset=963)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=967)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=967)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=968)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=969)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=969)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5158, raw_value=5158, offset=973)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=22, raw_value=22, offset=981)
# AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=989)
# AttributeValue(name='DW_AT_call_all_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=991)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=246, raw_value=246, offset=991)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'a', raw_value=b'a', offset=996)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=998)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=998)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=19, raw_value=19, offset=999)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1000)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 108], raw_value=[145, 108], offset=1004)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'b', raw_value=b'b', offset=1008)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1010)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=23, raw_value=23, offset=1010)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=26, raw_value=26, offset=1011)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1012)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 104], raw_value=[145, 104], offset=1016)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1021)
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'addf', raw_value=307, offset=1021)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1025)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=18, raw_value=18, offset=1025)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=7, raw_value=7, offset=1026)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1027)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=1027)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5128, raw_value=5128, offset=1031)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=30, raw_value=30, offset=1039)
# AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=1047)
# AttributeValue(name='DW_AT_call_all_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1049)
# AttributeValue(name='DW_AT_sibling', form='DW_FORM_ref4', value=304, raw_value=304, offset=1049)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'a', raw_value=b'a', offset=1054)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1056)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=18, raw_value=18, offset=1056)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=18, raw_value=18, offset=1057)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=1058)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 108], raw_value=[145, 108], offset=1062)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'b', raw_value=b'b', offset=1066)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1068)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=18, raw_value=18, offset=1068)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=27, raw_value=27, offset=1069)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=1070)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 104], raw_value=[145, 104], offset=1074)
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1
# AttributeValue(name='DW_AT_external', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1079)
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'add', raw_value=b'add', offset=1079)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_data1', value=1, raw_value=1, offset=1083)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=5, raw_value=5, offset=1084)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=5, raw_value=5, offset=1085)
# AttributeValue(name='DW_AT_prototyped', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1086)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1086)
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5010, raw_value=5010, offset=1090)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=118, raw_value=118, offset=1098)
# AttributeValue(name='DW_AT_frame_base', form='DW_FORM_exprloc', value=[156], raw_value=[156], offset=1106)
# AttributeValue(name='DW_AT_call_all_calls', form='DW_FORM_flag_present', value=True, raw_value=b'', offset=1108)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'a', raw_value=b'a', offset=1109)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1111)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=5, raw_value=5, offset=1111)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=13, raw_value=13, offset=1112)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1113)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 92], raw_value=[145, 92], offset=1117)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'b', raw_value=b'b', offset=1121)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1123)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=5, raw_value=5, offset=1123)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=20, raw_value=20, offset=1124)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1125)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 88], raw_value=[145, 88], offset=1129)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'ran', raw_value=b'ran', offset=1133)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1137)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=6, raw_value=6, offset=1137)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=9, raw_value=9, offset=1138)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1139)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 100], raw_value=[145, 100], offset=1143)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'fran', raw_value=339, offset=1147)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1151)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=9, raw_value=9, offset=1151)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=11, raw_value=11, offset=1152)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=181, raw_value=181, offset=1153)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 104], raw_value=[145, 104], offset=1157)
#
#
#
#
# TREE DEPTH:  2
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5079, raw_value=5079, offset=1161)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=30, raw_value=30, offset=1169)
#
#
#
#
# TREE DEPTH:  3
# AttributeValue(name='DW_AT_name', form='DW_FORM_string', value=b'i', raw_value=b'i', offset=1178)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1180)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=11, raw_value=11, offset=1180)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=14, raw_value=14, offset=1181)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1182)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 96], raw_value=[145, 96], offset=1186)
#
#
#
#
# TREE DEPTH:  3
# AttributeValue(name='DW_AT_low_pc', form='DW_FORM_addr', value=5088, raw_value=5088, offset=1190)
# AttributeValue(name='DW_AT_high_pc', form='DW_FORM_data8', value=11, raw_value=11, offset=1198)
#
#
#
#
# TREE DEPTH:  4
# AttributeValue(name='DW_AT_name', form='DW_FORM_strp', value=b'fran', raw_value=339, offset=1207)
# AttributeValue(name='DW_AT_decl_file', form='DW_FORM_implicit_const', value=1, raw_value=1, offset=1211)
# AttributeValue(name='DW_AT_decl_line', form='DW_FORM_data1', value=12, raw_value=12, offset=1211)
# AttributeValue(name='DW_AT_decl_column', form='DW_FORM_data1', value=13, raw_value=13, offset=1212)
# AttributeValue(name='DW_AT_type', form='DW_FORM_ref4', value=88, raw_value=88, offset=1213)
# AttributeValue(name='DW_AT_location', form='DW_FORM_exprloc', value=[145, 108], raw_value=[145, 108], offset=1217)
#
#
#
#
# TREE DEPTH:  4
#
#
#
#
# TREE DEPTH:  3
#
#
#
#
# TREE DEPTH:  2
#
#
#
#
# TREE DEPTH:  1

# %%
# sourceLocation_die src->type
# address_inst         add->instruction
# addr_lineProgram    add-> lineInfo (row,col)
# addr_sourceFile

# %%
# with open('stacktest.s', 'w') as outFile:
#     # outFile.write('file contents\n')
#     lastSource = ""
#     for address in address_inst:
#         inst = address_inst[address]
#         instrctionCode = (address+":\t"+ inst.mnemonic+" "+inst.op_str).ljust(45)
#         if address in addr_lineProgram:
#             line = addr_lineProgram[address]

#             srcFileName =list(addr_sourceFile[address].keys())[0] #TODO not single file always 
            
#             if srcFileName!=lastSource:
#                 outFile.write("\n"+ '#'*100+"\n"+ srcFileName.rjust(45) +'\n'+'#'*100+ "\n\n")
#                 lastSource = srcFileName
            
#             sourceCode = getSource(srcFileName,addr_lineProgram[address].state.line, addr_lineProgram[address].state.column)
#             src_key = srcFileName+"#"+str(addr_lineProgram[address].state.line)
            
#             if src_key in sourceLocation_die.keys():
#                 die_info = sourceLocation_die[src_key]
#                 print('\n'*2,die_info,'\n'*2)
#             else:
#                 print('\n'*2,"\nNONE\n",'\n'*2)
            
#             if '\n' not in  sourceCode:
#                 sourceCode+=sourceCode+"\n"
#             outFile.write(instrctionCode+"#"+ sourceCode  )
#             print(instrctionCode+"#"+ sourceCode)
#         else:
#             outFile.write(instrctionCode+ '\n'  )
#             print(instrctionCode)

# %%
# sourceLocation_die

# %%
import re 


C_KEYWARDS = ['alignas','alignof','auto','bool','break',
                'case','char','const','constexpr',
                'continue','default','do','double',
                'else','enum','extern','false',
                'float','for','goto','if',
                'inline','int','long','nullptr',
                'register','restrict','return','short',
                'signed','sizeof','static','static_assert',
                'struct','switch','thread_local','true',
                'typedef','typeof','typeof_unqual','union',
                'unsigned','void','volatile','while',
                '_Alignas','_Alignof','_Atomic','_BitInt',
                '_Bool','_Complex','_Decimal128','_Decimal32',
                '_Decimal64','_Generic','_Imaginary','_Noreturn',
                '_Static_assert','_Thread_local' ]

src= " int s; float b; for (int s=0;s<10;s++){s =s+1}"
pattern = r"([a-zA-Z_][a-zA-Z0-9]*)"
res =  [name for name in re.findall(pattern, src) if name not in C_KEYWARDS]

print(res)
# Out:
# ['s', 'b', 's', 's', 's', 's', 's']
