# %%
O3={'array_int': 699412, 'int': 1086557, 'array_signed char': 744067, 'unsigned long int': 61180, '*structure': 46397, '*signed char': 66656, 'signed char': 75978, 'double': 34500, 'array_float': 28976, 'float': 61767, 'structure': 487533, '*int': 34705, 'array_double': 20820, '*float': 1166, 'long long int': 9063, 'unsigned int': 19815, '*double': 969, 'long int': 16431, 'array_long long int': 5094, '*void': 63856, 'short int': 2631, 'array_char': 28453, 'array_unsigned long int': 663, 'array_long int': 6839, '*long int': 294, 'char': 8223, '*char': 960, '*unsigned long int': 567, 'unsigned short int': 1330, 'array_unsigned int': 16907, 'unsigned long long int': 1070, '*unsigned int': 1279, 'long double': 325, 'array_unsigned short int': 1087, 'array_long double': 40, 'array_unsigned long long int': 3050, 'array_short int': 2439, '*short int': 1045, '*long long int': 2082, '*unsigned short int': 184, '*unsigned long long int': 276}

# %%
O1={'array_signed char': 807954, 'int': 1105740, 'array_int': 711154, 'float': 62981, 'array_float': 36109, 'array_double': 20818, 'structure': 653357, 'signed char': 69525, '*structure': 68169, 'unsigned long int': 57267, 'double': 34505, '*int': 33625, '*signed char': 93344, 'unsigned int': 29316, 'unsigned long long int': 1614, 'long long int': 8263, 'long int': 22344, 'short int': 2271, 'array_unsigned int': 17024, 'array_char': 59794, 'array_long int': 3847, '*void': 76903, 'char': 11334, 'long double': 933, 'array_short int': 2283, 'unsigned short int': 5903, '*float': 1135, 'array_unsigned long int': 1022, 'array_long long int': 3965, 'array_unsigned long long int': 3127, 'array_unsigned short int': 1373, '*double': 1417, '*long int': 367, 'array_long double': 54, '*unsigned int': 1009, '*char': 1713, '*long long int': 301, '*unsigned long long int': 47, '*unsigned long int': 697, '*unsigned short int': 88, '*short int': 96}

# %%
O2={'double': 35082, 'int': 1127819, '*signed char': 76685, 'structure': 470885, 'float': 63909, 'array_signed char': 573321, 'signed char': 32371, 'array_char': 127289, 'char': 39693, 'array_int': 578779, 'long int': 16576, '*int': 32704, 'long unsigned int': 1876, 'unsigned long int': 65487, 'unsigned int': 25015, '*structure': 86055, 'array_short int': 1573, 'long long int': 10415, '*float': 1162, 'array_long int': 5009, 'array_double': 20947, 'array_structure': 4750, '*char': 13760, 'array_float': 21101, 'array_long long int': 3712, '*void': 70009, 'union': 1337, 'array_unsigned int': 16074, 'array_unsigned long long int': 5049, 'short unsigned int': 1452, 'short int': 2532, '*union': 16, 'long double': 355, '*double': 1552, '*unsigned int': 864, 'long long unsigned int': 691, '*short int': 334, 'unsigned short int': 759, 'unsigned long long int': 692, '*long int': 273, 'array_short unsigned int': 154, 'enumeration': 1293, '*unsigned long int': 294, '__int128 unsigned': 1, 'array_enumeration': 112, 'array_long unsigned int': 205, 'array_long long unsigned int': 45, '*long long int': 758, 'array_unsigned long int': 824, '*unsigned short int': 203, 'array_unsigned short int': 543, '*long unsigned int': 16, 'array_union': 13, '*enumeration': 3, '*short unsigned int': 6, '*unsigned long long int': 47, 'array_long double': 38, '*long double': 2, '_Bool': 6, '*long long unsigned int': 3}

# %%
O0 ={'int': 11161636, '*char': 1262928, 'structure': 190725, 'long int': 146811, '*int': 1527710, 'array_int': 468647, 'char': 436827, 'array_char': 612436, '*structure': 2132531, 'short int': 37207, 'array_structure': 24916, 'float': 285377, 'double': 208032, 'unsigned int': 218048, '*double': 37006, 'long unsigned int': 57656, '*float': 24130, 'enumeration': 22639, 'union': 6096, 'array_float': 17185, 'long long int': 87553, 'array_double': 12253, 'array_short int': 1184, '_Bool': 1988, 'short unsigned int': 29725, '*union': 19396, '*unsigned int': 15721, 'long long unsigned int': 66183, '*long int': 23290, '*enumeration': 2230, 'signed char': 10194, '*long long unsigned int': 2061, 'array_unsigned int': 5133, 'array_long long int': 4344, '*long unsigned int': 7423, 'array_long long unsigned int': 2450, 'array_long int': 5142, 'array_long unsigned int': 1905, '*short int': 7234, '*_Bool': 370, '*long long int': 6671, '*short unsigned int': 4840, 'array_short unsigned int': 1044, '*signed char': 4414, 'array_signed char': 193, 'array_enumeration': 24678, 'complex double': 31, 'array_union': 129, 'bool': 10, '__int128': 16, '__int128 unsigned': 255, '*__int128 unsigned': 10, 'array___int128 unsigned': 11, 'array__Bool': 23, '*long double': 6, 'long double': 11, 'array_long double': 1}

# %%
common_keys=list(O0.keys())
filtered_common_keys = []
print("BEFORE", len(common_keys), common_keys)
for key in common_keys:
    all_have= True
    for od in [O1,O2,O3]:
        if key not in od:
            all_have = False
            break
    if all_have:
        filtered_common_keys.append(key)
print("After", len(filtered_common_keys), filtered_common_keys)
# Out:
# BEFORE 57 ['int', '*char', 'structure', 'long int', '*int', 'array_int', 'char', 'array_char', '*structure', 'short int', 'array_structure', 'float', 'double', 'unsigned int', '*double', 'long unsigned int', '*float', 'enumeration', 'union', 'array_float', 'long long int', 'array_double', 'array_short int', '_Bool', 'short unsigned int', '*union', '*unsigned int', 'long long unsigned int', '*long int', '*enumeration', 'signed char', '*long long unsigned int', 'array_unsigned int', 'array_long long int', '*long unsigned int', 'array_long long unsigned int', 'array_long int', 'array_long unsigned int', '*short int', '*_Bool', '*long long int', '*short unsigned int', 'array_short unsigned int', '*signed char', 'array_signed char', 'array_enumeration', 'complex double', 'array_union', 'bool', '__int128', '__int128 unsigned', '*__int128 unsigned', 'array___int128 unsigned', 'array__Bool', '*long double', 'long double', 'array_long double']
# ...

# %%
def Average(lst): 
    return sum(lst) / len(lst)

# %%
table = {}
for key in filtered_common_keys:
    table[key] = []
    for data_set in  [O0,O1,O2,O3]:
        table[key].append(data_set[key])
print(table)

avg_table = {}
for key, value in table.items():
    avg_table[key] = Average(value)
print(avg_table)
# Out:
# {'int': [11161636, 1105740, 1127819, 1086557], '*char': [1262928, 1713, 13760, 960], 'structure': [190725, 653357, 470885, 487533], 'long int': [146811, 22344, 16576, 16431], '*int': [1527710, 33625, 32704, 34705], 'array_int': [468647, 711154, 578779, 699412], 'char': [436827, 11334, 39693, 8223], 'array_char': [612436, 59794, 127289, 28453], '*structure': [2132531, 68169, 86055, 46397], 'short int': [37207, 2271, 2532, 2631], 'float': [285377, 62981, 63909, 61767], 'double': [208032, 34505, 35082, 34500], 'unsigned int': [218048, 29316, 25015, 19815], '*double': [37006, 1417, 1552, 969], '*float': [24130, 1135, 1162, 1166], 'array_float': [17185, 36109, 21101, 28976], 'long long int': [87553, 8263, 10415, 9063], 'array_double': [12253, 20818, 20947, 20820], 'array_short int': [1184, 2283, 1573, 2439], '*unsigned int': [15721, 1009, 864, 1279], '*long int': [23290, 367, 273, 294], 'signed char': [10194, 69525, 32371, 75978], 'array_unsigned int': [5133, 17024, 16074, 16907], 'array_
# ...

# %%
from operator import itemgetter
sorted_table ={}
for i,k in sorted(avg_table.items(), key=itemgetter(1)):
    sorted_table[i]=int(k)
sorted_table
# Out:
# {'array_long double': 33,
#  'long double': 406,
#  'array_short int': 1869,
#  '*short int': 2177,
#  '*long long int': 2453,
#  'array_long long int': 4278,
#  '*unsigned int': 4718,
#  'array_long int': 5209,
#  '*long int': 6056,
#  '*float': 6898,
#  '*double': 10236,
#  'short int': 11160,
#  'array_unsigned int': 13784,
#  'array_double': 18709,
#  'array_float': 25842,
#  'long long int': 28823,
#  'signed char': 47017,
#  'long int': 50540,
#  '*signed char': 60274,
#  'unsigned int': 73048,
#  'double': 78029,
#  'float': 118508,
#  'char': 124019,
#  'array_char': 206993,
#  '*char': 319840,
#  '*int': 407186,
#  'structure': 450625,
#  'array_signed char': 531383,
#  '*structure': 583288,
#  'array_int': 614498,
#  'int': 3620438}

# %%
import matplotlib.pyplot as plt 

from math import log
import sys


font_size = 17
fig, ax = plt.subplots(figsize=(20, 7))
# line 1 points 
x = list(sorted_table.keys())
y = [log(z) for z in list(sorted_table.values())] 
# plotting the line 1 points  
plt.plot(x, y,linewidth=.50) 
  
plt.xticks(rotation=75,fontsize=font_size*.9)
plt.yticks(fontsize=font_size)
# plt.title("Co") 
  
# plt.grid(linestyle='--') 
# plt.xticks(r + width/2,labels,fontsize=font_size) 
  
# naming the x axis 
plt.xlabel('Types' , fontsize=font_size,color = 'tab:green') 
# naming the y axis 
plt.ylabel('log ( Frequency )',fontsize=font_size,color = 'tab:green') 
# giving a title to my graph 


idx = 0
for key, value in zip(x,y):
#     if idx%2==0:
    tag = list(sorted_table.values())[idx]
     
    plt.annotate(f"{tag:,}", (key, value),fontsize=font_size*.8,color = 'purple',rotation=50)
    idx = idx +1
# show a legend on the plot 
plt.grid(color = 'black' ,alpha=0.10)
plt.savefig('./output/data_freq.pdf',dpi=200,bbox_inches="tight")
# function to show the plot 
plt.show()
