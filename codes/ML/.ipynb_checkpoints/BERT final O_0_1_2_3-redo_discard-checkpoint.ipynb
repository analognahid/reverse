# %%
import torch

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device ,torch.cuda.is_available())
# Out:
# cuda True

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import sys,os, pickle

import torch.nn as nn
from transformers import BertModel, BertTokenizer
from transformers import BertForMaskedLM
from torch.utils.data import DataLoader, Dataset
from torch.utils.data import TensorDataset, random_split
from transformers import AdamW
from tqdm import tqdm  # for our progress bar

from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score
import numpy as np
from transformers import AutoModelForSequenceClassification

import random


EXPERIMENT_NAME="TYPE_WRITER_BERT_final_O_0123"

BATCH_SIZE = 30
MAX_TOKEN_SIZE = 512

# %%
data_paths = [
             '/home/raisul/type_data/instructions_and_type_data_100k/',
              '/home/raisul/type_data/O1_mix/instructions_and_type_data_100k',
              '/media/raisul/nahid_personal/optimizations/O2_ghidra/instructions_and_type_data_100k_mix/',
              '/home/raisul/type_data/O3_mix/instructions_and_type_data_100k'
             ]

all_bins_paths = []
for oi,data_path in enumerate(data_paths):
    for fi,pkl_file_name in enumerate(os.listdir(data_path)):
            if fi>300000:
                 break
            user_proj = pkl_file_name.rsplit('_____', 1)[0]
            user_proj = ''.join(user_proj.split('_____'))
            pkl_path = os.path.join(data_path,pkl_file_name)
            all_bins_paths.append( (pkl_path,oi ,user_proj) )

# %%
def fix_types(type_name):
    global TYPE_FIX_MAP
    
    prev_type_name= type_name
    
    if '*' in type_name:
        if type_name.rindex('*')>0:#reduce to single * (rightmost, ignore array before that)
            type_name = type_name[ type_name.rindex('*'): ]
    if 'array_' in type_name:
        if type_name.rindex('array_')>0:
            type_name = type_name[ type_name.rindex('array_'): ]
    if 'unsigned char' in type_name:
        type_name = type_name.replace('unsigned char' , 'char')
        
        
    if type_name not in TYPE_FIX_MAP:
        TYPE_FIX_MAP[prev_type_name] = type_name
    return type_name

# %%
MODEL_SAVE_PATH =  '/home/raisul/models/'
TYPE_COUNT ={}
FINAL_TYPE_COUNT = {}
TYPE_PROBABILITY = {}


REJECT = ['union' , 'enumeration' , 'int128' , '_Bool' , 'complex' ,'bool']
TYPE_FIX_MAP = {}
MAX_TYPE_SAMPLE  =40*1000
TYPE_MAPPING = {}


ALL_INPUT_LIST = []
ALL_INPUT_SLICE_INFO  = []
ALL_LABEL_LIST = []
ALL_OPT_LIST = []

TRAIN_SAMPLE_COUNT = 0
VAL_SAMPLE_COUNT   =0

# %%
import traceback
#TODO dont load all at a time in memry
def make_dataset():
    global TYPE_FIX_MAP, REJECT ,TYPE_COUNT,TYPE_MAPPING,TRAIN_SAMPLE_COUNT,VAL_SAMPLE_COUNT
    
    dbg_temp = []
    
    #count how many real samples
    for pkl_path, oi, user_proj_name in all_bins_paths:


        with open(pkl_path, 'rb') as file:
            try:
                model_input_list, model_type_list = pickle.load(file)

            except Exception as e:
                pass
            for i in range(len(model_input_list)):

                type_str = fix_types(model_type_list[i])
                
                if type_str not in TYPE_COUNT:
                    TYPE_COUNT[type_str] = 0
                    FINAL_TYPE_COUNT[type_str] = 0
                
                TYPE_COUNT[type_str] +=1

    print(TYPE_COUNT)
    
    #remove the unwanted types
    temp_removed_keys = []
    for rk in REJECT:
        for tk in TYPE_COUNT:
            
            if rk in tk:
                print("DBG 1", rk,tk)
                temp_removed_keys.append(tk)
        for tfm in TYPE_FIX_MAP:
            if tfm in rk:
                print("DBG 2", tfm,rk)
                temp_removed_keys.append(rk)
    print('temp_removed_keys',temp_removed_keys)
    for trk in temp_removed_keys:
        if trk in TYPE_COUNT:
            TYPE_COUNT.pop(trk)
        if trk in FINAL_TYPE_COUNT:
            FINAL_TYPE_COUNT.pop(trk)
        if trk in TYPE_FIX_MAP:
            TYPE_FIX_MAP.pop(trk)
    
    TYPE_COUNT = {k: v for k, v in sorted(TYPE_COUNT.items(), key=lambda item: item[1] , reverse=True)}


    ti = 0
    for key,val in TYPE_COUNT.items():
        TYPE_MAPPING[key]  = ti
        ti+=1

    #make the probability
    for key in TYPE_COUNT.keys():
        print(MAX_TYPE_SAMPLE , TYPE_COUNT[key] ,key)
        TYPE_PROBABILITY[key] = MAX_TYPE_SAMPLE/TYPE_COUNT[key]
    

    print(TYPE_PROBABILITY)
    
    
    ######################################
    #######################################
    

    #fill dataset with that probability
    for pkl_path,oi, user_proj_name in all_bins_paths:
        
        bin_numeric_value = sum(bytearray(user_proj_name,'utf-8') )%10
        
        
        with open(pkl_path, 'rb') as file:
            try:
                model_input_list, model_type_list = pickle.load(file)
            except Exception as e:
#                 print('err: ',e)
                pass
            for i in range(len(model_input_list)):
                
                try:
                    type_str = TYPE_FIX_MAP[model_type_list[i]]
                    type_label = TYPE_MAPPING[type_str]

                    backward_slice , target_slice, forward_slice = model_input_list[i]

                    if random.random()<=TYPE_PROBABILITY[type_str]:
                        
                        if bin_numeric_value>7:
                            
                            
                            ALL_INPUT_LIST.append(backward_slice + target_slice + forward_slice)
                            ALL_INPUT_SLICE_INFO.append([len(backward_slice) , len(target_slice) , len(forward_slice)])
                            ALL_LABEL_LIST.append(type_label)
                            ALL_OPT_LIST.append(oi)
                            VAL_SAMPLE_COUNT = VAL_SAMPLE_COUNT + 1
                        else:
                            
                            ALL_INPUT_LIST.insert( 0,  backward_slice + target_slice + forward_slice)
                            ALL_INPUT_SLICE_INFO.insert( 0 , [len(backward_slice) , len(target_slice) , len(forward_slice)])
                            ALL_LABEL_LIST.insert( 0 , type_label)
                            ALL_OPT_LIST.insert(0,oi)
                            TRAIN_SAMPLE_COUNT=TRAIN_SAMPLE_COUNT+1


                        FINAL_TYPE_COUNT[type_str]+=1
                except Exception as e:
                    pass
#                       print('err: _',e)
#                       print(traceback.print_exc())

make_dataset()
print(VAL_SAMPLE_COUNT , TRAIN_SAMPLE_COUNT)
# Out:
# {'int': 11480252, '*char': 939814, 'structure': 1749588, 'long int': 166715, '*int': 1107494, 'array_int': 2329534, 'char': 376572, 'array_char': 662925, '*structure': 1774618, 'short int': 39469, 'array_structure': 22527, 'float': 400049, 'double': 256462, 'unsigned int': 235871, '*double': 28754, 'long unsigned int': 46768, '*float': 20333, 'enumeration': 16686, 'union': 5939, 'array_float': 98687, 'long long int': 93940, 'array_double': 71979, 'array_short int': 7095, '_Bool': 1528, 'short unsigned int': 25336, '*union': 13488, '*unsigned int': 15764, 'long long unsigned int': 51082, '*long int': 22247, '*enumeration': 1371, 'signed char': 187310, '*long long unsigned int': 1486, 'array_unsigned int': 54227, 'array_long long int': 15846, '*long unsigned int': 5806, 'array_long long unsigned int': 1677, 'array_long int': 19950, 'array_long unsigned int': 1533, '*short int': 7832, '*_Bool': 244, '*long long int': 7753, '*short unsigned int': 3712, 'array_short unsigned int': 1000, '*signed char': 240988, 'array_signed char': 2125483, 'array_enumeration': 16337, 'complex double': 31, 'array_union': 110, 'bool': 10, '__int128': 16, '__int128 unsigned': 256, '*__int128 unsigned': 10, 'array___int128 unsigned': 11, 'array__Bool': 18, '*long double': 4, 'long double': 1622, 'unsigned long int': 183934, 'unsigned long long int': 3376, '*void': 210768, 'array_unsigned long long int': 11226, 'unsigned short int': 7992, 'array_unsigned short int': 3003, '*unsigned long int': 1558, 'array_unsigned long int': 2509, '*unsigned short int': 475, '*unsigned long long int': 370, 'array_long double': 132}
# DBG 1 union union
# DBG 1 union *union
# DBG 1 union array_union
# DBG 2 union union
# DBG 1 enumeration enumeration
# DBG 1 enumeration *enumeration
# DBG 1 enumeration array_enumeration
# DBG 2 enumeration enumeration
# DBG 1 int128 __int128
# DBG 1 int128 __int128 unsigned
# DBG 1 int128 *__int128 unsigned
# DBG 1 int128 array___int128 unsigned
# DBG 2 int int128
# DBG 1 _Bool _Bool
# DBG 1 _Bool *_Bool
# DBG 1 _Bool array__Bool
# DBG 2 _Bool _Bool
# DBG 1 complex complex double
# DBG 1 bool bool
# DBG 2 bool bool
# temp_removed_keys ['union', '*union', 'array_union', 'union', 'enumeration', '*enumeration', 'array_enumeration', 'enumeration', '__int128', '__int128 unsigned', '*__int128 unsigned', 'array___int128 unsigned', 'int128', '_Bool', '*_Bool', 'array__Bool', '_Bool', 'complex double', 'bool', 'bool']
# 40000 11480252 int
# 40000 2329534 array_int
# 40000 2125483 array_signed char
# 40000 1774618 *structure
# 40000 1749588 structure
# 40000 1107494 *int
# 40000 939814 *char
# 40000 662925 array_char
# 40000 400049 float
# 40000 376572 char
# 40000 256462 double
# 40000 240988 *signed char
# 40000 235871 unsigned int
# 40000 210768 *void
# 40000 187310 signed char
# 40000 183934 unsigned long int
# 40000 166715 long int
# 40000 98687 array_float
# 40000 93940 long long int
# 40000 71979 array_double
# 40000 54227 array_unsigned int
# 40000 51082 long long unsigned int
# 40000 46768 long unsigned int
# 40000 39469 short int
# 40000 28754 *double
# 40000 25336 short unsigned int
# 40000 22527 array_structure
# 40000 22247 *long int
# 40000 20333 *float
# 40000 19950 array_long int
# 40000 15846 array_long long int
# 40000 15764 *unsigned int
# 40000 11226 array_unsigned long long int
# 40000 7992 unsigned short int
# 40000 7832 *short int
# 40000 7753 *long long int
# 40000 7095 array_short int
# 40000 5806 *long unsigned int
# 40000 3712 *short unsigned int
# 40000 3376 unsigned long long int
# 40000 3003 array_unsigned short int
# 40000 2509 array_unsigned long int
# 40000 1677 array_long long unsigned int
# 40000 1622 long double
# 40000 1558 *unsigned long int
# 40000 1533 array_long unsigned int
# 40000 1486 *long long unsigned int
# 40000 1000 array_short unsigned int
# 40000 475 *unsigned short int
# 40000 370 *unsigned long long int
# 40000 132 array_long double
# 40000 4 *long double
# {'int': 0.003484244074084785, 'array_int': 0.01717081613747642, 'array_signed char': 0.01881925190650784, '*structure': 0.022540062142951327, 'structure': 0.02286252534882498, '*int': 0.036117577160688905, '*char': 0.04256161325538883, 'array_char': 0.06033865067692424, 'float': 0.0999877515004412, 'char': 0.10622138661398085, 'double': 0.1559685255515437, '*signed char': 0.16598336846647965, 'unsigned int': 0.1695842218839959, '*void': 0.1897821301146284, 'signed char': 0.21354973039346536, 'unsigned long int': 0.21746930964367653, 'long int': 0.23993042017814833, 'array_float': 0.4053218762349651, 'long long int': 0.4258037044922291, 'array_double': 0.5557176398671835, 'array_unsigned int': 0.7376399210725284, 'long long unsigned int': 0.7830546963705415, 'long unsigned int': 0.8552856654122477, 'short int': 1.0134535964934506, '*double': 1.3911108019753773, 'short unsigned int': 1.5787811809283234, 'array_structure': 1.7756470013761265, '*long int': 1.7979952353126265, '*float': 1.9672453646781094, 'array_long int': 2.0050125313283207, 'array_long long int': 2.524296352391771, '*unsigned int': 2.537427048972342, 'array_unsigned long long int': 3.5631569570639585, 'unsigned short int': 5.005005005005005, '*short int': 5.107252298263535, '*long long int': 5.159293176834773, 'array_short int': 5.637773079633544, '*long unsigned int': 6.889424733034792, '*short unsigned int': 10.775862068965518, 'unsigned long long int': 11.848341232227488, 'array_unsigned short int': 13.32001332001332, 'array_unsigned long int': 15.942606616181745, 'array_long long unsigned int': 23.85211687537269, 'long double': 24.66091245376079, '*unsigned long int': 25.673940949935815, 'array_long unsigned int': 26.09262883235486, '*long long unsigned int': 26.917900403768506, 'array_short unsigned int': 40.0, '*unsigned short int': 84.21052631578948, '*unsigned long long int': 108.10810810810811, 'array_long double': 303.030303030303, '*long double': 10000.0}
# 230666 935291

# %%
data_temp_path = 'data/typedata'+EXPERIMENT_NAME+'.ignore.pkl'
with open(data_temp_path, 'wb') as f:
    pickle.dump([ALL_OPT_LIST,VAL_SAMPLE_COUNT , TRAIN_SAMPLE_COUNT,TYPE_COUNT , TYPE_MAPPING ,ALL_INPUT_LIST, ALL_INPUT_SLICE_INFO ,ALL_LABEL_LIST,   FINAL_TYPE_COUNT ], f)
    
    
with open(data_temp_path, 'rb') as file:
    ALL_OPT_LIST,VAL_SAMPLE_COUNT , TRAIN_SAMPLE_COUNT,TYPE_COUNT , TYPE_MAPPING ,ALL_INPUT_LIST, ALL_INPUT_SLICE_INFO ,ALL_LABEL_LIST,     FINAL_TYPE_COUNT  = pickle.load(file)

# %%
print(len(ALL_INPUT_LIST), FINAL_TYPE_COUNT)
# Out:
# 1165957 {'int': 40219, '*char': 32891, 'structure': 39540, 'long int': 40121, '*int': 37875, 'array_int': 38877, 'char': 35827, 'array_char': 38062, '*structure': 37128, 'short int': 39446, 'array_structure': 19312, 'float': 40243, 'double': 40182, 'unsigned int': 39796, '*double': 28536, 'long unsigned int': 40057, '*float': 18622, 'array_float': 39138, 'long long int': 40095, 'array_double': 39064, 'array_short int': 6978, 'short unsigned int': 25336, '*unsigned int': 15260, 'long long unsigned int': 40075, '*long int': 20949, 'signed char': 39736, '*long long unsigned int': 1418, 'array_unsigned int': 39938, 'array_long long int': 15187, '*long unsigned int': 5660, 'array_long long unsigned int': 1457, 'array_long int': 19544, 'array_long unsigned int': 1519, '*short int': 7300, '*long long int': 7240, '*short unsigned int': 2878, 'array_short unsigned int': 814, '*signed char': 39335, 'array_signed char': 39869, '*long double': 4, 'long double': 232, 'unsigned long int': 39906, 'unsigned long long int': 3369, '*void': 39825, 'array_unsigned long long int': 11226, 'unsigned short int': 7974, 'array_unsigned short int': 2982, '*unsigned long int': 1558, 'array_unsigned long int': 2509, '*unsigned short int': 475, '*unsigned long long int': 370, 'array_long double': 3}

# %%
tokenizer  = BertTokenizer.from_pretrained("./multytask-tokenizer_optim_3_d4")

#https://github.com/huggingface/tokenizers/issues/247

mask_token_id, look_token_id, eoi_token_id = tokenizer.encode('[MASK] [LOOK] [EOI]')[1:-1]

print(mask_token_id, look_token_id, eoi_token_id)
# Out:
# 4 6 5

# %%
VOCAB_SIZE = tokenizer.vocab_size

print('VOCAB SIZE : ', (tokenizer.vocab_size))
# Out:
# VOCAB SIZE :  3000

# %%
# Create model instance
#TODO*** USE PRETRAINED
# PATH, local_files_only=True #/home/raisul/models/pretrain_100k #bert-base-uncased
model = AutoModelForSequenceClassification.from_pretrained("/home/raisul/models/pretrain_100k_O2", num_labels=len(TYPE_MAPPING.items()))
# model = AutoModelForSequenceClassification.from_pretrained(MODEL_SAVE_PATH  + EXPERIMENT_NAME, num_labels=len(TYPE_MAPPING.items()))
model.to(device)


print(model.config)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /home/raisul/models/pretrain_100k_O2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertConfig {
#   "_name_or_path": "/home/raisul/models/pretrain_100k_O2",
#   "architectures": [
#     "BertForPreTraining"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11",
#     "12": "LABEL_12",
#     "13": "LABEL_13",
#     "14": "LABEL_14",
#     "15": "LABEL_15",
#     "16": "LABEL_16",
#     "17": "LABEL_17",
#     "18": "LABEL_18",
#     "19": "LABEL_19",
#     "20": "LABEL_20",
#     "21": "LABEL_21",
#     "22": "LABEL_22",
#     "23": "LABEL_23",
#     "24": "LABEL_24",
#     "25": "LABEL_25",
#     "26": "LABEL_26",
#     "27": "LABEL_27",
#     "28": "LABEL_28",
#     "29": "LABEL_29",
#     "30": "LABEL_30",
#     "31": "LABEL_31",
#     "32": "LABEL_32",
#     "33": "LABEL_33",
#     "34": "LABEL_34",
#     "35": "LABEL_35",
#     "36": "LABEL_36",
#     "37": "LABEL_37",
#     "38": "LABEL_38",
#     "39": "LABEL_39",
#     "40": "LABEL_40",
#     "41": "LABEL_41",
#     "42": "LABEL_42",
#     "43": "LABEL_43",
#     "44": "LABEL_44",
#     "45": "LABEL_45",
#     "46": "LABEL_46",
#     "47": "LABEL_47",
#     "48": "LABEL_48",
#     "49": "LABEL_49",
#     "50": "LABEL_50",
#     "51": "LABEL_51"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_12": 12,
#     "LABEL_13": 13,
#     "LABEL_14": 14,
#     "LABEL_15": 15,
#     "LABEL_16": 16,
#     "LABEL_17": 17,
#     "LABEL_18": 18,
#     "LABEL_19": 19,
#     "LABEL_2": 2,
#     "LABEL_20": 20,
#     "LABEL_21": 21,
#     "LABEL_22": 22,
#     "LABEL_23": 23,
#     "LABEL_24": 24,
#     "LABEL_25": 25,
#     "LABEL_26": 26,
#     "LABEL_27": 27,
#     "LABEL_28": 28,
#     "LABEL_29": 29,
#     "LABEL_3": 3,
#     "LABEL_30": 30,
#     "LABEL_31": 31,
#     "LABEL_32": 32,
#     "LABEL_33": 33,
#     "LABEL_34": 34,
#     "LABEL_35": 35,
#     "LABEL_36": 36,
#     "LABEL_37": 37,
#     "LABEL_38": 38,
#     "LABEL_39": 39,
#     "LABEL_4": 4,
#     "LABEL_40": 40,
#     "LABEL_41": 41,
#     "LABEL_42": 42,
#     "LABEL_43": 43,
#     "LABEL_44": 44,
#     "LABEL_45": 45,
#     "LABEL_46": 46,
#     "LABEL_47": 47,
#     "LABEL_48": 48,
#     "LABEL_49": 49,
#     "LABEL_5": 5,
#     "LABEL_50": 50,
#     "LABEL_51": 51,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.33.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }

# %%
# Tokenize input text
# inputs = tokenizer(input_text, padding=True, truncation=True, return_tensors='pt')
# inputs = tokenizer(ALL_INPUT_LIST, max_length= MAX_TOKEN_SIZE,padding='max_length', truncation=True , return_tensors='pt')
# print(inputs.keys())

# labels = ALL_LABEL_LIST.to(device)

# %%
# print(inputs.keys())
# print(inputs.token_type_ids)
# inputs.token_type_ids[0][0] =1
# print(inputs.token_type_ids)
# #TODO set token type ids

# %%
# class BinaryDataset(torch.utils.data.Dataset):
#     def __init__(self, encodings):
#         self.encodings = encodings
#     def __getitem__(self, idx):
#         return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#     def __len__(self):
#         return len(self.encodings.input_ids)

# %%
class BinaryDataset(torch.utils.data.Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        
    def __getitem__(self, index):
        text = self.texts[index]
        label = self.labels[index]
        
        # Tokenize the text
        tokenized_text = (self.tokenizer(text , max_length= MAX_TOKEN_SIZE,padding='max_length', truncation=True , return_tensors='pt')).to(device)
        
        # Convert tokens to input IDs
#         input_ids = self.tokenizer.convert_tokens_to_ids(tokenized_text)
        
        # Create input tensors
#         input_ids = tokenized_text['input_ids']  #torch.tensor(input_ids)
        label = torch.tensor([label]).to(device)
        
        return tokenized_text, label
        
#         return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
    def __len__(self):
        return len(self.texts)

# %%
dataset = BinaryDataset(ALL_INPUT_LIST, ALL_LABEL_LIST,tokenizer)
# train_size = int(0.8 * len(dataset))
# validation_size = len(dataset) - train_size



# Created using indices from 0 to train_size.
train_dataset = torch.utils.data.Subset(dataset, range(TRAIN_SAMPLE_COUNT))

# Created using indices from train_size to train_size + test_size.
validation_dataset = torch.utils.data.Subset(dataset, range(TRAIN_SAMPLE_COUNT, TRAIN_SAMPLE_COUNT + VAL_SAMPLE_COUNT))


# train_dataset, validation_dataset = torch.utils.data.random_split(dataset, [train_size, validation_size])



train_loader      = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE ,shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
TRAIN_SAMPLE_COUNT,  VAL_SAMPLE_COUNT
len(validation_dataset),VAL_SAMPLE_COUNT, TRAIN_SAMPLE_COUNT+VAL_SAMPLE_COUNT- len(dataset)
# Out:
# (230666, 230666, 0)

# %%
dataset_path = 'data/typedata_dataset'+EXPERIMENT_NAME+'.ignore.pkl'
with open(dataset_path, 'wb') as f:
    pickle.dump([train_dataset, validation_dataset], f)
    
    
with open(dataset_path, 'rb') as file:
    train_dataset, validation_dataset  = pickle.load(file)    
    
    
# train_loader      = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE ,shuffle=True) 
# validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
len(validation_loader), len(train_loader)
# Out:
# (7689, 31177)

# %%
# global_task2_metrices, global_task1_metrices ,v_global_task1_metrices, v_global_task2_metrices

from numpy import *
import math
import matplotlib.pyplot as plt


def plot_graph(task1_metrices,   v_task1_metrices, label = "TypeGraph" ):
    
    plt.ioff()

    font_size = 10
    x_labels = [ i for i in range(len(task1_metrices)) ]
    
    task1_f1 = [ i['f1'] for i in task1_metrices ]

    
    v_task1_f1 = [ i['f1'] for i in v_task1_metrices ]

    

    plt.ylabel(' F1 ',fontsize=font_size)
    plt.plot(x_labels, task1_f1 , 'r') 

    print(x_labels, v_task1_f1 )
    plt.plot(x_labels, v_task1_f1 , 'r' , linestyle = '--') 

    
    plt.xlabel("Epoch", fontsize=font_size)
    plt.title(label,fontsize=font_size)
    plt.legend([' Type Train',  'Type Val' ], loc='upper left')
    
    plt.savefig('./output/'+label+'_f1.pdf')
    plt.close()
    plt.show()
    
    ################################
    ################# LOSS #########
    ################################
    
    task1_loss = [ i['loss'] for i in task1_metrices ]

    
    v_task1_loss = [ i['loss'] for i in v_task1_metrices ]
    

    plt.ylabel(' LOSS ',fontsize=font_size)
    plt.plot(x_labels, task1_loss , 'r') 
    
    plt.plot(x_labels, v_task1_loss , 'r' , linestyle = '--') 

    
    plt.xlabel("Epoch", fontsize=font_size)
    plt.title(label,fontsize=font_size)
    plt.legend([' Type Train',  'Type Val'], loc='upper left')
    
    plt.savefig('./output/'+label+'_loss.pdf')
    plt.close()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix,ConfusionMatrixDisplay
import seaborn as sns

def plot_confusion_matrix(true_labels, predicted_labels, label='confusion_matrix'):

    class_labels = list(TYPE_MAPPING.keys())  
    class_labels = [c for c in class_labels]

    cm = confusion_matrix(true_labels, predicted_labels ) 
    
    conf_per_class = cm.diagonal()/cm.sum(axis=1)
    average_acc = sum([i for i in conf_per_class  if not math.isnan(i)] )/len(conf_per_class)
    
    print('CONFUSION PER CLASS' , conf_per_class,average_acc)
    
    fig, ax = plt.subplots(figsize=(20, 20))
    
    res = sns.heatmap(cm,
            annot=True , cmap="Blues" , fmt='g' , xticklabels=class_labels,linewidths = .01,
                      yticklabels=class_labels,linecolor="Gray")
    for _, spine in res.spines.items():
        spine.set_visible(True)
        spine.set_linewidth(1)
    
    plt.ylabel('Actual',fontsize=13)
    plt.xlabel('Prediction',fontsize=13)
    plt.title('Confusion Matrix',fontsize=17)
    plt.savefig('./output/'+label+'_conf.pdf',dpi=200)
    plt.show()
    plt.close()
    
    f1_score_per_class = f1_score(true_labels, predicted_labels, average=None)
    print(f1_score_per_class,class_labels)
    f1_scores_with_labels = {label:score for label,score in zip(class_labels, f1_score_per_class)}
    print(f1_scores_with_labels)
# plot_confusion_matrix(v_ground_truth_s , v_prediction_s ,label=EXPERIMENT_NAME)

# %%
  #--optimizer adam --adam-betas '(0.9,0.98)' --adam-eps 1e-6 --clip-norm 0.0 \
 # --lr-scheduler polynomial_decay --lr $PEAK_LR --warmup-updates $WARMUP_UPDATES --total-num-update $TOTAL_UPDATES \
  #--dropout 0.1 --attention-dropout 0.1 --weight-decay 0.01 \

#     ( params: typing.Iterable[torch.nn.parameter.Parameter]lr: float = 0.001betas: typing.Tuple[float, 
# float] = (0.9, 0.999)eps: float = 1e-06weight_decay: float = 0.0correct_bias: bool = Trueno_deprecation_warning: bool = False )
    
# initialize optimizer
optim = AdamW( model.parameters() , lr=1e-5, eps = 1e-6, betas=(0.9,0.98), weight_decay=0.01)
criterion = nn.CrossEntropyLoss()
# Out:
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
def training_loop(model ,data_loop, is_training = False):
    
    prediction_s, ground_truth_s = [], []
    losses = []

    for N,batch in enumerate(data_loop):

        # Forward pass
        if is_training == True:
            optim.zero_grad()
        
        batch_input, batch_labels = batch
        if len(batch_labels)<BATCH_SIZE:
            continue
        batch_input_ids= batch_input['input_ids']
        batch_attention_mask=batch_input['attention_mask']
        batch_token_type_ids =batch_input['token_type_ids']

        outputs = model(input_ids=batch_input_ids.squeeze(),
                        attention_mask=batch_attention_mask.squeeze(),
                        token_type_ids=batch_token_type_ids.squeeze(),
                        labels=batch_labels )
        
#

        loss = outputs.loss
        losses.append(loss.item())
        
        logits = outputs.logits
        predictions = torch.argmax(logits, dim=1)
        


        prediction_s.extend(predictions.detach().cpu().numpy().flatten())
        ground_truth_s.extend(batch_labels.detach().cpu().numpy().flatten())


        if is_training == True:
            loss.backward()
            optim.step()


        # print relevant info to progress bar
        data_loop.set_description(f'Epoch {ecpoch}')
        data_loop.set_postfix(loss=loss.item())

    ###### Training Scores
    accuracy = accuracy_score(ground_truth_s, prediction_s)    
    precision, recall, f1, _ = precision_recall_fscore_support(ground_truth_s,prediction_s,average='weighted')
    metrices = {'accuracy':accuracy ,
                      'precision':precision, 
                      'recall':recall, 
                      'f1':f1,
                      'loss': (sum(losses) / len(losses))}
    


    return metrices , prediction_s, ground_truth_s

# %%
EPOCHS = 30


global_metrices = []
v_global_metrices = []


for ecpoch in range(EPOCHS):
    
    train_loop = tqdm(train_loader, leave=True)
    model.train()
    metrices,prediction_s, ground_truth_s  = training_loop(model ,train_loop, is_training = True)
    print('Training metrices: ',metrices)
    global_metrices.append(metrices)
    
    with torch.no_grad():
        model.eval()
        validation_loop = tqdm(validation_loader, leave=True)
        v_metrices, v_prediction_s, v_ground_truth_s  = training_loop(model ,validation_loop, is_training = False)
        plot_confusion_matrix(v_ground_truth_s , v_prediction_s ,label=EXPERIMENT_NAME)
        print('v_metrices: ',v_metrices)
        v_global_metrices.append(v_metrices)
    plot_graph(global_metrices,v_global_metrices , label = EXPERIMENT_NAME)
    print('SAVING MODEL @ ',MODEL_SAVE_PATH +EXPERIMENT_NAME)
#     model.save_pretrained(MODEL_SAVE_PATH +EXPERIMENT_NAME)
# Out:
# Epoch 0: 100%|██████| 31177/31177 [3:45:55<00:00,  2.30it/s, loss=0.362]
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training metrices:  {'accuracy': 0.7060527328714395, 'precision': 0.706061000897917, 'recall': 0.7060527328714395, 'f1': 0.7022337645987289, 'loss': 1.009885950724257}
# Epoch 0: 100%|██████████| 7689/7689 [24:28<00:00,  5.24it/s, loss=0.391]
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# CONFUSION PER CLASS [0.76875902 0.72918549 0.60580363 0.67018581 0.56277893 0.82475752
#  0.88208617 0.70040425 0.95538378 0.85228971 0.93428386 0.81136848
#  0.93139196 0.02040816 0.94271767 0.72488105 0.5601876  0.88100702
#  0.58812721 0.79735929 0.46782771 0.26137876 0.69486312 0.95284477
#  0.87532159 0.9476386  0.67220957 0.90643142 0.88724584 0.57145519
#  0.54003971 0.72652531 0.3853211  0.39760033 0.82217344 0.11710677
#  0.56933484 0.78960195 0.94946809 0.48915187 0.22591362 0.08433735
#  0.15789474 0.         0.01111111 0.31333333 0.04411765 0.33928571
#  0.17307692 0.        ] 0.5823195409673415
# [0.79116391 0.73297003 0.63619286 0.71967349 0.51992853 0.81491107
#  0.76329387 0.70155969 0.91642276 0.89779559 0.93379971 0.73633343
#  0.78852128 0.03753351 0.89909739 0.76042278 0.52260574 0.91439296
#  0.62341748 0.86443865 0.50379384 0.34595737 0.6738255  0.95602265
#  0.81983318 0.85667878 0.67667966 0.90396186 0.84235156 0.65548194
#  0.570131   0.67728923 0.30434783 0.55920861 0.87773438 0.14366197
#  0.5667789  0.73832131 0.77272727 0.48108632 0.29405405 0.07821229
#  0.25       0.         0.01360544 0.4        0.08053691 0.45508982
#  0.27067669 0.        ] ['int', 'array_int', 'array_signed char', '*structure', 'structure', '*int', '*char', 'array_char', 'float', 'char', 'double', '*signed char', 'unsigned int', '*void', 'signed char', 'unsigned long int', 'long int', 'array_float', 'long long int', 'array_double', 'array_unsigned int', 'long long unsigned int', 'long unsigned int', 'short int', '*double', 'short unsigned int', 'array_structure', '*long int', '*float', 'array_long int', 'array_long long int', '*unsigned int', 'array_unsigned long long int', 'unsigned short int', '*short int', '*long long int', 'array_short int', '*long unsigned int', '*short unsigned int', 'unsigned long long int', 'array_unsigned short int', 'array_unsigned long int', 'array_long long unsigned int', 'long double', '*unsigned long int', 'array_long unsigned int', '*long long unsigned int', 'array_short unsigned int', '*unsigned short int', '*unsigned long long int', 'array_long double', '*long double']
# {'int': 0.7911639131241879, 'array_int': 0.7329700272479565, 'array_signed char': 0.6361928616155291, '*structure': 0.7196734940669639, 'structure': 0.5199285321605277, '*int': 0.8149110696012344, '*char': 0.7632938714108184, 'array_char': 0.7015596880623876, 'float': 0.9164227642276422, 'char': 0.8977955911823647, 'double': 0.9337997149889882, '*signed char': 0.7363334340078526, 'unsigned int': 0.7885212760711997, '*void': 0.037533512064343154, 'signed char': 0.8990973871733967, 'unsigned long int': 0.7604227833235467, 'long int': 0.5226057365094798, 'array_float': 0.9143929551032192, 'long long int': 0.6234174844557644, 'array_double': 0.8644386486322556, 'array_unsigned int': 0.5037938439513243, 'long long unsigned int': 0.3459573718513299, 'long unsigned int': 0.6738255033557047, 'short int': 0.9560226479484991, '*double': 0.8198331788693235, 'short unsigned int': 0.8566787841287029, 'array_structure': 0.6766796606282962, '*long int': 0.9039618571915086, '*float': 0.8423515647850248, 'array_long int': 0.6554819405855953, 'array_long long int': 0.5701310043668122, '*unsigned int': 0.6772892295280355, 'array_unsigned long long int': 0.30434782608695654, 'unsigned short int': 0.559208612161769, '*short int': 0.8777343750000001, '*long long int': 0.14366197183098592, 'array_short int': 0.5667789001122335, '*long unsigned int': 0.738321306494493, '*short unsigned int': 0.7727272727272727, 'unsigned long long int': 0.48108632395732304, 'array_unsigned short int': 0.29405405405405405, 'array_unsigned long int': 0.0782122905027933, 'array_long long unsigned int': 0.25, 'long double': 0.0, '*unsigned long int': 0.013605442176870748, 'array_long unsigned int': 0.4, '*long long unsigned int': 0.08053691275167787, 'array_short unsigned int': 0.4550898203592814, '*unsigned short int': 0.27067669172932335, '*unsigned long long int': 0.0}
# v_metrices:  {'accuracy': 0.7607830385015609, 'precision': 0.7634808786344124, 'recall': 0.7607830385015609, 'f1': 0.7564095426686364, 'loss': 0.7920403092397953}
# [0] [0.7564095426686364]
# SAVING MODEL @  /home/raisul/models/TYPE_WRITER_BERT_final_O_0123
# Epoch 1: 100%|██████| 31177/31177 [3:52:49<00:00,  2.23it/s, loss=0.299]
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training metrices:  {'accuracy': 0.8483021127362929, 'precision': 0.8493094885200464, 'recall': 0.8483021127362929, 'f1': 0.8478924061266389, 'loss': 0.4866390426910616}
# Epoch 1: 100%|██████████| 7689/7689 [24:49<00:00,  5.16it/s, loss=0.702]
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# CONFUSION PER CLASS [0.83682059 0.80276236 0.80119205 0.81962827 0.660964   0.8590924
#  0.82751323 0.74356287 0.95023054 0.87294469 0.95735027 0.82323972
#  0.88461986 0.0728863  0.91739737 0.78371572 0.59145388 0.89526393
#  0.6259542  0.83631685 0.55927698 0.20808941 0.73636177 0.95276747
#  0.90540273 0.94095499 0.66795719 0.90562386 0.8831329  0.5832246
#  0.67460317 0.69207449 0.39908257 0.43442284 0.84632272 0.45235362
#  0.54114994 0.88789602 0.9481383  0.42800789 0.29568106 0.03614458
#  0.13157895 0.14473684 0.         0.44666667 0.11029412 0.34821429
#  0.17307692 0.        ] 0.6179229200439699
# [0.83742479 0.76631138 0.66352219 0.75372265 0.59188703 0.85564562
#  0.8183585  0.73574285 0.92679056 0.90053971 0.93879108 0.76485501
#  0.86478489 0.10729614 0.90114515 0.79743772 0.60228177 0.92791754
#  0.64229765 0.87462704 0.65693545 0.3049922  0.70706971 0.96082635
#  0.84432961 0.88151355 0.7228589  0.91415766 0.87317073 0.6770529
#  0.62053232 0.73793581 0.31238779 0.59255079 0.90422205 0.42525634
#  0.58252427 0.74001354 0.84830458 0.46417112 0.3827957  0.05769231
#  0.21505376 0.24444444 0.         0.44666667 0.16129032 0.44318182
#  0.27692308 0.        ] ['int', 'array_int', 'array_signed char', '*structure', 'structure', '*int', '*char', 'array_char', 'float', 'char', 'double', '*signed char', 'unsigned int', '*void', 'signed char', 'unsigned long int', 'long int', 'array_float', 'long long int', 'array_double', 'array_unsigned int', 'long long unsigned int', 'long unsigned int', 'short int', '*double', 'short unsigned int', 'array_structure', '*long int', '*float', 'array_long int', 'array_long long int', '*unsigned int', 'array_unsigned long long int', 'unsigned short int', '*short int', '*long long int', 'array_short int', '*long unsigned int', '*short unsigned int', 'unsigned long long int', 'array_unsigned short int', 'array_unsigned long int', 'array_long long unsigned int', 'long double', '*unsigned long int', 'array_long unsigned int', '*long long unsigned int', 'array_short unsigned int', '*unsigned short int', '*unsigned long long int', 'array_long double', '*long double']
# {'int': 0.837424789410349, 'array_int': 0.7663113794590597, 'array_signed char': 0.6635221850490868, '*structure': 0.7537226466399067, 'structure': 0.5918870312395924, '*int': 0.8556456235159258, '*char': 0.8183584990282553, 'array_char': 0.7357428529106799, 'float': 0.9267905561801469, 'char': 0.9005397070161912, 'double': 0.9387910760821203, '*signed char': 0.7648550052556731, 'unsigned int': 0.8647848850443888, '*void': 0.1072961373390558, 'signed char': 0.9011451502397965, 'unsigned long int': 0.7974377224199289, 'long int': 0.6022817723534094, 'array_float': 0.9279175376630865, 'long long int': 0.6422976501305484, 'array_double': 0.8746270403088985, 'array_unsigned int': 0.656935446101007, 'long long unsigned int': 0.3049921996879875, 'long unsigned int': 0.7070697124852303, 'short int': 0.9608263496394466, '*double': 0.8443296115161023, 'short unsigned int': 0.8815135481802148, 'array_structure': 0.7228589032655576, '*long int': 0.9141576649046197, '*float': 0.8731707317073172, 'array_long int': 0.6770529049010062, 'array_long long int': 0.620532319391635, '*unsigned int': 0.7379358115908566, 'array_unsigned long long int': 0.3123877917414722, 'unsigned short int': 0.5925507900677202, '*short int': 0.9042220484753715, '*long long int': 0.42525634106853755, 'array_short int': 0.5825242718446603, '*long unsigned int': 0.7400135409614083, '*short unsigned int': 0.8483045806067817, 'unsigned long long int': 0.4641711229946524, 'array_unsigned short int': 0.38279569892473114, 'array_unsigned long int': 0.05769230769230769, 'array_long long unsigned int': 0.2150537634408602, 'long double': 0.24444444444444444, '*unsigned long int': 0.0, 'array_long unsigned int': 0.44666666666666666, '*long long unsigned int': 0.16129032258064516, 'array_short unsigned int': 0.4431818181818182, '*unsigned short int': 0.2769230769230769, '*unsigned long long int': 0.0}
# v_metrices:  {'accuracy': 0.7930064169268124, 'precision': 0.7978932831657359, 'recall': 0.7930064169268124, 'f1': 0.7895193843989493, 'loss': 0.7509414759996608}
# [0, 1] [0.7564095426686364, 0.7895193843989493]
# SAVING MODEL @  /home/raisul/models/TYPE_WRITER_BERT_final_O_0123
# Epoch 2: 100%|██████| 31177/31177 [3:57:39<00:00,  2.19it/s, loss=0.396]
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training metrices:  {'accuracy': 0.8893764434180138, 'precision': 0.8899347638030479, 'recall': 0.8893764434180138, 'f1': 0.8891494562688788, 'loss': 0.35128882093247993}
# Epoch 2: 100%|████| 7689/7689 [24:26<00:00,  5.24it/s, loss=0.455]
# CONFUSION PER CLASS [0.89996393 0.79721182 0.73258278 0.77080107 0.70952381 0.87502056
#  0.86874338 0.77781105 0.95768344 0.87088883 0.95397978 0.7571885
#  0.84000932 0.23906706 0.926579   0.84298908 0.6509901  0.92183588
#  0.58128357 0.80185724 0.61978197 0.26031408 0.77009844 0.95268651
#  0.90599644 0.93447391 0.65178775 0.91462721 0.87738755 0.61740589
#  0.56051587 0.58138528 0.5        0.64418701 0.87783467 0.1836969
#  0.53776776 0.91233766 0.94680851 0.46153846 0.15448505 0.06024096
#  0.34210526 0.21052632 0.02222222 0.54666667 0.05882353 0.5
#  0.         0.        ] 0.6276342416792119
# [0.8190174  0.76940326 0.68559033 0.76761304 0.61034306 0.85067946
#  0.83014233 0.7210771  0.94152944 0.88191577 0.94201229 0.77141113
#  0.86779743 0.23229462 0.89034605 0.79461812 0.61520468 0.93804621
#  0.63135268 0.8637021  0.69400819 0.34730114 0.72497345 0.95397716
#  0.84644541 0.93081118 0.72446526 0.92017865 0.89153232 0.6872731
#  0.57988368 0.68398268 0.3154848  0.7595122  0.9109888  0.23686158
#  0.5788835  0.78988053 0.90069576 0.45392823 0.24505929 0.05865103
#  0.34899329 0.31683168 0.03809524 0.42268041 0.10702341 0.55445545
#  0.         0.        ] ['int', 'array_int', 'array_signed char', '*structure', 'structure', '*int', '*char', 'array_char', 'float', 'char', 'double', '*signed char', 'unsigned int', '*void', 'signed char', 'unsigned long int', 'long int', 'array_float', 'long long int', 'array_double', 'array_unsigned int', 'long long unsigned int', 'long unsigned int', 'short int', '*double', 'short unsigned int', 'array_structure', '*long int', '*float', 'array_long int', 'array_long long int', '*unsigned int', 'array_unsigned long long int', 'unsigned short int', '*short int', '*long long int', 'array_short int', '*long unsigned int', '*short unsigned int', 'unsigned long long int', 'array_unsigned short int', 'array_unsigned long int', 'array_long long unsigned int', 'long double', '*unsigned long int', 'array_long unsigned int', '*long long unsigned int', 'array_short unsigned int', '*unsigned short int', '*unsigned long long int', 'array_long double', '*long double']
# {'int': 0.8190173979647664, 'array_int': 0.7694032639840538, 'array_signed char': 0.6855903315773164, '*structure': 0.7676130389064143, 'structure': 0.6103430619559652, '*int': 0.850679456434852, '*char': 0.8301423307564483, 'array_char': 0.7210771045874106, 'float': 0.9415294352956863, 'char': 0.8819157720891825, 'double': 0.9420122887864825, '*signed char': 0.7714111344680273, 'unsigned int': 0.8677974257187537, '*void': 0.23229461756373937, 'signed char': 0.890346048915905, 'unsigned long int': 0.7946181242580135, 'long int': 0.6152046783625732, 'array_float': 0.9380462088242578, 'long long int': 0.6313526792568709, 'array_double': 0.863702096890817, 'array_unsigned int': 0.6940081875697803, 'long long unsigned int': 0.3473011363636363, 'long unsigned int': 0.7249734530360075, 'short int': 0.9539771627636927, '*double': 0.8464454100027735, 'short unsigned int': 0.930811179277437, 'array_structure': 0.7244652575623338, '*long int': 0.9201786532295007, '*float': 0.891532321177023, 'array_long int': 0.6872731044497459, 'array_long long int': 0.579883681149504, '*unsigned int': 0.683982683982684, 'array_unsigned long long int': 0.3154848046309696, 'unsigned short int': 0.7595121951219512, '*short int': 0.9109888024293036, '*long long int': 0.23686158401184307, 'array_short int': 0.5788834951456311, '*long unsigned int': 0.7898805340829232, '*short unsigned int': 0.900695762175838, 'unsigned long long int': 0.4539282250242483, 'array_unsigned short int': 0.2450592885375494, 'array_unsigned long int': 0.05865102639296187, 'array_long long unsigned int': 0.34899328859060397, 'long double': 0.31683168316831684, '*unsigned long int': 0.0380952380952381, 'array_long unsigned int': 0.42268041237113396, '*long long unsigned int': 0.10702341137123746, 'array_short unsigned int': 0.5544554455445545, '*unsigned short int': 0.0, '*unsigned long long int': 0.0}
# v_metrices:  {'accuracy': 0.7979361775927853, 'precision': 0.8011836408195493, 'recall': 0.7979361775927853, 'f1': 0.7950662717104234, 'loss': 0.7906497947398755}
# [0, 1, 2] [0.7564095426686364, 0.7895193843989493, 0.7950662717104234]
# SAVING MODEL @  /home/raisul/models/TYPE_WRITER_BERT_final_O_0123
# Epoch 3: 100%|█| 31177/31177 [3:38:34<00:00,  2.38it/s, loss=0.213
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training metrices:  {'accuracy': 0.9136707723890172, 'precision': 0.9140170437498282, 'recall': 0.9136707723890172, 'f1': 0.9135019940131998, 'loss': 0.26884986591302346}
# Epoch 3: 100%|█████| 7689/7689 [24:07<00:00,  5.31it/s, loss=1.54]
# CONFUSION PER CLASS [0.88289047 0.80518978 0.7981457  0.79251126 0.68977831 0.90891154
#  0.87845805 0.73892216 0.95768918 0.87973909 0.95733921 0.81312392
#  0.88831955 0.23906706 0.93743774 0.8265249  0.62662845 0.92259545
#  0.61187279 0.82434549 0.64601888 0.25399361 0.72859633 0.95895176
#  0.87373837 0.94078384 0.65360966 0.92940909 0.87122612 0.61286114
#  0.58928571 0.6733016  0.52293578 0.47743271 0.84522503 0.22962113
#  0.55806088 0.85227273 0.96404794 0.51084813 0.23421927 0.09036145
#  0.10526316 0.15789474 0.03333333 0.52666667 0.17647059 0.39285714
#  0.08653846 0.        ] 0.629506306360111
# [0.83876863 0.74334068 0.69939647 0.79926178 0.62107308 0.85539652
#  0.83353654 0.74443858 0.9460781  0.8941989  0.9473279  0.78521851
#  0.87346845 0.25786164 0.90830116 0.8176031  0.61254378 0.93669903
#  0.63503007 0.87850244 0.70160243 0.34515195 0.71539313 0.96080861
#  0.86407672 0.93470498 0.73759959 0.90942513 0.87867019 0.69061122
#  0.58870168 0.73275253 0.37936772 0.59601964 0.89569601 0.27855153
#  0.60624617 0.79335096 0.8877989  0.52857143 0.30954995 0.13888889
#  0.17977528 0.25806452 0.04761905 0.51973684 0.18426104 0.55345912
#  0.14634146 0.        ] ['int', 'array_int', 'array_signed char', '*structure', 'structure', '*int', '*char', 'array_char', 'float', 'char', 'double', '*signed char', 'unsigned int', '*void', 'signed char', 'unsigned long int', 'long int', 'array_float', 'long long int', 'array_double', 'array_unsigned int', 'long long unsigned int', 'long unsigned int', 'short int', '*double', 'short unsigned int', 'array_structure', '*long int', '*float', 'array_long int', 'array_long long int', '*unsigned int', 'array_unsigned long long int', 'unsigned short int', '*short int', '*long long int', 'array_short int', '*long unsigned int', '*short unsigned int', 'unsigned long long int', 'array_unsigned short int', 'array_unsigned long int', 'array_long long unsigned int', 'long double', '*unsigned long int', 'array_long unsigned int', '*long long unsigned int', 'array_short unsigned int', '*unsigned short int', '*unsigned long long int', 'array_long double', '*long double']
# {'int': 0.838768633274316, 'array_int': 0.7433406829152017, 'array_signed char': 0.6993964716805943, '*structure': 0.7992617830777967, 'structure': 0.6210730792417442, '*int': 0.8553965183752418, '*char': 0.8335365416337946, 'array_char': 0.7444385792926628, 'float': 0.946078103020966, 'char': 0.8941988950276243, 'double': 0.9473279014563419, '*signed char': 0.7852185089974294, 'unsigned int': 0.873468452994389, '*void': 0.2578616352201258, 'signed char': 0.9083011583011584, 'unsigned long int': 0.8176030999169666, 'long int': 0.612543775867558, 'array_float': 0.9366990291262135, 'long long int': 0.6350300718791257, 'array_double': 0.8785024442589722, 'array_unsigned int': 0.7016024252923344, 'long long unsigned int': 0.34515195369030394, 'long unsigned int': 0.7153931339977851, 'short int': 0.9608086128107816, '*double': 0.8640767198356004, 'short unsigned int': 0.9347049821458935, 'array_structure': 0.7375995887946544, '*long int': 0.9094251336898396, '*float': 0.878670187975765, 'array_long int': 0.6906112161310649, 'array_long long int': 0.5887016848364718, '*unsigned int': 0.732752531198493, 'array_unsigned long long int': 0.37936772046589023, 'unsigned short int': 0.596019643318687, '*short int': 0.8956960062039551, '*long long int': 0.2785515320334262, 'array_short int': 0.6062461726883037, '*long unsigned int': 0.7933509633547412, '*short unsigned int': 0.8877988963825874, 'unsigned long long int': 0.5285714285714286, 'array_unsigned short int': 0.30954994511525796, 'array_unsigned long int': 0.1388888888888889, 'array_long long unsigned int': 0.1797752808988764, 'long double': 0.25806451612903225, '*unsigned long int': 0.04761904761904761, 'array_long unsigned int': 0.5197368421052633, '*long long unsigned int': 0.18426103646833017, 'array_short unsigned int': 0.5534591194968554, '*unsigned short int': 0.14634146341463417, '*unsigned long long int': 0.0}
# v_metrices:  {'accuracy': 0.8038935137010059, 'precision': 0.8047254492434597, 'recall': 0.8038935137010059, 'f1': 0.8005649053724413, 'loss': 0.8251626563537575}
# [0, 1, 2, 3] [0.7564095426686364, 0.7895193843989493, 0.7950662717104234, 0.8005649053724413]
# SAVING MODEL @  /home/raisul/models/TYPE_WRITER_BERT_final_O_0123
# Epoch 4: 100%|█| 31177/31177 [3:38:23<00:00,  2.38it/s, loss=0.16]
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training metrices:  {'accuracy': 0.930897699084766, 'precision': 0.9311756544151896, 'recall': 0.930897699084766, 'f1': 0.9308006855249426, 'loss': 0.2127130806071109}
# Epoch 4: 100%|████| 7689/7689 [24:09<00:00,  5.31it/s, loss=0.408]
# CONFUSION PER CLASS [0.82878442 0.83092411 0.74940397 0.79512813 0.75260339 0.88788427
#  0.88450491 0.7524708  0.96256612 0.89222615 0.94968227 0.82390523
#  0.91151473 0.20699708 0.92288532 0.82876329 0.69615635 0.93192407
#  0.49264914 0.83359445 0.59306036 0.38461538 0.70444057 0.94635541
#  0.88418135 0.94781865 0.64845173 0.91175131 0.89032656 0.59772685
#  0.4593254  0.683254   0.7293578  0.34960695 0.84345282 0.21010333
#  0.57046223 0.8961039  0.96276596 0.19921105 0.22296173 0.15060241
#  0.42105263 0.15789474 0.         0.57333333 0.0625     0.52678571
#  0.         0.        ] 0.6292414072058713
# [0.84670188 0.74453568 0.69933873 0.79776789 0.5941629  0.85621433
#  0.84011774 0.7527526  0.94822633 0.89380531 0.94618515 0.7869311
#  0.87017895 0.27897839 0.90920691 0.81485557 0.6151632  0.93943642
#  0.57220261 0.88086088 0.68959654 0.43841019 0.70920448 0.95786879
#  0.87956672 0.93085777 0.72010114 0.91398893 0.87048193 0.68016538
#  0.52198422 0.74905123 0.38922889 0.50327576 0.90130936 0.2532872
#  0.54262735 0.75616438 0.88616891 0.28571429 0.235708   0.18587361
#  0.40251572 0.26373626 0.         0.35390947 0.08095238 0.56730769
#  0.         0.        ] ['int', 'array_int', 'array_signed char', '*structure', 'structure', '*int', '*char', 'array_char', 'float', 'char', 'double', '*signed char', 'unsigned int', '*void', 'signed char', 'unsigned long int', 'long int', 'array_float', 'long long int', 'array_double', 'array_unsigned int', 'long long unsigned int', 'long unsigned int', 'short int', '*double', 'short unsigned int', 'array_structure', '*long int', '*float', 'array_long int', 'array_long long int', '*unsigned int', 'array_unsigned long long int', 'unsigned short int', '*short int', '*long long int', 'array_short int', '*long unsigned int', '*short unsigned int', 'unsigned long long int', 'array_unsigned short int', 'array_unsigned long int', 'array_long long unsigned int', 'long double', '*unsigned long int', 'array_long unsigned int', '*long long unsigned int', 'array_short unsigned int', '*unsigned short int', '*unsigned long long int', 'array_long double', '*long double']
# {'int': 0.8467018793759981, 'array_int': 0.7445356771134498, 'array_signed char': 0.6993387306099746, '*structure': 0.7977678886769796, 'structure': 0.5941628985847672, '*int': 0.8562143310082434, '*char': 0.8401177399669754, 'array_char': 0.7527526028012883, 'float': 0.9482263344244772, 'char': 0.8938053097345133, 'double': 0.9461851540797209, '*signed char': 0.786931095855581, 'unsigned int': 0.8701789485384018, '*void': 0.27897838899803534, 'signed char': 0.9092069100903023, 'unsigned long int': 0.8148555708390648, 'long int': 0.6151632030395487, 'array_float': 0.9394364222627226, 'long long int': 0.5722026106231016, 'array_double': 0.8808608762490393, 'array_unsigned int': 0.6895965373318905, 'long long unsigned int': 0.4384101941747573, 'long unsigned int': 0.7092044809250941, 'short int': 0.9578687947424012, '*double': 0.8795667159034958, 'short unsigned int': 0.9308577669495085, 'array_structure': 0.720101137800253, '*long int': 0.9139889275726272, '*float': 0.8704819277108435, 'array_long int': 0.6801653768684406, 'array_long long int': 0.5219842164599774, '*unsigned int': 0.7490512333965844, 'array_unsigned long long int': 0.3892288861689106, 'unsigned short int': 0.5032757593805837, '*short int': 0.9013093609536839, '*long long int': 0.2532871972318339, 'array_short int': 0.542627345844504, '*long unsigned int': 0.756164383561644, '*short unsigned int': 0.8861689106487147, 'unsigned long long int': 0.2857142857142857, 'array_unsigned short int': 0.2357080035180299, 'array_unsigned long int': 0.1858736059479554, 'array_long long unsigned int': 0.4025157232704403, 'long double': 0.26373626373626374, '*unsigned long int': 0.0, 'array_long unsigned int': 0.35390946502057613, '*long long unsigned int': 0.08095238095238096, 'array_short unsigned int': 0.5673076923076924, '*unsigned short int': 0.0, '*unsigned long long int': 0.0}
# v_metrices:  {'accuracy': 0.7985995490808185, 'precision': 0.8052353159944304, 'recall': 0.7985995490808185, 'f1': 0.7962603633313358, 'loss': 0.9310582768667245}
# [0, 1, 2, 3, 4] [0.7564095426686364, 0.7895193843989493, 0.7950662717104234, 0.8005649053724413, 0.7962603633313358]
# SAVING MODEL @  /home/raisul/models/TYPE_WRITER_BERT_final_O_0123
# Epoch 5: 100%|█| 31177/31177 [3:42:29<00:00,  2.34it/s, loss=0.127
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training metrices:  {'accuracy': 0.9435121033273458, 'precision': 0.943740481947912, 'recall': 0.9435121033273458, 'f1': 0.9434434536215661, 'loss': 0.17180692061854863}
# Epoch 5: 100%|██████| 7689/7689 [27:08<00:00,  4.72it/s, loss=0.872]
# CONFUSION PER CLASS [0.84030784 0.81246773 0.81600212 0.86398198 0.71228801 0.88554514
#  0.86273621 0.73637725 0.96013019 0.89550211 0.96202203 0.81871423
#  0.89846297 0.28862974 0.81159709 0.83351987 0.56591975 0.87537381
#  0.76290117 0.81671702 0.63803191 0.37796114 0.72387983 0.93723429
#  0.89075797 0.95312233 0.71880692 0.90504383 0.83204931 0.58154706
#  0.64880952 0.6881767  0.60550459 0.59371121 0.81668496 0.30309989
#  0.53776776 0.87337662 0.96542553 0.40631164 0.17607973 0.06024096
#  0.23684211 0.07894737 0.         0.52666667 0.13970588 0.57142857
#  0.         0.        ] 0.6361282110302766
# [0.84101577 0.74141688 0.70711129 0.78170584 0.63636364 0.85333967
#  0.85026818 0.74586808 0.93206951 0.82565934 0.94728781 0.77634734
#  0.88062086 0.27576602 0.84152893 0.79898082 0.61871528 0.9221921
#  0.69086486 0.87554729 0.6974851  0.44312685 0.72689833 0.95713609
#  0.88254902 0.92989484 0.77141112 0.92580946 0.87181143 0.69433626
#  0.61766095 0.7454844  0.33460076 0.6964329  0.89351481 0.34874505
#  0.56382979 0.83637777 0.88321168 0.46978335 0.25178147 0.09569378
#  0.31578947 0.14117647 0.         0.48615385 0.19387755 0.59534884
#  0.         0.        ] ['int', 'array_int', 'array_signed char', '*structure', 'structure', '*int', '*char', 'array_char', 'float', 'char', 'double', '*signed char', 'unsigned int', '*void', 'signed char', 'unsigned long int', 'long int', 'array_float', 'long long int', 'array_double', 'array_unsigned int', 'long long unsigned int', 'long unsigned int', 'short int', '*double', 'short unsigned int', 'array_structure', '*long int', '*float', 'array_long int', 'array_long long int', '*unsigned int', 'array_unsigned long long int', 'unsigned short int', '*short int', '*long long int', 'array_short int', '*long unsigned int', '*short unsigned int', 'unsigned long long int', 'array_unsigned short int', 'array_unsigned long int', 'array_long long unsigned int', 'long double', '*unsigned long int', 'array_long unsigned int', '*long long unsigned int', 'array_short unsigned int', '*unsigned short int', '*unsigned long long int', 'array_long double', '*long double']
# {'int': 0.8410157660368276, 'array_int': 0.7414168776868265, 'array_signed char': 0.7071112896745682, '*structure': 0.7817058411363781, 'structure': 0.6363636363636364, '*int': 0.8533396719752794, '*char': 0.8502681764004767, 'array_char': 0.7458680818802123, 'float': 0.9320695102685624, 'char': 0.825659337217315, 'double': 0.9472878111040204, '*signed char': 0.7763473431780891, 'unsigned int': 0.8806208628167086, '*void': 0.2757660167130919, 'signed char': 0.8415289256198347, 'unsigned long int': 0.7989808233874213, 'long int': 0.6187152827232588, 'array_float': 0.9221921019854934, 'long long int': 0.6908648614045196, 'array_double': 0.8755472920290288, 'array_unsigned int': 0.6974850995784271, 'long long unsigned int': 0.4431268528631612, 'long unsigned int': 0.7268983268983269, 'short int': 0.957136090937796, '*double': 0.8825490196078432, 'short unsigned int': 0.9298948422633951, 'array_structure': 0.771411117898595, '*long int': 0.9258094572559982, '*float': 0.8718114304165322, 'array_long int': 0.6943362634917104, 'array_long long int': 0.6176609475838187, '*unsigned int': 0.7454844006568143, 'array_unsigned long long int': 0.33460076045627374, 'unsigned short int': 0.6964329046347973, '*short int': 0.8935148118494796, '*long long int': 0.3487450462351387, 'array_short int': 0.5638297872340425, '*long unsigned int': 0.8363777691410804, '*short unsigned int': 0.8832116788321168, 'unsigned long long int': 0.4697833523375143, 'array_unsigned short int': 0.2517814726840855, 'array_unsigned long int': 0.09569377990430622, 'array_long long unsigned int': 0.3157894736842105, 'long double': 0.1411764705882353, '*unsigned long int': 0.0, 'array_long unsigned int': 0.4861538461538461, '*long long unsigned int': 0.19387755102040818, 'array_short unsigned int': 0.5953488372093023, '*unsigned short int': 0.0, '*unsigned long long int': 0.0}
# v_metrices:  {'accuracy': 0.8021505376344086, 'precision': 0.8083106417788938, 'recall': 0.8021505376344086, 'f1': 0.8009911067837765, 'loss': 0.937074926957773}
# [0, 1, 2, 3, 4, 5] [0.7564095426686364, 0.7895193843989493, 0.7950662717104234, 0.8005649053724413, 0.7962603633313358, 0.8009911067837765]
# SAVING MODEL @  /home/raisul/models/TYPE_WRITER_BERT_final_O_0123
# Epoch 6: 100%|██| 31177/31177 [4:29:18<00:00,  1.93it/s, loss=0.186]
# /home/raisul/anaconda3/envs/pytorch/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training metrices:  {'accuracy': 0.953052561799675, 'precision': 0.9532423194977511, 'recall': 0.953052561799675, 'f1': 0.953004514157611, 'loss': 0.14229423249867448}
# Epoch 6:  35%|██    | 2721/7689 [09:42<17:46,  4.66it/s, loss=0.692]

# %%
model.save_pretrained( MODEL_SAVE_PATH  + EXPERIMENT_NAME )

# %%
print('Alhamdulillah')
