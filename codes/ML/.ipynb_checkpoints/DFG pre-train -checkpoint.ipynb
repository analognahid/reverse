# %%
import sys,os, pickle
from elftools.elf.elffile import ELFFile
from elftools.elf.segments import Segment
from capstone import *
from capstone.x86 import *
from collections import defaultdict
import posixpath
import random

# %%
DATA_PATH = './dfg_data/'

# %%
file_name = 'array'

with (open(DATA_PATH+file_name , "rb")) as openfile:
    bb_data , ins_data = pickle.load(openfile)

# %%
ins_data['start']
# Out:
# [['0x10a4',
#   '0x10a6',
#   '0x10a9',
#   '0x10aa',
#   '0x10ad',
#   '0x10b1',
#   '0x10b2',
#   '0x10b3',
#   '0x10b6',
#   '0x10bf'],
#  ['0x10c5'],
#  ['0x10a4', '0x10ad', '0x10b3', '0x10b6'],
#  ['0x10b8'],
#  ['0x10c5'],
#  ['0x10b1'],
#  ['0x10bf']]

# %%
bb_data
# Out:
# {4256: [4256, 4294],
#  4260: [4256, 4294],
#  4262: [4256, 4294],
#  4265: [4256, 4294],
#  4266: [4256, 4294],
#  4269: [4256, 4294],
#  4273: [4256, 4294],
#  4274: [4256, 4294],
#  4275: [4256, 4294],
#  4278: [4256, 4294],
#  4280: [4256, 4294],
#  4287: [4256, 4294],
#  4293: [4256, 4294],
#  4304: [4304, 4323],
#  4311: [4304, 4323],
#  4318: [4304, 4323],
#  4321: [4304, 4323],
#  4323: [4323, 4335],
#  4330: [4323, 4335],
#  4333: [4323, 4335],
#  4335: [4335, 4337],
#  4344: [4344, 4345],
#  4352: [4352, 4388],
#  4359: [4352, 4388],
#  4366: [4352, 4388],
#  4369: [4352, 4388],
#  4372: [4352, 4388],
#  4376: [4352, 4388],
#  4380: [4352, 4388],
#  4383: [4352, 4388],
#  4386: [4352, 4388],
#  4388: [4388, 4400],
#  4395: [4388, 4400],
#  4398: [4388, 4400],
#  4400: [4400, 4402],
#  4408: [4408, 4409],
#  4416: [4416, 4429],
#  4420: [4416, 4429],
#  4427: [4416, 4429],
#  4429: [4429, 4443],
#  4430: [4429, 4443],
#  4438: [4429, 4443],
#  4441: [4429, 4443],
#  4443: [4443, 4455],
#  4450: [4443, 4455],
#  4455: [4455, 4469],
#  4460: [4455, 4469],
#  4467: [4455, 4469],
#  4468: [4455, 4469],
#  4472: [4472, 4473],
#  4480: [4480, 4489],
#  4484: [4480, 4489],
#  4489: [4489, 4545],
#  4493: [4489, 4545],
#  4494: [4489, 4545],
#  4497: [4489, 4545],
#  4501: [4489, 4545],
#  4510: [4489, 4545],
#  4514: [4489, 4545],
#  4516: [4489, 4545],
#  4523: [4489, 4545],
#  4526: [4489, 4545],
#  4531: [4489, 4545],
#  4536: [4489, 4545],
#  4543: [4489, 4545],
#  4545: [4545, 4600],
#  4548: [4545, 4600],
#  4550: [4545, 4600],
#  4553: [4545, 4600],
#  4557: [4545, 4600],
#  4561: [4545, 4600],
#  4564: [4545, 4600],
#  4566: [4545, 4600],
#  4570: [4545, 4600],
#  4573: [4545, 4600],
#  4576: [4545, 4600],
#  4583: [4545, 4600],
#  4586: [4545, 4600],
#  4591: [4545, 4600],
#  4596: [4545, 4600],
#  4600: [4600, 4606],
#  4604: [4600, 4606],
#  4606: [4606, 4635],
#  4613: [4606, 4635],
#  4616: [4606, 4635],
#  4621: [4606, 4635],
#  4626: [4606, 4635],
#  4633: [4606, 4635],
#  4635: [4635, 4656],
#  4638: [4635, 4656],
#  4640: [4635, 4656],
#  4643: [4635, 4656],
#  4647: [4635, 4656],
#  4654: [4635, 4656],
#  4656: [4656, 4751],
#  4659: [4656, 4751],
#  4663: [4656, 4751],
#  4665: [4656, 4751],
#  4668: [4656, 4751],
#  4672: [4656, 4751],
#  4675: [4656, 4751],
#  4682: [4656, 4751],
#  4686: [4656, 4751],
#  4688: [4656, 4751],
#  4690: [4656, 4751],
#  4693: [4656, 4751],
#  4695: [4656, 4751],
#  4697: [4656, 4751],
#  4700: [4656, 4751],
#  4702: [4656, 4751],
#  4704: [4656, 4751],
#  4706: [4656, 4751],
#  4709: [4656, 4751],
#  4716: [4656, 4751],
#  4720: [4656, 4751],
#  4722: [4656, 4751],
#  4724: [4656, 4751],
#  4727: [4656, 4751],
#  4729: [4656, 4751],
#  4731: [4656, 4751],
#  4734: [4656, 4751],
#  4736: [4656, 4751],
#  4738: [4656, 4751],
#  4740: [4656, 4751],
#  4743: [4656, 4751],
#  4747: [4656, 4751],
#  4751: [4751, 4757],
#  4755: [4751, 4757],
#  4757: [4757, 4761],
#  4761: [4761, 4771],
#  4765: [4761, 4771],
#  4771: [4771, 4791],
#  4776: [4771, 4791],
#  4780: [4771, 4791],
#  4789: [4771, 4791],
#  4791: [4791, 4796],
#  4796: [4796, 4798],
#  4797: [4796, 4798]}

# %%
bin_path = '/home/nahid/reverse/binaries/array'
md = Cs(CS_ARCH_X86, CS_MODE_64)

with open(bin_path, 'rb') as f:
        
        bin_bytearray = bytearray(f.read())
        elffile = ELFFile(f)



# for fname, connected_comps in ins_data.items():
    
#     merged_ins_data[fname] = []
#     checked = []
#     for ia, connected_comp_A in enumerate(connected_comps):
#         for ib,connected_comp_B in enumerate(connected_comps):
#             if ia==ib or ia in checked or ib in checked:
#                 continue
#             connected_comp_A_set = set(connected_comp_A)
#             connected_comp_B_set = set(connected_comp_B)
#             if len( connected_comp_A_set & connected_comp_B_set)>0:
#                 print(fname , connected_comp_A , connected_comp_B)
#                 merged_ins_data[fname].append(connected_comp_A_set.union(connected_comp_B_set))
#                 checked.append(ia )
#                 checked.append(ib )

# %%
# https://www.analyticsvidhya.com/blog/2022/04/all-about-popular-graph-network-tools-in-natural-language-processing/

import networkx as nx
from pyvis.network import Network
net = Network(notebook=True)



merged_ins_data= {}


for fname, connected_comps in ins_data.items():
    Graph = nx.DiGraph()
    for ia, connected_comp in enumerate(connected_comps):
        for addr in connected_comp:
            Graph.add_node(addr)
        
        
        for k in range(len(connected_comp)-1):
            Graph.add_edge(connected_comp[k] , connected_comp[k+1])
    
    merged_conn_comp = list(nx.weakly_connected_components(Graph) )
    merged_conn_comp = [ list(i) for i in merged_conn_comp]
    merged_ins_data[fname] = merged_conn_comp
#     print()
    


# #Create nodes
# Graph.add_node("C++")
# Graph.add_node("Python")
# Graph.add_node("Java")
# Graph.add_node("C#")
# Graph.add_node("Go")
# Graph.add_node("Julia")
# #For adding the edges between nodes with weight and value (Edges with higher value will appear as bold)
# Graph.add_edge("C++", "C#", weight=.75, value=20)
# Graph.add_edge("Python", "Julia", weight=.75, value=20)
# Graph.add_edge("Java", "Go", weight=.5)
# Graph.add_edge("Python", "C#", weight=.5)
# Graph.add_edge("Go", "C++", weight=.5)
# Graph.add_edge("Java", "Julia", weight=.5)
# Graph.add_edge("Java", "C#", weight=.75, value=20)
#For visualizing the graph
# net.from_nx(Graph)
# net.show("graph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %%
merged_ins_data
# Out:
# {'start': [['0x10b3',
#    '0x10a6',
#    '0x10b6',
#    '0x10bf',
#    '0x10aa',
#    '0x10b1',
#    '0x10ad',
#    '0x10a4',
#    '0x10a9',
#    '0x10b2'],
#   ['0x10c5'],
#   ['0x10b8']],
#  'deregister_tm_clones': [['0x10ed',
#    '0x10ef',
#    '0x10e1',
#    '0x10d7',
#    '0x10d0',
#    '0x10ea',
#    '0x10e3',
#    '0x10f8',
#    '0x10de']],
#  'register_tm_clones': [['0x1107',
#    '0x111c',
#    '0x111f',
#    '0x1138',
#    '0x110e',
#    '0x1124',
#    '0x1111',
#    '0x112e',
#    '0x1130',
#    '0x1118',
#    '0x1114',
#    '0x112b',
#    '0x1122',
#    '0x1100']],
#  '__do_global_dtors_aux': [['0x10ed', '0x10ea', '0x10e3'],
#   ['0x1159',
#    '0x114d',
#    '0x1174',
#    '0x114b',
#    '0x1144',
#    '0x114e',
#    '0x1167',
#    '0x115b',
#    '0x1162',
#    '0x1156',
#    '0x1173',
#    '0x1178'],
#   ['0x10f8'],
#   ['0x116c'],
#   ['0x10ef'],
#   ['0x10de', '0x10d7', '0x10d0', '0x10e1'],
#   ['0x1064']],
#  'frame_dummy': [['0x1107',
#    '0x111c',
#    '0x111f',
#    '0x1138',
#    '0x110e',
#    '0x1124',
#    '0x1111',
#    '0x112e',
#    '0x1130',
#    '0x1118',
#    '0x1114',
#    '0x112b',
#    '0x1122',
#    '0x1100'],
#   ['0x1184']],
#  'main': [['0x11a2',
#    '0x11c9',
#    '0x1212',
#    '0x121b',
#    '0x1239',
#    '0x11fc',
#    '0x1299',
#    '0x1230',
#    '0x11cd',
#    '0x123c',
#    '0x1252',
#    '0x1257',
#    '0x124a',
#    '0x1265',
#    '0x125c',
#    '0x1277',
#    '0x1287',
#    '0x1255',
#    '0x1223',
#    '0x122e',
#    '0x1243',
#    '0x125e',
#    '0x12b7',
#    '0x12bc',
#    '0x1240',
#    '0x11c4',
#    '0x128b',
#    '0x11d4',
#    '0x127e',
#    '0x1233',
#    '0x11ae',
#    '0x118d',
#    '0x11ef',
#    '0x120d',
#    '0x128f',
#    '0x1293',
#    '0x1295',
#    '0x11f4',
#    '0x1270',
#    '0x12ac',
#    '0x129d',
#    '0x1262',
#    '0x11b3',
#    '0x1250',
#    '0x1274',
#    '0x1282',
#    '0x1220',
#    '0x126c',
#    '0x11c1',
#    '0x11f8',
#    '0x1284',
#    '0x127b',
#    '0x12b5',
#    '0x11da',
#    '0x124e',
#    '0x11dd',
#    '0x12bd',
#    '0x1272',
#    '0x11b8',
#    '0x11c6',
#    '0x118e',
#    '0x12a8',
#    '0x1191',
#    '0x11d1',
#    '0x11d6',
#    '0x1259',
#    '0x121e',
#    '0x119e',
#    '0x1227',
#    '0x1279',
#    '0x1280',
#    '0x1195',
#    '0x1237',
#    '0x1260'],
#   ['0x11bf'],
#   ['0x11e7', '0x11e0'],
#   ['0x11ea'],
#   ['0x1208'],
#   ['0x1219'],
#   ['0x1074'],
#   ['0x1094'],
#   ['0x11a4', '0x11ab'],
#   ['0x1084'],
#   ['0x12a3'],
#   ['0x11fe', '0x1205']]}

# %%
        
input_list = []
label_list = []
dbug = []
    
for fname, connected_comps in merged_ins_data.items():
    
    print (fname,connected_comps)
    
    print(fname,'   ', len(connected_comps),'__'*10)
    

    
    prev_basic_blocks = []
    for connected_comp in connected_comps:
#         print(connected_comp)
#         continue
        if len(connected_comp)<2:
            continue
        bbs = []
        for addr in connected_comp:
            addr_int = int(addr, 16)
            if addr_int not in bb_data:
                continue
#             print(addr, addr_int,':' , bb_data[addr_int]  )
            bb_inf = bb_data[addr_int]  
            
            if bb_inf not in bbs:
                bbs.append(bb_inf)

        
        if bbs == prev_basic_blocks:
            print(">>>> same program. So CONTINUE")
            continue
            
            

        
        not_connected_nodes = []
        addr_inst = {}
        for bb_entry, bb_end in bbs:
            for inst in md.disasm(bin_bytearray[bb_entry:bb_end], bb_entry):
                print( inst.address , ' ', hex(inst.address) in connected_comp,'    ',hex(inst.address), '  : ' , inst.mnemonic+"  "+inst.op_str   )
                
                if hex(inst.address) not in connected_comp:
                    not_connected_nodes.append(str(hex(inst.address)))
                
                addr_inst[inst.address]=inst
                
                if inst.address == bb_end:
                    break
        prev_basic_blocks = bbs
        print(not_connected_nodes)  
        print('#'*100)
        node1 =None
        node2 = None
        label = None
        if len(not_connected_nodes)>0: #at least some note conneted instructions
            if random.randint(1,2)%2==0: # pair connected
                
                node1, node2 = random.sample(connected_comp, 2)
                label = True
            else:                        #pair disconnected
                
                node1 = random.choice(connected_comp)
                node2 = random.choice(not_connected_nodes)
                label = False
            
        else:
            node1, node2 = random.sample(connected_comp, 2)
            label = True
            
        input_slice = []
        
#         if node1== None or node2 == None:
#             print("WOW"*110)


        dbug.append([node1,node2])
        for addr,inst in addr_inst.items():
            print(addr,inst.mnemonic, inst.op_str)
            inst_str =str(hex(addr))+":" + inst.mnemonic + ' '+ inst.op_str + "<EOI>"
            
            if str(hex(addr)) in [node1,node2]:
                inst_str  =  "<LOOK>" +inst_str + "<LOOK>"  
            
            input_slice.append(inst_str)
              
        input_list.append( ''.join(input_slice))
        label_list.append( 1 if label==True else 0  )
# Out:
# start [['0x10b3', '0x10a6', '0x10b6', '0x10bf', '0x10aa', '0x10b1', '0x10ad', '0x10a4', '0x10a9', '0x10b2'], ['0x10c5'], ['0x10b8']]
# start     3 ____________________
# 4256   False      0x10a0   :  endbr64
# 4260   True      0x10a4   :  xor  ebp, ebp
# 4262   True      0x10a6   :  mov  r9, rdx
# 4265   True      0x10a9   :  pop  rsi
# 4266   True      0x10aa   :  mov  rdx, rsp
# 4269   True      0x10ad   :  and  rsp, 0xfffffffffffffff0
# 4273   True      0x10b1   :  push  rax
# 4274   True      0x10b2   :  push  rsp
# 4275   True      0x10b3   :  xor  r8d, r8d
# 4278   True      0x10b6   :  xor  ecx, ecx
# 4280   False      0x10b8   :  lea  rdi, [rip + 0xca]
# 4287   True      0x10bf   :  call  qword ptr [rip + 0x2f13]
# 4293   False      0x10c5   :  hlt
# ['0x10a0', '0x10b8', '0x10c5']
# ####################################################################################################
# 4256 endbr64
# 4260 xor ebp, ebp
# 4262 mov r9, rdx
# 4265 pop rsi
# 4266 mov rdx, rsp
# 4269 and rsp, 0xfffffffffffffff0
# 4273 push rax
# 4274 push rsp
# 4275 xor r8d, r8d
# 4278 xor ecx, ecx
# 4280 lea rdi, [rip + 0xca]
# 4287 call qword ptr [rip + 0x2f13]
# 4293 hlt
# deregister_tm_clones [['0x10ed', '0x10ef', '0x10e1', '0x10d7', '0x10d0', '0x10ea', '0x10e3', '0x10f8', '0x10de']]
# deregister_tm_clones     1 ____________________
# 4323   True      0x10e3   :  mov  rax, qword ptr [rip + 0x2ef6]
# 4330   True      0x10ea   :  test  rax, rax
# 4333   True      0x10ed   :  je  0x10f8
# 4335   True      0x10ef   :  jmp  rax
# 4304   True      0x10d0   :  lea  rdi, [rip + 0x2f39]
# 4311   True      0x10d7   :  lea  rax, [rip + 0x2f32]
# 4318   True      0x10de   :  cmp  rax, rdi
# 4321   True      0x10e1   :  je  0x10f8
# 4344   True      0x10f8   :  ret
# []
# ####################################################################################################
# 4323 mov rax, qword ptr [rip + 0x2ef6]
# 4330 test rax, rax
# 4333 je 0x10f8
# 4335 jmp rax
# 4304 lea rdi, [rip + 0x2f39]
# 4311 lea rax, [rip + 0x2f32]
# 4318 cmp rax, rdi
# 4321 je 0x10f8
# 4344 ret
# register_tm_clones [['0x1107', '0x111c', '0x111f', '0x1138', '0x110e', '0x1124', '0x1111', '0x112e', '0x1130', '0x1118', '0x1114', '0x112b', '0x1122', '0x1100']]
# register_tm_clones     1 ____________________
# 4352   True      0x1100   :  lea  rdi, [rip + 0x2f09]
# 4359   True      0x1107   :  lea  rsi, [rip + 0x2f02]
# 4366   True      0x110e   :  sub  rsi, rdi
# 4369   True      0x1111   :  mov  rax, rsi
# 4372   True      0x1114   :  shr  rsi, 0x3f
# 4376   True      0x1118   :  sar  rax, 3
# 4380   True      0x111c   :  add  rsi, rax
# 4383   True      0x111f   :  sar  rsi, 1
# 4386   True      0x1122   :  je  0x1138
# 4408   True      0x1138   :  ret
# 4388   True      0x1124   :  mov  rax, qword ptr [rip + 0x2ec5]
# 4395   True      0x112b   :  test  rax, rax
# 4398   True      0x112e   :  je  0x1138
# 4400   True      0x1130   :  jmp  rax
# []
# ####################################################################################################
# 4352 lea rdi, [rip + 0x2f09]
# 4359 lea rsi, [rip + 0x2f02]
# 4366 sub rsi, rdi
# 4369 mov rax, rsi
# 4372 shr rsi, 0x3f
# 4376 sar rax, 3
# 4380 add rsi, rax
# 4383 sar rsi, 1
# 4386 je 0x1138
# 4408 ret
# 4388 mov rax, qword ptr [rip + 0x2ec5]
# 4395 test rax, rax
# 4398 je 0x1138
# 4400 jmp rax
# __do_global_dtors_aux [['0x10ed', '0x10ea', '0x10e3'], ['0x1159', '0x114d', '0x1174', '0x114b', '0x1144', '0x114e', '0x1167', '0x115b', '0x1162', '0x1156', '0x1173', '0x1178'], ['0x10f8'], ['0x116c'], ['0x10ef'], ['0x10de', '0x10d7', '0x10d0', '0x10e1'], ['0x1064']]
# __do_global_dtors_aux     7 ____________________
# 4323   True      0x10e3   :  mov  rax, qword ptr [rip + 0x2ef6]
# 4330   True      0x10ea   :  test  rax, rax
# 4333   True      0x10ed   :  je  0x10f8
# []
# ####################################################################################################
# 4323 mov rax, qword ptr [rip + 0x2ef6]
# 4330 test rax, rax
# 4333 je 0x10f8
# 4429   True      0x114d   :  push  rbp
# 4430   True      0x114e   :  cmp  qword ptr [rip + 0x2ea2], 0
# 4438   True      0x1156   :  mov  rbp, rsp
# 4441   True      0x1159   :  je  0x1167
# 4455   True      0x1167   :  call  0x10d0
# 4460   False      0x116c   :  mov  byte ptr [rip + 0x2e9d], 1
# 4467   True      0x1173   :  pop  rbp
# 4468   True      0x1174   :  ret
# 4416   False      0x1140   :  endbr64
# 4420   True      0x1144   :  cmp  byte ptr [rip + 0x2ec5], 0
# 4427   True      0x114b   :  jne  0x1178
# 4443   True      0x115b   :  mov  rdi, qword ptr [rip + 0x2ea6]
# 4450   True      0x1162   :  call  0x1060
# 4472   True      0x1178   :  ret
# ['0x116c', '0x1140']
# ####################################################################################################
# 4429 push rbp
# 4430 cmp qword ptr [rip + 0x2ea2], 0
# 4438 mov rbp, rsp
# 4441 je 0x1167
# 4455 call 0x10d0
# 4460 mov byte ptr [rip + 0x2e9d], 1
# 4467 pop rbp
# 4468 ret
# 4416 endbr64
# 4420 cmp byte ptr [rip + 0x2ec5], 0
# 4427 jne 0x1178
# 4443 mov rdi, qword ptr [rip + 0x2ea6]
# 4450 call 0x1060
# 4472 ret
# 4304   True      0x10d0   :  lea  rdi, [rip + 0x2f39]
# 4311   True      0x10d7   :  lea  rax, [rip + 0x2f32]
# 4318   True      0x10de   :  cmp  rax, rdi
# 4321   True      0x10e1   :  je  0x10f8
# []
# ####################################################################################################
# 4304 lea rdi, [rip + 0x2f39]
# 4311 lea rax, [rip + 0x2f32]
# 4318 cmp rax, rdi
# 4321 je 0x10f8
# frame_dummy [['0x1107', '0x111c', '0x111f', '0x1138', '0x110e', '0x1124', '0x1111', '0x112e', '0x1130', '0x1118', '0x1114', '0x112b', '0x1122', '0x1100'], ['0x1184']]
# frame_dummy     2 ____________________
# 4352   True      0x1100   :  lea  rdi, [rip + 0x2f09]
# 4359   True      0x1107   :  lea  rsi, [rip + 0x2f02]
# 4366   True      0x110e   :  sub  rsi, rdi
# 4369   True      0x1111   :  mov  rax, rsi
# 4372   True      0x1114   :  shr  rsi, 0x3f
# 4376   True      0x1118   :  sar  rax, 3
# 4380   True      0x111c   :  add  rsi, rax
# 4383   True      0x111f   :  sar  rsi, 1
# 4386   True      0x1122   :  je  0x1138
# 4408   True      0x1138   :  ret
# 4388   True      0x1124   :  mov  rax, qword ptr [rip + 0x2ec5]
# 4395   True      0x112b   :  test  rax, rax
# 4398   True      0x112e   :  je  0x1138
# 4400   True      0x1130   :  jmp  rax
# []
# ####################################################################################################
# 4352 lea rdi, [rip + 0x2f09]
# 4359 lea rsi, [rip + 0x2f02]
# 4366 sub rsi, rdi
# 4369 mov rax, rsi
# 4372 shr rsi, 0x3f
# 4376 sar rax, 3
# 4380 add rsi, rax
# 4383 sar rsi, 1
# 4386 je 0x1138
# 4408 ret
# 4388 mov rax, qword ptr [rip + 0x2ec5]
# 4395 test rax, rax
# 4398 je 0x1138
# 4400 jmp rax
# main [['0x11a2', '0x11c9', '0x1212', '0x121b', '0x1239', '0x11fc', '0x1299', '0x1230', '0x11cd', '0x123c', '0x1252', '0x1257', '0x124a', '0x1265', '0x125c', '0x1277', '0x1287', '0x1255', '0x1223', '0x122e', '0x1243', '0x125e', '0x12b7', '0x12bc', '0x1240', '0x11c4', '0x128b', '0x11d4', '0x127e', '0x1233', '0x11ae', '0x118d', '0x11ef', '0x120d', '0x128f', '0x1293', '0x1295', '0x11f4', '0x1270', '0x12ac', '0x129d', '0x1262', '0x11b3', '0x1250', '0x1274', '0x1282', '0x1220', '0x126c', '0x11c1', '0x11f8', '0x1284', '0x127b', '0x12b5', '0x11da', '0x124e', '0x11dd', '0x12bd', '0x1272', '0x11b8', '0x11c6', '0x118e', '0x12a8', '0x1191', '0x11d1', '0x11d6', '0x1259', '0x121e', '0x119e', '0x1227', '0x1279', '0x1280', '0x1195', '0x1237', '0x1260'], ['0x11bf'], ['0x11e7', '0x11e0'], ['0x11ea'], ['0x1208'], ['0x1219'], ['0x1074'], ['0x1094'], ['0x11a4', '0x11ab'], ['0x1084'], ['0x12a3'], ['0x11fe', '0x1205']]
# main     12 ____________________
# 4489   False      0x1189   :  endbr64
# 4493   True      0x118d   :  push  rbp
# 4494   True      0x118e   :  mov  rbp, rsp
# 4497   True      0x1191   :  sub  rsp, 0x30
# 4501   True      0x1195   :  mov  rax, qword ptr fs:[0x28]
# 4510   True      0x119e   :  mov  qword ptr [rbp - 8], rax
# 4514   True      0x11a2   :  xor  eax, eax
# 4516   False      0x11a4   :  lea  rax, [rip + 0xe59]
# 4523   False      0x11ab   :  mov  rdi, rax
# 4526   True      0x11ae   :  mov  eax, 0
# 4531   True      0x11b3   :  call  0x1080
# 4536   True      0x11b8   :  mov  dword ptr [rbp - 0x2c], 0
# 4543   False      0x11bf   :  jmp  0x11f8
# 4545   True      0x11c1   :  mov  eax, dword ptr [rbp - 0x2c]
# 4548   True      0x11c4   :  cdqe
# 4550   True      0x11c6   :  mov  edx, dword ptr [rbp - 0x2c]
# 4553   True      0x11c9   :  mov  dword ptr [rbp + rax*4 - 0x20], edx
# 4557   True      0x11cd   :  lea  rdx, [rbp - 0x20]
# 4561   True      0x11d1   :  mov  eax, dword ptr [rbp - 0x2c]
# 4564   True      0x11d4   :  cdqe
# 4566   True      0x11d6   :  shl  rax, 2
# 4570   True      0x11da   :  add  rax, rdx
# 4573   True      0x11dd   :  mov  rsi, rax
# 4576   False      0x11e0   :  lea  rax, [rip + 0xe30]
# 4583   False      0x11e7   :  mov  rdi, rax
# 4586   False      0x11ea   :  mov  eax, 0
# 4591   True      0x11ef   :  call  0x1090
# 4596   True      0x11f4   :  add  dword ptr [rbp - 0x2c], 1
# 4606   False      0x11fe   :  lea  rax, [rip + 0xe15]
# 4613   False      0x1205   :  mov  rdi, rax
# 4616   False      0x1208   :  mov  eax, 0
# 4621   True      0x120d   :  call  0x1080
# 4626   True      0x1212   :  mov  dword ptr [rbp - 0x28], 0
# 4633   False      0x1219   :  jmp  0x1299
# 4635   True      0x121b   :  mov  eax, dword ptr [rbp - 0x28]
# 4638   True      0x121e   :  cdqe
# 4640   True      0x1220   :  mov  edx, dword ptr [rbp - 0x28]
# 4643   True      0x1223   :  mov  dword ptr [rbp + rax*4 - 0x20], edx
# 4647   True      0x1227   :  mov  dword ptr [rbp - 0x24], 0
# 4654   True      0x122e   :  jmp  0x128f
# 4656   True      0x1230   :  mov  eax, dword ptr [rbp - 0x28]
# 4659   True      0x1233   :  imul  eax, dword ptr [rbp - 0x24]
# 4663   True      0x1237   :  mov  ecx, eax
# 4665   True      0x1239   :  mov  eax, dword ptr [rbp - 0x28]
# 4668   True      0x123c   :  imul  eax, dword ptr [rbp - 0x24]
# 4672   True      0x1240   :  movsxd  rdx, eax
# 4675   True      0x1243   :  imul  rdx, rdx, 0x66666667
# 4682   True      0x124a   :  shr  rdx, 0x20
# 4686   True      0x124e   :  sar  edx, 1
# 4688   True      0x1250   :  mov  esi, eax
# 4690   True      0x1252   :  sar  esi, 0x1f
# 4693   True      0x1255   :  sub  edx, esi
# 4695   True      0x1257   :  mov  esi, edx
# 4697   True      0x1259   :  shl  esi, 2
# 4700   True      0x125c   :  add  esi, edx
# 4702   True      0x125e   :  sub  eax, esi
# 4704   True      0x1260   :  mov  edx, eax
# 4706   True      0x1262   :  movsxd  rax, ecx
# 4709   True      0x1265   :  imul  rax, rax, 0x66666667
# 4716   True      0x126c   :  shr  rax, 0x20
# 4720   True      0x1270   :  sar  eax, 1
# 4722   True      0x1272   :  mov  esi, ecx
# 4724   True      0x1274   :  sar  esi, 0x1f
# 4727   True      0x1277   :  sub  eax, esi
# 4729   True      0x1279   :  mov  esi, eax
# 4731   True      0x127b   :  shl  esi, 2
# 4734   True      0x127e   :  add  esi, eax
# 4736   True      0x1280   :  mov  eax, ecx
# 4738   True      0x1282   :  sub  eax, esi
# 4740   True      0x1284   :  movsxd  rdx, edx
# 4743   True      0x1287   :  mov  dword ptr [rbp + rdx*4 - 0x20], eax
# 4747   True      0x128b   :  add  dword ptr [rbp - 0x24], 1
# 4600   True      0x11f8   :  cmp  dword ptr [rbp - 0x2c], 4
# 4604   True      0x11fc   :  jle  0x11c1
# 4761   True      0x1299   :  cmp  dword ptr [rbp - 0x28], 4
# 4765   True      0x129d   :  jle  0x121b
# 4791   True      0x12b7   :  call  0x1070
# 4796   True      0x12bc   :  leave
# 4797   True      0x12bd   :  ret
# 4751   True      0x128f   :  cmp  dword ptr [rbp - 0x24], 4
# 4755   True      0x1293   :  jle  0x1230
# 4757   True      0x1295   :  add  dword ptr [rbp - 0x28], 1
# 4771   False      0x12a3   :  mov  eax, 0
# 4776   True      0x12a8   :  mov  rdx, qword ptr [rbp - 8]
# 4780   True      0x12ac   :  sub  rdx, qword ptr fs:[0x28]
# 4789   True      0x12b5   :  je  0x12bc
# ['0x1189', '0x11a4', '0x11ab', '0x11bf', '0x11e0', '0x11e7', '0x11ea', '0x11fe', '0x1205', '0x1208', '0x1219', '0x12a3']
# ####################################################################################################
# 4489 endbr64
# 4493 push rbp
# 4494 mov rbp, rsp
# 4497 sub rsp, 0x30
# 4501 mov rax, qword ptr fs:[0x28]
# 4510 mov qword ptr [rbp - 8], rax
# 4514 xor eax, eax
# 4516 lea rax, [rip + 0xe59]
# 4523 mov rdi, rax
# 4526 mov eax, 0
# 4531 call 0x1080
# 4536 mov dword ptr [rbp - 0x2c], 0
# 4543 jmp 0x11f8
# 4545 mov eax, dword ptr [rbp - 0x2c]
# 4548 cdqe
# 4550 mov edx, dword ptr [rbp - 0x2c]
# 4553 mov dword ptr [rbp + rax*4 - 0x20], edx
# 4557 lea rdx, [rbp - 0x20]
# 4561 mov eax, dword ptr [rbp - 0x2c]
# 4564 cdqe
# 4566 shl rax, 2
# 4570 add rax, rdx
# 4573 mov rsi, rax
# 4576 lea rax, [rip + 0xe30]
# 4583 mov rdi, rax
# 4586 mov eax, 0
# 4591 call 0x1090
# 4596 add dword ptr [rbp - 0x2c], 1
# 4606 lea rax, [rip + 0xe15]
# 4613 mov rdi, rax
# 4616 mov eax, 0
# 4621 call 0x1080
# 4626 mov dword ptr [rbp - 0x28], 0
# 4633 jmp 0x1299
# 4635 mov eax, dword ptr [rbp - 0x28]
# 4638 cdqe
# 4640 mov edx, dword ptr [rbp - 0x28]
# 4643 mov dword ptr [rbp + rax*4 - 0x20], edx
# 4647 mov dword ptr [rbp - 0x24], 0
# 4654 jmp 0x128f
# 4656 mov eax, dword ptr [rbp - 0x28]
# 4659 imul eax, dword ptr [rbp - 0x24]
# 4663 mov ecx, eax
# 4665 mov eax, dword ptr [rbp - 0x28]
# 4668 imul eax, dword ptr [rbp - 0x24]
# 4672 movsxd rdx, eax
# 4675 imul rdx, rdx, 0x66666667
# 4682 shr rdx, 0x20
# 4686 sar edx, 1
# 4688 mov esi, eax
# 4690 sar esi, 0x1f
# 4693 sub edx, esi
# 4695 mov esi, edx
# 4697 shl esi, 2
# 4700 add esi, edx
# 4702 sub eax, esi
# 4704 mov edx, eax
# 4706 movsxd rax, ecx
# 4709 imul rax, rax, 0x66666667
# 4716 shr rax, 0x20
# 4720 sar eax, 1
# 4722 mov esi, ecx
# 4724 sar esi, 0x1f
# 4727 sub eax, esi
# 4729 mov esi, eax
# 4731 shl esi, 2
# 4734 add esi, eax
# 4736 mov eax, ecx
# 4738 sub eax, esi
# 4740 movsxd rdx, edx
# 4743 mov dword ptr [rbp + rdx*4 - 0x20], eax
# 4747 add dword ptr [rbp - 0x24], 1
# 4600 cmp dword ptr [rbp - 0x2c], 4
# 4604 jle 0x11c1
# 4761 cmp dword ptr [rbp - 0x28], 4
# 4765 jle 0x121b
# 4791 call 0x1070
# 4796 leave
# 4797 ret
# 4751 cmp dword ptr [rbp - 0x24], 4
# 4755 jle 0x1230
# 4757 add dword ptr [rbp - 0x28], 1
# 4771 mov eax, 0
# 4776 mov rdx, qword ptr [rbp - 8]
# 4780 sub rdx, qword ptr fs:[0x28]
# 4789 je 0x12bc
# 4545   False      0x11c1   :  mov  eax, dword ptr [rbp - 0x2c]
# 4548   False      0x11c4   :  cdqe
# 4550   False      0x11c6   :  mov  edx, dword ptr [rbp - 0x2c]
# 4553   False      0x11c9   :  mov  dword ptr [rbp + rax*4 - 0x20], edx
# 4557   False      0x11cd   :  lea  rdx, [rbp - 0x20]
# 4561   False      0x11d1   :  mov  eax, dword ptr [rbp - 0x2c]
# 4564   False      0x11d4   :  cdqe
# 4566   False      0x11d6   :  shl  rax, 2
# 4570   False      0x11da   :  add  rax, rdx
# 4573   False      0x11dd   :  mov  rsi, rax
# 4576   True      0x11e0   :  lea  rax, [rip + 0xe30]
# 4583   True      0x11e7   :  mov  rdi, rax
# 4586   False      0x11ea   :  mov  eax, 0
# 4591   False      0x11ef   :  call  0x1090
# 4596   False      0x11f4   :  add  dword ptr [rbp - 0x2c], 1
# ['0x11c1', '0x11c4', '0x11c6', '0x11c9', '0x11cd', '0x11d1', '0x11d4', '0x11d6', '0x11da', '0x11dd', '0x11ea', '0x11ef', '0x11f4']
# ####################################################################################################
# 4545 mov eax, dword ptr [rbp - 0x2c]
# 4548 cdqe
# 4550 mov edx, dword ptr [rbp - 0x2c]
# 4553 mov dword ptr [rbp + rax*4 - 0x20], edx
# 4557 lea rdx, [rbp - 0x20]
# 4561 mov eax, dword ptr [rbp - 0x2c]
# 4564 cdqe
# 4566 shl rax, 2
# 4570 add rax, rdx
# 4573 mov rsi, rax
# 4576 lea rax, [rip + 0xe30]
# 4583 mov rdi, rax
# 4586 mov eax, 0
# 4591 call 0x1090
# 4596 add dword ptr [rbp - 0x2c], 1
# 4489   False      0x1189   :  endbr64
# 4493   False      0x118d   :  push  rbp
# 4494   False      0x118e   :  mov  rbp, rsp
# 4497   False      0x1191   :  sub  rsp, 0x30
# 4501   False      0x1195   :  mov  rax, qword ptr fs:[0x28]
# 4510   False      0x119e   :  mov  qword ptr [rbp - 8], rax
# 4514   False      0x11a2   :  xor  eax, eax
# 4516   True      0x11a4   :  lea  rax, [rip + 0xe59]
# 4523   True      0x11ab   :  mov  rdi, rax
# 4526   False      0x11ae   :  mov  eax, 0
# 4531   False      0x11b3   :  call  0x1080
# 4536   False      0x11b8   :  mov  dword ptr [rbp - 0x2c], 0
# 4543   False      0x11bf   :  jmp  0x11f8
# ['0x1189', '0x118d', '0x118e', '0x1191', '0x1195', '0x119e', '0x11a2', '0x11ae', '0x11b3', '0x11b8', '0x11bf']
# ####################################################################################################
# 4489 endbr64
# 4493 push rbp
# 4494 mov rbp, rsp
# 4497 sub rsp, 0x30
# 4501 mov rax, qword ptr fs:[0x28]
# 4510 mov qword ptr [rbp - 8], rax
# 4514 xor eax, eax
# 4516 lea rax, [rip + 0xe59]
# 4523 mov rdi, rax
# 4526 mov eax, 0
# 4531 call 0x1080
# 4536 mov dword ptr [rbp - 0x2c], 0
# 4543 jmp 0x11f8
# 4606   True      0x11fe   :  lea  rax, [rip + 0xe15]
# 4613   True      0x1205   :  mov  rdi, rax
# 4616   False      0x1208   :  mov  eax, 0
# 4621   False      0x120d   :  call  0x1080
# 4626   False      0x1212   :  mov  dword ptr [rbp - 0x28], 0
# 4633   False      0x1219   :  jmp  0x1299
# ['0x1208', '0x120d', '0x1212', '0x1219']
# ####################################################################################################
# 4606 lea rax, [rip + 0xe15]
# 4613 mov rdi, rax
# 4616 mov eax, 0
# 4621 call 0x1080
# 4626 mov dword ptr [rbp - 0x28], 0
# 4633 jmp 0x1299

# %%
len(input_list)
# Out:
# 11

# %%
for i, inx in enumerate(input_list):
    print(dbug[i])
    print(inx, '\n\n')
# Out:
# ['0x10a9', '0x10a0']
# <LOOK>0x10a0:endbr64 <EOI><LOOK>0x10a4:xor ebp, ebp<EOI>0x10a6:mov r9, rdx<EOI><LOOK>0x10a9:pop rsi<EOI><LOOK>0x10aa:mov rdx, rsp<EOI>0x10ad:and rsp, 0xfffffffffffffff0<EOI>0x10b1:push rax<EOI>0x10b2:push rsp<EOI>0x10b3:xor r8d, r8d<EOI>0x10b6:xor ecx, ecx<EOI>0x10b8:lea rdi, [rip + 0xca]<EOI>0x10bf:call qword ptr [rip + 0x2f13]<EOI>0x10c5:hlt <EOI>
#
#
# ['0x10de', '0x10f8']
# 0x10e3:mov rax, qword ptr [rip + 0x2ef6]<EOI>0x10ea:test rax, rax<EOI>0x10ed:je 0x10f8<EOI>0x10ef:jmp rax<EOI>0x10d0:lea rdi, [rip + 0x2f39]<EOI>0x10d7:lea rax, [rip + 0x2f32]<EOI><LOOK>0x10de:cmp rax, rdi<EOI><LOOK>0x10e1:je 0x10f8<EOI><LOOK>0x10f8:ret <EOI><LOOK>
#
#
# ['0x111f', '0x110e']
# 0x1100:lea rdi, [rip + 0x2f09]<EOI>0x1107:lea rsi, [rip + 0x2f02]<EOI><LOOK>0x110e:sub rsi, rdi<EOI><LOOK>0x1111:mov rax, rsi<EOI>0x1114:shr rsi, 0x3f<EOI>0x1118:sar rax, 3<EOI>0x111c:add rsi, rax<EOI><LOOK>0x111f:sar rsi, 1<EOI><LOOK>0x1122:je 0x1138<EOI>0x1138:ret <EOI>0x1124:mov rax, qword ptr [rip + 0x2ec5]<EOI>0x112b:test rax, rax<EOI>0x112e:je 0x1138<EOI>0x1130:jmp rax<EOI>
#
#
# ['0x10ea', '0x10e3']
# <LOOK>0x10e3:mov rax, qword ptr [rip + 0x2ef6]<EOI><LOOK><LOOK>0x10ea:test rax, rax<EOI><LOOK>0x10ed:je 0x10f8<EOI>
#
#
# ['0x1159', '0x1174']
# 0x114d:push rbp<EOI>0x114e:cmp qword ptr [rip + 0x2ea2], 0<EOI>0x1156:mov rbp, rsp<EOI><LOOK>0x1159:je 0x1167<EOI><LOOK>0x1167:call 0x10d0<EOI>0x116c:mov byte ptr [rip + 0x2e9d], 1<EOI>0x1173:pop rbp<EOI><LOOK>0x1174:ret <EOI><LOOK>0x1140:endbr64 <EOI>0x1144:cmp byte ptr [rip + 0x2ec5], 0<EOI>0x114b:jne 0x1178<EOI>0x115b:mov rdi, qword ptr [rip + 0x2ea6]<EOI>0x1162:call 0x1060<EOI>0x1178:ret <EOI>
#
#
# ['0x10d0', '0x10d7']
# <LOOK>0x10d0:lea rdi, [rip + 0x2f39]<EOI><LOOK><LOOK>0x10d7:lea rax, [rip + 0x2f32]<EOI><LOOK>0x10de:cmp rax, rdi<EOI>0x10e1:je 0x10f8<EOI>
#
#
# ['0x1118', '0x112e']
# 0x1100:lea rdi, [rip + 0x2f09]<EOI>0x1107:lea rsi, [rip + 0x2f02]<EOI>0x110e:sub rsi, rdi<EOI>0x1111:mov rax, rsi<EOI>0x1114:shr rsi, 0x3f<EOI><LOOK>0x1118:sar rax, 3<EOI><LOOK>0x111c:add rsi, rax<EOI>0x111f:sar rsi, 1<EOI>0x1122:je 0x1138<EOI>0x1138:ret <EOI>0x1124:mov rax, qword ptr [rip + 0x2ec5]<EOI>0x112b:test rax, rax<EOI><LOOK>0x112e:je 0x1138<EOI><LOOK>0x1130:jmp rax<EOI>
#
#
# ['0x125e', '0x11a4']
# 0x1189:endbr64 <EOI>0x118d:push rbp<EOI>0x118e:mov rbp, rsp<EOI>0x1191:sub rsp, 0x30<EOI>0x1195:mov rax, qword ptr fs:[0x28]<EOI>0x119e:mov qword ptr [rbp - 8], rax<EOI>0x11a2:xor eax, eax<EOI><LOOK>0x11a4:lea rax, [rip + 0xe59]<EOI><LOOK>0x11ab:mov rdi, rax<EOI>0x11ae:mov eax, 0<EOI>0x11b3:call 0x1080<EOI>0x11b8:mov dword ptr [rbp - 0x2c], 0<EOI>0x11bf:jmp 0x11f8<EOI>0x11c1:mov eax, dword ptr [rbp - 0x2c]<EOI>0x11c4:cdqe <EOI>0x11c6:mov edx, dword ptr [rbp - 0x2c]<EOI>0x11c9:mov dword ptr [rbp + rax*4 - 0x20], edx<EOI>0x11cd:lea rdx, [rbp - 0x20]<EOI>0x11d1:mov eax, dword ptr [rbp - 0x2c]<EOI>0x11d4:cdqe <EOI>0x11d6:shl rax, 2<EOI>0x11da:add rax, rdx<EOI>0x11dd:mov rsi, rax<EOI>0x11e0:lea rax, [rip + 0xe30]<EOI>0x11e7:mov rdi, rax<EOI>0x11ea:mov eax, 0<EOI>0x11ef:call 0x1090<EOI>0x11f4:add dword ptr [rbp - 0x2c], 1<EOI>0x11fe:lea rax, [rip + 0xe15]<EOI>0x1205:mov rdi, rax<EOI>0x1208:mov eax, 0<EOI>0x120d:call 0x1080<EOI>0x1212:mov dword ptr [rbp - 0x28], 0<EOI>0x1219:jmp 0x1299<EOI>0x121b:mov eax, dword ptr [rbp - 0x28]<EOI>0x121e:cdqe <EOI>0x1220:mov edx, dword ptr [rbp - 0x28]<EOI>0x1223:mov dword ptr [rbp + rax*4 - 0x20], edx<EOI>0x1227:mov dword ptr [rbp - 0x24], 0<EOI>0x122e:jmp 0x128f<EOI>0x1230:mov eax, dword ptr [rbp - 0x28]<EOI>0x1233:imul eax, dword ptr [rbp - 0x24]<EOI>0x1237:mov ecx, eax<EOI>0x1239:mov eax, dword ptr [rbp - 0x28]<EOI>0x123c:imul eax, dword ptr [rbp - 0x24]<EOI>0x1240:movsxd rdx, eax<EOI>0x1243:imul rdx, rdx, 0x66666667<EOI>0x124a:shr rdx, 0x20<EOI>0x124e:sar edx, 1<EOI>0x1250:mov esi, eax<EOI>0x1252:sar esi, 0x1f<EOI>0x1255:sub edx, esi<EOI>0x1257:mov esi, edx<EOI>0x1259:shl esi, 2<EOI>0x125c:add esi, edx<EOI><LOOK>0x125e:sub eax, esi<EOI><LOOK>0x1260:mov edx, eax<EOI>0x1262:movsxd rax, ecx<EOI>0x1265:imul rax, rax, 0x66666667<EOI>0x126c:shr rax, 0x20<EOI>0x1270:sar eax, 1<EOI>0x1272:mov esi, ecx<EOI>0x1274:sar esi, 0x1f<EOI>0x1277:sub eax, esi<EOI>0x1279:mov esi, eax<EOI>0x127b:shl esi, 2<EOI>0x127e:add esi, eax<EOI>0x1280:mov eax, ecx<EOI>0x1282:sub eax, esi<EOI>0x1284:movsxd rdx, edx<EOI>0x1287:mov dword ptr [rbp + rdx*4 - 0x20], eax<EOI>0x128b:add dword ptr [rbp - 0x24], 1<EOI>0x11f8:cmp dword ptr [rbp - 0x2c], 4<EOI>0x11fc:jle 0x11c1<EOI>0x1299:cmp dword ptr [rbp - 0x28], 4<EOI>0x129d:jle 0x121b<EOI>0x12b7:call 0x1070<EOI>0x12bc:leave <EOI>0x12bd:ret <EOI>0x128f:cmp dword ptr [rbp - 0x24], 4<EOI>0x1293:jle 0x1230<EOI>0x1295:add dword ptr [rbp - 0x28], 1<EOI>0x12a3:mov eax, 0<EOI>0x12a8:mov rdx, qword ptr [rbp - 8]<EOI>0x12ac:sub rdx, qword ptr fs:[0x28]<EOI>0x12b5:je 0x12bc<EOI>
#
#
# ['0x11e0', '0x11d1']
# 0x11c1:mov eax, dword ptr [rbp - 0x2c]<EOI>0x11c4:cdqe <EOI>0x11c6:mov edx, dword ptr [rbp - 0x2c]<EOI>0x11c9:mov dword ptr [rbp + rax*4 - 0x20], edx<EOI>0x11cd:lea rdx, [rbp - 0x20]<EOI><LOOK>0x11d1:mov eax, dword ptr [rbp - 0x2c]<EOI><LOOK>0x11d4:cdqe <EOI>0x11d6:shl rax, 2<EOI>0x11da:add rax, rdx<EOI>0x11dd:mov rsi, rax<EOI><LOOK>0x11e0:lea rax, [rip + 0xe30]<EOI><LOOK>0x11e7:mov rdi, rax<EOI>0x11ea:mov eax, 0<EOI>0x11ef:call 0x1090<EOI>0x11f4:add dword ptr [rbp - 0x2c], 1<EOI>
#
#
# ['0x11a4', '0x11ab']
# 0x1189:endbr64 <EOI>0x118d:push rbp<EOI>0x118e:mov rbp, rsp<EOI>0x1191:sub rsp, 0x30<EOI>0x1195:mov rax, qword ptr fs:[0x28]<EOI>0x119e:mov qword ptr [rbp - 8], rax<EOI>0x11a2:xor eax, eax<EOI><LOOK>0x11a4:lea rax, [rip + 0xe59]<EOI><LOOK><LOOK>0x11ab:mov rdi, rax<EOI><LOOK>0x11ae:mov eax, 0<EOI>0x11b3:call 0x1080<EOI>0x11b8:mov dword ptr [rbp - 0x2c], 0<EOI>0x11bf:jmp 0x11f8<EOI>
#
#
# ['0x1205', '0x11fe']
# <LOOK>0x11fe:lea rax, [rip + 0xe15]<EOI><LOOK><LOOK>0x1205:mov rdi, rax<EOI><LOOK>0x1208:mov eax, 0<EOI>0x120d:call 0x1080<EOI>0x1212:mov dword ptr [rbp - 0x28], 0<EOI>0x1219:jmp 0x1299<EOI>
