# %%
import os,sys
from collections import defaultdict
import posixpath
from elftools.elf.elffile import ELFFile
from capstone import *

# %%
#look at dwarf lineprogram and get the concrete addresees
def get_lineprogram_addresses(elffile ,bin_bytearray):
    lineprogram_addresses = []
    
    text_section = elffile.get_section_by_name(".text")
    textSectionLen = len(bin_bytearray)
    textSectionStart = text_section.header.sh_addr
    textSectionEnd = textSectionStart + textSectionLen
    program_entry_point = elffile._parse_elf_header().e_entry




    if not elffile.has_dwarf_info():
        print('  file has no DWARF info')
    dwarfinfo = elffile.get_dwarf_info()
    cc = 0
    for CU in dwarfinfo.iter_CUs():
        print('  Found a compile unit at offset %s, length %s' % (
            CU.cu_offset, CU['unit_length']))

        # Every compilation unit in the DWARF information may or may not
        # have a corresponding line program in .debug_line.
        line_program = dwarfinfo.line_program_for_CU(CU)
        if line_program is None:
            print('  DWARF info is missing a line program for this CU')
            continue
        for le in line_program.get_entries():
            if le.state is not None:
                lineprogram_addresses.append(le.state.address)
    return lineprogram_addresses

# %%
JUMP_OPCODES = ['JO','JNO','JS','JNS','JE','JZ','JNE','JNZ','JB','JNAE','JC','JNB','JAE','JNC','JBE','JNA','JA',
'JNBE','JL','JNGE','JGE','JNL','JLE','JNG','JG','JNLE','JP','JPE','JNP','JPO','JCXZ','JECXZ']


def do_recursive_dissembly(bin_bytearray , elffile , filename, lineprogram_addresses):
    
    
    text_section = elffile.get_section_by_name(".text")
    textSectionLen = len(bin_bytearray)
    textSectionStart = text_section.header.sh_addr
    textSectionEnd = textSectionStart + textSectionLen
    program_entry_point = elffile._parse_elf_header().e_entry
    
    
    md = Cs(CS_ARCH_X86, CS_MODE_64)


    visited_addresses = []
    entry_addresses = []
    address_and_instructions = {}

    entry_addresses.append(program_entry_point)
    entry_addresses += lineprogram_addresses


    while len(entry_addresses)>0 :

        current_entry_address = entry_addresses.pop(0)

        if current_entry_address in visited_addresses:
            continue


        CODE = bin_bytearray[current_entry_address: textSectionEnd]
        if len(CODE)==0:
            continue
        for i in md.disasm(CODE, current_entry_address):

            print("0x%x:\t%s\t%s \t%s" %(i.address, i.mnemonic, i.op_str ,i.size))  


            address_and_instructions[i.address] = i

            visited_addresses.append(i.address)

            # IF there is a conditional jump
            if i.mnemonic.upper() in JUMP_OPCODES:
                try:
                    if int(i.op_str,0)>=0:
                        if i.op_str not in visited_addresses:
                            entry_addresses.append(int(i.address + i.size))
                            entry_addresses.append(int(i.op_str,0))
                    break
                except: 
                    break

            #direct jump  TODO: check all versions
            if i.mnemonic.upper() in ['JMP']: #TODO handle JMP 0xACDC:0x5578
                print(i.op_str)
                try:
                    if int(i.op_str,0)>=0:

                        if int(i.op_str,0)>=textSectionStart and int(i.op_str,0)<=textSectionEnd:
                            entry_addresses.append(int(i.op_str,0))
                    break
                except:
                    break
            if i.mnemonic.upper() in ['RET', 'LEAVE']:
    #             end of basic block
                break
    #         TODO: check all versions
            if i.mnemonic.upper() in ["CALL"]:
                try:
                    if int(i.op_str,0) >= 0:
                        call_addr = int(i.op_str,0)
                        if call_addr >textSectionStart and call_addr<textSectionEnd:
                            entry_addresses.append(int(i.op_str,0))
                except:

                    break

#     Process data for loading into model                   
    addresses = list(address_and_instructions.keys())
    addresses.sort()
    sorted_address_and_instructions = {i: address_and_instructions[i] for i in addresses}

    predicted_address = list(sorted_address_and_instructions.keys())[0]

    with open('./compare/recursive/'+filename+'.txt', 'w') as data_file:
        for address, inst in sorted_address_and_instructions.items():
            data_file.write(str(int(inst.address))+":\t"+inst.mnemonic+" "+inst.op_str+"\n")

# %%
data_dir_path = "./data/binaries/"
dir_file_list = os.listdir(data_dir_path)

for filename in dir_file_list:
    filePath = os.path.join(data_dir_path,filename)

    
    with open(filePath, 'rb') as f:
        
        bin_bytearray = bytearray(f.read())
        elffile = ELFFile(f)

        lineprogram_addresses = get_lineprogram_addresses(elffile ,bin_bytearray)
        
        do_recursive_dissembly(bin_bytearray , elffile ,filename ,lineprogram_addresses)
# Out:
#   Found a compile unit at offset 0, length 1326
# 0x11a0:	endbr64	 	4
# 0x11a4:	xor	ebp, ebp 	2
# 0x11a6:	mov	r9, rdx 	3
# 0x11a9:	pop	rsi 	1
# 0x11aa:	mov	rdx, rsp 	3
# 0x11ad:	and	rsp, 0xfffffffffffffff0 	4
# 0x11b1:	push	rax 	1
# 0x11b2:	push	rsp 	1
# 0x11b3:	xor	r8d, r8d 	3
# 0x11b6:	xor	ecx, ecx 	2
# 0x11b8:	lea	rdi, [rip + 0x310] 	7
# 0x11bf:	call	qword ptr [rip + 0x2e13] 	6
# 0x1289:	endbr64	 	4
# 0x128d:	push	rbp 	1
# 0x128e:	mov	rbp, rsp 	3
# 0x1291:	mov	rdx, qword ptr [rip + 0x2d98] 	7
# 0x1298:	mov	rax, qword ptr [rip + 0x2d81] 	7
# 0x129f:	lea	rcx, [rip + 0xd62] 	7
# 0x12a6:	mov	rsi, rcx 	3
# 0x12a9:	mov	rdi, rax 	3
# 0x12ac:	mov	eax, 0 	5
# 0x12b1:	call	0x1120 	5
# 0x12b6:	mov	edi, 1 	5
# 0x12bb:	call	0x1170 	5
# 0x12c0:	endbr64	 	4
# 0x12c4:	push	rbp 	1
# 0x12c5:	mov	rbp, rsp 	3
# 0x12c8:	sub	rsp, 0x20 	4
# 0x12cc:	mov	dword ptr [rbp - 0x14], edi 	3
# 0x12cf:	mov	eax, dword ptr [rbp - 0x14] 	3
# 0x12d2:	mov	edx, 1 	5
# 0x12d7:	mov	esi, 0 	5
# 0x12dc:	mov	edi, eax 	2
# 0x12de:	call	0x1180 	5
# 0x12e3:	mov	qword ptr [rbp - 0x10], rax 	4
# 0x12e7:	mov	eax, dword ptr [rbp - 0x14] 	3
# 0x12ea:	mov	edx, 2 	5
# 0x12ef:	mov	esi, 0 	5
# 0x12f4:	mov	edi, eax 	2
# 0x12f6:	call	0x1180 	5
# 0x12fb:	mov	qword ptr [rbp - 8], rax 	4
# 0x12ff:	mov	rcx, qword ptr [rbp - 0x10] 	4
# 0x1303:	mov	eax, dword ptr [rbp - 0x14] 	3
# 0x1306:	mov	edx, 0 	5
# 0x130b:	mov	rsi, rcx 	3
# 0x130e:	mov	edi, eax 	2
# 0x1310:	call	0x1180 	5
# 0x1315:	mov	rax, qword ptr [rbp - 8] 	4
# 0x1319:	leave	 	1
# 0x131b:	endbr64	 	4
# 0x131f:	push	rbp 	1
# 0x1320:	mov	rbp, rsp 	3
# 0x1323:	sub	rsp, 0x40 	4
# 0x1327:	mov	qword ptr [rbp - 0x38], rdi 	4
# 0x132b:	mov	rax, qword ptr [rbp - 0x38] 	4
# 0x132f:	mov	esi, 2 	5
# 0x1334:	mov	rdi, rax 	3
# 0x1337:	mov	eax, 0 	5
# 0x133c:	call	0x1160 	5
# 0x1341:	mov	dword ptr [rbp - 0x2c], eax 	3
# 0x1344:	cmp	dword ptr [rbp - 0x2c], -1 	4
# 0x1348:	jne	0x137a 	2
# 0x134a:	mov	rdx, qword ptr [rip + 0x2cdf] 	7
# 0x1351:	mov	rax, qword ptr [rip + 0x2cc8] 	7
# 0x1358:	mov	rcx, qword ptr [rbp - 0x38] 	4
# 0x135c:	lea	rsi, [rip + 0xcbd] 	7
# 0x1363:	mov	rdi, rax 	3
# 0x1366:	mov	eax, 0 	5
# 0x136b:	call	0x1120 	5
# 0x1370:	mov	eax, 1 	5
# 0x1375:	jmp	0x14cd 	5
# 0x14cd
# 0x137a:	mov	eax, dword ptr [rbp - 0x2c] 	3
# 0x137d:	mov	edi, eax 	2
# 0x137f:	mov	eax, 0 	5
# 0x1384:	call	0x12c0 	5
# 0x1389:	mov	qword ptr [rbp - 0x18], rax 	4
# 0x138d:	cmp	qword ptr [rbp - 0x18], 0 	5
# 0x1392:	jne	0x139e 	2
# 0x1394:	mov	eax, 0 	5
# 0x1399:	jmp	0x14cd 	5
# 0x14cd
# 0x139e:	mov	edi, 0x10000 	5
# 0x13a3:	call	0x1150 	5
# 0x13a8:	mov	qword ptr [rbp - 0x10], rax 	4
# 0x13ac:	cmp	qword ptr [rbp - 0x10], 0 	5
# 0x13b1:	jne	0x13e2 	2
# 0x13b3:	mov	rdx, qword ptr [rip + 0x2c76] 	7
# 0x13ba:	mov	rax, qword ptr [rip + 0x2c5f] 	7
# 0x13c1:	lea	rcx, [rip + 0xc78] 	7
# 0x13c8:	mov	rsi, rcx 	3
# 0x13cb:	mov	rdi, rax 	3
# 0x13ce:	mov	eax, 0 	5
# 0x13d3:	call	0x1120 	5
# 0x13d8:	mov	eax, 1 	5
# 0x13dd:	jmp	0x14cd 	5
# 0x14cd
# 0x13e2:	mov	qword ptr [rbp - 0x28], 0 	8
# 0x13ea:	jmp	0x14ab 	5
# 0x14ab
# 0x13ef:	mov	rax, qword ptr [rbp - 0x18] 	4
# 0x13f3:	sub	rax, qword ptr [rbp - 0x28] 	4
# 0x13f7:	mov	edx, 0x10000 	5
# 0x13fc:	cmp	rax, rdx 	3
# 0x13ff:	cmovg	rax, rdx 	4
# 0x1403:	mov	qword ptr [rbp - 8], rax 	4
# 0x1407:	mov	qword ptr [rbp - 0x20], 0 	8
# 0x140f:	jmp	0x1451 	2
# 0x1451
# 0x1411:	call	0x1190 	5
# 0x1416:	movsxd	rdx, eax 	3
# 0x1419:	imul	rdx, rdx, -0x7f7f7f7f 	7
# 0x1420:	shr	rdx, 0x20 	4
# 0x1424:	add	edx, eax 	2
# 0x1426:	sar	edx, 7 	3
# 0x1429:	mov	esi, eax 	2
# 0x142b:	sar	esi, 0x1f 	3
# 0x142e:	mov	ecx, edx 	2
# 0x1430:	sub	ecx, esi 	2
# 0x1432:	mov	edx, ecx 	2
# 0x1434:	shl	edx, 8 	3
# 0x1437:	sub	edx, ecx 	2
# 0x1439:	sub	eax, edx 	2
# 0x143b:	mov	ecx, eax 	2
# 0x143d:	mov	rdx, qword ptr [rbp - 0x20] 	4
# 0x1441:	mov	rax, qword ptr [rbp - 0x10] 	4
# 0x1445:	add	rax, rdx 	3
# 0x1448:	mov	edx, ecx 	2
# 0x144a:	mov	byte ptr [rax], dl 	2
# 0x144c:	add	qword ptr [rbp - 0x20], 1 	5
# 0x1451:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x1455:	cmp	rax, qword ptr [rbp - 8] 	4
# 0x1459:	jl	0x1411 	2
# 0x145b:	mov	rdx, qword ptr [rbp - 8] 	4
# 0x145f:	mov	rcx, qword ptr [rbp - 0x10] 	4
# 0x1463:	mov	eax, dword ptr [rbp - 0x2c] 	3
# 0x1466:	mov	rsi, rcx 	3
# 0x1469:	mov	edi, eax 	2
# 0x146b:	call	0x10f0 	5
# 0x1470:	cmp	qword ptr [rbp - 8], rax 	4
# 0x1474:	je	0x14a3 	2
# 0x1476:	mov	rdx, qword ptr [rip + 0x2bb3] 	7
# 0x147d:	mov	rax, qword ptr [rip + 0x2b9c] 	7
# 0x1484:	mov	rcx, qword ptr [rbp - 0x38] 	4
# 0x1488:	lea	rsi, [rip + 0xbd0] 	7
# 0x148f:	mov	rdi, rax 	3
# 0x1492:	mov	eax, 0 	5
# 0x1497:	call	0x1120 	5
# 0x149c:	mov	eax, 1 	5
# 0x14a1:	jmp	0x14cd 	2
# 0x14cd
# 0x14a3:	add	qword ptr [rbp - 0x28], 0x10000 	8
# 0x14ab:	mov	rax, qword ptr [rbp - 0x28] 	4
# 0x14af:	cmp	rax, qword ptr [rbp - 0x18] 	4
# 0x14b3:	jl	0x13ef 	6
# 0x14b9:	mov	eax, dword ptr [rbp - 0x2c] 	3
# 0x14bc:	mov	edi, eax 	2
# 0x14be:	call	0x1100 	5
# 0x14c3:	call	0x1140 	5
# 0x14c8:	mov	eax, 0 	5
# 0x14cd:	leave	 	1
# 0x14cf:	endbr64	 	4
# 0x14d3:	push	rbp 	1
# 0x14d4:	mov	rbp, rsp 	3
# 0x14d7:	sub	rsp, 0x20 	4
# 0x14db:	mov	dword ptr [rbp - 0x14], edi 	3
# 0x14de:	mov	qword ptr [rbp - 0x20], rsi 	4
# 0x14e2:	mov	dword ptr [rbp - 4], 0 	7
# 0x14e9:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x14ed:	mov	rax, qword ptr [rax] 	3
# 0x14f0:	mov	qword ptr [rip + 0x2b39], rax 	7
# 0x14f7:	cmp	dword ptr [rbp - 0x14], 1 	4
# 0x14fb:	jg	0x1507 	2
# 0x14fd:	mov	eax, 0 	5
# 0x1502:	call	0x1289 	5
# 0x1507:	mov	edi, 0 	5
# 0x150c:	call	0x1130 	5
# 0x1511:	mov	edi, eax 	2
# 0x1513:	call	0x1110 	5
# 0x1518:	mov	dword ptr [rbp - 8], 1 	7
# 0x151f:	jmp	0x154c 	2
# 0x154c
# 0x1521:	mov	eax, dword ptr [rbp - 8] 	3
# 0x1524:	cdqe	 	2
# 0x1526:	lea	rdx, [rax*8] 	8
# 0x152e:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x1532:	add	rax, rdx 	3
# 0x1535:	mov	rax, qword ptr [rax] 	3
# 0x1538:	mov	rdi, rax 	3
# 0x153b:	mov	eax, 0 	5
# 0x1540:	call	0x131b 	5
# 0x1545:	add	dword ptr [rbp - 4], eax 	3
# 0x1548:	add	dword ptr [rbp - 8], 1 	4
# 0x154c:	mov	eax, dword ptr [rbp - 8] 	3
# 0x154f:	cmp	eax, dword ptr [rbp - 0x14] 	3
# 0x1552:	jl	0x1521 	2
# 0x1554:	cmp	dword ptr [rbp - 4], 0 	4
# 0x1558:	setne	al 	3
# 0x155b:	movzx	eax, al 	3
# 0x155e:	leave	 	1
# 0x1560:	endbr64	 	4
# 0x1564:	sub	rsp, 8 	4
# 0x1568:	add	rsp, 8 	4
# 0x156c:	ret	 	1
#   Found a compile unit at offset 0, length 585
#   Found a compile unit at offset 589, length 249
#   Found a compile unit at offset 842, length 1840
# 0x11a0:	endbr64	 	4
# 0x11a4:	xor	ebp, ebp 	2
# 0x11a6:	mov	r9, rdx 	3
# 0x11a9:	pop	rsi 	1
# 0x11aa:	mov	rdx, rsp 	3
# 0x11ad:	and	rsp, 0xfffffffffffffff0 	4
# 0x11b1:	push	rax 	1
# 0x11b2:	push	rsp 	1
# 0x11b3:	xor	r8d, r8d 	3
# 0x11b6:	xor	ecx, ecx 	2
# 0x11b8:	lea	rdi, [rip + 0x21f] 	7
# 0x11bf:	call	qword ptr [rip + 0x2e13] 	6
# 0x1289:	endbr64	 	4
# 0x128d:	push	rbp 	1
# 0x128e:	mov	rbp, rsp 	3
# 0x1291:	sub	rsp, 0x10 	4
# 0x1295:	mov	qword ptr [rbp - 8], rdi 	4
# 0x1299:	mov	qword ptr [rbp - 8], 0 	8
# 0x12a1:	mov	edi, 1 	5
# 0x12a6:	call	0x1190 	5
# 0x12ab:	endbr64	 	4
# 0x12af:	push	rbp 	1
# 0x12b0:	mov	rbp, rsp 	3
# 0x12b3:	push	rbx 	1
# 0x12b4:	sub	rsp, 0x38 	4
# 0x12b8:	mov	qword ptr [rbp - 0x38], rdi 	4
# 0x12bc:	mov	qword ptr [rbp - 0x40], rsi 	4
# 0x12c0:	mov	dword ptr [rbp - 0x28], 0 	7
# 0x12c7:	mov	rax, qword ptr [rbp - 0x40] 	4
# 0x12cb:	mov	qword ptr [rbp - 0x20], rax 	4
# 0x12cf:	jmp	0x13c0 	5
# 0x13c0
# 0x12d4:	mov	dword ptr [rbp - 0x24], 0 	7
# 0x12db:	jmp	0x12e6 	2
# 0x12e6
# 0x12dd:	add	dword ptr [rbp - 0x24], 1 	4
# 0x12e1:	add	qword ptr [rbp - 0x20], 1 	5
# 0x12e6:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x12ea:	movzx	eax, byte ptr [rax] 	3
# 0x12ed:	cmp	al, 0x3a 	2
# 0x12ef:	je	0x12fc 	2
# 0x12f1:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x12f5:	movzx	eax, byte ptr [rax] 	3
# 0x12f8:	test	al, al 	2
# 0x12fa:	jne	0x12dd 	2
# 0x12fc:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x1300:	movzx	eax, byte ptr [rax] 	3
# 0x1303:	mov	byte ptr [rbp - 0x29], al 	3
# 0x1306:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x130a:	mov	byte ptr [rax], 0 	3
# 0x130d:	mov	eax, dword ptr [rbp - 0x24] 	3
# 0x1310:	cdqe	 	2
# 0x1312:	neg	rax 	3
# 0x1315:	mov	rdx, rax 	3
# 0x1318:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x131c:	add	rax, rdx 	3
# 0x131f:	mov	rdi, rax 	3
# 0x1322:	call	0x1120 	5
# 0x1327:	mov	rbx, rax 	3
# 0x132a:	mov	rax, qword ptr [rbp - 0x38] 	4
# 0x132e:	mov	rdi, rax 	3
# 0x1331:	call	0x1120 	5
# 0x1336:	add	rax, rbx 	3
# 0x1339:	add	rax, 2 	4
# 0x133d:	mov	rdi, rax 	3
# 0x1340:	call	0x14a0 	5
# 0x1345:	mov	qword ptr [rbp - 0x18], rax 	4
# 0x1349:	mov	eax, dword ptr [rbp - 0x24] 	3
# 0x134c:	cdqe	 	2
# 0x134e:	neg	rax 	3
# 0x1351:	mov	rdx, rax 	3
# 0x1354:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x1358:	lea	rsi, [rdx + rax] 	4
# 0x135c:	mov	rdx, qword ptr [rbp - 0x38] 	4
# 0x1360:	mov	rax, qword ptr [rbp - 0x18] 	4
# 0x1364:	mov	rcx, rdx 	3
# 0x1367:	mov	rdx, rsi 	3
# 0x136a:	lea	rsi, [rip + 0xc93] 	7
# 0x1371:	mov	rdi, rax 	3
# 0x1374:	mov	eax, 0 	5
# 0x1379:	call	0x1180 	5
# 0x137e:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x1382:	movzx	edx, byte ptr [rbp - 0x29] 	4
# 0x1386:	mov	byte ptr [rax], dl 	2
# 0x1388:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x138c:	movzx	eax, byte ptr [rax] 	3
# 0x138f:	test	al, al 	2
# 0x1391:	je	0x1398 	2
# 0x1393:	add	qword ptr [rbp - 0x20], 1 	5
# 0x1398:	mov	rax, qword ptr [rbp - 0x18] 	4
# 0x139c:	mov	esi, 1 	5
# 0x13a1:	mov	rdi, rax 	3
# 0x13a4:	call	0x1170 	5
# 0x13a9:	test	eax, eax 	2
# 0x13ab:	sete	al 	3
# 0x13ae:	movzx	eax, al 	3
# 0x13b1:	mov	dword ptr [rbp - 0x28], eax 	3
# 0x13b4:	mov	rax, qword ptr [rbp - 0x18] 	4
# 0x13b8:	mov	rdi, rax 	3
# 0x13bb:	call	0x1467 	5
# 0x13c0:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x13c4:	movzx	eax, byte ptr [rax] 	3
# 0x13c7:	test	al, al 	2
# 0x13c9:	je	0x13d5 	2
# 0x13cb:	cmp	dword ptr [rbp - 0x28], 0 	4
# 0x13cf:	je	0x12d4 	6
# 0x13d5:	mov	eax, dword ptr [rbp - 0x28] 	3
# 0x13d8:	mov	rbx, qword ptr [rbp - 8] 	4
# 0x13dc:	leave	 	1
# 0x13de:	endbr64	 	4
# 0x13e2:	push	rbp 	1
# 0x13e3:	mov	rbp, rsp 	3
# 0x13e6:	sub	rsp, 0x20 	4
# 0x13ea:	mov	dword ptr [rbp - 0x14], edi 	3
# 0x13ed:	mov	qword ptr [rbp - 0x20], rsi 	4
# 0x13f1:	lea	rax, [rip + 0xc12] 	7
# 0x13f8:	mov	rdi, rax 	3
# 0x13fb:	call	0x10f0 	5
# 0x1400:	mov	qword ptr [rbp - 8], rax 	4
# 0x1404:	sub	dword ptr [rbp - 0x14], 1 	4
# 0x1408:	add	qword ptr [rbp - 0x20], 8 	5
# 0x140d:	jmp	0x143e 	2
# 0x143e
# 0x140f:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x1413:	mov	rax, qword ptr [rax] 	3
# 0x1416:	mov	rdx, qword ptr [rbp - 8] 	4
# 0x141a:	mov	rsi, rdx 	3
# 0x141d:	mov	rdi, rax 	3
# 0x1420:	mov	eax, 0 	5
# 0x1425:	call	0x12ab 	5
# 0x142a:	test	eax, eax 	2
# 0x142c:	je	0x1435 	2
# 0x142e:	mov	eax, 0 	5
# 0x1433:	jmp	0x1449 	2
# 0x1449
# 0x1435:	sub	dword ptr [rbp - 0x14], 1 	4
# 0x1439:	add	qword ptr [rbp - 0x20], 8 	5
# 0x143e:	cmp	dword ptr [rbp - 0x14], 0 	4
# 0x1442:	jne	0x140f 	2
# 0x1444:	mov	eax, 1 	5
# 0x1449:	leave	 	1
# 0x144b:	endbr64	 	4
# 0x144f:	push	rbp 	1
# 0x1450:	mov	rbp, rsp 	3
# 0x1453:	lea	rax, [rip + 0xbb5] 	7
# 0x145a:	mov	rdi, rax 	3
# 0x145d:	call	0x1289 	5
# 0x1462:	call	0x1110 	5
# 0x1467:	endbr64	 	4
# 0x146b:	push	rbp 	1
# 0x146c:	mov	rbp, rsp 	3
# 0x146f:	sub	rsp, 0x10 	4
# 0x1473:	mov	qword ptr [rbp - 8], rdi 	4
# 0x1477:	cmp	qword ptr [rbp - 8], 0 	5
# 0x147c:	je	0x148c 	2
# 0x147e:	mov	rax, qword ptr [rbp - 8] 	4
# 0x1482:	mov	rdi, rax 	3
# 0x1485:	call	0x1100 	5
# 0x148a:	jmp	0x149b 	2
# 0x149b
# 0x148c:	lea	rax, [rip + 0xb95] 	7
# 0x1493:	mov	rdi, rax 	3
# 0x1496:	call	0x1289 	5
# 0x149b:	nop	 	1
# 0x149c:	leave	 	1
# 0x149e:	nop	 	2
# 0x14a0:	endbr64	 	4
# 0x14a4:	push	rbx 	1
# 0x14a5:	mov	rbx, rdi 	3
# 0x14a8:	call	0x1150 	5
# 0x14ad:	test	rax, rax 	3
# 0x14b0:	jne	0x14b7 	2
# 0x14b7:	pop	rbx 	1
# 0x14b8:	ret	 	1
# 0x14b9:	call	0x144b 	5
# 0x14be:	nop	 	2
# 0x14c0:	endbr64	 	4
# 0x14c4:	push	rbx 	1
# 0x14c5:	mov	rbx, rsi 	3
# 0x14c8:	call	0x1160 	5
# 0x14cd:	test	rax, rax 	3
# 0x14d0:	jne	0x14d7 	2
# 0x14d7:	pop	rbx 	1
# 0x14d8:	ret	 	1
# 0x14d9:	call	0x144b 	5
# 0x14de:	nop	 	2
# 0x14e0:	endbr64	 	4
# 0x14e4:	push	rbx 	1
# 0x14e5:	mov	rax, rsi 	3
# 0x14e8:	mov	rsi, qword ptr [rsi] 	3
# 0x14eb:	test	rdi, rdi 	3
# 0x14ee:	je	0x1520 	2
# 0x14f0:	movabs	rdx, 0xaaaaaaaaaaaaaaa9 	10
# 0x14fa:	cmp	rsi, rdx 	3
# 0x14fd:	ja	0x1531 	2
# 0x14ff:	lea	rdx, [rsi + 1] 	4
# 0x1503:	shr	rdx, 1 	3
# 0x1506:	add	rsi, rdx 	3
# 0x1509:	setne	bl 	3
# 0x150c:	mov	qword ptr [rax], rsi 	3
# 0x150f:	call	0x1160 	5
# 0x1514:	test	rax, rax 	3
# 0x1517:	jne	0x151d 	2
# 0x151d:	pop	rbx 	1
# 0x151e:	ret	 	1
# 0x1520:	mov	ebx, 1 	5
# 0x1525:	test	rsi, rsi 	3
# 0x1528:	jne	0x150c 	2
# 0x152a:	mov	esi, 0x40 	5
# 0x152f:	jmp	0x150c 	2
# 0x150c
# 0x1531:	call	0x144b 	5
# 0x1536:	nop	word ptr cs:[rax + rax] 	10
# 0x1540:	endbr64	 	4
# 0x1544:	push	rbx 	1
# 0x1545:	mov	esi, 1 	5
# 0x154a:	mov	rbx, rdi 	3
# 0x154d:	call	0x1130 	5
# 0x1552:	test	rax, rax 	3
# 0x1555:	jne	0x155c 	2
# 0x155c:	pop	rbx 	1
# 0x155d:	ret	 	1
# 0x155e:	call	0x144b 	5
# 0x1563:	nop	word ptr cs:[rax + rax] 	11
# 0x156e:	nop	 	2
# 0x1570:	endbr64	 	4
# 0x1574:	sub	rsp, 8 	4
# 0x1578:	call	0x1130 	5
# 0x157d:	test	rax, rax 	3
# 0x1580:	je	0x1587 	2
# 0x1582:	add	rsp, 8 	4
# 0x1586:	ret	 	1
# 0x1587:	call	0x144b 	5
# 0x158c:	nop	dword ptr [rax] 	4
# 0x1590:	endbr64	 	4
# 0x1594:	push	r12 	2
# 0x1596:	mov	r12, rsi 	3
# 0x1599:	push	rbp 	1
# 0x159a:	mov	rbp, rdi 	3
# 0x159d:	mov	rdi, rsi 	3
# 0x15a0:	sub	rsp, 8 	4
# 0x15a4:	call	0x1150 	5
# 0x15a9:	mov	rdi, rax 	3
# 0x15ac:	test	rax, rax 	3
# 0x15af:	jne	0x15b6 	2
# 0x15b6:	add	rsp, 8 	4
# 0x15ba:	mov	rdx, r12 	3
# 0x15bd:	mov	rsi, rbp 	3
# 0x15c0:	pop	rbp 	1
# 0x15c1:	pop	r12 	2
# 0x15c3:	jmp	0x1140 	5
# 0x1140
# 0x15c8:	call	0x144b 	5
# 0x15cd:	nop	dword ptr [rax] 	3
# 0x15d0:	endbr64	 	4
# 0x15d4:	push	r12 	2
# 0x15d6:	push	rbp 	1
# 0x15d7:	mov	rbp, rdi 	3
# 0x15da:	sub	rsp, 8 	4
# 0x15de:	call	0x1120 	5
# 0x15e3:	lea	r12, [rax + 1] 	4
# 0x15e7:	mov	rdi, r12 	3
# 0x15ea:	call	0x1150 	5
# 0x15ef:	test	rax, rax 	3
# 0x15f2:	je	0x1609 	2
# 0x15f4:	add	rsp, 8 	4
# 0x15f8:	mov	rdx, r12 	3
# 0x15fb:	mov	rsi, rbp 	3
# 0x15fe:	mov	rdi, rax 	3
# 0x1601:	pop	rbp 	1
# 0x1602:	pop	r12 	2
# 0x1604:	jmp	0x1140 	5
# 0x1140
# 0x1609:	call	0x144b 	5
# 0x160e:	add	byte ptr [rax], al 	2
# 0x1610:	endbr64	 	4
# 0x1614:	sub	rsp, 8 	4
# 0x1618:	add	rsp, 8 	4
# 0x161c:	ret	 	1
# 0x14b2:	test	rbx, rbx 	3
# 0x14b5:	jne	0x14b9 	2
# 0x14d2:	test	rbx, rbx 	3
# 0x14d5:	jne	0x14d9 	2
# 0x1519:	test	bl, bl 	2
# 0x151b:	jne	0x1531 	2
# 0x1557:	test	rbx, rbx 	3
# 0x155a:	jne	0x155e 	2
# 0x15b1:	test	r12, r12 	3
# 0x15b4:	jne	0x15c8 	2
#   Found a compile unit at offset 0, length 4843
#   Found a compile unit at offset 4847, length 7795
#   Found a compile unit at offset 12646, length 931
#   Found a compile unit at offset 13581, length 4279
#   Found a compile unit at offset 17864, length 1585
#   Found a compile unit at offset 19453, length 1102
#   Found a compile unit at offset 20559, length 1910
#   Found a compile unit at offset 22473, length 249
#   Found a compile unit at offset 22726, length 1840
# 0x3920:	endbr64	 	4
# 0x3924:	xor	ebp, ebp 	2
# 0x3926:	mov	r9, rdx 	3
# 0x3929:	pop	rsi 	1
# 0x392a:	mov	rdx, rsp 	3
# 0x392d:	and	rsp, 0xfffffffffffffff0 	4
# 0x3931:	push	rax 	1
# 0x3932:	push	rsp 	1
# 0x3933:	xor	r8d, r8d 	3
# 0x3936:	xor	ecx, ecx 	2
# 0x3938:	lea	rdi, [rip + 0x1373] 	7
# 0x393f:	call	qword ptr [rip + 0xb683] 	6
# 0x3a09:	endbr64	 	4
# 0x3a0d:	push	rbp 	1
# 0x3a0e:	mov	rbp, rsp 	3
# 0x3a11:	sub	rsp, 0x10 	4
# 0x3a15:	mov	eax, dword ptr [rip + 0xbfd1] 	6
# 0x3a1b:	test	eax, eax 	2
# 0x3a1d:	jne	0x3a26 	2
# 0x3a1f:	mov	eax, 0x7fffffff 	5
# 0x3a24:	jmp	0x3a79 	2
# 0x3a79
# 0x3a26:	mov	eax, dword ptr [rip + 0xbfbc] 	6
# 0x3a2c:	mov	edx, 1 	5
# 0x3a31:	mov	esi, 0 	5
# 0x3a36:	mov	edi, eax 	2
# 0x3a38:	call	0x38d0 	5
# 0x3a3d:	mov	qword ptr [rbp - 0x10], rax 	4
# 0x3a41:	mov	eax, dword ptr [rip + 0xbfa1] 	6
# 0x3a47:	mov	edx, 2 	5
# 0x3a4c:	mov	esi, 0 	5
# 0x3a51:	mov	edi, eax 	2
# 0x3a53:	call	0x38d0 	5
# 0x3a58:	mov	qword ptr [rbp - 8], rax 	4
# 0x3a5c:	mov	eax, dword ptr [rip + 0xbf86] 	6
# 0x3a62:	mov	rcx, qword ptr [rbp - 0x10] 	4
# 0x3a66:	mov	edx, 0 	5
# 0x3a6b:	mov	rsi, rcx 	3
# 0x3a6e:	mov	edi, eax 	2
# 0x3a70:	call	0x38d0 	5
# 0x3a75:	mov	rax, qword ptr [rbp - 8] 	4
# 0x3a79:	leave	 	1
# 0x3a7b:	endbr64	 	4
# 0x3a7f:	push	rbp 	1
# 0x3a80:	mov	rbp, rsp 	3
# 0x3a83:	mov	eax, dword ptr [rip + 0xc033] 	6
# 0x3a89:	cmp	eax, 8 	3
# 0x3a8c:	jle	0x3ac5 	2
# 0x3a8e:	lea	rax, [rip + 0xb803] 	7
# 0x3a95:	mov	rdi, rax 	3
# 0x3a98:	call	0x35d0 	5
# 0x3a9d:	mov	edx, eax 	2
# 0x3a9f:	mov	eax, dword ptr [rip + 0xbf0b] 	6
# 0x3aa5:	add	eax, edx 	2
# 0x3aa7:	mov	edx, eax 	2
# 0x3aa9:	mov	eax, dword ptr [rip + 0xc00d] 	6
# 0x3aaf:	lea	ecx, [rax - 5] 	3
# 0x3ab2:	mov	rax, qword ptr [rip + 0xbf57] 	7
# 0x3ab9:	mov	esi, ecx 	2
# 0x3abb:	mov	rdi, rax 	3
# 0x3abe:	call	0x8794 	5
# 0x3ac3:	jmp	0x3ae8 	2
# 0x3ae8
# 0x3ac5:	mov	eax, dword ptr [rip + 0xbff5] 	6
# 0x3acb:	lea	edx, [rax - 1] 	3
# 0x3ace:	mov	eax, dword ptr [rip + 0xbfe8] 	6
# 0x3ad4:	lea	ecx, [rax - 1] 	3
# 0x3ad7:	mov	rax, qword ptr [rip + 0xbf32] 	7
# 0x3ade:	mov	esi, ecx 	2
# 0x3ae0:	mov	rdi, rax 	3
# 0x3ae3:	call	0x8794 	5
# 0x3ae8:	nop	 	1
# 0x3ae9:	pop	rbp 	1
# 0x3aea:	ret	 	1
# 0x3aeb:	endbr64	 	4
# 0x3aef:	push	rbp 	1
# 0x3af0:	mov	rbp, rsp 	3
# 0x3af3:	mov	eax, dword ptr [rip + 0xbfc7] 	6
# 0x3af9:	movsxd	rdx, eax 	3
# 0x3afc:	mov	rax, qword ptr [rip + 0xbedd] 	7
# 0x3b03:	mov	esi, 0x20 	5
# 0x3b08:	mov	rdi, rax 	3
# 0x3b0b:	call	0x3620 	5
# 0x3b10:	mov	rax, qword ptr [rip + 0xbf09] 	7
# 0x3b17:	mov	rdi, rax 	3
# 0x3b1a:	call	0x35d0 	5
# 0x3b1f:	mov	edx, eax 	2
# 0x3b21:	mov	eax, dword ptr [rip + 0xbf99] 	6
# 0x3b27:	cmp	edx, eax 	2
# 0x3b29:	jge	0x3b3e 	2
# 0x3b2b:	mov	rax, qword ptr [rip + 0xbeee] 	7
# 0x3b32:	mov	rdi, rax 	3
# 0x3b35:	call	0x35d0 	5
# 0x3b3a:	cdqe	 	2
# 0x3b3c:	jmp	0x3b46 	2
# 0x3b46
# 0x3b3e:	mov	eax, dword ptr [rip + 0xbf7c] 	6
# 0x3b44:	cdqe	 	2
# 0x3b46:	mov	rsi, qword ptr [rip + 0xbed3] 	7
# 0x3b4d:	mov	rcx, qword ptr [rip + 0xbe8c] 	7
# 0x3b54:	mov	rdx, rax 	3
# 0x3b57:	mov	rdi, rcx 	3
# 0x3b5a:	call	0x3730 	5
# 0x3b5f:	mov	edx, dword ptr [rip + 0xb5ff] 	6
# 0x3b65:	mov	ecx, dword ptr [rip + 0xb5f5] 	6
# 0x3b6b:	mov	eax, dword ptr [rip + 0xb5f7] 	6
# 0x3b71:	mov	esi, ecx 	2
# 0x3b73:	mov	edi, eax 	2
# 0x3b75:	call	0x6aff 	5
# 0x3b7a:	mov	rax, qword ptr [rip + 0xbe7f] 	7
# 0x3b81:	mov	edx, 0 	5
# 0x3b86:	mov	esi, 0 	5
# 0x3b8b:	mov	rdi, rax 	3
# 0x3b8e:	call	0x8794 	5
# 0x3b93:	mov	edx, dword ptr [rip + 0xbf27] 	6
# 0x3b99:	mov	rcx, qword ptr [rip + 0xbe40] 	7
# 0x3ba0:	mov	rax, qword ptr [rip + 0xbe59] 	7
# 0x3ba7:	mov	rsi, rcx 	3
# 0x3baa:	mov	rdi, rax 	3
# 0x3bad:	call	0x8690 	5
# 0x3bb2:	nop	 	1
# 0x3bb3:	pop	rbp 	1
# 0x3bb4:	ret	 	1
# 0x3bb5:	endbr64	 	4
# 0x3bb9:	push	rbp 	1
# 0x3bba:	mov	rbp, rsp 	3
# 0x3bbd:	mov	eax, dword ptr [rip + 0xbefd] 	6
# 0x3bc3:	movsxd	rdx, eax 	3
# 0x3bc6:	mov	rax, qword ptr [rip + 0xbe13] 	7
# 0x3bcd:	mov	esi, 0x20 	5
# 0x3bd2:	mov	rdi, rax 	3
# 0x3bd5:	call	0x3620 	5
# 0x3bda:	mov	rax, qword ptr [rip + 0xbdef] 	7
# 0x3be1:	mov	rdi, rax 	3
# 0x3be4:	call	0x35d0 	5
# 0x3be9:	mov	edx, eax 	2
# 0x3beb:	mov	eax, dword ptr [rip + 0xbecf] 	6
# 0x3bf1:	cmp	edx, eax 	2
# 0x3bf3:	jge	0x3c08 	2
# 0x3bf5:	mov	rax, qword ptr [rip + 0xbdd4] 	7
# 0x3bfc:	mov	rdi, rax 	3
# 0x3bff:	call	0x35d0 	5
# 0x3c04:	cdqe	 	2
# 0x3c06:	jmp	0x3c10 	2
# 0x3c10
# 0x3c08:	mov	eax, dword ptr [rip + 0xbeb2] 	6
# 0x3c0e:	cdqe	 	2
# 0x3c10:	mov	rsi, qword ptr [rip + 0xbdb9] 	7
# 0x3c17:	mov	rcx, qword ptr [rip + 0xbdc2] 	7
# 0x3c1e:	mov	rdx, rax 	3
# 0x3c21:	mov	rdi, rcx 	3
# 0x3c24:	call	0x3730 	5
# 0x3c29:	mov	edx, dword ptr [rip + 0xb541] 	6
# 0x3c2f:	mov	ecx, dword ptr [rip + 0xb537] 	6
# 0x3c35:	mov	eax, dword ptr [rip + 0xb539] 	6
# 0x3c3b:	mov	esi, ecx 	2
# 0x3c3d:	mov	edi, eax 	2
# 0x3c3f:	call	0x6aff 	5
# 0x3c44:	mov	rax, qword ptr [rip + 0xbdbd] 	7
# 0x3c4b:	mov	edx, 0 	5
# 0x3c50:	mov	esi, 0 	5
# 0x3c55:	mov	rdi, rax 	3
# 0x3c58:	call	0x8794 	5
# 0x3c5d:	mov	edx, dword ptr [rip + 0xbe5d] 	6
# 0x3c63:	mov	rcx, qword ptr [rip + 0xbd76] 	7
# 0x3c6a:	mov	rax, qword ptr [rip + 0xbd97] 	7
# 0x3c71:	mov	rsi, rcx 	3
# 0x3c74:	mov	rdi, rax 	3
# 0x3c77:	call	0x8690 	5
# 0x3c7c:	nop	 	1
# 0x3c7d:	pop	rbp 	1
# 0x3c7e:	ret	 	1
# 0x3c7f:	endbr64	 	4
# 0x3c83:	push	rbp 	1
# 0x3c84:	mov	rbp, rsp 	3
# 0x3c87:	mov	eax, dword ptr [rip + 0xbe33] 	6
# 0x3c8d:	movsxd	rdx, eax 	3
# 0x3c90:	mov	rax, qword ptr [rip + 0xbd49] 	7
# 0x3c97:	mov	esi, 0x20 	5
# 0x3c9c:	mov	rdi, rax 	3
# 0x3c9f:	call	0x3620 	5
# 0x3ca4:	mov	rax, qword ptr [rip + 0xbd7d] 	7
# 0x3cab:	mov	rdi, rax 	3
# 0x3cae:	call	0x35d0 	5
# 0x3cb3:	mov	edx, eax 	2
# 0x3cb5:	mov	eax, dword ptr [rip + 0xbe05] 	6
# 0x3cbb:	cmp	edx, eax 	2
# 0x3cbd:	jge	0x3cd2 	2
# 0x3cbf:	mov	rax, qword ptr [rip + 0xbd62] 	7
# 0x3cc6:	mov	rdi, rax 	3
# 0x3cc9:	call	0x35d0 	5
# 0x3cce:	cdqe	 	2
# 0x3cd0:	jmp	0x3cda 	2
# 0x3cda
# 0x3cd2:	mov	eax, dword ptr [rip + 0xbde8] 	6
# 0x3cd8:	cdqe	 	2
# 0x3cda:	mov	rsi, qword ptr [rip + 0xbd47] 	7
# 0x3ce1:	mov	rcx, qword ptr [rip + 0xbcf8] 	7
# 0x3ce8:	mov	rdx, rax 	3
# 0x3ceb:	mov	rdi, rcx 	3
# 0x3cee:	call	0x3730 	5
# 0x3cf3:	mov	edx, dword ptr [rip + 0xb48f] 	6
# 0x3cf9:	mov	ecx, dword ptr [rip + 0xb485] 	6
# 0x3cff:	mov	eax, dword ptr [rip + 0xb487] 	6
# 0x3d05:	mov	esi, ecx 	2
# 0x3d07:	mov	edi, eax 	2
# 0x3d09:	call	0x6aff 	5
# 0x3d0e:	mov	rax, qword ptr [rip + 0xbd03] 	7
# 0x3d15:	mov	edx, 0 	5
# 0x3d1a:	mov	esi, 0 	5
# 0x3d1f:	mov	rdi, rax 	3
# 0x3d22:	call	0x8794 	5
# 0x3d27:	mov	edx, dword ptr [rip + 0xbd93] 	6
# 0x3d2d:	mov	rcx, qword ptr [rip + 0xbcac] 	7
# 0x3d34:	mov	rax, qword ptr [rip + 0xbcdd] 	7
# 0x3d3b:	mov	rsi, rcx 	3
# 0x3d3e:	mov	rdi, rax 	3
# 0x3d41:	call	0x8690 	5
# 0x3d46:	nop	 	1
# 0x3d47:	pop	rbp 	1
# 0x3d48:	ret	 	1
# 0x3d49:	endbr64	 	4
# 0x3d4d:	push	rbp 	1
# 0x3d4e:	mov	rbp, rsp 	3
# 0x3d51:	sub	rsp, 0x20 	4
# 0x3d55:	mov	eax, 0 	5
# 0x3d5a:	call	0x73cb 	5
# 0x3d5f:	mov	qword ptr [rbp - 0x20], rax 	4
# 0x3d63:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x3d67:	mov	rdi, rax 	3
# 0x3d6a:	call	0x35d0 	5
# 0x3d6f:	mov	qword ptr [rbp - 0x18], rax 	4
# 0x3d73:	cmp	qword ptr [rbp - 0x18], 0 	5
# 0x3d78:	je	0x3ec4 	6
# 0x3d7e:	mov	rax, qword ptr [rbp - 0x18] 	4
# 0x3d82:	lea	rdx, [rax - 1] 	4
# 0x3d86:	mov	rax, qword ptr [rbp - 0x20] 	4
# 0x3d8a:	add	rax, rdx 	3
# 0x3d8d:	movzx	eax, byte ptr [rax] 	3
# 0x3d90:	cmp	al, 7 	2
# 0x3d92:	je	0x3ec4 	6
# 0x3d98:	mov	eax, 0 	5
# 0x3d9d:	call	0x73cb 	5
# 0x3da2:	mov	rdi, rax 	3
# 0x3da5:	call	0x5e3c 	5
# 0x3daa:	mov	qword ptr [rbp - 0x10], rax 	4
# 0x3dae:	mov	rax, qword ptr [rbp - 0x10] 	4
# 0x3db2:	mov	rdi, rax 	3
# 0x3db5:	call	0x35d0 	5
# 0x3dba:	sub	rax, -0x80 	4
# 0x3dbe:	mov	rdi, rax 	3
# 0x3dc1:	call	0xae20 	5
# 0x3dc6:	mov	qword ptr [rbp - 8], rax 	4
# 0x3dca:	mov	rdx, qword ptr [rbp - 0x10] 	4
# 0x3dce:	mov	rax, qword ptr [rbp - 8] 	4
# 0x3dd2:	lea	rcx, [rip + 0x72f8] 	7
# 0x3dd9:	mov	rsi, rcx 	3
# 0x3ddc:	mov	rdi, rax 	3
# 0x3ddf:	mov	eax, 0 	5
# 0x3de4:	call	0x38a0 	5
# 0x3de9:	mov	eax, dword ptr [rip + 0xbcd1] 	6
# 0x3def:	movsxd	rdx, eax 	3
# 0x3df2:	mov	rax, qword ptr [rip + 0xbbe7] 	7
# 0x3df9:	mov	esi, 0x20 	5
# 0x3dfe:	mov	rdi, rax 	3
# 0x3e01:	call	0x3620 	5
# 0x3e06:	mov	rax, qword ptr [rbp - 8] 	4
# 0x3e0a:	mov	rdi, rax 	3
# 0x3e0d:	call	0x35d0 	5
# 0x3e12:	mov	edx, eax 	2
# 0x3e14:	mov	eax, dword ptr [rip + 0xbca6] 	6
# 0x3e1a:	cmp	edx, eax 	2
# 0x3e1c:	jge	0x3e2e 	2
# 0x3e1e:	mov	rax, qword ptr [rbp - 8] 	4
# 0x3e22:	mov	rdi, rax 	3
# 0x3e25:	call	0x35d0 	5
# 0x3e2a:	cdqe	 	2
# 0x3e2c:	jmp	0x3e36 	2
# 0x3e36
# 0x3e2e:	mov	eax, dword ptr [rip + 0xbc8c] 	6
# 0x3e34:	cdqe	 	2
# 0x3e36:	mov	rcx, qword ptr [rip + 0xbba3] 	7
# 0x3e3d:	mov	rsi, qword ptr [rbp - 8] 	4
# 0x3e41:	mov	rdx, rax 	3
# 0x3e44:	mov	rdi, rcx 	3
# 0x3e47:	call	0x3730 	5
# 0x3e4c:	mov	rax, qword ptr [rbp - 8] 	4
# 0x3e50:	mov	rdi, rax 	3
# 0x3e53:	call	0xaddd 	5
# 0x3e58:	mov	edx, 1 	5
# 0x3e5d:	mov	esi, 7 	5
# 0x3e62:	mov	edi, 1 	5
# 0x3e67:	call	0x6aff 	5
# 0x3e6c:	mov	rax, qword ptr [rip + 0xbba5] 	7
# 0x3e73:	mov	edx, 0 	5
# 0x3e78:	mov	esi, 0 	5
# 0x3e7d:	mov	rdi, rax 	3
# 0x3e80:	call	0x8794 	5
# 0x3e85:	mov	edx, dword ptr [rip + 0xbc35] 	6
# 0x3e8b:	mov	rcx, qword ptr [rip + 0xbb4e] 	7
# 0x3e92:	mov	rax, qword ptr [rip + 0xbb7f] 	7
# 0x3e99:	mov	rsi, rcx 	3
# 0x3e9c:	mov	rdi, rax 	3
# 0x3e9f:	call	0x8690 	5
# 0x3ea4:	mov	eax, 0 	5
# 0x3ea9:	call	0x6b35 	5
# 0x3eae:	mov	eax, 0 	5
# 0x3eb3:	call	0x602d 	5
# 0x3eb8:	mov	edi, 1 	5
# 0x3ebd:	call	0x38f0 	5
# 0x3ec2:	jmp	0x3ece 	2
# 0x3ece
# 0x3ec4:	mov	eax, 0 	5
# 0x3ec9:	call	0x6b35 	5
# 0x3ece:	mov	eax, 0 	5
# 0x3ed3:	call	0x3c7f 	5
# 0x3ed8:	mov	eax, 0 	5
# 0x3edd:	call	0x3a7b 	5
# 0x3ee2:	mov	eax, 0 	5
# 0x3ee7:	call	0x602d 	5
# 0x3eec:	nop	 	1
# 0x3eed:	leave	 	1
# 0x3eef:	endbr64	 	4
# 0x3ef3:	push	rbp 	1
# 0x3ef4:	mov	rbp, rsp 	3
# 0x3ef7:	sub	rsp, 0x10 	4
# 0x3efb:	mov	eax, edi 	2
# 0x3efd:	mov	dword ptr [rbp - 8], esi 	3
# 0x3f00:	mov	dword ptr [rbp - 0xc], edx 	3
# 0x3f03:	mov	byte ptr [rbp - 4], al 	3
# 0x3f06:	mov	eax, dword ptr [rbp - 8] 	3
# 0x3f09:	cmp	eax, dword ptr [rbp - 0xc] 	3
# 0x3f0c:	jge	0x3f3d 	2
# 0x3f0e:	call	0x3910 	5
# 0x3f13:	mov	rdx, qword ptr [rax] 	3
# 0x3f16:	movsx	rax, byte ptr [rbp - 4] 	5
# 0x3f1b:	add	rax, rax 	3
# 0x3f1e:	add	rax, rdx 	3
# 0x3f21:	movzx	eax, word ptr [rax] 	3
# 0x3f24:	movzx	eax, ax 	3
# 0x3f27:	and	eax, 0x4000 	5
# 0x3f2c:	test	eax, eax 	2
# 0x3f2e:	je	0x3f36 	2
# 0x3f30:	movzx	eax, byte ptr [rbp - 4] 	4
# 0x3f34:	jmp	0x3f42 	2
# 0x3f42
# 0x3f36:	mov	eax, 0x2e 	5
# 0x3f3b:	jmp	0x3f42 	2
# 0x3f42
# 0x3f3d:	mov	eax, 0x20 	5
# 0x3f42:	leave	 	1
# 0x3f44:	endbr64	 	4
# 0x3f48:	push	rbp 	1
# 0x3f49:	mov	rbp, rsp 	3
# 0x3f4c:	push	r15 	2
# 0x3f4e:	push	r14 	2
# 0x3f50:	push	r13 	2
# 0x3f52:	push	r12 	2
# 0x3f54:	push	rbx 	1
# 0x3f55:	sub	rsp, 0x98 	7
# 0x3f5c:	mov	qword ptr [rbp - 0x68], rdi 	4
# 0x3f60:	mov	rax, qword ptr fs:[0x28] 	9
# 0x3f69:	mov	qword ptr [rbp - 0x38], rax 	4
# 0x3f6d:	xor	eax, eax 	2
# 0x3f6f:	mov	eax, dword ptr [rip + 0xbb4b] 	6
# 0x3f75:	mov	edx, 0x51 	5
# 0x3f7a:	cmp	eax, edx 	2
# 0x3f7c:	cmovl	eax, edx 	3
# 0x3f7f:	cdqe	 	2
# 0x3f81:	mov	rdi, rax 	3
# 0x3f84:	call	0xae20 	5
# 0x3f89:	mov	qword ptr [rbp - 0x58], rax 	4
# 0x3f8d:	mov	eax, dword ptr [rip + 0xbb2d] 	6
# 0x3f93:	movsxd	rdx, eax 	3
# 0x3f96:	mov	rax, qword ptr [rbp - 0x58] 	4
# 0x3f9a:	mov	esi, 0x20 	5
# 0x3f9f:	mov	rdi, rax 	3
# 0x3fa2:	call	0x3620 	5
# 0x3fa7:	lea	rax, [rbp - 0x50] 	4
# 0x3fab:	mov	edx, 0x10 	5
# 0x3fb0:	mov	esi, 0 	5
# 0x3fb5:	mov	rdi, rax 	3
# 0x3fb8:	call	0x3620 	5
# 0x3fbd:	mov	rax, qword ptr [rbp - 0x68] 	4
# 0x3fc1:	shl	rax, 4 	4
# 0x3fc5:	mov	rcx, rax 	3
# 0x3fc8:	mov	eax, dword ptr [rip + 0xba1a] 	6
# 0x3fce:	mov	edx, 0 	5
# 0x3fd3:	mov	rsi, rcx 	3
# 0x3fd6:	mov	edi, eax 	2
# 0x3fd8:	call	0x38d0 	5
# 0x3fdd:	mov	eax, dword ptr [rip + 0xba05] 	6
# 0x3fe3:	lea	rcx, [rbp - 0x50] 	4
# 0x3fe7:	mov	edx, 0x10 	5
# 0x3fec:	mov	rsi, rcx 	3
# 0x3fef:	mov	edi, eax 	2
# 0x3ff1:	call	0x34a0 	5
# 0x3ff6:	mov	qword ptr [rbp - 0x60], rax 	4
# 0x3ffa:	cmp	qword ptr [rbp - 0x60], 0 	5
# 0x3fff:	je	0x43af 	6
# 0x4005:	movzx	eax, byte ptr [rbp - 0x41] 	4
# 0x4009:	movzx	eax, al 	3
# 0x400c:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x4010:	mov	esi, 0xf 	5
# 0x4015:	mov	edi, eax 	2
# 0x4017:	mov	eax, 0 	5
# 0x401c:	call	0x3eef 	5
# 0x4021:	movsx	eax, al 	3
# 0x4024:	mov	ebx, eax 	2
# 0x4026:	movzx	eax, byte ptr [rbp - 0x42] 	4
# 0x402a:	movzx	eax, al 	3
# 0x402d:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x4031:	mov	esi, 0xe 	5
# 0x4036:	mov	edi, eax 	2
# 0x4038:	mov	eax, 0 	5
# 0x403d:	call	0x3eef 	5
# 0x4042:	movsx	ecx, al 	3
# 0x4045:	mov	dword ptr [rbp - 0x6c], ecx 	3
# 0x4048:	movzx	eax, byte ptr [rbp - 0x43] 	4
# 0x404c:	movzx	eax, al 	3
# 0x404f:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x4053:	mov	esi, 0xd 	5
# 0x4058:	mov	edi, eax 	2
# 0x405a:	mov	eax, 0 	5
# 0x405f:	call	0x3eef 	5
# 0x4064:	movsx	esi, al 	3
# 0x4067:	mov	dword ptr [rbp - 0x70], esi 	3
# 0x406a:	movzx	eax, byte ptr [rbp - 0x44] 	4
# 0x406e:	movzx	eax, al 	3
# 0x4071:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x4075:	mov	esi, 0xc 	5
# 0x407a:	mov	edi, eax 	2
# 0x407c:	mov	eax, 0 	5
# 0x4081:	call	0x3eef 	5
# 0x4086:	movsx	edi, al 	3
# 0x4089:	mov	dword ptr [rbp - 0x74], edi 	3
# 0x408c:	movzx	eax, byte ptr [rbp - 0x45] 	4
# 0x4090:	movzx	eax, al 	3
# 0x4093:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x4097:	mov	esi, 0xb 	5
# 0x409c:	mov	edi, eax 	2
# 0x409e:	mov	eax, 0 	5
# 0x40a3:	call	0x3eef 	5
# 0x40a8:	movsx	edx, al 	3
# 0x40ab:	mov	dword ptr [rbp - 0x78], edx 	3
# 0x40ae:	movzx	eax, byte ptr [rbp - 0x46] 	4
# 0x40b2:	movzx	eax, al 	3
# 0x40b5:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x40b9:	mov	esi, 0xa 	5
# 0x40be:	mov	edi, eax 	2
# 0x40c0:	mov	eax, 0 	5
# 0x40c5:	call	0x3eef 	5
# 0x40ca:	movsx	r10d, al 	4
# 0x40ce:	mov	dword ptr [rbp - 0x7c], r10d 	4
# 0x40d2:	movzx	eax, byte ptr [rbp - 0x47] 	4
# 0x40d6:	movzx	eax, al 	3
# 0x40d9:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x40dd:	mov	esi, 9 	5
# 0x40e2:	mov	edi, eax 	2
# 0x40e4:	mov	eax, 0 	5
# 0x40e9:	call	0x3eef 	5
# 0x40ee:	movsx	r11d, al 	4
# 0x40f2:	mov	dword ptr [rbp - 0x80], r11d 	4
# 0x40f6:	movzx	eax, byte ptr [rbp - 0x48] 	4
# 0x40fa:	movzx	eax, al 	3
# 0x40fd:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x4101:	mov	esi, 8 	5
# 0x4106:	mov	edi, eax 	2
# 0x4108:	mov	eax, 0 	5
# 0x410d:	call	0x3eef 	5
# 0x4112:	movsx	r14d, al 	4
# 0x4116:	mov	dword ptr [rbp - 0x84], r14d 	7
# 0x411d:	movzx	eax, byte ptr [rbp - 0x49] 	4
# 0x4121:	movzx	eax, al 	3
# 0x4124:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x4128:	mov	esi, 7 	5
# 0x412d:	mov	edi, eax 	2
# 0x412f:	mov	eax, 0 	5
# 0x4134:	call	0x3eef 	5
# 0x4139:	movsx	r15d, al 	4
# 0x413d:	mov	dword ptr [rbp - 0x88], r15d 	7
# 0x4144:	movzx	eax, byte ptr [rbp - 0x4a] 	4
# 0x4148:	movzx	eax, al 	3
# 0x414b:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x414f:	mov	esi, 6 	5
# 0x4154:	mov	edi, eax 	2
# 0x4156:	mov	eax, 0 	5
# 0x415b:	call	0x3eef 	5
# 0x4160:	movsx	r8d, al 	4
# 0x4164:	mov	dword ptr [rbp - 0x8c], r8d 	7
# 0x416b:	movzx	eax, byte ptr [rbp - 0x4b] 	4
# 0x416f:	movzx	eax, al 	3
# 0x4172:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x4176:	mov	esi, 5 	5
# 0x417b:	mov	edi, eax 	2
# 0x417d:	mov	eax, 0 	5
# 0x4182:	call	0x3eef 	5
# 0x4187:	movsx	r9d, al 	4
# 0x418b:	mov	dword ptr [rbp - 0x90], r9d 	7
# 0x4192:	movzx	eax, byte ptr [rbp - 0x4c] 	4
# 0x4196:	movzx	eax, al 	3
# 0x4199:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x419d:	mov	esi, 4 	5
# 0x41a2:	mov	edi, eax 	2
# 0x41a4:	mov	eax, 0 	5
# 0x41a9:	call	0x3eef 	5
# 0x41ae:	movsx	r12d, al 	4
# 0x41b2:	mov	dword ptr [rbp - 0x94], r12d 	7
# 0x41b9:	movzx	eax, byte ptr [rbp - 0x4d] 	4
# 0x41bd:	movzx	ecx, al 	3
# 0x41c0:	mov	rax, qword ptr [rbp - 0x60] 	4
# 0x41c4:	mov	rdx, rax 	3
# 0x41c7:	mov	esi, 3 	5
# 0x41cc:	mov	edi, ecx 	2
# 0x41ce:	mov	eax, 0 	5
# 0x41d3:	call	0x3eef 	5
# 0x41d8:	movsx	r13d, al 	4
# 0x41dc:	mov	dword ptr [rbp - 0x98], r13d 	7
# 0x41e3:	movzx	eax, byte ptr [rbp - 0x4e] 	4
# 0x41e7:	movzx	ecx, al 	3
# 0x41ea:	mov	rax, qword ptr [rbp - 0x60] 	4
# 0x41ee:	mov	rdx, rax 	3
# 0x41f1:	mov	esi, 2 	5
# 0x41f6:	mov	edi, ecx 	2
# 0x41f8:	mov	eax, 0 	5
# 0x41fd:	call	0x3eef 	5
# 0x4202:	movsx	eax, al 	3
# 0x4205:	mov	dword ptr [rbp - 0x9c], eax 	6
# 0x420b:	movzx	eax, byte ptr [rbp - 0x4f] 	4
# 0x420f:	movzx	ecx, al 	3
# 0x4212:	mov	rax, qword ptr [rbp - 0x60] 	4
# 0x4216:	mov	rdx, rax 	3
# 0x4219:	mov	esi, 1 	5
# 0x421e:	mov	edi, ecx 	2
# 0x4220:	mov	eax, 0 	5
# 0x4225:	call	0x3eef 	5
# 0x422a:	movsx	ecx, al 	3
# 0x422d:	mov	dword ptr [rbp - 0xa0], ecx 	6
# 0x4233:	movzx	eax, byte ptr [rbp - 0x50] 	4
# 0x4237:	movzx	ecx, al 	3
# 0x423a:	mov	rax, qword ptr [rbp - 0x60] 	4
# 0x423e:	mov	rdx, rax 	3
# 0x4241:	mov	esi, 0 	5
# 0x4246:	mov	edi, ecx 	2
# 0x4248:	mov	eax, 0 	5
# 0x424d:	call	0x3eef 	5
# 0x4252:	movsx	esi, al 	3
# 0x4255:	mov	dword ptr [rbp - 0xa4], esi 	6
# 0x425b:	movzx	eax, byte ptr [rbp - 0x41] 	4
# 0x425f:	movzx	edi, al 	3
# 0x4262:	mov	dword ptr [rbp - 0xa8], edi 	6
# 0x4268:	movzx	eax, byte ptr [rbp - 0x42] 	4
# 0x426c:	movzx	edx, al 	3
# 0x426f:	mov	dword ptr [rbp - 0xac], edx 	6
# 0x4275:	movzx	eax, byte ptr [rbp - 0x43] 	4
# 0x4279:	movzx	r10d, al 	4
# 0x427d:	mov	dword ptr [rbp - 0xb0], r10d 	7
# 0x4284:	movzx	eax, byte ptr [rbp - 0x44] 	4
# 0x4288:	movzx	r11d, al 	4
# 0x428c:	mov	dword ptr [rbp - 0xb4], r11d 	7
# 0x4293:	movzx	eax, byte ptr [rbp - 0x45] 	4
# 0x4297:	movzx	r15d, al 	4
# 0x429b:	movzx	eax, byte ptr [rbp - 0x46] 	4
# 0x429f:	movzx	r14d, al 	4
# 0x42a3:	movzx	eax, byte ptr [rbp - 0x47] 	4
# 0x42a7:	movzx	r13d, al 	4
# 0x42ab:	movzx	eax, byte ptr [rbp - 0x48] 	4
# 0x42af:	movzx	r12d, al 	4
# 0x42b3:	movzx	eax, byte ptr [rbp - 0x49] 	4
# 0x42b7:	movzx	eax, al 	3
# 0x42ba:	mov	dword ptr [rbp - 0xb8], eax 	6
# 0x42c0:	movzx	eax, byte ptr [rbp - 0x4a] 	4
# 0x42c4:	movzx	r11d, al 	4
# 0x42c8:	movzx	eax, byte ptr [rbp - 0x4b] 	4
# 0x42cc:	movzx	r10d, al 	4
# 0x42d0:	movzx	eax, byte ptr [rbp - 0x4c] 	4
# 0x42d4:	movzx	r8d, al 	4
# 0x42d8:	movzx	eax, byte ptr [rbp - 0x4d] 	4
# 0x42dc:	movzx	ecx, al 	3
# 0x42df:	movzx	eax, byte ptr [rbp - 0x4e] 	4
# 0x42e3:	movzx	r9d, al 	4
# 0x42e7:	movzx	eax, byte ptr [rbp - 0x4f] 	4
# 0x42eb:	movzx	esi, al 	3
# 0x42ee:	movzx	eax, byte ptr [rbp - 0x50] 	4
# 0x42f2:	movzx	edx, al 	3
# 0x42f5:	mov	rax, qword ptr [rbp - 0x68] 	4
# 0x42f9:	mov	rdi, qword ptr [rbp - 0x58] 	4
# 0x42fd:	sub	rsp, 8 	4
# 0x4301:	push	rbx 	1
# 0x4302:	mov	ebx, dword ptr [rbp - 0x6c] 	3
# 0x4305:	push	rbx 	1
# 0x4306:	mov	ebx, dword ptr [rbp - 0x70] 	3
# 0x4309:	push	rbx 	1
# 0x430a:	mov	ebx, dword ptr [rbp - 0x74] 	3
# 0x430d:	push	rbx 	1
# 0x430e:	mov	ebx, dword ptr [rbp - 0x78] 	3
# 0x4311:	push	rbx 	1
# 0x4312:	mov	ebx, dword ptr [rbp - 0x7c] 	3
# 0x4315:	push	rbx 	1
# 0x4316:	mov	ebx, dword ptr [rbp - 0x80] 	3
# 0x4319:	push	rbx 	1
# 0x431a:	mov	ebx, dword ptr [rbp - 0x84] 	6
# 0x4320:	push	rbx 	1
# 0x4321:	mov	ebx, dword ptr [rbp - 0x88] 	6
# 0x4327:	push	rbx 	1
# 0x4328:	mov	ebx, dword ptr [rbp - 0x8c] 	6
# 0x432e:	push	rbx 	1
# 0x432f:	mov	ebx, dword ptr [rbp - 0x90] 	6
# 0x4335:	push	rbx 	1
# 0x4336:	mov	ebx, dword ptr [rbp - 0x94] 	6
# 0x433c:	push	rbx 	1
# 0x433d:	mov	ebx, dword ptr [rbp - 0x98] 	6
# 0x4343:	push	rbx 	1
# 0x4344:	mov	ebx, dword ptr [rbp - 0x9c] 	6
# 0x434a:	push	rbx 	1
# 0x434b:	mov	ebx, dword ptr [rbp - 0xa0] 	6
# 0x4351:	push	rbx 	1
# 0x4352:	mov	ebx, dword ptr [rbp - 0xa4] 	6
# 0x4358:	push	rbx 	1
# 0x4359:	mov	ebx, dword ptr [rbp - 0xa8] 	6
# 0x435f:	push	rbx 	1
# 0x4360:	mov	ebx, dword ptr [rbp - 0xac] 	6
# 0x4366:	push	rbx 	1
# 0x4367:	mov	ebx, dword ptr [rbp - 0xb0] 	6
# 0x436d:	push	rbx 	1
# 0x436e:	mov	ebx, dword ptr [rbp - 0xb4] 	6
# 0x4374:	push	rbx 	1
# 0x4375:	push	r15 	2
# 0x4377:	push	r14 	2
# 0x4379:	push	r13 	2
# 0x437b:	push	r12 	2
# 0x437d:	mov	ebx, dword ptr [rbp - 0xb8] 	6
# 0x4383:	push	rbx 	1
# 0x4384:	push	r11 	2
# 0x4386:	push	r10 	2
# 0x4388:	push	r8 	2
# 0x438a:	push	rcx 	1
# 0x438b:	mov	r8d, esi 	3
# 0x438e:	mov	ecx, edx 	2
# 0x4390:	mov	edx, eax 	2
# 0x4392:	lea	rax, [rip + 0x6d4f] 	7
# 0x4399:	mov	rsi, rax 	3
# 0x439c:	mov	eax, 0 	5
# 0x43a1:	call	0x38a0 	5
# 0x43a6:	add	rsp, 0xf0 	7
# 0x43ad:	jmp	0x43be 	2
# 0x43be
# 0x43af:	mov	qword ptr [rbp - 0x60], 0 	8
# 0x43b7:	mov	rax, qword ptr [rbp - 0x58] 	4
# 0x43bb:	mov	byte ptr [rax], 0 	3
# 0x43be:	cmp	qword ptr [rbp - 0x60], 7 	5
# 0x43c3:	jg	0x440b 	2
# 0x43c5:	mov	eax, 0x10 	5
# 0x43ca:	sub	rax, qword ptr [rbp - 0x60] 	4
# 0x43ce:	mov	rdx, rax 	3
# 0x43d1:	mov	rax, rdx 	3
# 0x43d4:	add	rax, rax 	3
# 0x43d7:	add	rax, rdx 	3
# 0x43da:	add	rax, 1 	4
# 0x43de:	mov	rcx, rax 	3
# 0x43e1:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x43e5:	mov	rax, rdx 	3
# 0x43e8:	add	rax, rax 	3
# 0x43eb:	add	rax, rdx 	3
# 0x43ee:	lea	rdx, [rax + 0xc] 	4
# 0x43f2:	mov	rax, qword ptr [rbp - 0x58] 	4
# 0x43f6:	add	rax, rdx 	3
# 0x43f9:	mov	rdx, rcx 	3
# 0x43fc:	mov	esi, 0x20 	5
# 0x4401:	mov	rdi, rax 	3
# 0x4404:	call	0x3620 	5
# 0x4409:	jmp	0x4459 	2
# 0x4459
# 0x440b:	cmp	qword ptr [rbp - 0x60], 7 	5
# 0x4410:	jle	0x4459 	2
# 0x4412:	cmp	qword ptr [rbp - 0x60], 0xf 	5
# 0x4417:	jg	0x4459 	2
# 0x4419:	mov	eax, 0x10 	5
# 0x441e:	sub	rax, qword ptr [rbp - 0x60] 	4
# 0x4422:	mov	rdx, rax 	3
# 0x4425:	mov	rax, rdx 	3
# 0x4428:	add	rax, rax 	3
# 0x442b:	add	rax, rdx 	3
# 0x442e:	mov	rcx, rax 	3
# 0x4431:	mov	rdx, qword ptr [rbp - 0x60] 	4
# 0x4435:	mov	rax, rdx 	3
# 0x4438:	add	rax, rax 	3
# 0x443b:	add	rax, rdx 	3
# 0x443e:	lea	rdx, [rax + 0xd] 	4
# 0x4442:	mov	rax, qword ptr [rbp - 0x58] 	4
# 0x4446:	add	rax, rdx 	3
# 0x4449:	mov	rdx, rcx 	3
# 0x444c:	mov	esi, 0x20 	5
# 0x4451:	mov	rdi, rax 	3
# 0x4454:	call	0x3620 	5
# 0x4459:	mov	rax, qword ptr [rbp - 0x58] 	4
# 0x445d:	mov	rdi, rax 	3
# 0x4460:	call	0x35d0 	5
# 0x4465:	mov	rdx, qword ptr [rbp - 0x58] 	4
# 0x4469:	add	rax, rdx 	3
# 0x446c:	mov	byte ptr [rax], 0x20 	3
# 0x446f:	mov	edx, dword ptr [rip + 0xb64b] 	6
# 0x4475:	mov	rax, qword ptr [rip + 0xb594] 	7
# 0x447c:	mov	rcx, qword ptr [rbp - 0x58] 	4
# 0x4480:	mov	rsi, rcx 	3
# 0x4483:	mov	rdi, rax 	3
# 0x4486:	call	0x8690 	5
# 0x448b:	mov	rax, qword ptr [rbp - 0x58] 	4
# 0x448f:	mov	rdi, rax 	3
# 0x4492:	call	0xaddd 	5
# 0x4497:	nop	 	1
# 0x4498:	mov	rax, qword ptr [rbp - 0x38] 	4
# 0x449c:	sub	rax, qword ptr fs:[0x28] 	9
# 0x44a5:	je	0x44ac 	2
# 0x44bb:	endbr64	 	4
# 0x44bf:	push	rbp 	1
# 0x44c0:	mov	rbp, rsp 	3
# 0x44c3:	sub	rsp, 0x10 	4
# 0x44c7:	mov	edx, dword ptr [rip + 0xacaf] 	6
# 0x44cd:	mov	ecx, dword ptr [rip + 0xaca5] 	6
# 0x44d3:	mov	eax, dword ptr [rip + 0xaca7] 	6
# 0x44d9:	mov	esi, ecx 	2
# 0x44db:	mov	edi, eax 	2
# 0x44dd:	call	0x6aff 	5
# 0x44e2:	mov	rax, qword ptr [rip + 0xb507] 	7
# 0x44e9:	mov	qword ptr [rbp - 8], rax 	4
# 0x44ed:	jmp	0x4533 	2
# 0x4533
# 0x44ef:	mov	rax, qword ptr [rbp - 8] 	4
# 0x44f3:	mov	edx, eax 	2
# 0x44f5:	mov	rax, qword ptr [rip + 0xb4f4] 	7
# 0x44fc:	mov	ecx, eax 	2
# 0x44fe:	mov	eax, edx 	2
# 0x4500:	sub	eax, ecx 	2
# 0x4502:	add	eax, 3 	3
# 0x4505:	mov	ecx, eax 	2
# 0x4507:	mov	rax, qword ptr [rip + 0xb502] 	7
# 0x450e:	mov	edx, 0 	5
# 0x4513:	mov	esi, ecx 	2
# 0x4515:	mov	rdi, rax 	3
# 0x4518:	call	0x8794 	5
# 0x451d:	mov	rax, qword ptr [rbp - 8] 	4
# 0x4521:	mov	rdi, rax 	3
# 0x4524:	mov	eax, 0 	5
# 0x4529:	call	0x3f44 	5
# 0x452e:	add	qword ptr [rbp - 8], 1 	5
# 0x4533:	mov	eax, dword ptr [rip + 0xb583] 	6
# 0x4539:	sub	eax, 9 	3
# 0x453c:	movsxd	rdx, eax 	3
# 0x453f:	mov	rax, qword ptr [rip + 0xb4aa] 	7
# 0x4546:	add	rax, rdx 	3
# 0x4549:	cmp	qword ptr [rbp - 8], rax 	4
# 0x454d:	jl	0x44ef 	2
# 0x454f:	nop	 	1
# 0x4550:	nop	 	1
# 0x4551:	leave	 	1
# 0x4553:	endbr64	 	4
# 0x4557:	push	rbp 	1
# 0x4558:	mov	rbp, rsp 	3
# 0x455b:	mov	edi, 0 	5
# 0x4560:	call	0x5cae 	5
# 0x4565:	nop	 	1
# 0x4566:	pop	rbp 	1
# 0x4567:	ret	 	1
# 0x4568:	endbr64	 	4
# 0x456c:	push	rbp 	1
# 0x456d:	mov	rbp, rsp 	3
# 0x4570:	sub	rsp, 0x10 	4
# 0x4574:	mov	qword ptr [rbp - 8], rdi 	4
# 0x4578:	mov	eax, 0 	5
# 0x457d:	call	0x4553 	5
# 0x4582:	mov	rdx, qword ptr [rip + 0xb40f] 	7
# 0x4589:	mov	rax, qword ptr [rip + 0xb3f0] 	7
# 0x4590:	mov	rcx, qword ptr [rbp - 8] 	4
# 0x4594:	lea	rsi, [rip + 0x6bc9] 	7
# 0x459b:	mov	rdi, rax 	3
# 0x459e:	mov	eax, 0 	5
# 0x45a3:	call	0x3700 	5
# 0x45a8:	mov	edi, 1 	5
# 0x45ad:	call	0x38b0 	5
# 0x45b2:	endbr64	 	4
# 0x45b6:	push	rbp 	1
# 0x45b7:	mov	rbp, rsp 	3
# 0x45ba:	sub	rsp, 0x90 	7
# 0x45c1:	mov	dword ptr [rbp - 0x84], edi 	6
# 0x45c7:	mov	rax, qword ptr fs:[0x28] 	9
# 0x45d0:	mov	qword ptr [rbp - 8], rax 	4
# 0x45d4:	xor	eax, eax 	2
# 0x45d6:	mov	eax, dword ptr [rbp - 0x84] 	6
# 0x45dc:	mov	dword ptr [rbp - 0x7c], eax 	3
# 0x45df:	jmp	0x4736 	5
# 0x4736
# 0x45e4:	lea	rsi, [rbp - 0x70] 	4
# 0x45e8:	lea	rax, [rbp - 0x60] 	4
# 0x45ec:	mov	ecx, 0 	5
# 0x45f1:	mov	edx, 1 	5
# 0x45f6:	mov	rdi, rax 	3
# 0x45f9:	call	0xa0ce 	5
# 0x45fe:	movzx	eax, byte ptr [rbp - 0x60] 	4
# 0x4602:	test	al, al 	2
# 0x4604:	je	0x4745 	6
# 0x460a:	movzx	eax, byte ptr [rbp - 0x60] 	4
# 0x460e:	cmp	al, 0x5e 	2
# 0x4610:	je	0x465d 	2
# 0x4612:	lea	rax, [rbp - 0x60] 	4
# 0x4616:	mov	rdi, rax 	3
# 0x4619:	call	0x7ad4 	5
# 0x461e:	mov	qword ptr [rbp - 0x68], rax 	4
# 0x4622:	cmp	qword ptr [rbp - 0x68], 0 	5
# 0x4627:	je	0x4654 	2
# 0x4629:	mov	rax, qword ptr [rbp - 0x68] 	4
# 0x462d:	movzx	eax, byte ptr [rax] 	3
# 0x4630:	test	al, al 	2
# 0x4632:	je	0x472e 	6
# 0x4638:	mov	rdx, qword ptr [rbp - 0x68] 	4
# 0x463c:	lea	rax, [rbp - 0x60] 	4
# 0x4640:	mov	rsi, rdx 	3
# 0x4643:	mov	rdi, rax 	3
# 0x4646:	call	0x3540 	5
# 0x464b:	mov	dword ptr [rbp - 0x74], 0 	7
# 0x4652:	jmp	0x4664 	2
# 0x4664
# 0x4654:	mov	dword ptr [rbp - 0x74], 1 	7
# 0x465b:	jmp	0x4664 	2
# 0x4664
# 0x465d:	mov	dword ptr [rbp - 0x74], 1 	7
# 0x4664:	mov	rax, qword ptr [rbp - 0x70] 	4
# 0x4668:	test	rax, rax 	3
# 0x466b:	je	0x4731 	6
# 0x4671:	mov	dword ptr [rbp - 0x78], 0 	7
# 0x4678:	jmp	0x46af 	2
# 0x46af
# 0x467a:	mov	eax, dword ptr [rbp - 0x78] 	3
# 0x467d:	movsxd	rdx, eax 	3
# 0x4680:	mov	rax, rdx 	3
# 0x4683:	shl	rax, 2 	4
# 0x4687:	add	rax, rdx 	3
# 0x468a:	shl	rax, 2 	4
# 0x468e:	lea	rdx, [rip + 0xa98b] 	7
# 0x4695:	add	rdx, rax 	3
# 0x4698:	mov	rax, qword ptr [rbp - 0x70] 	4
# 0x469c:	mov	rsi, rdx 	3
# 0x469f:	mov	rdi, rax 	3
# 0x46a2:	call	0x36e0 	5
# 0x46a7:	test	eax, eax 	2
# 0x46a9:	je	0x46b7 	2
# 0x46ab:	add	dword ptr [rbp - 0x78], 1 	4
# 0x46af:	cmp	dword ptr [rbp - 0x78], 0xa 	4
# 0x46b3:	jle	0x467a 	2
# 0x46b7:	nop	 	1
# 0x46b8:	cmp	dword ptr [rbp - 0x78], 0xa 	4
# 0x46bc:	jg	0x4706 	2
# 0x46be:	cmp	dword ptr [rbp - 0x74], 0 	4
# 0x46c2:	je	0x46d5 	2
# 0x46c4:	lea	rax, [rbp - 0x60] 	4
# 0x46c8:	mov	rdi, rax 	3
# 0x46cb:	call	0x5d2d 	5
# 0x46d0:	test	rax, rax 	3
# 0x46d3:	je	0x4732 	2
# 0x46d5:	mov	eax, dword ptr [rbp - 0x78] 	3
# 0x46d8:	not	eax 	2
# 0x46da:	movsxd	rdx, eax 	3
# 0x46dd:	mov	rax, rdx 	3
# 0x46e0:	shl	rax, 2 	4
# 0x46e4:	add	rax, rdx 	3
# 0x46e7:	shl	rax, 2 	4
# 0x46eb:	lea	rdx, [rip + 0xa92e] 	7
# 0x46f2:	add	rdx, rax 	3
# 0x46f5:	lea	rax, [rbp - 0x60] 	4
# 0x46f9:	mov	rsi, rdx 	3
# 0x46fc:	mov	rdi, rax 	3
# 0x46ff:	call	0x6dfb 	5
# 0x4704:	jmp	0x4732 	2
# 0x4732
# 0x4706:	mov	rcx, qword ptr [rbp - 0x70] 	4
# 0x470a:	mov	rdx, qword ptr [rip + 0xb287] 	7
# 0x4711:	mov	rax, qword ptr [rip + 0xb268] 	7
# 0x4718:	lea	rsi, [rip + 0x6a61] 	7
# 0x471f:	mov	rdi, rax 	3
# 0x4722:	mov	eax, 0 	5
# 0x4727:	call	0x3700 	5
# 0x472c:	jmp	0x4732 	2
# 0x4732
# 0x472e:	nop	 	1
# 0x472f:	jmp	0x4732 	2
# 0x4732
# 0x4731:	nop	 	1
# 0x4732:	add	dword ptr [rbp - 0x7c], 1 	4
# 0x4736:	cmp	dword ptr [rbp - 0x7c], 0x7ff 	7
# 0x473d:	jle	0x45e4 	6
# 0x4745:	nop	 	1
# 0x4746:	mov	eax, dword ptr [rbp - 0x7c] 	3
# 0x4749:	mov	rdx, qword ptr [rbp - 8] 	4
# 0x474d:	sub	rdx, qword ptr fs:[0x28] 	9
# 0x4756:	je	0x475d 	2
# 0x475f:	endbr64	 	4
# 0x4763:	push	rbp 	1
# 0x4764:	mov	rbp, rsp 	3
# 0x4767:	sub	rsp, 0x30 	4
# 0x476b:	mov	dword ptr [rbp - 0x24], edi 	3
# 0x476e:	mov	dword ptr [rbp - 0x14], 0 	7
# 0x4775:	mov	dword ptr [rbp - 0x10], 0 	7
# 0x477c:	mov	dword ptr [rbp - 0xc], 0 	7
# 0x4783:	mov	eax, dword ptr [rip + 0xb333] 	6
# 0x4789:	mov	dword ptr [rbp - 8], eax 	3
# 0x478c:	mov	eax, dword ptr [rip + 0xb32e] 	6
# 0x4792:	mov	dword ptr [rbp - 4], eax 	3
# 0x4795:	mov	eax, 0 	5
# 0x479a:	call	0x73dc 	5
# 0x479f:	cmp	dword ptr [rbp - 0x24], 0 	4
# 0x47a3:	jne	0x47bf 	2
# 0x47a5:	mov	eax, dword ptr [rip + 0xb311] 	6
# 0x47ab:	cmp	dword ptr [rbp - 8], eax 	3
# 0x47ae:	jne	0x47bf 	2
# 0x47b0:	mov	eax, dword ptr [rip + 0xb30a] 	6
# 0x47b6:	cmp	dword ptr [rbp - 4], eax 	3
# 0x47b9:	je	0x4945 	6
# 0x47bf:	mov	eax, dword ptr [rip + 0xb35b] 	6
# 0x47c5:	test	eax, eax 	2
# 0x47c7:	je	0x47f9 	2
# 0x47c9:	mov	edx, dword ptr [rip + 0xb2f1] 	6
# 0x47cf:	mov	eax, dword ptr [rip + 0xb2e7] 	6
# 0x47d5:	imul	eax, edx 	3
# 0x47d8:	add	eax, 2 	3
# 0x47db:	add	eax, eax 	2
# 0x47dd:	movsxd	rdx, eax 	3
# 0x47e0:	mov	rax, qword ptr [rip + 0xb1b9] 	7
# 0x47e7:	mov	rsi, rdx 	3
# 0x47ea:	mov	rdi, rax 	3
# 0x47ed:	call	0xae40 	5
# 0x47f2:	mov	qword ptr [rip + 0xb1a7], rax 	7
# 0x47f9:	mov	eax, dword ptr [rip + 0xb2c1] 	6
# 0x47ff:	add	eax, 1 	3
# 0x4802:	movsxd	rdx, eax 	3
# 0x4805:	mov	rax, qword ptr [rip + 0xb1d4] 	7
# 0x480c:	mov	rsi, rdx 	3
# 0x480f:	mov	rdi, rax 	3
# 0x4812:	call	0xae40 	5
# 0x4817:	mov	qword ptr [rip + 0xb1c2], rax 	7
# 0x481e:	mov	rax, qword ptr [rip + 0xb183] 	7
# 0x4825:	mov	rdi, rax 	3
# 0x4828:	call	0x35d0 	5
# 0x482d:	lea	rdx, [rax + 0xa] 	4
# 0x4831:	mov	rax, qword ptr [rip + 0xb198] 	7
# 0x4838:	mov	rsi, rdx 	3
# 0x483b:	mov	rdi, rax 	3
# 0x483e:	call	0xae40 	5
# 0x4843:	mov	qword ptr [rip + 0xb186], rax 	7
# 0x484a:	mov	edx, dword ptr [rip + 0xb270] 	6
# 0x4850:	mov	rax, qword ptr [rip + 0xb1a9] 	7
# 0x4857:	mov	r8d, edx 	3
# 0x485a:	mov	ecx, 1 	5
# 0x485f:	mov	edx, 0 	5
# 0x4864:	mov	esi, 0 	5
# 0x4869:	mov	rdi, rax 	3
# 0x486c:	call	0x864d 	5
# 0x4871:	mov	eax, dword ptr [rip + 0xb245] 	6
# 0x4877:	cmp	eax, 1 	3
# 0x487a:	jle	0x4883 	2
# 0x487c:	mov	dword ptr [rbp - 0x14], 1 	7
# 0x4883:	mov	eax, dword ptr [rip + 0xb233] 	6
# 0x4889:	cmp	eax, 2 	3
# 0x488c:	jle	0x4895 	2
# 0x488e:	mov	dword ptr [rbp - 0x10], 1 	7
# 0x4895:	mov	eax, dword ptr [rip + 0xb221] 	6
# 0x489b:	cmp	eax, 3 	3
# 0x489e:	jle	0x48a7 	2
# 0x48a0:	mov	dword ptr [rbp - 0xc], 1 	7
# 0x48a7:	mov	ecx, dword ptr [rip + 0xb213] 	6
# 0x48ad:	cmp	dword ptr [rbp - 0x14], 0 	4
# 0x48b1:	setne	al 	3
# 0x48b4:	movzx	edx, al 	3
# 0x48b7:	mov	eax, dword ptr [rip + 0xb1ff] 	6
# 0x48bd:	lea	esi, [rax - 1] 	3
# 0x48c0:	mov	rax, qword ptr [rip + 0xb151] 	7
# 0x48c7:	mov	r8d, ecx 	3
# 0x48ca:	mov	ecx, edx 	2
# 0x48cc:	mov	edx, esi 	2
# 0x48ce:	mov	esi, 0 	5
# 0x48d3:	mov	rdi, rax 	3
# 0x48d6:	call	0x864d 	5
# 0x48db:	mov	ecx, dword ptr [rip + 0xb1df] 	6
# 0x48e1:	cmp	dword ptr [rbp - 0x10], 0 	4
# 0x48e5:	setne	al 	3
# 0x48e8:	movzx	edx, al 	3
# 0x48eb:	mov	rax, qword ptr [rip + 0xb116] 	7
# 0x48f2:	mov	r8d, ecx 	3
# 0x48f5:	mov	ecx, edx 	2
# 0x48f7:	mov	edx, 1 	5
# 0x48fc:	mov	esi, 0 	5
# 0x4901:	mov	rdi, rax 	3
# 0x4904:	call	0x864d 	5
# 0x4909:	mov	ecx, dword ptr [rip + 0xb1b1] 	6
# 0x490f:	cmp	dword ptr [rbp - 0xc], 0 	4
# 0x4913:	je	0x4920 	2
# 0x4915:	mov	eax, dword ptr [rip + 0xb1a1] 	6
# 0x491b:	lea	edx, [rax - 2] 	3
# 0x491e:	jmp	0x4925 	2
# 0x4925
# 0x4920:	mov	edx, 0 	5
# 0x4925:	mov	rax, qword ptr [rip + 0xb0e4] 	7
# 0x492c:	mov	r8d, ecx 	3
# 0x492f:	mov	ecx, edx 	2
# 0x4931:	mov	edx, 2 	5
# 0x4936:	mov	esi, 0 	5
# 0x493b:	mov	rdi, rax 	3
# 0x493e:	call	0x864d 	5
# 0x4943:	jmp	0x4946 	2
# 0x4946
# 0x4945:	nop	 	1
# 0x4946:	leave	 	1
# 0x4948:	endbr64	 	4
# 0x494c:	push	rbp 	1
# 0x494d:	mov	rbp, rsp 	3
# 0x4950:	sub	rsp, 0x10 	4
# 0x4954:	mov	dword ptr [rbp - 4], edi 	3
# 0x4957:	mov	edi, 0 	5
# 0x495c:	mov	eax, 0 	5
# 0x4961:	call	0x475f 	5
# 0x4966:	cmp	dword ptr [rbp - 4], 0x12 	4
# 0x496a:	jne	0x4980 	2
# 0x496c:	mov	edi, 1 	5
# 0x4971:	call	0x5922 	5
# 0x4976:	mov	eax, 0 	5
# 0x497b:	call	0x6bf9 	5
# 0x4980:	mov	edx, dword ptr [rip + 0xa7f6] 	6
# 0x4986:	mov	ecx, dword ptr [rip + 0xa7ec] 	6
# 0x498c:	mov	eax, dword ptr [rip + 0xa7ee] 	6
# 0x4992:	mov	esi, ecx 	2
# 0x4994:	mov	edi, eax 	2
# 0x4996:	call	0x6aff 	5
# 0x499b:	mov	eax, 0 	5
# 0x49a0:	call	0x64dc 	5
# 0x49a5:	mov	eax, 0 	5
# 0x49aa:	call	0x3a09 	5
# 0x49af:	mov	qword ptr [rip + 0xb002], rax 	7
# 0x49b6:	mov	rax, qword ptr [rip + 0xaffb] 	7
# 0x49bd:	lea	rdx, [rax + 0xf] 	4
# 0x49c1:	test	rax, rax 	3
# 0x49c4:	cmovs	rax, rdx 	4
# 0x49c8:	sar	rax, 4 	4
# 0x49cc:	mov	rdx, rax 	3
# 0x49cf:	mov	rax, qword ptr [rip + 0xafe2] 	7
# 0x49d6:	and	eax, 0xf 	3
# 0x49d9:	test	rax, rax 	3
# 0x49dc:	je	0x49e5 	2
# 0x49de:	mov	eax, 1 	5
# 0x49e3:	jmp	0x49ea 	2
# 0x49ea
# 0x49e5:	mov	eax, 0 	5
# 0x49ea:	add	rax, rdx 	3
# 0x49ed:	mov	qword ptr [rip + 0xb004], rax 	7
# 0x49f4:	mov	eax, dword ptr [rip + 0xb0c2] 	6
# 0x49fa:	cmp	eax, 4 	3
# 0x49fd:	jle	0x4a36 	2
# 0x49ff:	mov	rax, qword ptr [rip + 0xb00a] 	7
# 0x4a06:	mov	edx, 0 	5
# 0x4a0b:	mov	esi, 1 	5
# 0x4a10:	mov	rdi, rax 	3
# 0x4a13:	call	0x8794 	5
# 0x4a18:	mov	rax, qword ptr [rip + 0xaff1] 	7
# 0x4a1f:	mov	edx, 0x51 	5
# 0x4a24:	lea	rcx, [rip + 0xa7b5] 	7
# 0x4a2b:	mov	rsi, rcx 	3
# 0x4a2e:	mov	rdi, rax 	3
# 0x4a31:	call	0x8690 	5
# 0x4a36:	mov	eax, dword ptr [rip + 0xb080] 	6
# 0x4a3c:	cmp	eax, 5 	3
# 0x4a3f:	jle	0x4a78 	2
# 0x4a41:	mov	rax, qword ptr [rip + 0xafc8] 	7
# 0x4a48:	mov	edx, 0 	5
# 0x4a4d:	mov	esi, 2 	5
# 0x4a52:	mov	rdi, rax 	3
# 0x4a55:	call	0x8794 	5
# 0x4a5a:	mov	rax, qword ptr [rip + 0xafaf] 	7
# 0x4a61:	mov	edx, 0x51 	5
# 0x4a66:	lea	rcx, [rip + 0xa7d3] 	7
# 0x4a6d:	mov	rsi, rcx 	3
# 0x4a70:	mov	rdi, rax 	3
# 0x4a73:	call	0x8690 	5
# 0x4a78:	mov	eax, dword ptr [rip + 0xb03e] 	6
# 0x4a7e:	cmp	eax, 8 	3
# 0x4a81:	jle	0x4b5b 	6
# 0x4a87:	mov	eax, dword ptr [rip + 0xb02f] 	6
# 0x4a8d:	cmp	eax, 9 	3
# 0x4a90:	jne	0x4a9f 	2
# 0x4a92:	mov	qword ptr [rip + 0xaf53], 0 	11
# 0x4a9d:	jmp	0x4ade 	2
# 0x4ade
# 0x4a9f:	mov	rax, qword ptr [rip + 0xaf52] 	7
# 0x4aa6:	mov	edx, dword ptr [rip + 0xb010] 	6
# 0x4aac:	sub	edx, 9 	3
# 0x4aaf:	movsxd	rsi, edx 	3
# 0x4ab2:	cqo	 	2
# 0x4ab4:	idiv	rsi 	3
# 0x4ab7:	mov	rdx, rax 	3
# 0x4aba:	mov	eax, dword ptr [rip + 0xaffc] 	6
# 0x4ac0:	sub	eax, 9 	3
# 0x4ac3:	cdqe	 	2
# 0x4ac5:	imul	rdx, rax 	4
# 0x4ac9:	mov	rax, qword ptr [rip + 0xaf20] 	7
# 0x4ad0:	cmp	rdx, rax 	3
# 0x4ad3:	cmovle	rax, rdx 	4
# 0x4ad7:	mov	qword ptr [rip + 0xaf12], rax 	7
# 0x4ade:	mov	eax, dword ptr [rip + 0xafd8] 	6
# 0x4ae4:	lea	ecx, [rax - 5] 	3
# 0x4ae7:	mov	rax, qword ptr [rip + 0xaf22] 	7
# 0x4aee:	mov	edx, 0 	5
# 0x4af3:	mov	esi, ecx 	2
# 0x4af5:	mov	rdi, rax 	3
# 0x4af8:	call	0x8794 	5
# 0x4afd:	mov	rax, qword ptr [rip + 0xaf0c] 	7
# 0x4b04:	mov	edx, 0xa 	5
# 0x4b09:	lea	rcx, [rip + 0xa788] 	7
# 0x4b10:	mov	rsi, rcx 	3
# 0x4b13:	mov	rdi, rax 	3
# 0x4b16:	call	0x8690 	5
# 0x4b1b:	mov	eax, dword ptr [rip + 0xaf9b] 	6
# 0x4b21:	lea	ecx, [rax - 5] 	3
# 0x4b24:	mov	rax, qword ptr [rip + 0xaee5] 	7
# 0x4b2b:	mov	edx, 0xa 	5
# 0x4b30:	mov	esi, ecx 	2
# 0x4b32:	mov	rdi, rax 	3
# 0x4b35:	call	0x8794 	5
# 0x4b3a:	mov	edx, dword ptr [rip + 0xae70] 	6
# 0x4b40:	mov	rax, qword ptr [rip + 0xaec9] 	7
# 0x4b47:	lea	rcx, [rip + 0xae72] 	7
# 0x4b4e:	mov	rsi, rcx 	3
# 0x4b51:	mov	rdi, rax 	3
# 0x4b54:	call	0x8690 	5
# 0x4b59:	jmp	0x4b66 	2
# 0x4b66
# 0x4b5b:	mov	qword ptr [rip + 0xae8a], 0 	11
# 0x4b66:	mov	eax, 0 	5
# 0x4b6b:	call	0x3aeb 	5
# 0x4b70:	mov	eax, 0 	5
# 0x4b75:	call	0x3c7f 	5
# 0x4b7a:	mov	eax, 0 	5
# 0x4b7f:	call	0x3bb5 	5
# 0x4b84:	mov	eax, 0 	5
# 0x4b89:	call	0x44bb 	5
# 0x4b8e:	mov	eax, dword ptr [rip + 0xaf28] 	6
# 0x4b94:	cmp	eax, 8 	3
# 0x4b97:	jle	0x4bc0 	2
# 0x4b99:	mov	eax, dword ptr [rip + 0xae11] 	6
# 0x4b9f:	add	eax, 0xa 	3
# 0x4ba2:	mov	edx, eax 	2
# 0x4ba4:	mov	eax, dword ptr [rip + 0xaf12] 	6
# 0x4baa:	lea	ecx, [rax - 5] 	3
# 0x4bad:	mov	rax, qword ptr [rip + 0xae5c] 	7
# 0x4bb4:	mov	esi, ecx 	2
# 0x4bb6:	mov	rdi, rax 	3
# 0x4bb9:	call	0x8794 	5
# 0x4bbe:	jmp	0x4be3 	2
# 0x4be3
# 0x4bc0:	mov	eax, dword ptr [rip + 0xaefa] 	6
# 0x4bc6:	lea	edx, [rax - 1] 	3
# 0x4bc9:	mov	eax, dword ptr [rip + 0xaeed] 	6
# 0x4bcf:	lea	ecx, [rax - 1] 	3
# 0x4bd2:	mov	rax, qword ptr [rip + 0xae37] 	7
# 0x4bd9:	mov	esi, ecx 	2
# 0x4bdb:	mov	rdi, rax 	3
# 0x4bde:	call	0x8794 	5
# 0x4be3:	mov	eax, 0 	5
# 0x4be8:	call	0x602d 	5
# 0x4bed:	cmp	dword ptr [rbp - 4], 0x12 	4
# 0x4bf1:	jne	0x4c02 	2
# 0x4bf3:	mov	rax, qword ptr [rip + 0xadd6] 	7
# 0x4bfa:	mov	rdi, rax 	3
# 0x4bfd:	call	0x83eb 	5
# 0x4c02:	nop	 	1
# 0x4c03:	leave	 	1
# 0x4c05:	endbr64	 	4
# 0x4c09:	push	rbp 	1
# 0x4c0a:	mov	rbp, rsp 	3
# 0x4c0d:	mov	edi, 0 	5
# 0x4c12:	call	0x5922 	5
# 0x4c17:	mov	eax, 0 	5
# ...
# 0x2370:	call	0x12c0 	5
# 0x2375:	lea	eax, [rbx + 0xa] 	3
# 0x2378:	cmp	ebx, 0xd 	3
# 0x237b:	mov	r13d, 1 	6
# 0x2381:	cmovl	ebx, eax 	3
# 0x2384:	cmp	r12d, r14d 	3
# 0x2387:	jne	0x239a 	2
# 0x2389:	mov	eax, 0x17 	5
# 0x238e:	xor	r13d, r13d 	3
# 0x2391:	sub	eax, ebx 	2
# 0x2393:	cmp	eax, 8 	3
# 0x2396:	seta	r13b 	4
# 0x239a:	mov	edx, dword ptr [rsp + 0x10] 	4
# 0x239e:	mov	esi, dword ptr [rsp + 0x3c] 	4
# 0x23a2:	lea	eax, [r12 + 7] 	5
# 0x23a7:	mov	rdi, qword ptr [rip + 0x2e72] 	7
# 0x23ae:	test	edx, edx 	2
# 0x23b0:	mov	edx, 1 	5
# 0x23b5:	cmove	r12d, eax 	4
# 0x23b9:	call	0x1310 	5
# 0x23be:	cmp	eax, -1 	3
# 0x23c1:	je	0x23e5 	2
# 0x23c3:	mov	rdi, qword ptr [rip + 0x2e56] 	7
# 0x23ca:	mov	edx, 0xfffffffc 	5
# 0x23cf:	test	rdi, rdi 	3
# 0x23d2:	je	0x23db 	2
# 0x23d4:	movsx	edx, word ptr [rdi + 6] 	4
# 0x23d8:	sub	edx, 2 	3
# 0x23db:	mov	esi, 0x2d 	5
# 0x23e0:	call	0x1340 	5
# 0x23e5:	mov	rdi, qword ptr [rip + 0x2e34] 	7
# 0x23ec:	call	0x1280 	5
# 0x23f1:	mov	esi, ebx 	2
# 0x23f3:	mov	edi, r14d 	3
# 0x23f6:	sub	ebx, 7 	3
# 0x23f9:	call	0x19f0 	5
# 0x23fe:	mov	rdi, qword ptr [rip + 0x2e1b] 	7
# 0x2405:	call	0x1280 	5
# 0x240a:	mov	edi, r15d 	3
# 0x240d:	call	0x1370 	5
# 0x2412:	cmp	r15d, 0x3d08f 	7
# 0x2419:	jg	0x1f20 	6
# 0x241f:	lea	eax, [r15 - 0x258] 	7
# 0x2426:	lea	edx, [r15 - 0xc8] 	7
# 0x242d:	cmp	r15d, 0x30d40 	7
# 0x2434:	cmovl	eax, edx 	3
# 0x2437:	mov	r15d, eax 	3
# 0x243a:	cmp	r13d, 1 	4
# 0x243e:	je	0x1f31 	6
# 0x2444:	sub	rsp, 0x30 	4
# 0x2448:	mov	edx, r12d 	3
# 0x244b:	mov	ecx, 5 	5
# 0x2450:	mov	rax, qword ptr [rsp + 0xe0] 	8
# 0x2458:	mov	esi, dword ptr [rsp + 0x68] 	4
# 0x245c:	movdqu	xmm0, xmmword ptr [rsp + 0xc0] 	9
# 0x2465:	mov	edi, dword ptr [rsp + 0x3c] 	4
# 0x2469:	movdqu	xmm1, xmmword ptr [rsp + 0xd0] 	9
# 0x2472:	mov	qword ptr [rsp + 0x20], rax 	5
# 0x2477:	movzx	eax, word ptr [rsp + 0xe8] 	8
# 0x247f:	movups	xmmword ptr [rsp], xmm0 	4
# 0x2483:	movups	xmmword ptr [rsp + 0x10], xmm1 	5
# 0x2488:	mov	word ptr [rsp + 0x28], ax 	5
# 0x248d:	movzx	eax, byte ptr [rsp + 0xea] 	8
# 0x2495:	mov	byte ptr [rsp + 0x2a], al 	4
# 0x2499:	call	0x29b0 	5
# 0x249e:	add	rsp, 0x30 	4
# 0x24a2:	xor	edx, edx 	2
# 0x24a4:	mov	esi, 0x100 	5
# 0x24a9:	mov	rdi, qword ptr [rip + 0x2d70] 	7
# 0x24b0:	call	0x1350 	5
# 0x24b5:	add	rsp, 0x58 	4
# 0x24b9:	pop	rbx 	1
# 0x24ba:	pop	rbp 	1
# 0x24bb:	pop	r12 	2
# 0x24bd:	pop	r13 	2
# 0x24bf:	pop	r14 	2
# 0x24c1:	pop	r15 	2
# 0x24c3:	ret	 	1
# 0x24c8:	mov	esi, ebx 	2
# 0x24ca:	mov	edi, r14d 	3
# 0x24cd:	call	0x1630 	5
# 0x24d2:	jmp	0x2375 	5
# 0x2375
# 0x24e0:	call	0x12c0 	5
# 0x24e5:	mov	edi, dword ptr [rsp + 0x18] 	4
# 0x24e9:	mov	esi, 5 	5
# 0x24ee:	xor	eax, eax 	2
# 0x24f0:	lea	rdx, [rip + 0xb1d] 	7
# 0x24f7:	call	0x12c0 	5
# 0x24fc:	mov	edi, dword ptr [rsp + 0x14] 	4
# 0x2500:	mov	esi, 5 	5
# 0x2505:	xor	eax, eax 	2
# 0x2507:	lea	rdx, [rip + 0xb15] 	7
# 0x250e:	call	0x12c0 	5
# 0x2513:	mov	esi, 5 	5
# 0x2518:	mov	edi, r13d 	3
# 0x251b:	xor	eax, eax 	2
# 0x251d:	lea	rdx, [rip + 0xb0e] 	7
# 0x2524:	call	0x12c0 	5
# 0x2529:	xor	eax, eax 	2
# 0x252b:	mov	esi, 5 	5
# 0x2530:	mov	edi, r12d 	3
# 0x2533:	lea	rdx, [rip + 0xb0c] 	7
# 0x253a:	call	0x12c0 	5
# 0x253f:	mov	eax, dword ptr [rip + 0x2ce7] 	6
# 0x2545:	sub	eax, 1 	3
# 0x2548:	cmp	byte ptr [rsp + 8], 0x20 	5
# 0x254d:	mov	dword ptr [rip + 0x2cd9], eax 	6
# 0x2553:	jne	0x22e9 	6
# 0x2559:	lea	r13, [rip + 0xc55] 	7
# 0x2560:	lea	edi, [r12 + 3] 	5
# 0x2565:	mov	esi, 0xf 	5
# 0x256a:	xor	eax, eax 	2
# 0x256c:	mov	rdx, r13 	3
# 0x256f:	call	0x12c0 	5
# 0x2574:	lea	edi, [r12 + 4] 	5
# 0x2579:	mov	rdx, r13 	3
# 0x257c:	xor	eax, eax 	2
# 0x257e:	mov	esi, 0xd 	5
# 0x2583:	call	0x12c0 	5
# 0x2588:	lea	edi, [r12 + 5] 	5
# 0x258d:	lea	rdx, [rip + 0xc1c] 	7
# 0x2594:	xor	eax, eax 	2
# 0x2596:	mov	esi, 5 	5
# 0x259b:	call	0x12c0 	5
# 0x25a0:	lea	edi, [r12 + 6] 	5
# 0x25a5:	lea	rdx, [rip + 0xc06] 	7
# 0x25ac:	xor	eax, eax 	2
# 0x25ae:	mov	esi, 5 	5
# 0x25b3:	call	0x12c0 	5
# 0x25b8:	lea	edi, [r12 + 7] 	5
# 0x25bd:	lea	rdx, [rip + 0xbef] 	7
# 0x25c4:	xor	eax, eax 	2
# 0x25c6:	mov	esi, 5 	5
# 0x25cb:	call	0x12c0 	5
# 0x25d0:	jmp	0x22e9 	5
# 0x22e9
# 0x25d8:	lea	eax, [r12 - 3] 	5
# 0x25dd:	sub	dword ptr [rsp + 0x10], 1 	5
# 0x25e2:	lea	edi, [r12 - 4] 	5
# 0x25e7:	mov	dword ptr [rsp + 0x18], eax 	4
# 0x25eb:	lea	eax, [r12 - 2] 	5
# 0x25f0:	lea	r13d, [r12 - 1] 	5
# 0x25f5:	mov	dword ptr [rsp + 0x14], eax 	4
# 0x25f9:	jmp	0x2252 	5
# 0x2252
# 0x2600:	xor	eax, eax 	2
# 0x2602:	mov	ecx, 1 	5
# 0x2607:	mov	esi, 6 	5
# 0x260c:	mov	edi, 3 	5
# 0x2611:	lea	rdx, [rip + 0xbb5] 	7
# 0x2618:	call	0x12c0 	5
# 0x261d:	cmp	byte ptr [rsp + 8], 0x6b 	5
# 0x2622:	jne	0x20e2 	6
# 0x2628:	add	dword ptr [rsp + 0x28], 1 	5
# 0x262d:	jmp	0x20f0 	5
# 0x20f0
# 0x2638:	mov	eax, dword ptr [rsp + 0x34] 	4
# 0x263c:	mov	edi, dword ptr [rsp + 0x2c] 	4
# 0x2640:	lea	rdx, [rip + 0xb75] 	7
# 0x2647:	lea	esi, [rax - 2] 	3
# 0x264a:	xor	eax, eax 	2
# 0x264c:	call	0x12c0 	5
# 0x2651:	jmp	0x2022 	5
# 0x2022
# 0x2660:	mov	rdi, qword ptr [rip + 0x2bb9] 	7
# 0x2667:	xor	edx, edx 	2
# 0x2669:	mov	esi, 0x100 	5
# 0x266e:	call	0x12a0 	5
# 0x2673:	mov	esi, ebp 	2
# 0x2675:	mov	edi, 0xa 	5
# 0x267a:	call	0x1710 	5
# 0x267f:	jmp	0x2017 	5
# 0x2017
# 0x2688:	lea	esi, [rbx - 1] 	3
# 0x268b:	mov	edi, r14d 	3
# 0x268e:	call	0x19f0 	5
# 0x2693:	mov	edi, dword ptr [rsp + 0x2c] 	4
# 0x2697:	mov	esi, dword ptr [rsp + 0x34] 	4
# 0x269b:	xor	eax, eax 	2
# 0x269d:	lea	rdx, [rip + 0xb18] 	7
# 0x26a4:	call	0x12c0 	5
# 0x26a9:	mov	rdi, qword ptr [rip + 0x2b70] 	7
# 0x26b0:	test	rdi, rdi 	3
# 0x26b3:	je	0x26d0 	2
# 0x26b5:	movsx	ebx, word ptr [rdi + 6] 	4
# 0x26b9:	mov	byte ptr [rsp + 0x1f], 0 	5
# 0x26be:	mov	dword ptr [rsp + 0x34], 0x14 	8
# 0x26c6:	sub	ebx, 0x13 	3
# 0x26c9:	jmp	0x212c 	5
# 0x212c
# 0x26d0:	mov	byte ptr [rsp + 0x1f], 0 	5
# 0x26d5:	mov	ebx, 0xffffffeb 	5
# 0x26da:	mov	dword ptr [rsp + 0x34], 0x14 	8
# 0x26e2:	jmp	0x212c 	5
# 0x212c
# 0x26f0:	mov	ebp, 0xfffffff6 	5
# 0x26f5:	mov	ebx, 0xffffffeb 	5
# 0x26fa:	mov	dword ptr [rsp + 0x2c], 0xfffffff6 	8
# 0x2702:	mov	r15d, 0xfffffff9 	6
# 0x2708:	mov	dword ptr [rsp + 0x3c], 0xfffffffa 	8
# 0x2710:	jmp	0x1e90 	5
# 0x1e90
# 0x2720:	endbr64	 	4
# 0x2724:	push	r15 	2
# 0x2726:	lea	rsi, [rip + 0xaac] 	7
# 0x272d:	lea	rdi, [rip + 0xaa7] 	7
# 0x2734:	push	r14 	2
# 0x2736:	push	r13 	2
# 0x2738:	push	r12 	2
# 0x273a:	push	rbp 	1
# 0x273b:	push	rbx 	1
# 0x273c:	sub	rsp, 0x78 	4
# 0x2740:	mov	rax, qword ptr fs:[0x28] 	9
# 0x2749:	mov	qword ptr [rsp + 0x68], rax 	5
# 0x274e:	xor	eax, eax 	2
# 0x2750:	call	0x1300 	5
# 0x2755:	lea	rdx, [rsp + 0x2c] 	5
# 0x275a:	lea	rsi, [rip + 0xa73] 	7
# 0x2761:	mov	rdi, rax 	3
# 0x2764:	mov	rbp, rax 	3
# 0x2767:	xor	eax, eax 	2
# 0x2769:	call	0x11f0 	5
# 0x276e:	mov	rdi, rbp 	3
# 0x2771:	call	0x1240 	5
# 0x2776:	mov	rdx, qword ptr [rip + 0x2aa3] 	7
# 0x277d:	test	rdx, rdx 	3
# 0x2780:	je	0x2960 	6
# 0x2786:	movsx	eax, word ptr [rdx + 6] 	4
# 0x278a:	add	eax, 1 	3
# 0x278d:	mov	r12d, eax 	3
# 0x2790:	shr	r12d, 0x1f 	4
# 0x2794:	add	r12d, eax 	3
# 0x2797:	movsx	eax, word ptr [rdx + 4] 	4
# 0x279b:	sar	r12d, 1 	3
# 0x279e:	add	eax, 1 	3
# 0x27a1:	lea	ecx, [r12 - 0x1c] 	5
# 0x27a6:	lea	r10d, [r12 - 0x1a] 	5
# 0x27ab:	mov	ebp, eax 	2
# 0x27ad:	lea	r8d, [r12 - 0x15] 	5
# 0x27b2:	lea	r13d, [r12 - 0xf] 	5
# 0x27b7:	shr	ebp, 0x1f 	3
# 0x27ba:	add	ebp, eax 	2
# 0x27bc:	sar	ebp, 1 	2
# 0x27be:	lea	eax, [rbp + 6] 	3
# 0x27c1:	lea	r11d, [rbp + 1] 	4
# 0x27c5:	mov	dword ptr [rsp + 8], eax 	4
# 0x27c9:	lea	r9d, [rbp + 2] 	4
# 0x27cd:	lea	ebx, [rbp + 3] 	3
# 0x27d0:	lea	r15d, [rbp + 4] 	4
# 0x27d4:	lea	r14d, [rbp + 5] 	4
# 0x27d8:	xor	edx, edx 	2
# 0x27da:	mov	esi, 2 	5
# 0x27df:	mov	edi, 3 	5
# 0x27e4:	mov	dword ptr [rsp + 0x14], ecx 	4
# 0x27e8:	mov	dword ptr [rsp + 0x1c], r8d 	5
# 0x27ed:	mov	dword ptr [rsp + 0x18], r9d 	5
# 0x27f2:	mov	dword ptr [rsp + 0x10], r10d 	5
# 0x27f7:	mov	dword ptr [rsp + 0xc], r11d 	5
# 0x27fc:	call	0x12e0 	5
# 0x2801:	mov	rdi, qword ptr [rip + 0x2a18] 	7
# 0x2808:	xor	edx, edx 	2
# 0x280a:	mov	esi, 0x300 	5
# 0x280f:	call	0x12a0 	5
# 0x2814:	mov	esi, r12d 	3
# 0x2817:	mov	edi, ebp 	2
# 0x2819:	call	0x1950 	5
# 0x281e:	mov	rdi, qword ptr [rip + 0x29fb] 	7
# 0x2825:	xor	edx, edx 	2
# 0x2827:	mov	esi, 0x300 	5
# 0x282c:	call	0x1350 	5
# 0x2831:	mov	esi, dword ptr [rsp + 0x14] 	4
# 0x2835:	mov	edi, dword ptr [rsp + 0xc] 	4
# 0x2839:	xor	eax, eax 	2
# 0x283b:	lea	rdx, [rip + 0xbb6] 	7
# 0x2842:	call	0x12c0 	5
# 0x2847:	mov	esi, dword ptr [rsp + 0x10] 	4
# 0x284b:	mov	edi, dword ptr [rsp + 0x18] 	4
# 0x284f:	xor	eax, eax 	2
# 0x2851:	lea	rdx, [rip + 0xbd0] 	7
# 0x2858:	call	0x12c0 	5
# 0x285d:	mov	esi, dword ptr [rsp + 0x1c] 	4
# 0x2861:	mov	edi, ebx 	2
# 0x2863:	xor	eax, eax 	2
# 0x2865:	lea	rdx, [rip + 0x97f] 	7
# 0x286c:	call	0x12c0 	5
# 0x2871:	mov	esi, r13d 	3
# 0x2874:	mov	edi, r15d 	3
# 0x2877:	xor	eax, eax 	2
# 0x2879:	lea	rdx, [rip + 0x988] 	7
# 0x2880:	call	0x12c0 	5
# 0x2885:	lea	rsi, [rsp + 0x30] 	5
# 0x288a:	mov	edx, 0xffffffff 	5
# 0x288f:	mov	rdi, qword ptr [rip + 0x298a] 	7
# 0x2896:	call	0x12f0 	5
# 0x289b:	mov	esi, r13d 	3
# 0x289e:	mov	edi, r14d 	3
# 0x28a1:	xor	eax, eax 	2
# 0x28a3:	lea	rdx, [rip + 0x965] 	7
# 0x28aa:	call	0x12c0 	5
# 0x28af:	lea	rsi, [rsp + 0x44] 	5
# 0x28b4:	mov	edx, 0xffffffff 	5
# 0x28b9:	mov	rdi, qword ptr [rip + 0x2960] 	7
# 0x28c0:	call	0x12f0 	5
# 0x28c5:	mov	edi, dword ptr [rsp + 8] 	4
# 0x28c9:	mov	esi, r13d 	3
# 0x28cc:	xor	eax, eax 	2
# 0x28ce:	lea	rdx, [rip + 0x946] 	7
# 0x28d5:	call	0x12c0 	5
# 0x28da:	lea	rsi, [rsp + 0x58] 	5
# 0x28df:	mov	edx, 0xffffffff 	5
# 0x28e4:	mov	rdi, qword ptr [rip + 0x2935] 	7
# 0x28eb:	call	0x12f0 	5
# 0x28f0:	call	0x1250 	5
# 0x28f5:	sub	rsp, 0x30 	4
# 0x28f9:	mov	rax, qword ptr [rsp + 0x80] 	8
# 0x2901:	movdqa	xmm0, xmmword ptr [rsp + 0x60] 	6
# 0x2907:	movdqa	xmm1, xmmword ptr [rsp + 0x70] 	6
# 0x290d:	mov	edi, dword ptr [rsp + 0x5c] 	4
# 0x2911:	mov	qword ptr [rsp + 0x20], rax 	5
# 0x2916:	movzx	eax, word ptr [rsp + 0x88] 	8
# 0x291e:	movups	xmmword ptr [rsp], xmm0 	4
# 0x2922:	mov	word ptr [rsp + 0x28], ax 	5
# 0x2927:	movzx	eax, byte ptr [rsp + 0x8a] 	8
# 0x292f:	movups	xmmword ptr [rsp + 0x10], xmm1 	5
# 0x2934:	mov	byte ptr [rsp + 0x2a], al 	4
# 0x2938:	call	0x1e30 	5
# 0x293d:	add	rsp, 0x30 	4
# 0x2941:	mov	rax, qword ptr [rsp + 0x68] 	5
# 0x2946:	sub	rax, qword ptr fs:[0x28] 	9
# 0x294f:	jne	0x29a6 	2
# 0x2951:	add	rsp, 0x78 	4
# 0x2955:	pop	rbx 	1
# 0x2956:	pop	rbp 	1
# 0x2957:	pop	r12 	2
# 0x2959:	pop	r13 	2
# 0x295b:	pop	r14 	2
# 0x295d:	pop	r15 	2
# 0x295f:	ret	 	1
# 0x2960:	mov	r14d, 5 	6
# 0x2966:	mov	ebx, 3 	5
# 0x296b:	xor	r12d, r12d 	3
# 0x296e:	xor	ebp, ebp 	2
# 0x2970:	mov	dword ptr [rsp + 8], 6 	8
# 0x2978:	mov	r15d, 4 	6
# 0x297e:	mov	r13d, 0xfffffff1 	6
# 0x2984:	mov	r8d, 0xffffffeb 	6
# 0x298a:	mov	r9d, 2 	6
# 0x2990:	mov	r10d, 0xffffffe6 	6
# 0x2996:	mov	r11d, 1 	6
# 0x299c:	mov	ecx, 0xffffffe4 	5
# 0x29a1:	jmp	0x27d8 	5
# 0x27d8
# 0x29a6:	call	0x1260 	5
# 0x29ab:	nop	dword ptr [rax + rax] 	5
# 0x29b0:	endbr64	 	4
# 0x29b4:	push	r15 	2
# 0x29b6:	lea	r15d, [rdx - 4] 	4
# 0x29ba:	push	r14 	2
# 0x29bc:	lea	r14, [rip + 0x860] 	7
# 0x29c3:	push	r13 	2
# 0x29c5:	lea	r13, [rip + 0x866] 	7
# 0x29cc:	push	r12 	2
# 0x29ce:	mov	r12d, edx 	3
# 0x29d1:	push	rbp 	1
# 0x29d2:	mov	ebp, esi 	2
# 0x29d4:	push	rbx 	1
# 0x29d5:	mov	ebx, ecx 	2
# 0x29d7:	sub	rsp, 0x28 	4
# 0x29db:	mov	dword ptr [rsp + 0xc], edi 	4
# 0x29df:	jmp	0x29ec 	2
# 0x29ec
# 0x29e8:	mov	ebp, dword ptr [rsp + 0x10] 	4
# 0x29ec:	mov	rdi, qword ptr [rip + 0x282d] 	7
# 0x29f3:	xor	esi, esi 	2
# 0x29f5:	call	0x11e0 	5
# 0x29fa:	xor	edx, edx 	2
# 0x29fc:	mov	esi, 1 	5
# 0x2a01:	mov	edi, 2 	5
# 0x2a06:	call	0x12e0 	5
# 0x2a0b:	mov	dword ptr [rsp + 0x10], ebp 	4
# 0x2a0f:	cmp	dword ptr [rsp + 0xc], ebp 	4
# 0x2a13:	jg	0x2b78 	6
# 0x2a19:	mov	rdi, qword ptr [rip + 0x2800] 	7
# 0x2a20:	test	rdi, rdi 	3
# 0x2a23:	je	0x2bcc 	6
# 0x2a29:	movsx	eax, word ptr [rdi + 6] 	4
# 0x2a2d:	add	eax, 1 	3
# 0x2a30:	mov	r9d, eax 	3
# 0x2a33:	shr	r9d, 0x1f 	4
# 0x2a37:	add	r9d, eax 	3
# 0x2a3a:	movsx	eax, word ptr [rdi + 4] 	4
# 0x2a3e:	sar	r9d, 1 	3
# 0x2a41:	add	eax, 1 	3
# 0x2a44:	mov	r8d, eax 	3
# 0x2a47:	shr	r8d, 0x1f 	4
# 0x2a4b:	add	r8d, eax 	3
# 0x2a4e:	sar	r8d, 1 	3
# 0x2a51:	xor	edx, edx 	2
# 0x2a53:	mov	esi, 0x200 	5
# 0x2a58:	mov	dword ptr [rsp + 0x1c], r9d 	5
# 0x2a5d:	mov	dword ptr [rsp + 0x18], r8d 	5
# 0x2a62:	call	0x12a0 	5
# 0x2a67:	mov	esi, dword ptr [rsp + 0x1c] 	4
# 0x2a6b:	mov	edi, dword ptr [rsp + 0x18] 	4
# 0x2a6f:	call	0x1880 	5
# 0x2a74:	mov	rdx, r14 	3
# 0x2a77:	mov	esi, ebx 	2
# 0x2a79:	mov	edi, r15d 	3
# 0x2a7c:	xor	eax, eax 	2
# 0x2a7e:	call	0x12c0 	5
# 0x2a83:	mov	edi, r12d 	3
# 0x2a86:	xor	eax, eax 	2
# 0x2a88:	mov	rdx, r13 	3
# 0x2a8b:	mov	esi, ebx 	2
# 0x2a8d:	call	0x12c0 	5
# 0x2a92:	mov	rdi, qword ptr [rip + 0x2787] 	7
# 0x2a99:	call	0x1220 	5
# 0x2a9e:	cmp	al, 0x72 	2
# 0x2aa0:	je	0x2be0 	6
# 0x2aa6:	cmp	al, 0x71 	2
# 0x2aa8:	je	0x2c45 	6
# 0x2ac0:	movsx	eax, word ptr [rdi + 6] 	4
# 0x2ac4:	add	eax, 1 	3
# 0x2ac7:	mov	r8d, eax 	3
# 0x2aca:	shr	r8d, 0x1f 	4
# 0x2ace:	add	r8d, eax 	3
# 0x2ad1:	movsx	eax, word ptr [rdi + 4] 	4
# 0x2ad5:	sar	r8d, 1 	3
# 0x2ad8:	add	eax, 1 	3
# 0x2adb:	mov	ebp, eax 	2
# 0x2add:	shr	ebp, 0x1f 	3
# 0x2ae0:	add	ebp, eax 	2
# 0x2ae2:	sar	ebp, 1 	2
# 0x2ae4:	xor	edx, edx 	2
# 0x2ae6:	mov	esi, 0x200 	5
# 0x2aeb:	mov	dword ptr [rsp + 0xc], r8d 	5
# 0x2af0:	call	0x12a0 	5
# 0x2af5:	mov	esi, dword ptr [rsp + 0xc] 	4
# 0x2af9:	mov	edi, ebp 	2
# 0x2afb:	call	0x1880 	5
# 0x2b00:	mov	rdx, r14 	3
# 0x2b03:	mov	esi, ebx 	2
# 0x2b05:	mov	edi, r15d 	3
# 0x2b08:	xor	eax, eax 	2
# 0x2b0a:	call	0x12c0 	5
# 0x2b0f:	mov	edi, r12d 	3
# 0x2b12:	xor	eax, eax 	2
# 0x2b14:	mov	rdx, r13 	3
# 0x2b17:	mov	esi, ebx 	2
# 0x2b19:	call	0x12c0 	5
# 0x2b1e:	mov	rdi, qword ptr [rip + 0x26fb] 	7
# 0x2b25:	call	0x1220 	5
# 0x2b2a:	cmp	al, 0x72 	2
# 0x2b2c:	je	0x2be0 	6
# 0x2b32:	cmp	al, 0x71 	2
# 0x2b34:	je	0x2c45 	6
# 0x2b3a:	mov	rdi, qword ptr [rip + 0x26df] 	7
# 0x2b41:	xor	esi, esi 	2
# 0x2b43:	call	0x11e0 	5
# 0x2b48:	mov	edi, 2 	5
# 0x2b4d:	xor	edx, edx 	2
# 0x2b4f:	mov	esi, 1 	5
# 0x2b54:	call	0x12e0 	5
# 0x2b59:	mov	rdi, qword ptr [rip + 0x26c0] 	7
# 0x2b60:	test	rdi, rdi 	3
# 0x2b63:	jne	0x2ac0 	6
# 0x2b6c:	xor	ebp, ebp 	2
# 0x2b6e:	jmp	0x2ae4 	5
# 0x2ae4
# 0x2b78:	lea	rsi, [rip + 0x6a2] 	7
# 0x2b7f:	lea	rdi, [rip + 0x655] 	7
# 0x2b86:	call	0x1300 	5
# 0x2b8b:	mov	ecx, dword ptr [rsp + 0xc] 	4
# 0x2b8f:	mov	esi, 1 	5
# 0x2b94:	lea	rdx, [rip + 0x639] 	7
# 0x2b9b:	mov	rdi, rax 	3
# 0x2b9e:	mov	qword ptr [rsp + 0x10], rax 	5
# 0x2ba3:	xor	eax, eax 	2
# 0x2ba5:	call	0x1320 	5
# 0x2baa:	mov	rdi, qword ptr [rsp + 0x10] 	5
# 0x2baf:	call	0x1240 	5
# 0x2bb4:	mov	eax, dword ptr [rsp + 0xc] 	4
# 0x2bb8:	mov	rdi, qword ptr [rip + 0x2661] 	7
# 0x2bbf:	mov	dword ptr [rsp + 0x10], eax 	4
# 0x2bc3:	test	rdi, rdi 	3
# 0x2bc6:	jne	0x2a29 	6
# 0x2bcc:	xor	r9d, r9d 	3
# 0x2bcf:	xor	r8d, r8d 	3
# 0x2bd2:	jmp	0x2a51 	5
# 0x2a51
# 0x2be0:	mov	rdi, qword ptr [rip + 0x2639] 	7
# 0x2be7:	xor	edx, edx 	2
# 0x2be9:	mov	esi, 0x200 	5
# 0x2bee:	call	0x1350 	5
# 0x2bf3:	sub	rsp, 0x30 	4
# 0x2bf7:	mov	rax, qword ptr [rsp + 0xb0] 	8
# 0x2bff:	mov	edi, dword ptr [rsp + 0x40] 	4
# 0x2c03:	movdqu	xmm0, xmmword ptr [rsp + 0x90] 	9
# 0x2c0c:	movdqu	xmm1, xmmword ptr [rsp + 0xa0] 	9
# 0x2c15:	mov	qword ptr [rsp + 0x20], rax 	5
# 0x2c1a:	movzx	eax, word ptr [rsp + 0xb8] 	8
# 0x2c22:	movups	xmmword ptr [rsp], xmm0 	4
# 0x2c26:	mov	word ptr [rsp + 0x28], ax 	5
# 0x2c2b:	movzx	eax, byte ptr [rsp + 0xba] 	8
# 0x2c33:	movups	xmmword ptr [rsp + 0x10], xmm1 	5
# 0x2c38:	mov	byte ptr [rsp + 0x2a], al 	4
# 0x2c3c:	call	0x1e30 	5
# 0x2c41:	add	rsp, 0x30 	4
# 0x2c45:	add	rsp, 0x28 	4
# 0x2c49:	pop	rbx 	1
# 0x2c4a:	pop	rbp 	1
# 0x2c4b:	pop	r12 	2
# 0x2c4d:	pop	r13 	2
# 0x2c4f:	pop	r14 	2
# 0x2c51:	pop	r15 	2
# 0x2c53:	ret	 	1
# 0x2c54:	endbr64	 	4
# 0x2c58:	sub	rsp, 8 	4
# 0x2c5c:	add	rsp, 8 	4
# 0x2c60:	ret	 	1
# 0x1380:	endbr64	 	4
# 0x1384:	sub	rsp, 8 	4
# 0x1388:	call	0x1270 	5
# 0x138d:	call	0x1290 	5
# 0x1392:	xor	edi, edi 	2
# 0x1394:	call	0x1200 	5
# 0x1399:	xor	eax, eax 	2
# 0x139b:	call	0x2720 	5
# 0x13a0:	call	0x1330 	5
# 0x13a5:	xor	eax, eax 	2
# 0x13a7:	add	rsp, 8 	4
# 0x13ab:	ret	 	1
# 0x13ac:	nop	dword ptr [rax] 	4
# 0x13b0:	endbr64	 	4
# 0x13b4:	xor	ebp, ebp 	2
# 0x13b6:	mov	r9, rdx 	3
# 0x13b9:	pop	rsi 	1
# 0x13ba:	mov	rdx, rsp 	3
# 0x13bd:	and	rsp, 0xfffffffffffffff0 	4
# 0x13c1:	push	rax 	1
# 0x13c2:	push	rsp 	1
# 0x13c3:	xor	r8d, r8d 	3
# 0x13c6:	xor	ecx, ecx 	2
# 0x13c8:	lea	rdi, [rip - 0x4f] 	7
# 0x13cf:	call	qword ptr [rip + 0x3c03] 	6
# 0x2091:	mov	r10d, dword ptr [rsp + 0x28] 	5
# 0x2096:	test	r10d, r10d 	3
# 0x2099:	je	0x2600 	6
# 0x20a8:	cmp	dword ptr [rsp + 0x28], 1 	5
# 0x20ad:	jle	0x2600 	6
# 0x2247:	mov	dword ptr [rsp + 0x10], 2 	8
# 0x224f:	mov	r12d, ecx 	3
# 0x2252:	mov	r8d, dword ptr [rip + 0x2fd3] 	7
# 0x2259:	lea	rdx, [rip + 0xda4] 	7
# 0x2260:	mov	esi, 5 	5
# 0x2265:	xor	eax, eax 	2
# 0x2267:	test	r8d, r8d 	3
# 0x226a:	jne	0x24e0 	6
# 0x2aae:	cmp	dword ptr [rsp + 0xc], ebp 	4
# 0x2ab2:	jg	0x29e8 	6
# 0x2b69:	xor	r8d, r8d 	3
# 0x2b6c:	xor	ebp, ebp 	2
# 0x2b6e:	jmp	0x2ae4 	5
# 0x2ae4
# 0x2ab8:	jmp	0x2b3a 	5
# 0x2b3a
